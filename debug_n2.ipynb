# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-15 22:36:27,148 - INFO - jlpt - ---Generator----
# 2025-11-15 22:36:34,088 - INFO - jlpt - ---REVISOR---
# 2025-11-15 22:36:34,697 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-15 22:36:34,699 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-15 22:36:34,700 - INFO - jlpt - --- Formatter ---
# 2025-11-15 22:36:34,702 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N2 level.
#
# Task: Task: Your job is to write a reading question for a JLPT N2 level exam.
# First you need to write a long article around 450 words for student to read.
# Then, you give 2 questions by the related content in the article.
# The purpose is to ensure the students are able to understand the meaning of the article.
#
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N2 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
#
# Formal exam paper:
# <div class="reading-text">
#   <h3>A</h3>
#   <p>
#     新しい商品を企画するとき、いいアイデアがなかなか思いつかないことがある。そんなとき、自分には才能がないからだと思い込み、
#     自信をなくしてしまうのはよくない。アイデアは生まれつきの能力に関係なく、努力次第で誰でも生み出すことができる。
#     アイデアは、情報の組み合わせによって生まれることがほとんどだ。そのため、日ごろから情報を集めておくことが有効だ。
#     担当する商品に関連する情報だけを集めていると、似たようなアイデアばかりになってしまう。発想の幅を広げるには、
#     関連する分野以外の情報も頭に入れておくほうがいい。ふだんから視野を広げてさまざまな情報を蓄積しておけば、
#     必ずアイデアの役に立つはずだ。
#   </p>
#
#   <h3>B</h3>
#   <p>
#     新しい商品を企画するには、これまでとは異なるアイデアが必要だ。現在流行している商品の情報を集めるだけでは、
#     他社に勝つことはできないだろう。私はアイデアを生み出すために、一般的に考えられていることとは逆の発想をするようにしている。
#     現在流行している商品が若者向けの物なら高齢者向けにできないかと考えたり、多機能の物なら機能を一つに絞れないかと考えたりするのである。
#   </p>
#   <p>
#     アイデアは一部の才能がある人しか生み出せないものだという印象があるせいか、生み出し方を知ろうとしない人が多いと思う。
#     才能がないからといってあきらめるのではなく、思い切って発想を転換してみれば、いいアイデアにつながっていく。
#   </p>
# </div>
#
# <body>
#     <h1>65. アイデアを生み出すことについて、AとBが共通して述べていることは何か。</h1>
#     <ol>
#         <li>アイデアを生み出し方は、簡単に身につけることができる。</li>
#         <li>多くの情報を得ることで、アイデアを生み出しやすくなる。</li>
#         <li>特別な能力がなくても、アイデアを生み出すことができる。</li>
#         <li>発想のしかたを大きく変えなければ、アイデアは生み出せない。</li>
#     </ol>
#
#     <h1>66. 新しい商品を企画することについて、AとBはどのようなアドバイスをしているか。</h1>
#     <ol>
#         <li>AもBも、いろいろな分野の情報をできるだけ多く集めるといいと述べている。</li>
#         <li>AもBも、流行している商品について詳しく調べるといいと述べている。</li>
#         <li>Aは関連する分野の他社の商品の情報を集めるといいと述べ、Bは流行に逆らった考え方をするといいと述べている。</li>
#         <li>AもBも、流行している商品について詳しく調べるといいと述べている。</li>
#     </ol>
#
#     <h1>67. 新しい商品を企画する際の注意点について、AとBが共通して述べていることは何か。</h1>
#     <ol>
#         <li>十分な時間と資金を確保すること。</li>
#         <li>多くの消費者の意見を取り入れること。</li>
#         <li>市場の需要を調べる前に、デザインや機能にこだわること。</li>
#         <li>競合他社の動きを分析し、それに合わせること。</li>
#     </ol>
# </body>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 環境問題について話す
# AI: <div class="reading-text">
#   <h3>A</h3>
#   <p>
#     近年、地球の温暖化が進んでいることが世界中で大きな問題となっている。気温が上昇することで、海面が高くなり、島や海岸が消えてしまう危険性がある。また、異常気象が増え、洪水や干ばつなどの自然災害が頻繁に発生するようになった。これらの現象は人間の生活だけでなく、動物や植物にも大きな影響を与えている。温暖化の主な原因は、工場や自動車から出るガスや、森林の減少だと言われている。そのため、私たちはエネルギーの使い方を見直したり、木を植えたりすることが必要だ。環境を守るためには、一人ひとりができることを考えて行動することが大切だと思う。
#   </p>
#   <h3>B</h3>
#   <p>
#     環境問題は、私たちの未来に深く関わっている。最近では、プラスチックごみが海に流れ込み、魚や鳥がそれを食べてしまうことが問題になっている。プラスチックは自然に分解されにくいため、長い間海に残ってしまう。私たちが日常生活で使うものを減らしたり、リサイクルを心がけたりすることで、ごみの量を減らすことができる。さらに、公共交通機関を利用することで、空気を汚す原因を減らすこともできる。環境を守るためには、社会全体で協力し、意識を高めることが重要だと考える。
#   </p>
# </div>
# <body>
#     <h1>地球の温暖化について、Aが述べていることは何か。</h1>
#     <ol>
#         <li>気温が下がることで、動物の数が減る。</li>
#         <li>気温が上がることで、自然災害が増える。</li>
#         <li>気温が上がることで、森林が増える。</li>
#         <li>気温が下がることで、海面が高くなる。</li>
#     </ol>
#     正解: 2
#
#     <h1>環境を守るために、Bが提案していることは何か。</h1>
#     <ol>
#         <li>自動車をたくさん使うこと。</li>
#         <li>ごみを増やすこと。</li>
#         <li>公共交通機関を利用すること。</li>
#         <li>プラスチックを多く使うこと。</li>
#     </ol>
#     正解: 3
# </body>
# HUMAN: GOOD ENOUGH
# 2025-11-15 22:36:39,940 - INFO - jlpt - Formatter: {'html_article': '<h3>A</h3><p>近年、地球の温暖化が進んでいることが世界中で大きな問題となっている。気温が上昇することで、海面が高くなり、島や海岸が消えてしまう危険性がある。また、異常気象が増え、洪水や干ばつなどの自然災害が頻繁に発生するようになった。これらの現象は人間の生活だけでなく、動物や植物にも大きな影響を与えている。温暖化の主な原因は、工場や自動車から出るガスや、森林の減少だと言われている。そのため、私たちはエネルギーの使い方を見直したり、木を植えたりすることが必要だ。環境を守るためには、一人ひとりができることを考えて行動することが大切だと思う。</p><h3>B</h3><p>環境問題は、私たちの未来に深く関わっている。最近では、プラスチックごみが海に流れ込み、魚や鳥がそれを食べてしまうことが問題になっている。プラスチックは自然に分解されにくいため、長い間海に残ってしまう。私たちが日常生活で使うものを減らしたり、リサイクルを心がけたりすることで、ごみの量を減らすことができる。さらに、公共交通機関を利用することで、空気を汚す原因を減らすこともできる。環境を守るためには、社会全体で協力し、意識を高めることが重要だと考える。</p>', 'questions': [{'html_question': '地球の温暖化について、Aが述べていることは何か。', 'correct_answer': 2, 'choices': ['気温が下がることで、動物の数が減る。', '気温が上がることで、自然災害が増える。', '気温が上がることで、森林が増える。', '気温が下がることで、海面が高くなる。']}, {'html_question': '環境を守るために、Bが提案していることは何か。', 'correct_answer': 3, 'choices': ['自動車をたくさん使うこと。', 'ごみを増やすこと。', '公共交通機関を利用すること。', 'プラスチックを多く使うこと。']}]}
# <strong>1番.</strong></br></br><h3>A</h3><p>近年、地球の温暖化が進んでいることが世界中で大きな問題となっている。気温が上昇することで、海面が高くなり、島や海岸が消えてしまう危険性がある。また、異常気象が増え、洪水や干ばつなどの自然災害が頻繁に発生するようになった。これらの現象は人間の生活だけでなく、動物や植物にも大きな影響を与えている。温暖化の主な原因は、工場や自動車から出るガスや、森林の減少だと言われている。そのため、私たちはエネルギーの使い方を見直したり、木を植えたりすることが必要だ。環境を守るためには、一人ひとりができることを考えて行動することが大切だと思う。</p><h3>B</h3><p>環境問題は、私たちの未来に深く関わっている。最近では、プラスチックごみが海に流れ込み、魚や鳥がそれを食べてしまうことが問題になっている。プラスチックは自然に分解されにくいため、長い間海に残ってしまう。私たちが日常生活で使うものを減らしたり、リサイクルを心がけたりすることで、ごみの量を減らすことができる。さらに、公共交通機関を利用することで、空気を汚す原因を減らすこともできる。環境を守るためには、社会全体で協力し、意識を高めることが重要だと考える。</p>
# <p><strong>1.地球の温暖化について、Aが述べていることは何か。</strong></p>
# <ul>
# <li>気温が下がることで、動物の数が減る。</li>
# <li><b>気温が上がることで、自然災害が増える。</b> <span style='color:green;'>(correct)</span></li>
# <li>気温が上がることで、森林が増える。</li>
# <li>気温が下がることで、海面が高くなる。</li>
# </ul>
# <p><strong>2.環境を守るために、Bが提案していることは何か。</strong></p>
# <ul>
# <li>自動車をたくさん使うこと。</li>
# <li>ごみを増やすこと。</li>
# <li><b>公共交通機関を利用すること。</b> <span style='color:green;'>(correct)</span></li>
# <li>プラスチックを多く使うこと。</li>
# </ul>

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-15 22:36:39,998 - INFO - jlpt - ---Generator----
# 2025-11-15 22:36:45,179 - INFO - jlpt - ---REVISOR---
# 2025-11-15 22:36:45,822 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-15 22:36:45,824 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-15 22:36:45,825 - INFO - jlpt - --- Formatter ---
# 2025-11-15 22:36:45,827 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问1个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# - 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# - 女1: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# - 男1: 市の方針でゴミ箱は置かないことになってるからね。
# - 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# - 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# - 女1: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# - 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# - 女1: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# - 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: ガーデニングについて話す
# AI: <p class='background'>大学のサークルでガーデニング活動をしている3人が、次のイベントについて話しています。</p>
#
# <div class='conversation'>
# - 女1: 来月のガーデニングイベント、今年はどんなテーマにするか決めましたか？
# - 男1: 去年は「春の花を楽しむ」だったよね。今年は少し違うことをやってみたいなと思ってるんだ。
# - 男2: 僕は野菜を育てる体験が面白いと思うんだけど、どうかな？最近、家庭菜園に興味を持つ人が増えているし。
# - 女1: いいですね。花だけじゃなくて、野菜も育てると、みんなで収穫して食べる楽しみもありますし。
# - 男1: でも、野菜は花よりも手入れが大変じゃない？水やりや虫の対策も必要だし、初心者には難しいかもしれない。
# - 男2: それなら、簡単に育てられる野菜を選んだらどうですか？例えば、ミニトマトやラディッシュなら、初めてでも育てやすいですよ。
# - 女1: それなら安心ですね。子どもたちも参加できるし、みんなで協力して育てるのは楽しいと思います。
# - 男1: よし、じゃあ今年のテーマは「みんなで育てる野菜」にしようか。イベントの案内も早めに作らないとね。
# - 男2: 僕、案内のデザインを担当します。みんなでアイデアを出し合いましょう。
# - 女1: ありがとうございます。準備が楽しみですね！
# </div>
#
# <a class='follow_up'>今年のガーデニングイベントのテーマは何になりましたか？</a>
# <ul class='options'>
#     <li>春の花を楽しむこと</li>
#     <li>みんなで野菜を育てること</li>
#     <li>虫の対策について学ぶこと</li>
#     <li>案内のデザインを考えること</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-11-15 22:36:48,863 - INFO - jlpt - Formatter: {'background': '大学のサークルでガーデニング活動をしている3人が、次のイベントについて話しています。', 'conversation': [{'gender': 'female1', 'context': '来月のガーデニングイベント、今年はどんなテーマにするか決めましたか？'}, {'gender': 'male1', 'context': '去年は「春の花を楽しむ」だったよね。今年は少し違うことをやってみたいなと思ってるんだ。'}, {'gender': 'male2', 'context': '僕は野菜を育てる体験が面白いと思うんだけど、どうかな？最近、家庭菜園に興味を持つ人が増えているし。'}, {'gender': 'female1', 'context': 'いいですね。花だけじゃなくて、野菜も育てると、みんなで収穫して食べる楽しみもありますし。'}, {'gender': 'male1', 'context': 'でも、野菜は花よりも手入れが大変じゃない？水やりや虫の対策も必要だし、初心者には難しいかもしれない。'}, {'gender': 'male2', 'context': 'それなら、簡単に育てられる野菜を選んだらどうですか？例えば、ミニトマトやラディッシュなら、初めてでも育てやすいですよ。'}, {'gender': 'female1', 'context': 'それなら安心ですね。子どもたちも参加できるし、みんなで協力して育てるのは楽しいと思います。'}, {'gender': 'male1', 'context': 'よし、じゃあ今年のテーマは「みんなで育てる野菜」にしようか。イベントの案内も早めに作らないとね。'}, {'gender': 'male2', 'context': '僕、案内のデザインを担当します。みんなでアイデアを出し合いましょう。'}, {'gender': 'female1', 'context': 'ありがとうございます。準備が楽しみですね！'}], 'follow_up': '今年のガーデニングイベントのテーマは何になりましたか？', 'choices': ['春の花を楽しむこと', 'みんなで野菜を育てること', '虫の対策について学ぶこと', '案内のデザインを考えること'], 'correct_answer': 2}
# 2025-11-15 22:37:42,115 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-15 22:37:42,125 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1.wav
# 2025-11-15 22:37:42,127 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-15 22:37:42,136 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_background.wav
# 2025-11-15 22:37:42,143 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-15 22:37:42,146 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_0_speaker.wav
# 2025-11-15 22:37:42,151 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_1_speaker.wav
# 2025-11-15 22:37:42,158 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_2_speaker.wav
# 2025-11-15 22:37:42,166 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_3_speaker.wav
# 2025-11-15 22:37:42,176 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_4_speaker.wav
# 2025-11-15 22:37:42,186 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_5_speaker.wav
# 2025-11-15 22:37:42,199 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_6_speaker.wav
# 2025-11-15 22:37:42,212 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_7_speaker.wav
# 2025-11-15 22:37:42,226 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_8_speaker.wav
# 2025-11-15 22:37:42,238 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_9_speaker.wav
# 2025-11-15 22:37:42,249 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-15 22:37:42,261 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_follow_up.wav
# 2025-11-15 22:37:42,274 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_1_seq.wav
# 2025-11-15 22:37:42,284 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_1_option.wav
# 2025-11-15 22:37:42,296 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_2_seq.wav
# 2025-11-15 22:37:42,317 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_2_option.wav
# 2025-11-15 22:37:42,342 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_3_seq.wav
# 2025-11-15 22:37:42,364 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_3_option.wav
# 2025-11-15 22:37:42,390 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_4_seq.wav
# 2025-11-15 22:37:42,414 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_4_option.wav
# 2025-11-15 22:37:43,183 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_conversation_output.mp3
# 2025-11-15 22:37:47,620 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_listen_answer_1_conversation_output.mp3 as blob 77a353ec-c230-11f0-8e6e-d4d8537023c7/comprehensive_expression_listen_answer_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学のサークルでガーデニング活動をしている3人が、次のイベントについて話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 来月のガーデニングイベント、今年はどんなテーマにするか決めましたか？</p>
# <p><strong>Male1:</strong> 去年は「春の花を楽しむ」だったよね。今年は少し違うことをやってみたいなと思ってるんだ。</p>
# <p><strong>Male2:</strong> 僕は野菜を育てる体験が面白いと思うんだけど、どうかな？最近、家庭菜園に興味を持つ人が増えているし。</p>
# <p><strong>Female1:</strong> いいですね。花だけじゃなくて、野菜も育てると、みんなで収穫して食べる楽しみもありますし。</p>
# <p><strong>Male1:</strong> でも、野菜は花よりも手入れが大変じゃない？水やりや虫の対策も必要だし、初心者には難しいかもしれない。</p>
# <p><strong>Male2:</strong> それなら、簡単に育てられる野菜を選んだらどうですか？例えば、ミニトマトやラディッシュなら、初めてでも育てやすいですよ。</p>
# <p><strong>Female1:</strong> それなら安心ですね。子どもたちも参加できるし、みんなで協力して育てるのは楽しいと思います。</p>
# <p><strong>Male1:</strong> よし、じゃあ今年のテーマは「みんなで育てる野菜」にしようか。イベントの案内も早めに作らないとね。</p>
# <p><strong>Male2:</strong> 僕、案内のデザインを担当します。みんなでアイデアを出し合いましょう。</p>
# <p><strong>Female1:</strong> ありがとうございます。準備が楽しみですね！</p>
# </div>
# <p><strong>follow-up question: </strong>今年のガーデニングイベントのテーマは何になりましたか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/77a353ec-c230-11f0-8e6e-d4d8537023c7/comprehensive_expression_listen_answer_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 春の花を楽しむこと</li>
# <li>2. <b>みんなで野菜を育てること</b> <span style='color:green;'>(correct)</span></li>
# <li>3. 虫の対策について学ぶこと</li>
# <li>4. 案内のデザインを考えること</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-15 22:37:47,634 - INFO - jlpt - ---Generator----
# 2025-11-15 22:37:56,406 - INFO - jlpt - ---REVISOR---
# 2025-11-15 22:37:57,110 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-15 22:37:57,112 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-15 22:37:57,115 - INFO - jlpt - --- Formatter ---
# 2025-11-15 22:37:57,116 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问2个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。</p>
#
# <div class='conversation'>
# - 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方なども教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方も楽しめいただけます。西会場では、新鮮な魚介類を販売しています。
# - 女2: 新鮮な魚、おいしそう。なくなり前に早く行かなきゃ？
# - 男1: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# - 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# - 男1: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、買い物は最後にしようよ。
# - 女2: いいよ。釣りはいいの？
# - 男1: うーん、初心者向けって言ってたから今日は初めてていいかな。
# </div>
# <a class='follow_up'>質問1: 2人は最初にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
# <a class='follow_up'>質問2: 2人は2番目にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
#
#
#
# HUMAN: Generate a JLPT question regarding Topic: おすすめを尋ねる
# AI: <p class='background'>大学の食堂で昼食を選ぼうとしている三人の学生が話しています。</p>
#
# <div class='conversation'>
# - 女1: 今日、何食べようかな。最近、同じものばかり食べてる気がする。
# - 男1: そうだね。メニューもたくさんあるし、迷っちゃうよね。あ、そういえば、昨日カレーを食べたんだけど、意外と美味しかったよ。
# - 女2: カレーかぁ。私はまだ食べたことないな。辛いのは苦手だけど、どうだった？
# - 男1: そんなに辛くなかったよ。野菜もたくさん入ってて、ヘルシーな感じだった。
# - 女1: いいね。私はパスタにしようかなと思ってたけど、カレーも気になるな。女2は何にする？
# - 女2: うーん、迷うな。男1のおすすめなら、カレーにしてみようかな。女1はどうする？
# - 女1: じゃあ、今日はみんなでカレーにしようか。たまには違うものもいいよね。
# - 男1: そうしよう！みんなで同じもの食べるのも楽しいしね。
# - 女2: うん、楽しみ！次は女1のおすすめも食べてみたいな。
# </div>
#
# <a class='follow_up'>質問1: 男1がすすめた料理は何ですか？</a>
# <ul class='options'>
#     <li>ラーメン</li>
#     <li>カレー</li>
#     <li>パスタ</li>
#     <li>サンドイッチ</li>
# </ul>
# 正解:2
#
# <a class='follow_up'>質問2: 女2は何を食べることに決めましたか？</a>
# <ul class='options'>
#     <li>ラーメン</li>
#     <li>カレー</li>
#     <li>パスタ</li>
#     <li>サンドイッチ</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-11-15 22:37:59,742 - INFO - jlpt - Formatter: {'background': '大学の食堂で昼食を選ぼうとしている三人の学生が話しています。', 'conversation': [{'gender': 'female1', 'context': '今日、何食べようかな。最近、同じものばかり食べてる気がする。'}, {'gender': 'male1', 'context': 'そうだね。メニューもたくさんあるし、迷っちゃうよね。あ、そういえば、昨日カレーを食べたんだけど、意外と美味しかったよ。'}, {'gender': 'female2', 'context': 'カレーかぁ。私はまだ食べたことないな。辛いのは苦手だけど、どうだった？'}, {'gender': 'male1', 'context': 'そんなに辛くなかったよ。野菜もたくさん入ってて、ヘルシーな感じだった。'}, {'gender': 'female1', 'context': 'いいね。私はパスタにしようかなと思ってたけど、カレーも気になるな。女2は何にする？'}, {'gender': 'female2', 'context': 'うーん、迷うな。男1のおすすめなら、カレーにしてみようかな。女1はどうする？'}, {'gender': 'female1', 'context': 'じゃあ、今日はみんなでカレーにしようか。たまには違うものもいいよね。'}, {'gender': 'male1', 'context': 'そうしよう！みんなで同じもの食べるのも楽しいしね。'}, {'gender': 'female2', 'context': 'うん、楽しみ！次は女1のおすすめも食べてみたいな。'}], 'listen_questions': [{'follow_up': '質問1: 男1がすすめた料理は何ですか？', 'correct_answer': 2, 'choices': ['ラーメン', 'カレー', 'パスタ', 'サンドイッチ']}, {'follow_up': '質問2: 女2は何を食べることに決めましたか？', 'correct_answer': 2, 'choices': ['ラーメン', 'カレー', 'パスタ', 'サンドイッチ']}]}
# 2025-11-15 22:38:32,644 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-15 22:38:32,647 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3.wav
# 2025-11-15 22:38:32,656 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-15 22:38:32,657 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_background.wav
# 2025-11-15 22:38:32,678 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-15 22:38:32,681 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-11-15 22:38:32,693 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-11-15 22:38:32,709 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-11-15 22:38:32,723 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-11-15 22:38:32,739 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-11-15 22:38:32,757 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-11-15 22:38:32,773 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-11-15 22:38:32,789 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-11-15 22:38:32,805 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_8_speaker.wav
# 2025-11-15 22:38:32,821 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-15 22:38:32,826 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_1_follow_up.wav
# 2025-11-15 22:38:32,839 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-15 22:38:32,846 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-15 22:38:32,853 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_2_follow_up.wav
# 2025-11-15 22:38:32,868 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-15 22:38:33,500 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-11-15 22:38:35,222 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\77a353ec-c230-11f0-8e6e-d4d8537023c7\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob 77a353ec-c230-11f0-8e6e-d4d8537023c7/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の食堂で昼食を選ぼうとしている三人の学生が話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 今日、何食べようかな。最近、同じものばかり食べてる気がする。</p>
# <p><strong>Male1:</strong> そうだね。メニューもたくさんあるし、迷っちゃうよね。あ、そういえば、昨日カレーを食べたんだけど、意外と美味しかったよ。</p>
# <p><strong>Female2:</strong> カレーかぁ。私はまだ食べたことないな。辛いのは苦手だけど、どうだった？</p>
# <p><strong>Male1:</strong> そんなに辛くなかったよ。野菜もたくさん入ってて、ヘルシーな感じだった。</p>
# <p><strong>Female1:</strong> いいね。私はパスタにしようかなと思ってたけど、カレーも気になるな。女2は何にする？</p>
# <p><strong>Female2:</strong> うーん、迷うな。男1のおすすめなら、カレーにしてみようかな。女1はどうする？</p>
# <p><strong>Female1:</strong> じゃあ、今日はみんなでカレーにしようか。たまには違うものもいいよね。</p>
# <p><strong>Male1:</strong> そうしよう！みんなで同じもの食べるのも楽しいしね。</p>
# <p><strong>Female2:</strong> うん、楽しみ！次は女1のおすすめも食べてみたいな。</p>
# </div>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/77a353ec-c230-11f0-8e6e-d4d8537023c7/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <p><strong>1.質問1: 男1がすすめた料理は何ですか？</strong></p>
# <ul>
# <li>ラーメン</li>
# <li><b>カレー</b> <span style='color:green;'>(correct)</span></li>
# <li>パスタ</li>
# <li>サンドイッチ</li>
# </ul>
# <p><strong>2.質問2: 女2は何を食べることに決めましたか？</strong></p>
# <ul>
# <li>ラーメン</li>
# <li><b>カレー</b> <span style='color:green;'>(correct)</span></li>
# <li>パスタ</li>
# <li>サンドイッチ</li>
# </ul>
