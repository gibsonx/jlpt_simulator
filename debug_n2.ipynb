# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-21 09:54:50,945 - INFO - jlpt - ---Generator----
# 2025-11-21 09:55:01,609 - INFO - jlpt - ---REVISOR---
# 2025-11-21 09:55:02,328 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-21 09:55:02,329 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-21 09:55:02,330 - INFO - jlpt - --- Formatter ---
# 2025-11-21 09:55:02,331 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N2 level.
#
# Task: Task: Your job is to write a reading question for a JLPT N2 level exam.
# First you need to write a long article around 450 words for student to read.
# Then, you give 2 questions by the related content in the article.
# The purpose is to ensure the students are able to understand the meaning of the article.
#
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N2 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n . The options are 1,2,3,4. ensuring a balanced distribution of correct answers across options.
#
#
#
# Formal exam paper:
# <div class='article'>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#     <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>
#     <p style="margin-bottom: 1.2em; text-align: justify;">新しい商品を企画するとき、いいアイデアがなかなか思いつかないことがある。そんなとき、自分には才能がないからだと思い込み、</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">自信をなくしてしまうのはよくない。アイデアは生まれつきの能力に関係なく、努力次第で誰でも生み出すことができる。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">アイデアは、情報の組み合わせによって生まれることがほとんどだ。そのため、日ごろから情報を集めておくことが有効だ。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">担当する商品に関連する情報だけを集めていると、似たようなアイデアばかりになってしまう。発想の幅を広げるには、</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">関連する分野以外の情報も頭に入れておくほうがいい。ふだんから視野を広げてさまざまな情報を蓄積しておけば、</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">必ずアイデアの役に立つはずだ。</p>
#   </div>
# <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#     <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>
#     <p style="margin-bottom: 1.2em; text-align: justify;">新しい商品を企画するには、これまでとは異なるアイデアが必要だ。現在流行している商品の情報を集めるだけでは、</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">他社に勝つことはできないだろう。私はアイデアを生み出すために、一般的に考えられていることとは逆の発想をするようにしている。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">現在流行している商品が若者向けの物なら高齢者向けにできないかと考えたり、多機能の物なら機能を一つに絞れないかと考えたりするのである。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;"></p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">アイデアは一部の才能がある人しか生み出せないものだという印象があるせいか、生み出し方を知ろうとしない人が多いと思う。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">才能がないからといってあきらめるのではなく、思い切って発想を転換してみれば、いいアイデアにつながっていく。</p>
#   </div>
# </div>
#
# <a>アイデアを生み出すことについて、AとBが共通して述べていることは何か。</a>
# <ul class="options">
#     <li>アイデアを生み出し方は、簡単に身につけることができる。</li>
#     <li>多くの情報を得ることで、アイデアを生み出しやすくなる。</li>
#     <li>特別な能力がなくても、アイデアを生み出すことができる。</li>
#     <li>発想のしかたを大きく変えなければ、アイデアは生み出せない。</li>
# </ul>
#
# <a>新しい商品を企画することについて、AとBはどのようなアドバイスをしているか。</a>
# <ul class="options">
#     <li>AもBも、いろいろな分野の情報をできるだけ多く集めるといいと述べている。</li>
#     <li>AもBも、流行している商品について詳しく調べるといいと述べている。</li>
#     <li>Aは関連する分野の他社の商品の情報を集めるといいと述べ、Bは流行に逆らった考え方をするといいと述べている。</li>
#     <li>AもBも、流行している商品について詳しく調べるといいと述べている。</li>
# </ul>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: 引退後の生活について話す
# AI: <div class='article'>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#     <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>
#     <p style="margin-bottom: 1.2em; text-align: justify;">長年働いてきた会社を退職した後、私は新しい生活を始めることになった。最初は毎日何をして過ごせばいいのか分からず、時間を持て余してしまった。しかし、友人から地域のボランティア活動に参加してみてはどうかと勧められ、思い切って参加することにした。活動を通じて多くの人と知り合い、今まで知らなかったことを学ぶ機会も増えた。特に、子どもたちと一緒に公園の掃除をしたり、イベントの準備を手伝ったりすることで、社会とのつながりを感じることができた。引退後は孤独になりがちだと思っていたが、積極的に外に出ることで充実した毎日を送れるようになった。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">また、趣味だった料理にも時間をかけるようになった。新しいレシピに挑戦したり、家族や友人に手料理をふるまったりすることで、生活に楽しみが増えた。今では、退職前よりも健康に気をつかうようになり、体調も良くなったと感じている。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">引退後の生活は不安もあったが、自分から行動することで新しい人間関係が広がり、毎日が充実するようになった。これからも積極的にいろいろなことに挑戦していきたいと思っている。</p>
#   </div>
#   <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#     <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>
#     <p style="margin-bottom: 1.2em; text-align: justify;">私は定年を迎えた後、しばらく家で過ごしていた。最初は自由な時間が増えてうれしかったが、次第に何か物足りなさを感じるようになった。そこで、以前から興味があった絵画教室に通い始めた。最初はうまく描けず、難しいと感じたが、先生や仲間の助けを受けて少しずつ上達した。教室では年齢や職業が違う人たちと交流でき、毎週通うのが楽しみになった。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">また、健康のために毎朝散歩をするようになった。自然の中を歩くことで気分がすっきりし、体力もついてきた。引退後は生活が変わるので、何か新しいことに挑戦することが大切だと感じている。今では、以前よりも前向きに毎日を過ごせるようになった。</p>
#     <p style="margin-bottom: 1.2em; text-align: justify;">引退後の生活は自分次第で楽しくできると分かったので、これからも新しい趣味や活動を続けていきたいと思う。</p>
#   </div>
# </div>
# <a>引退後の生活について、AとBが共通して述べていることは何か。</a>
# <ul class="options">
#     <li>家族と過ごす時間が増えることで、毎日が楽しくなる。</li>
#     <li>新しいことに挑戦することで、生活が充実するようになる。</li>
#     <li>退職後は健康が自然に良くなると感じている。</li>
#     <li>友人の勧めで趣味を始める人が多い。</li>
# </ul>
# <a>AとBの引退後の生活について、どのような違いがあるか。</a>
# <ul class="options">
#     <li>Aは地域の活動に参加し、Bは芸術を学び始めた。</li>
#     <li>Aは家で過ごすことが多く、Bは外に出ることが多い。</li>
#     <li>Aは運動を中心に生活し、Bは料理を楽しんでいる。</li>
#     <li>AもBも最初から積極的に新しいことを始めた。</li>
# </ul>
# 正解: 2, 1
# HUMAN: GOOD ENOUGH
# 2025-11-21 09:55:09,278 - INFO - jlpt - Formatter: {'html_article': '<div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">    <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>    <p style="margin-bottom: 1.2em; text-align: justify;">長年働いてきた会社を退職した後、私は新しい生活を始めることになった。最初は毎日何をして過ごせばいいのか分からず、時間を持て余してしまった。しかし、友人から地域のボランティア活動に参加してみてはどうかと勧められ、思い切って参加することにした。活動を通じて多くの人と知り合い、今まで知らなかったことを学ぶ機会も増えた。特に、子どもたちと一緒に公園の掃除をしたり、イベントの準備を手伝ったりすることで、社会とのつながりを感じることができた。引退後は孤独になりがちだと思っていたが、積極的に外に出ることで充実した毎日を送れるようになった。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">また、趣味だった料理にも時間をかけるようになった。新しいレシピに挑戦したり、家族や友人に手料理をふるまったりすることで、生活に楽しみが増えた。今では、退職前よりも健康に気をつかうようになり、体調も良くなったと感じている。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">引退後の生活は不安もあったが、自分から行動することで新しい人間関係が広がり、毎日が充実するようになった。これからも積極的にいろいろなことに挑戦していきたいと思っている。</p>  </div>  <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">    <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>    <p style="margin-bottom: 1.2em; text-align: justify;">私は定年を迎えた後、しばらく家で過ごしていた。最初は自由な時間が増えてうれしかったが、次第に何か物足りなさを感じるようになった。そこで、以前から興味があった絵画教室に通い始めた。最初はうまく描けず、難しいと感じたが、先生や仲間の助けを受けて少しずつ上達した。教室では年齢や職業が違う人たちと交流でき、毎週通うのが楽しみになった。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">また、健康のために毎朝散歩をするようになった。自然の中を歩くことで気分がすっきりし、体力もついてきた。引退後は生活が変わるので、何か新しいことに挑戦することが大切だと感じている。今では、以前よりも前向きに毎日を過ごせるようになった。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">引退後の生活は自分次第で楽しくできると分かったので、これからも新しい趣味や活動を続けていきたいと思う。</p>  </div>', 'questions': [{'html_question': '引退後の生活について、AとBが共通して述べていることは何か。', 'correct_answer': 2, 'choices': ['家族と過ごす時間が増えることで、毎日が楽しくなる。', '新しいことに挑戦することで、生活が充実するようになる。', '退職後は健康が自然に良くなると感じている。', '友人の勧めで趣味を始める人が多い。']}, {'html_question': 'AとBの引退後の生活について、どのような違いがあるか。', 'correct_answer': 1, 'choices': ['Aは地域の活動に参加し、Bは芸術を学び始めた。', 'Aは家で過ごすことが多く、Bは外に出ることが多い。', 'Aは運動を中心に生活し、Bは料理を楽しんでいる。', 'AもBも最初から積極的に新しいことを始めた。']}]}
# <strong>1番.</strong></br></br><div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">    <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>    <p style="margin-bottom: 1.2em; text-align: justify;">長年働いてきた会社を退職した後、私は新しい生活を始めることになった。最初は毎日何をして過ごせばいいのか分からず、時間を持て余してしまった。しかし、友人から地域のボランティア活動に参加してみてはどうかと勧められ、思い切って参加することにした。活動を通じて多くの人と知り合い、今まで知らなかったことを学ぶ機会も増えた。特に、子どもたちと一緒に公園の掃除をしたり、イベントの準備を手伝ったりすることで、社会とのつながりを感じることができた。引退後は孤独になりがちだと思っていたが、積極的に外に出ることで充実した毎日を送れるようになった。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">また、趣味だった料理にも時間をかけるようになった。新しいレシピに挑戦したり、家族や友人に手料理をふるまったりすることで、生活に楽しみが増えた。今では、退職前よりも健康に気をつかうようになり、体調も良くなったと感じている。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">引退後の生活は不安もあったが、自分から行動することで新しい人間関係が広がり、毎日が充実するようになった。これからも積極的にいろいろなことに挑戦していきたいと思っている。</p>  </div>  <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">    <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>    <p style="margin-bottom: 1.2em; text-align: justify;">私は定年を迎えた後、しばらく家で過ごしていた。最初は自由な時間が増えてうれしかったが、次第に何か物足りなさを感じるようになった。そこで、以前から興味があった絵画教室に通い始めた。最初はうまく描けず、難しいと感じたが、先生や仲間の助けを受けて少しずつ上達した。教室では年齢や職業が違う人たちと交流でき、毎週通うのが楽しみになった。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">また、健康のために毎朝散歩をするようになった。自然の中を歩くことで気分がすっきりし、体力もついてきた。引退後は生活が変わるので、何か新しいことに挑戦することが大切だと感じている。今では、以前よりも前向きに毎日を過ごせるようになった。</p>    <p style="margin-bottom: 1.2em; text-align: justify;">引退後の生活は自分次第で楽しくできると分かったので、これからも新しい趣味や活動を続けていきたいと思う。</p>  </div>
# <p><strong>1.引退後の生活について、AとBが共通して述べていることは何か。</strong></p>
# <ul>
# <li>家族と過ごす時間が増えることで、毎日が楽しくなる。</li>
# <li><b>新しいことに挑戦することで、生活が充実するようになる。</b> <span style='color:green;'>(correct)</span></li>
# <li>退職後は健康が自然に良くなると感じている。</li>
# <li>友人の勧めで趣味を始める人が多い。</li>
# </ul>
# <p><strong>2.AとBの引退後の生活について、どのような違いがあるか。</strong></p>
# <ul>
# <li><b>Aは地域の活動に参加し、Bは芸術を学び始めた。</b> <span style='color:green;'>(correct)</span></li>
# <li>Aは家で過ごすことが多く、Bは外に出ることが多い。</li>
# <li>Aは運動を中心に生活し、Bは料理を楽しんでいる。</li>
# <li>AもBも最初から積極的に新しいことを始めた。</li>
# </ul>

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-21 09:55:09,343 - INFO - jlpt - ---Generator----
# 2025-11-21 09:55:15,549 - INFO - jlpt - ---REVISOR---
# 2025-11-21 09:55:16,193 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-21 09:55:16,195 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-21 09:55:16,196 - INFO - jlpt - --- Formatter ---
# 2025-11-21 09:55:16,197 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问1个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -在输出中显示正确答案，选项为1,2,3,4.例如：正解：n, 正确答案分布要平均，不要集中在某个选项
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# 女1: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# 男1: 市の方針でゴミ箱は置かないことになってるからね。
# 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# 女1: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# 女1: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
# 历史题目：
#
# HUMAN: Generate a JLPT question regarding Topic: 領収書を求める
# AI: <p class='background'>会社の同僚3人が昼食後、レストランで会計を済ませた後に話しています。</p>
#
# <div class='conversation'>
# 女1: 今日はみんなでランチできてよかったですね。お会計、私がまとめて払いましたけど、領収書は必要ですか？
# 男1: うん、会社に経費申請するから、領収書をもらいたいんだけど、店員さんにお願いしてもらえる？
# 女1: わかりました。ちょっと待っててくださいね。（店員に声をかける）すみません、領収書をお願いします。
# 男2: ありがとう。領収書には会社名を書いてもらった方がいいですよね？
# 男1: そうだね。会社名を書いてもらうと、申請がスムーズになるから。
# 女1: 店員さん、会社名も書いてもらえますか？「株式会社グリーンテック」でお願いします。
# 店員: かしこまりました。少々お待ちください。
# 男2: こういう時、領収書をもらい忘れることがあるから、気をつけないとね。
# 男1: そうだね。領収書がないと、経費として認められないこともあるし。
# 女1: これからは、みんなで外食する時は、最初に領収書が必要か確認した方がいいですね。
# 男2: そうですね。今日は助かりました。ありがとうございます。
# 女1: いえいえ、また何かあったら言ってくださいね。
# </div>
#
# <a class='follow_up'>この会話で、領収書をもらう理由は何ですか？</a>
# <ul class='options'>
#     <li>レストランのサービスを確認するため</li>
#     <li>会社に経費申請をするため</li>
#     <li>個人的な記念にするため</li>
#     <li>支払い金額を確認するため</li>
# </ul>
# 正解：2
# HUMAN: GOOD ENOUGH
# 2025-11-21 09:55:19,054 - INFO - jlpt - Formatter: {'background': '会社の同僚3人が昼食後、レストランで会計を済ませた後に話しています。', 'conversation': [{'gender': 'female1', 'context': '今日はみんなでランチできてよかったですね。お会計、私がまとめて払いましたけど、領収書は必要ですか？'}, {'gender': 'male1', 'context': 'うん、会社に経費申請するから、領収書をもらいたいんだけど、店員さんにお願いしてもらえる？'}, {'gender': 'female1', 'context': 'わかりました。ちょっと待っててくださいね。（店員に声をかける）すみません、領収書をお願いします。'}, {'gender': 'male2', 'context': 'ありがとう。領収書には会社名を書いてもらった方がいいですよね？'}, {'gender': 'male1', 'context': 'そうだね。会社名を書いてもらうと、申請がスムーズになるから。'}, {'gender': 'female1', 'context': '店員さん、会社名も書いてもらえますか？「株式会社グリーンテック」でお願いします。'}, {'gender': 'male2', 'context': 'こういう時、領収書をもらい忘れることがあるから、気をつけないとね。'}, {'gender': 'male1', 'context': 'そうだね。領収書がないと、経費として認められないこともあるし。'}, {'gender': 'female1', 'context': 'これからは、みんなで外食する時は、最初に領収書が必要か確認した方がいいですね。'}, {'gender': 'male2', 'context': 'そうですね。今日は助かりました。ありがとうございます。'}, {'gender': 'female1', 'context': 'いえいえ、また何かあったら言ってくださいね。'}], 'follow_up': 'この会話で、領収書をもらう理由は何ですか？', 'choices': ['レストランのサービスを確認するため', '会社に経費申請をするため', '個人的な記念にするため', '支払い金額を確認するため'], 'correct_answer': 2}
# 2025-11-21 09:56:19,439 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-21 09:56:19,457 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1.wav
# 2025-11-21 09:56:19,459 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-21 09:56:19,466 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_background.wav
# 2025-11-21 09:56:19,470 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-21 09:56:19,472 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_0_speaker.wav
# 2025-11-21 09:56:19,477 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_1_speaker.wav
# 2025-11-21 09:56:19,482 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_2_speaker.wav
# 2025-11-21 09:56:19,495 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_3_speaker.wav
# 2025-11-21 09:56:19,507 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_4_speaker.wav
# 2025-11-21 09:56:19,519 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_5_speaker.wav
# 2025-11-21 09:56:19,536 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_6_speaker.wav
# 2025-11-21 09:56:19,550 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_7_speaker.wav
# 2025-11-21 09:56:19,563 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_8_speaker.wav
# 2025-11-21 09:56:19,578 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_9_speaker.wav
# 2025-11-21 09:56:19,593 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_10_speaker.wav
# 2025-11-21 09:56:19,606 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-21 09:56:19,612 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_follow_up.wav
# 2025-11-21 09:56:19,626 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_1_seq.wav
# 2025-11-21 09:56:19,640 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_1_option.wav
# 2025-11-21 09:56:19,654 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_2_seq.wav
# 2025-11-21 09:56:19,667 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_2_option.wav
# 2025-11-21 09:56:19,683 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_3_seq.wav
# 2025-11-21 09:56:19,696 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_3_option.wav
# 2025-11-21 09:56:19,716 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_4_seq.wav
# 2025-11-21 09:56:19,730 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_4_option.wav
# 2025-11-21 09:56:20,458 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_conversation_output.mp3
# 2025-11-21 09:56:23,941 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_listen_answer_1_conversation_output.mp3 as blob 11101435-c67d-11f0-a8d8-d4d8537023c7/comprehensive_expression_listen_answer_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>会社の同僚3人が昼食後、レストランで会計を済ませた後に話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 今日はみんなでランチできてよかったですね。お会計、私がまとめて払いましたけど、領収書は必要ですか？</p>
# <p><strong>Male1:</strong> うん、会社に経費申請するから、領収書をもらいたいんだけど、店員さんにお願いしてもらえる？</p>
# <p><strong>Female1:</strong> わかりました。ちょっと待っててくださいね。（店員に声をかける）すみません、領収書をお願いします。</p>
# <p><strong>Male2:</strong> ありがとう。領収書には会社名を書いてもらった方がいいですよね？</p>
# <p><strong>Male1:</strong> そうだね。会社名を書いてもらうと、申請がスムーズになるから。</p>
# <p><strong>Female1:</strong> 店員さん、会社名も書いてもらえますか？「株式会社グリーンテック」でお願いします。</p>
# <p><strong>Male2:</strong> こういう時、領収書をもらい忘れることがあるから、気をつけないとね。</p>
# <p><strong>Male1:</strong> そうだね。領収書がないと、経費として認められないこともあるし。</p>
# <p><strong>Female1:</strong> これからは、みんなで外食する時は、最初に領収書が必要か確認した方がいいですね。</p>
# <p><strong>Male2:</strong> そうですね。今日は助かりました。ありがとうございます。</p>
# <p><strong>Female1:</strong> いえいえ、また何かあったら言ってくださいね。</p>
# </div>
# <p><strong>follow-up question: </strong>この会話で、領収書をもらう理由は何ですか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/11101435-c67d-11f0-a8d8-d4d8537023c7/comprehensive_expression_listen_answer_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. レストランのサービスを確認するため</li>
# <li>2. <b>会社に経費申請をするため</b> <span style='color:green;'>(correct)</span></li>
# <li>3. 個人的な記念にするため</li>
# <li>4. 支払い金額を確認するため</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-21 09:56:23,951 - INFO - jlpt - ---Generator----
# 2025-11-21 09:56:31,079 - INFO - jlpt - ---REVISOR---
# 2025-11-21 09:56:31,783 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-21 09:56:31,785 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-21 09:56:31,787 - INFO - jlpt - --- Formatter ---
# 2025-11-21 09:56:31,788 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问2个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -在输出中显示正确答案，选项为1,2,3,4.例如：正解：n, 正确答案分布要平均，不要集中在某个选项
#
#
# 正式试卷：
# <p class='background'>池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。</p>
#
# <div class='conversation'>
# 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方なども教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方も楽しめいただけます。西会場では、新鮮な魚介類を販売しています。
# 女2: 新鮮な魚、おいしそう。なくなり前に早く行かなきゃ？
# 男1: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# 男1: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、買い物は最後にしようよ。
# 女2: いいよ。釣りはいいの？
# 男1: うーん、初心者向けって言ってたから今日は初めてていいかな。
# </div>
# <a class='follow_up'>質問1: 2人は最初にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
# <a class='follow_up'>質問2: 2人は2番目にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
#
#
# 历史题目：
#
# HUMAN: Generate a JLPT question regarding Topic: 引っ越しの準備について話す
# AI: <p class='background'>大学の寮から新しいアパートに引っ越すことになった3人が、引っ越しの準備について話しています。</p>
#
# <div class='conversation'>
# 男1: 来週の土曜日、いよいよ引っ越しだね。みんな、準備は進んでる？
# 女1: 私はまだ全然終わってないよ。荷物が多すぎて、何から始めればいいかわからなくて困ってるの。
# 男2: 僕は昨日から少しずつ箱に詰め始めたよ。使わないものから片付けると楽だよ。
# 女1: なるほど。じゃあ、まず冬服とか、今使わないものから箱に入れればいいんだね。
# 男1: そうそう。あと、いらないものはこの機会に捨てたり、リサイクルショップに持っていったりするといいよ。
# 女1: それ、いいアイデアだね。使ってない本とか服、たくさんあるし。
# 男2: 引っ越し当日は、荷物を運ぶのに車が必要だけど、誰か運転できる？
# 男1: 僕は免許持ってるから運転できるよ。レンタカーも予約してあるし。
# 女1: 助かる！じゃあ、当日はみんなで協力して運ぼうね。
# 男2: うん。あと、引っ越し先の掃除も忘れないようにしよう。荷物を入れる前にきれいにした方がいいよ。
# 女1: そうだね。掃除道具も用意しておくね。
# 男1: じゃあ、今週中にそれぞれ準備して、何か困ったことがあったら連絡し合おう。
# 女1: わかった。みんなで頑張ろうね！
# 男2: 楽しみだね、新しい生活！
# </div>
#
# <a class='follow_up'>質問1: 女の人は引っ越しの準備について何に困っていますか？</a>
# <ul class='options'>
#     <li>荷物を運ぶ方法がわからない</li>
#     <li>荷物が多すぎて何から始めればいいかわからない</li>
#     <li>掃除道具が足りない</li>
#     <li>レンタカーの予約ができない</li>
# </ul>
# 正解：2
#
# <a class='follow_up'>質問2: 男の人たちは引っ越し当日に何をする予定ですか？</a>
# <ul class='options'>
#     <li>新しいアパートで料理を作る</li>
#     <li>リサイクルショップに行く</li>
#     <li>荷物を運んで掃除する</li>
#     <li>冬服を買いに行く</li>
# </ul>
# 正解：3
# HUMAN: GOOD ENOUGH
# 2025-11-21 09:56:36,373 - INFO - jlpt - Formatter: {'background': '大学の寮から新しいアパートに引っ越すことになった3人が、引っ越しの準備について話しています。', 'conversation': [{'gender': 'male1', 'context': '来週の土曜日、いよいよ引っ越しだね。みんな、準備は進んでる？'}, {'gender': 'female1', 'context': '私はまだ全然終わってないよ。荷物が多すぎて、何から始めればいいかわからなくて困ってるの。'}, {'gender': 'male2', 'context': '僕は昨日から少しずつ箱に詰め始めたよ。使わないものから片付けると楽だよ。'}, {'gender': 'female1', 'context': 'なるほど。じゃあ、まず冬服とか、今使わないものから箱に入れればいいんだね。'}, {'gender': 'male1', 'context': 'そうそう。あと、いらないものはこの機会に捨てたり、リサイクルショップに持っていったりするといいよ。'}, {'gender': 'female1', 'context': 'それ、いいアイデアだね。使ってない本とか服、たくさんあるし。'}, {'gender': 'male2', 'context': '引っ越し当日は、荷物を運ぶのに車が必要だけど、誰か運転できる？'}, {'gender': 'male1', 'context': '僕は免許持ってるから運転できるよ。レンタカーも予約してあるし。'}, {'gender': 'female1', 'context': '助かる！じゃあ、当日はみんなで協力して運ぼうね。'}, {'gender': 'male2', 'context': 'うん。あと、引っ越し先の掃除も忘れないようにしよう。荷物を入れる前にきれいにした方がいいよ。'}, {'gender': 'female1', 'context': 'そうだね。掃除道具も用意しておくね。'}, {'gender': 'male1', 'context': 'じゃあ、今週中にそれぞれ準備して、何か困ったことがあったら連絡し合おう。'}, {'gender': 'female1', 'context': 'わかった。みんなで頑張ろうね！'}, {'gender': 'male2', 'context': '楽しみだね、新しい生活！'}], 'listen_questions': [{'follow_up': '質問1: 女の人は引っ越しの準備について何に困っていますか？', 'correct_answer': 2, 'choices': ['荷物を運ぶ方法がわからない', '荷物が多すぎて何から始めればいいかわからない', '掃除道具が足りない', 'レンタカーの予約ができない']}, {'follow_up': '質問2: 男の人たちは引っ越し当日に何をする予定ですか？', 'correct_answer': 3, 'choices': ['新しいアパートで料理を作る', 'リサイクルショップに行く', '荷物を運んで掃除する', '冬服を買いに行く']}]}
# 2025-11-21 09:57:24,790 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-21 09:57:24,793 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3.wav
# 2025-11-21 09:57:24,794 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-21 09:57:24,796 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_background.wav
# 2025-11-21 09:57:24,801 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-21 09:57:24,802 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-11-21 09:57:24,806 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-11-21 09:57:24,812 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-11-21 09:57:24,819 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-11-21 09:57:24,825 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-11-21 09:57:24,832 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-11-21 09:57:24,840 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-11-21 09:57:24,848 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-11-21 09:57:24,856 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_8_speaker.wav
# 2025-11-21 09:57:24,865 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_9_speaker.wav
# 2025-11-21 09:57:24,875 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_10_speaker.wav
# 2025-11-21 09:57:24,882 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_11_speaker.wav
# 2025-11-21 09:57:24,891 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_12_speaker.wav
# 2025-11-21 09:57:24,898 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_13_speaker.wav
# 2025-11-21 09:57:24,907 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-21 09:57:24,914 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_1_follow_up.wav
# 2025-11-21 09:57:24,924 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-21 09:57:24,932 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-21 09:57:24,940 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_2_follow_up.wav
# 2025-11-21 09:57:24,959 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-21 09:57:25,705 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-11-21 09:57:28,092 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\11101435-c67d-11f0-a8d8-d4d8537023c7\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob 11101435-c67d-11f0-a8d8-d4d8537023c7/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の寮から新しいアパートに引っ越すことになった3人が、引っ越しの準備について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Male1:</strong> 来週の土曜日、いよいよ引っ越しだね。みんな、準備は進んでる？</p>
# <p><strong>Female1:</strong> 私はまだ全然終わってないよ。荷物が多すぎて、何から始めればいいかわからなくて困ってるの。</p>
# <p><strong>Male2:</strong> 僕は昨日から少しずつ箱に詰め始めたよ。使わないものから片付けると楽だよ。</p>
# <p><strong>Female1:</strong> なるほど。じゃあ、まず冬服とか、今使わないものから箱に入れればいいんだね。</p>
# <p><strong>Male1:</strong> そうそう。あと、いらないものはこの機会に捨てたり、リサイクルショップに持っていったりするといいよ。</p>
# <p><strong>Female1:</strong> それ、いいアイデアだね。使ってない本とか服、たくさんあるし。</p>
# <p><strong>Male2:</strong> 引っ越し当日は、荷物を運ぶのに車が必要だけど、誰か運転できる？</p>
# <p><strong>Male1:</strong> 僕は免許持ってるから運転できるよ。レンタカーも予約してあるし。</p>
# <p><strong>Female1:</strong> 助かる！じゃあ、当日はみんなで協力して運ぼうね。</p>
# <p><strong>Male2:</strong> うん。あと、引っ越し先の掃除も忘れないようにしよう。荷物を入れる前にきれいにした方がいいよ。</p>
# <p><strong>Female1:</strong> そうだね。掃除道具も用意しておくね。</p>
# <p><strong>Male1:</strong> じゃあ、今週中にそれぞれ準備して、何か困ったことがあったら連絡し合おう。</p>
# <p><strong>Female1:</strong> わかった。みんなで頑張ろうね！</p>
# <p><strong>Male2:</strong> 楽しみだね、新しい生活！</p>
# </div>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/11101435-c67d-11f0-a8d8-d4d8537023c7/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <p><strong>1.質問1: 女の人は引っ越しの準備について何に困っていますか？</strong></p>
# <ul>
# <li>荷物を運ぶ方法がわからない</li>
# <li><b>荷物が多すぎて何から始めればいいかわからない</b> <span style='color:green;'>(correct)</span></li>
# <li>掃除道具が足りない</li>
# <li>レンタカーの予約ができない</li>
# </ul>
# <p><strong>2.質問2: 男の人たちは引っ越し当日に何をする予定ですか？</strong></p>
# <ul>
# <li>新しいアパートで料理を作る</li>
# <li>リサイクルショップに行く</li>
# <li><b>荷物を運んで掃除する</b> <span style='color:green;'>(correct)</span></li>
# <li>冬服を買いに行く</li>
# </ul>
