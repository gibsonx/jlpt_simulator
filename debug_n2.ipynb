# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))
# Out:
# 2025-10-28 23:36:03,157 - INFO - jlpt - ---Generator----
# 2025-10-28 23:36:18,089 - INFO - jlpt - ---REVISOR---
# 2025-10-28 23:36:18,749 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-28 23:36:18,750 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-28 23:36:18,752 - INFO - jlpt - --- Formatter ---
# 2025-10-28 23:36:18,752 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N2 level.
#
# Task: Task: Your job is to write a reading question for a JLPT N2 level exam.
# First you need to write a long article around 450 words for student to read.
# Then, you give 4 questions by the related content in the article.
# The purpose is to ensure the students are able to understand the meaning of the article.
#
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N2 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
#
# Formal exam paper:
# <div class="reading-text">
#   <h3>A</h3>
#   <p>
#     新しい商品を企画するとき、いいアイデアがなかなか思いつかないことがある。そんなとき、自分には才能がないからだと思い込み、
#     自信をなくしてしまうのはよくない。アイデアは生まれつきの能力に関係なく、努力次第で誰でも生み出すことができる。
#     アイデアは、情報の組み合わせによって生まれることがほとんどだ。そのため、日ごろから情報を集めておくことが有効だ。
#     担当する商品に関連する情報だけを集めていると、似たようなアイデアばかりになってしまう。発想の幅を広げるには、
#     関連する分野以外の情報も頭に入れておくほうがいい。ふだんから視野を広げてさまざまな情報を蓄積しておけば、
#     必ずアイデアの役に立つはずだ。
#   </p>
#
#   <h3>B</h3>
#   <p>
#     新しい商品を企画するには、これまでとは異なるアイデアが必要だ。現在流行している商品の情報を集めるだけでは、
#     他社に勝つことはできないだろう。私はアイデアを生み出すために、一般的に考えられていることとは逆の発想をするようにしている。
#     現在流行している商品が若者向けの物なら高齢者向けにできないかと考えたり、多機能の物なら機能を一つに絞れないかと考えたりするのである。
#   </p>
#   <p>
#     アイデアは一部の才能がある人しか生み出せないものだという印象があるせいか、生み出し方を知ろうとしない人が多いと思う。
#     才能がないからといってあきらめるのではなく、思い切って発想を転換してみれば、いいアイデアにつながっていく。
#   </p>
# </div>
#
# <body>
#     <h1>65. アイデアを生み出すことについて、AとBが共通して述べていることは何か。</h1>
#     <ol>
#         <li>アイデアを生み出し方は、簡単に身につけることができる。</li>
#         <li>多くの情報を得ることで、アイデアを生み出しやすくなる。</li>
#         <li>特別な能力がなくても、アイデアを生み出すことができる。</li>
#         <li>発想のしかたを大きく変えなければ、アイデアは生み出せない。</li>
#     </ol>
#
#     <h1>66. 新しい商品を企画することについて、AとBはどのようなアドバイスをしているか。</h1>
#     <ol>
#         <li>AもBも、いろいろな分野の情報をできるだけ多く集めるといいと述べている。</li>
#         <li>AもBも、流行している商品について詳しく調べるといいと述べている。</li>
#         <li>Aは関連する分野の他社の商品の情報を集めるといいと述べ、Bは流行に逆らった考え方をするといいと述べている。</li>
#         <li>AもBも、流行している商品について詳しく調べるといいと述べている。</li>
#     </ol>
#
#     <h1>67. 新しい商品を企画する際の注意点について、AとBが共通して述べていることは何か。</h1>
#     <ol>
#         <li>十分な時間と資金を確保すること。</li>
#         <li>多くの消費者の意見を取り入れること。</li>
#         <li>市場の需要を調べる前に、デザインや機能にこだわること。</li>
#         <li>競合他社の動きを分析し、それに合わせること。</li>
#     </ol>
# </body>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 領収書を求める
# AI: <div class="reading-text">
#   <h3>A</h3>
#   <p>
#     会社で経費を精算する際、必ず証明書類が必要になる。特に、飲食店や交通機関で支払いをした場合は、店員にお願いして記録をもらうことが重要だ。もし、支払い後に記録をもらい忘れてしまうと、後で経理担当者に説明しなければならず、手続きが複雑になることがある。私は以前、出張先のホテルで記録をもらい忘れ、後日ホテルに連絡して郵送してもらったことがある。その経験から、支払いの際は必ず記録を受け取るように心がけている。
#   </p>
#   <p>
#     また、会社によっては、記録に会社名や担当者名を記載してもらう必要がある場合もある。事前に会社の規則を確認しておくことで、後から困ることがなくなる。最近は電子記録も増えているが、紙の記録が必要な場合もあるので、状況に応じて対応することが大切だと思う。
#   </p>
#
#   <h3>B</h3>
#   <p>
#     私は小売店で働いているが、お客様から記録を求められることがよくある。特に、会社員の方は仕事で使うために記録を必要とする場合が多い。記録を発行する際は、日付や金額が正しく記載されているか確認し、間違いがないように注意している。もし記載内容に誤りがあると、お客様が会社で使えなくなってしまうことがあるからだ。
#   </p>
#   <p>
#     最近はレジのシステムで簡単に記録を発行できるようになったが、時々手書きで対応しなければならないこともある。その場合は、丁寧に書くことを心がけている。お客様が安心して利用できるよう、記録の発行はとても重要な仕事だと感じている。
#   </p>
# </div>
#
# <body>
#     <h1>領収書について、AとBが共通して述べていることは何か。</h1>
#     <ol>
#         <li>発行する際は、必ず手書きで作成しなければならない。</li>
#         <li>記載内容に誤りがあっても、後で修正できる。</li>
#         <li>必要な場合は、事前に確認しておくことが大切である。</li>
#         <li>発行するのは、会社員だけに限られている。</li>
#     </ol>
#     正解: 3
#
#     <h1>Aが領収書について経験したことは何か。</h1>
#     <ol>
#         <li>飲食店で記録をもらうのを忘れた。</li>
#         <li>ホテルで記録をもらい忘れ、後で郵送してもらった。</li>
#         <li>交通機関で記録を受け取らなかった。</li>
#         <li>会社名を記載してもらうのを忘れた。</li>
#     </ol>
#     正解: 2
#
#     <h1>Bが領収書を発行する際に気をつけていることは何か。</h1>
#     <ol>
#         <li>必ず電子記録で発行すること。</li>
#         <li>日付や金額が正しいか確認すること。</li>
#         <li>会社名を必ず記載すること。</li>
#         <li>お客様の住所を書くこと。</li>
#     </ol>
#     正解: 2
#
#     <h1>この文章からわかる領収書の役割は何か。</h1>
#     <ol>
#         <li>商品の保証をするためのもの。</li>
#         <li>支払いの証明として使われるもの。</li>
#         <li>店員の評価に使われるもの。</li>
#         <li>会社の規則を示すもの。</li>
#     </ol>
#     正解: 2
# </body>
# HUMAN: GOOD ENOUGH
# 2025-10-28 23:36:25,077 - INFO - jlpt - Formatter: {'html_article': '<h3>A</h3>  <p>    会社で経費を精算する際、必ず証明書類が必要になる。特に、飲食店や交通機関で支払いをした場合は、店員にお願いして記録をもらうことが重要だ。もし、支払い後に記録をもらい忘れてしまうと、後で経理担当者に説明しなければならず、手続きが複雑になることがある。私は以前、出張先のホテルで記録をもらい忘れ、後日ホテルに連絡して郵送してもらったことがある。その経験から、支払いの際は必ず記録を受け取るように心がけている。  </p>  <p>    また、会社によっては、記録に会社名や担当者名を記載してもらう必要がある場合もある。事前に会社の規則を確認しておくことで、後から困ることがなくなる。最近は電子記録も増えているが、紙の記録が必要な場合もあるので、状況に応じて対応することが大切だと思う。  </p>  <h3>B</h3>  <p>    私は小売店で働いているが、お客様から記録を求められることがよくある。特に、会社員の方は仕事で使うために記録を必要とする場合が多い。記録を発行する際は、日付や金額が正しく記載されているか確認し、間違いがないように注意している。もし記載内容に誤りがあると、お客様が会社で使えなくなってしまうことがあるからだ。  </p>  <p>    最近はレジのシステムで簡単に記録を発行できるようになったが、時々手書きで対応しなければならないこともある。その場合は、丁寧に書くことを心がけている。お客様が安心して利用できるよう、記録の発行はとても重要な仕事だと感じている。  </p>', 'questions': [{'html_question': '領収書について、AとBが共通して述べていることは何か。', 'correct_answer': 3, 'choices': ['発行する際は、必ず手書きで作成しなければならない。', '記載内容に誤りがあっても、後で修正できる。', '必要な場合は、事前に確認しておくことが大切である。', '発行するのは、会社員だけに限られている。']}, {'html_question': 'Aが領収書について経験したことは何か。', 'correct_answer': 2, 'choices': ['飲食店で記録をもらうのを忘れた。', 'ホテルで記録をもらい忘れ、後で郵送してもらった。', '交通機関で記録を受け取らなかった。', '会社名を記載してもらうのを忘れた。']}, {'html_question': 'Bが領収書を発行する際に気をつけていることは何か。', 'correct_answer': 2, 'choices': ['必ず電子記録で発行すること。', '日付や金額が正しいか確認すること。', '会社名を必ず記載すること。', 'お客様の住所を書くこと。']}, {'html_question': 'この文章からわかる領収書の役割は何か。', 'correct_answer': 2, 'choices': ['商品の保証をするためのもの。', '支払いの証明として使われるもの。', '店員の評価に使われるもの。', '会社の規則を示すもの。']}]}
# <strong>1番.</strong></br></br><h3>A</h3>  <p>    会社で経費を精算する際、必ず証明書類が必要になる。特に、飲食店や交通機関で支払いをした場合は、店員にお願いして記録をもらうことが重要だ。もし、支払い後に記録をもらい忘れてしまうと、後で経理担当者に説明しなければならず、手続きが複雑になることがある。私は以前、出張先のホテルで記録をもらい忘れ、後日ホテルに連絡して郵送してもらったことがある。その経験から、支払いの際は必ず記録を受け取るように心がけている。  </p>  <p>    また、会社によっては、記録に会社名や担当者名を記載してもらう必要がある場合もある。事前に会社の規則を確認しておくことで、後から困ることがなくなる。最近は電子記録も増えているが、紙の記録が必要な場合もあるので、状況に応じて対応することが大切だと思う。  </p>  <h3>B</h3>  <p>    私は小売店で働いているが、お客様から記録を求められることがよくある。特に、会社員の方は仕事で使うために記録を必要とする場合が多い。記録を発行する際は、日付や金額が正しく記載されているか確認し、間違いがないように注意している。もし記載内容に誤りがあると、お客様が会社で使えなくなってしまうことがあるからだ。  </p>  <p>    最近はレジのシステムで簡単に記録を発行できるようになったが、時々手書きで対応しなければならないこともある。その場合は、丁寧に書くことを心がけている。お客様が安心して利用できるよう、記録の発行はとても重要な仕事だと感じている。  </p>
# <p><strong>1.領収書について、AとBが共通して述べていることは何か。</strong></p>
# <ul>
# <li>発行する際は、必ず手書きで作成しなければならない。</li>
# <li>記載内容に誤りがあっても、後で修正できる。</li>
# <li><b>必要な場合は、事前に確認しておくことが大切である。</b> <span style='color:green;'>(correct)</span></li>
# <li>発行するのは、会社員だけに限られている。</li>
# </ul>
# <p><strong>2.Aが領収書について経験したことは何か。</strong></p>
# <ul>
# <li>飲食店で記録をもらうのを忘れた。</li>
# <li><b>ホテルで記録をもらい忘れ、後で郵送してもらった。</b> <span style='color:green;'>(correct)</span></li>
# <li>交通機関で記録を受け取らなかった。</li>
# <li>会社名を記載してもらうのを忘れた。</li>
# </ul>
# <p><strong>3.Bが領収書を発行する際に気をつけていることは何か。</strong></p>
# <ul>
# <li>必ず電子記録で発行すること。</li>
# <li><b>日付や金額が正しいか確認すること。</b> <span style='color:green;'>(correct)</span></li>
# <li>会社名を必ず記載すること。</li>
# <li>お客様の住所を書くこと。</li>
# </ul>
# <p><strong>4.この文章からわかる領収書の役割は何か。</strong></p>
# <ul>
# <li>商品の保証をするためのもの。</li>
# <li><b>支払いの証明として使われるもの。</b> <span style='color:green;'>(correct)</span></li>
# <li>店員の評価に使われるもの。</li>
# <li>会社の規則を示すもの。</li>
# </ul>

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-28 23:36:25,134 - INFO - jlpt - ---Generator----
# 2025-10-28 23:36:31,693 - INFO - jlpt - ---REVISOR---
# 2025-10-28 23:36:32,596 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-28 23:36:32,600 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-28 23:36:32,603 - INFO - jlpt - --- Formatter ---
# 2025-10-28 23:36:32,604 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问一个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# 女: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# 男1: 市の方針でゴミ箱は置かないことになってるからね。
# 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。
# 他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# 女: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# 女: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。
# 花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 公共施設の利用方法について話す
# AI: <p class='background'>市民センターの利用について、職員と利用者2人が話しています。</p>
#
# <div class='conversation'>
# 女1: すみません、市民センターの会議室を使いたいんですが、予約はどうすればいいですか？
# 男: はい、会議室の予約は、窓口かインターネットでできます。ご希望の日にちと時間を教えていただけますか？
# 女2: インターネットでもできるんですね。便利ですね。利用料はどうなっていますか？
# 男: 利用料は部屋の大きさと利用時間によって違います。小さい部屋なら1時間500円、大きい部屋は1時間1000円です。
# 女1: 支払いはどうすればいいですか？
# 男: 窓口で現金か、インターネットの場合はクレジットカードでお支払いできます。
# 女2: キッチン付きの部屋もあると聞いたんですが、使えますか？
# 男: はい、キッチン付きの部屋もあります。ただし、調理器具や食器はご自身で持ち込んでいただく必要があります。
# 女1: なるほど。利用後は掃除などしないといけませんか？
# 男: はい、使った後は必ず掃除をして、元の状態に戻してください。ゴミは持ち帰っていただくようお願いしています。
# 女2: わかりました。ありがとうございます。予約はインターネットでしてみます。
# 男: 何か分からないことがあれば、いつでもご連絡ください。
# </div>
#
# <a class='follow_up'>市民センターの会議室を利用する場合、利用者は何をしなければなりませんか？</a>
# <ul class='options'>
#     <li>利用後に掃除をして、ゴミを持ち帰る</li>
#     <li>調理器具を借りる</li>
#     <li>現金のみで支払う</li>
#     <li>窓口でしか予約できない</li>
# </ul>
# 正解:1
# HUMAN: GOOD ENOUGH
# 2025-10-28 23:36:37,183 - INFO - jlpt - Formatter: {'background': '市民センターの利用について、職員と利用者2人が話しています。', 'follow_up': '市民センターの会議室を利用する場合、利用者は何をしなければなりませんか？', 'conversation': [{'gender': 'female1', 'context': 'すみません、市民センターの会議室を使いたいんですが、予約はどうすればいいですか？'}, {'gender': 'male1', 'context': 'はい、会議室の予約は、窓口かインターネットでできます。ご希望の日にちと時間を教えていただけますか？'}, {'gender': 'female2', 'context': 'インターネットでもできるんですね。便利ですね。利用料はどうなっていますか？'}, {'gender': 'male1', 'context': '利用料は部屋の大きさと利用時間によって違います。小さい部屋なら1時間500円、大きい部屋は1時間1000円です。'}, {'gender': 'female1', 'context': '支払いはどうすればいいですか？'}, {'gender': 'male1', 'context': '窓口で現金か、インターネットの場合はクレジットカードでお支払いできます。'}, {'gender': 'female2', 'context': 'キッチン付きの部屋もあると聞いたんですが、使えますか？'}, {'gender': 'male1', 'context': 'はい、キッチン付きの部屋もあります。ただし、調理器具や食器はご自身で持ち込んでいただく必要があります。'}, {'gender': 'female1', 'context': 'なるほど。利用後は掃除などしないといけませんか？'}, {'gender': 'male1', 'context': 'はい、使った後は必ず掃除をして、元の状態に戻してください。ゴミは持ち帰っていただくようお願いしています。'}, {'gender': 'female2', 'context': 'わかりました。ありがとうございます。予約はインターネットでしてみます。'}, {'gender': 'male1', 'context': '何か分からないことがあれば、いつでもご連絡ください。'}], 'choices': ['利用後に掃除をして、ゴミを持ち帰る', '調理器具を借りる', '現金のみで支払う', '窓口でしか予約できない'], 'correct_answer': 1}
# 2025-10-28 23:37:26,178 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-28 23:37:26,180 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3.wav
# 2025-10-28 23:37:26,194 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-28 23:37:26,197 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_background.wav
# 2025-10-28 23:37:26,217 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-28 23:37:26,221 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_follow_up.wav
# 2025-10-28 23:37:26,234 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-28 23:37:26,238 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-10-28 23:37:26,255 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-10-28 23:37:26,274 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-10-28 23:37:26,290 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-10-28 23:37:26,310 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-10-28 23:37:26,324 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-10-28 23:37:26,340 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-10-28 23:37:26,360 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-10-28 23:37:26,381 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_8_speaker.wav
# 2025-10-28 23:37:26,398 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_9_speaker.wav
# 2025-10-28 23:37:26,417 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_10_speaker.wav
# 2025-10-28 23:37:26,437 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_11_speaker.wav
# 2025-10-28 23:37:26,454 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-28 23:37:26,463 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_follow_up.wav
# 2025-10-28 23:37:27,190 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-10-28 23:37:30,852 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob cfb15c27-b413-11f0-a85a-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>市民センターの利用について、職員と利用者2人が話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> すみません、市民センターの会議室を使いたいんですが、予約はどうすればいいですか？</p>
# <p><strong>Male1:</strong> はい、会議室の予約は、窓口かインターネットでできます。ご希望の日にちと時間を教えていただけますか？</p>
# <p><strong>Female2:</strong> インターネットでもできるんですね。便利ですね。利用料はどうなっていますか？</p>
# <p><strong>Male1:</strong> 利用料は部屋の大きさと利用時間によって違います。小さい部屋なら1時間500円、大きい部屋は1時間1000円です。</p>
# <p><strong>Female1:</strong> 支払いはどうすればいいですか？</p>
# <p><strong>Male1:</strong> 窓口で現金か、インターネットの場合はクレジットカードでお支払いできます。</p>
# <p><strong>Female2:</strong> キッチン付きの部屋もあると聞いたんですが、使えますか？</p>
# <p><strong>Male1:</strong> はい、キッチン付きの部屋もあります。ただし、調理器具や食器はご自身で持ち込んでいただく必要があります。</p>
# <p><strong>Female1:</strong> なるほど。利用後は掃除などしないといけませんか？</p>
# <p><strong>Male1:</strong> はい、使った後は必ず掃除をして、元の状態に戻してください。ゴミは持ち帰っていただくようお願いしています。</p>
# <p><strong>Female2:</strong> わかりました。ありがとうございます。予約はインターネットでしてみます。</p>
# <p><strong>Male1:</strong> 何か分からないことがあれば、いつでもご連絡ください。</p>
# </div>
# <p><strong>follow-up question: </strong>市民センターの会議室を利用する場合、利用者は何をしなければなりませんか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cfb15c27-b413-11f0-a85a-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>利用後に掃除をして、ゴミを持ち帰る</b> <span style='color:green;'>(correct)</span></li>
# <li>2. 調理器具を借りる</li>
# <li>3. 現金のみで支払う</li>
# <li>4. 窓口でしか予約できない</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-28 23:37:30,864 - INFO - jlpt - ---Generator----
# 2025-10-28 23:37:39,132 - INFO - jlpt - ---REVISOR---
# 2025-10-28 23:37:39,792 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-28 23:37:39,794 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-28 23:37:39,795 - INFO - jlpt - --- Formatter ---
# 2025-10-28 23:37:39,795 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问一个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。</p>
#
# <div class='conversation'>
# 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方なども教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方も楽しめいただけます。西会場では、新鮮な魚介類を販売しています。
# 女2: 新鮮な魚、おいしそう。なくなり前に早く行かなきゃ？
# 男: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# 男: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、買い物は最後にしようよ。
# 女2: いいよ。釣りはいいの？
# 男: うーん、初心者向けって言ってたから今日は初めてていいかな。
# </div>
# <a class='follow_up'>質問1: 2人は最初にどの会場に行くですか？</a>
# <a class='follow_up'>質問2: 2人は2番目にどの会場に行くですか？</a>
#
#
# HUMAN: Generate a JLPT question regarding Topic: ショッピング体験を説明する
# AI: <p class='background'>休日にショッピングモールで買い物をしている男女3人が、休憩スペースで話しています。</p>
#
# <div class='conversation'>
# 男1: 今日はみんなで来てよかったね。久しぶりにこんなに広いモールに来た気がするよ。
# 女: ほんとだね。私は新しい靴を探しているんだけど、どこにいいお店があるかな？
# 男2: さっき2階にスポーツ用品のお店があったよ。そこは種類も多かったし、店員さんも親切だったよ。
# 女: ありがとう。じゃあ、あとで見に行ってみるね。男1は何か買いたいものある？
# 男1: 僕は本屋に行きたいな。最近、話題の小説を読んでみたくて。
# 男2: 本屋なら3階にあるよ。カフェも隣にあるから、買った本をすぐ読めるよ。
# 女: いいね！みんなでカフェで休憩しながら、買ったものを見せ合うのはどう？
# 男1: 賛成！それに、カフェで新しい靴を履いてみるのも楽しそうだね。
# 男2: じゃあ、まず靴屋に行って、それから本屋、最後にカフェに集合しようか。
# 女: うん、そうしよう。今日の買い物、すごく楽しみになってきた！
# 男1: みんなで買い物すると、いろいろな発見があって面白いね。
# 男2: そうだね。ひとりだと見逃してしまう店も、みんなで歩くと気づくことが多いし。
# 女: じゃあ、そろそろ行こうか。
# </div>
#
# <a class='follow_up'>この会話で、3人は買い物の後に何をする予定ですか？</a>
#
# 1. 映画を見る
# 2. カフェで休憩する
# 3. レストランで食事する
# 4. 公園を散歩する
#
# 正解: 2
# HUMAN: GOOD ENOUGH
# 2025-10-28 23:37:46,154 - INFO - jlpt - Formatter: {'background': '休日にショッピングモールで買い物をしている男女3人が、休憩スペースで話しています。', 'follow_up': 'この会話で、3人は買い物の後に何をする予定ですか？', 'conversation': [{'gender': 'male1', 'context': '今日はみんなで来てよかったね。久しぶりにこんなに広いモールに来た気がするよ。'}, {'gender': 'female1', 'context': 'ほんとだね。私は新しい靴を探しているんだけど、どこにいいお店があるかな？'}, {'gender': 'male2', 'context': 'さっき2階にスポーツ用品のお店があったよ。そこは種類も多かったし、店員さんも親切だったよ。'}, {'gender': 'female1', 'context': 'ありがとう。じゃあ、あとで見に行ってみるね。男1は何か買いたいものある？'}, {'gender': 'male1', 'context': '僕は本屋に行きたいな。最近、話題の小説を読んでみたくて。'}, {'gender': 'male2', 'context': '本屋なら3階にあるよ。カフェも隣にあるから、買った本をすぐ読めるよ。'}, {'gender': 'female1', 'context': 'いいね！みんなでカフェで休憩しながら、買ったものを見せ合うのはどう？'}, {'gender': 'male1', 'context': '賛成！それに、カフェで新しい靴を履いてみるのも楽しそうだね。'}, {'gender': 'male2', 'context': 'じゃあ、まず靴屋に行って、それから本屋、最後にカフェに集合しようか。'}, {'gender': 'female1', 'context': 'うん、そうしよう。今日の買い物、すごく楽しみになってきた！'}, {'gender': 'male1', 'context': 'みんなで買い物すると、いろいろな発見があって面白いね。'}, {'gender': 'male2', 'context': 'そうだね。ひとりだと見逃してしまう店も、みんなで歩くと気づくことが多いし。'}, {'gender': 'female1', 'context': 'じゃあ、そろそろ行こうか。'}], 'choices': ['映画を見る  ', 'カフェで休憩する  ', 'レストランで食事する  ', '公園を散歩する  '], 'correct_answer': 2}
# 2025-10-28 23:38:54,993 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-28 23:38:54,999 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3.wav
# 2025-10-28 23:38:55,002 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-28 23:38:55,004 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_background.wav
# 2025-10-28 23:38:55,011 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-28 23:38:55,013 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_0_speaker.wav
# 2025-10-28 23:38:55,017 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_1_speaker.wav
# 2025-10-28 23:38:55,023 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_2_speaker.wav
# 2025-10-28 23:38:55,032 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_3_speaker.wav
# 2025-10-28 23:38:55,040 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_4_speaker.wav
# 2025-10-28 23:38:55,048 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_5_speaker.wav
# 2025-10-28 23:38:55,055 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_6_speaker.wav
# 2025-10-28 23:38:55,064 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_7_speaker.wav
# 2025-10-28 23:38:55,072 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_8_speaker.wav
# 2025-10-28 23:38:55,082 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_9_speaker.wav
# 2025-10-28 23:38:55,094 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_10_speaker.wav
# 2025-10-28 23:38:55,101 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_11_speaker.wav
# 2025-10-28 23:38:55,113 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_12_speaker.wav
# 2025-10-28 23:38:55,122 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-28 23:38:55,133 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_follow_up.wav
# 2025-10-28 23:38:55,144 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_1_seq.wav
# 2025-10-28 23:38:55,152 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_1_option.wav
# 2025-10-28 23:38:55,162 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_2_seq.wav
# 2025-10-28 23:38:55,172 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_2_option.wav
# 2025-10-28 23:38:55,192 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_3_seq.wav
# 2025-10-28 23:38:55,212 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_3_option.wav
# 2025-10-28 23:38:55,231 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_4_seq.wav
# 2025-10-28 23:38:55,250 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_4_option.wav
# 2025-10-28 23:38:55,972 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_conversation_output.mp3
# 2025-10-28 23:38:58,230 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cfb15c27-b413-11f0-a85a-005056c00008\comprehensive_expression_listen_answer_3_conversation_output.mp3 as blob cfb15c27-b413-11f0-a85a-005056c00008/comprehensive_expression_listen_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>休日にショッピングモールで買い物をしている男女3人が、休憩スペースで話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Male1:</strong> 今日はみんなで来てよかったね。久しぶりにこんなに広いモールに来た気がするよ。</p>
# <p><strong>Female1:</strong> ほんとだね。私は新しい靴を探しているんだけど、どこにいいお店があるかな？</p>
# <p><strong>Male2:</strong> さっき2階にスポーツ用品のお店があったよ。そこは種類も多かったし、店員さんも親切だったよ。</p>
# <p><strong>Female1:</strong> ありがとう。じゃあ、あとで見に行ってみるね。男1は何か買いたいものある？</p>
# <p><strong>Male1:</strong> 僕は本屋に行きたいな。最近、話題の小説を読んでみたくて。</p>
# <p><strong>Male2:</strong> 本屋なら3階にあるよ。カフェも隣にあるから、買った本をすぐ読めるよ。</p>
# <p><strong>Female1:</strong> いいね！みんなでカフェで休憩しながら、買ったものを見せ合うのはどう？</p>
# <p><strong>Male1:</strong> 賛成！それに、カフェで新しい靴を履いてみるのも楽しそうだね。</p>
# <p><strong>Male2:</strong> じゃあ、まず靴屋に行って、それから本屋、最後にカフェに集合しようか。</p>
# <p><strong>Female1:</strong> うん、そうしよう。今日の買い物、すごく楽しみになってきた！</p>
# <p><strong>Male1:</strong> みんなで買い物すると、いろいろな発見があって面白いね。</p>
# <p><strong>Male2:</strong> そうだね。ひとりだと見逃してしまう店も、みんなで歩くと気づくことが多いし。</p>
# <p><strong>Female1:</strong> じゃあ、そろそろ行こうか。</p>
# </div>
# <p><strong>follow-up question: </strong>この会話で、3人は買い物の後に何をする予定ですか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cfb15c27-b413-11f0-a85a-005056c00008/comprehensive_expression_listen_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 映画を見る  </li>
# <li>2. <b>カフェで休憩する  </b> <span style='color:green;'>(correct)</span></li>
# <li>3. レストランで食事する  </li>
# <li>4. 公園を散歩する  </li>
# </ul>
