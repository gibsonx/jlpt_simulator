# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)
# Out:
# '...をはじめとして'

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))
# Out:
# 2025-12-19 14:48:05,698 - INFO - jlpt - ---Generator----
# 2025-12-19 14:48:08,383 - INFO - jlpt - ---REVISOR---
# 2025-12-19 14:48:10,101 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-12-19 14:48:10,102 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-12-19 14:48:10,103 - INFO - jlpt - --- Formatter ---
# 2025-12-19 14:48:10,104 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N2 level.
#
# Task: Your job is to write a question for a JLPT N2 level exam paper.
# You should write a short sentence and ask candidate to identify the correct kanji writing of a given word in hiragana.
# The number of kanji characters in the options must be the same. The kanji characters must be usded in Japanese daily life.
# The word in hiragana being tested needs to be underlined with <u></u>, no other tags can appear in the sentence.
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content.  The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N2 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Words in sentences should not be used in options
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n .
# - By referring the correct answer(c) in the "Historical Generation" during the question generation, you should ensure that the selection of correct answers (4,3,2,1) remains randomly distributed （25% for each）, avoid selecting the same answer(c) continuously
#
# Formal exam paper:
# --- example 1 ---
# <a>この会社を<u>しぼう</u>した理由を教えてください。</a>
# <ul>
#     <li>指望</li>
#     <li>貴望</li>
#     <li>希望</li>
#     <li>志望</li>
# </ul>
#
# --- example 2 ---
# <a>このセーターにはとても<u>やわらかい</u>毛系が使われている。</a>
# <ul>
#     <li>伸らかい</li>
#     <li>軽らかい</li>
#     <li>暖らかい</li>
#     <li>柔らかい</li>
# </ul>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: みかけ
# AI: <a>駅で<u>みかけ</u>た人が友人に似ていました。</a>
# <ul>
#     <li>見掛</li>
#     <li>味掛</li>
#     <li>未掛</li>
#     <li>美掛</li>
# </ul>
# 正解: 1 .
# HUMAN: GOOD ENOUGH
# 2025-12-19 14:48:12,393 - INFO - jlpt - Formatter: {'html_question': '駅で<u>みかけ</u>た人が友人に似ていました。', 'correct_answer': 1, 'choices': ['見掛', '味掛', '未掛', '美掛']}
# <strong>1番.</strong></br></br><p>駅で<u>みかけ</u>た人が友人に似ていました。</p><ul>
# <li>1. <b>見掛</b> <span style='color:green;'>(correct)</span></li>
# <li>2. 味掛</li>
# <li>3. 未掛</li>
# <li>4. 美掛</li>
# </ul>

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.sentence_structure(word=random.choice(topics),grammar=random.choice(grammar))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-12-19 15:06:15,654 - INFO - jlpt - ---Generator----
# 2025-12-19 15:06:24,168 - INFO - jlpt - ---REVISOR---
# 2025-12-19 15:06:26,147 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-12-19 15:06:26,148 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-12-19 15:06:26,150 - INFO - jlpt - --- Formatter ---
# 2025-12-19 15:06:26,151 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是按照以下步骤为JLPT N2级别出一道填入正确内容的语法题。根据语法参考列表中的4个语法点出题
#
# 步骤1：问题的灵感来源"主题"。写一篇日语短文。短文需要符合以下要求：
# - 短文需要有1-3个段落，350-500个词。
# - 确保短文中的词汇95%限制在N2级别。
# - 整段内容需要保证语义通顺，没有语法错误。短文需要包含“语法参考列表”中的语法点。
#
# 步骤2：辨析并优化步骤1中生成的短文。使优化后的短文符合以下几个条件：
# - 短文通篇语义通顺、连贯，表达流畅。
# - 短文的语法正确、时态正确
#
# 步骤3：将步骤2优化后的短文中，提取5个短语，作为题目的正确选项。被提取的5个短语可以是以下几种情况：
# - 连接词或用于连接的短语
# - 助词、副助词
# - 阐述动作的谓语短语，或者作为定语、状语的谓语短语
# 对被提取的5个短语的附加要求：
# - 被提取的5个短语不能再出现在题干中，题干中不能保留被提取的短语
# - 至少有2个短语是谓语短语、至少1个短语是连接词或用于连接的短语、至少1个助词或副助词的短语
#
# 步骤4：提取的5个短语用48/49/50/51/52，这5个标号代替。要求这5个标号需要以“【48】”的形式呈现
# - 提取的5个短语，两两之间不能一样
#
# 步骤5：把步骤3中提取的5个短语分别作为5道题的正确选项的答案，并生成每道题的其他3个选项。生成的选项需要符合以下几个要求：
# - 每道题的3个错误选项要和正确选项有一定相似度，首先保证词性相同。比如正确选项是助词，则其他3个错误选项也必须是助词或副助词
# - 每道题只能有1个正确选项，其他3个选项只能是错误选项
# - 如果是谓语短语，那么其他3个错误选项要和正确选项有一定相似度，可以把动词的形态、时态等做一下调整
#
# 步骤6：把步骤5中生成的每道题的选项，在每道题的范围内打乱顺序。要求：
# - 要求每道题正确选项尽量不同。避免正确答案都是连续同一个选项
#
# 步骤7：生成题目。
# 题目格式：遵循正式试卷中示例的格式，而不是内容。输出必须为html格式，并删除行更改标记
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈和批评（如果存在）,避免重复生成"历史题目"的问题(q)或给出的答案(a)。
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。问题中的单词也不能出现在选项中
# -在输出中显示正确答案，选项为4,3,2,1 随机例如：正解：n, 考虑历史题目的正确答案（c）, 正确答案分布要随机平均（25%），避免重复选同一答案
#
# 历史题目:
# 正式试卷：
# <div class="article">
#   <p style="font-family: 'Hiragino Mincho ProN', 'Yu Mincho', serif; line-height: 1.8; margin-bottom: 1.5em;">
#     以下は、留学生がスピーチのために書いた文章である
#   </p>
#
#   <div style="border: 1px solid #000; padding: 20px; margin-bottom: 20px; font-family: 'Hiragino Mincho ProN', 'Yu Mincho', serif; line-height: 1.8;">
#     <div style="text-align: center; font-size: 1.5em; font-weight: bold; margin-bottom: 10px;">
#       紅葉の異変
#     </div>
#
#     <div style="text-align: right; margin-bottom: 20px;">
#       サリム ソフィア
#     </div>
#
#     <p style="margin-bottom: 1.5em;">
#       私は日本の秋の景色が好きです。秋になって紅葉が始まり、緑だった葉が黄色やオレンジ、赤に変わると、とてもきれいです。秋の紅葉は、日本の四季の変化を感じさせてくれるものです。
#     </p>
#
#     <p style="margin-bottom: 1.5em;">
#       【48】ですが、先日テレビで、紅葉がピークを迎える時期が年々遅くなっているというニュースを見ました。中には、1月になってからピークを迎えたところもあるそうで、驚きました。温暖化によって平均気温が上昇していることが大きな原因だそうです。私は、夏が過ぎて気温が下がってくれば、必ず紅葉が始まると思っていました。【49】そうではありませんでした。紅葉には、条件となる気温の変化があります。
#     </p>
#
#     <p style="margin-bottom: 1.5em;">
#       葉の変色が始まるのは、1日の最低気温が大体8度以下になってからです。秋になっても、最低気温が一定の気温まで下がらなければ、紅葉は【50】その後、さらに寒くなり、5～6度まで下がると、紅葉は一気に進みます。また、5度以下の日が続くと、最も美しい新葉が見られるといわれています。
#     </p>
#
#     <p style="margin-bottom: 1.5em;">
#       紅葉に起きている異変を知り、このまま温暖化が進むと、日本の秋の景色が変わってしまう可能性もあるのではないかと思いました。もしかしたら、紅葉自体が見られなくなる日も来るかもしれません。紅葉を通して、温暖化が身近な問題であることをより強く【51】
#     </p>
#   </div>
# </div>
#
# <div class="follow-up">
#     <a><strong>48</strong></a>
#     <div class="options">
#         <li>そこの紅葉</li>
#         <li>そんな紅葉</li>
#         <li>そちら</li>
#         <li>紅葉</li>
#     </div>
#
#     <a><strong>49</strong></a>
#     <div class="options">
#         <li>結局</li>
#         <li>確かに</li>
#         <li>しかし</li>
#         <li>つまり</li>
#
#     <p><strong>50</strong></p>
#     <div class="options">
#         <li>始まらないのです</li>
#         <li>始まらないためです</li>
#         <li>始まらないのでしょうか</li>
#         <li>始まらないためでしょうか</li>
#     </div>
#
#     <p><strong>51</strong></p>
#     <div class="options">
#         <li>1. 感じているからだと思います</li>
#         <li>感じられるところだと思います</li>
#         <li>感じさせることができました</li>
#         <li>感じるようになりました</li>
#     </div>
# </div>
#
#
# 语法参考列表：...わけにはいかない
#
# HUMAN: Generate a JLPT question regarding Topic: 季節のイベントや活動について話す
# AI: <div class="article">
#   <p style="font-family: 'Hiragino Mincho ProN', 'Yu Mincho', serif; line-height: 1.8; margin-bottom: 1.5em;">
#     以下は、留学生がスピーチのために書いた文章である
#   </p>
#
#   <div style="border: 1px solid #000; padding: 20px; margin-bottom: 20px; font-family: 'Hiragino Mincho ProN', 'Yu Mincho', serif; line-height: 1.8;">
#     <div style="text-align: center; font-size: 1.5em; font-weight: bold; margin-bottom: 10px;">
#       季節のイベントと日本の文化
#     </div>
#
#     <div style="text-align: right; margin-bottom: 20px;">
#       リー ミン
#     </div>
#
#     <p style="margin-bottom: 1.5em;">
#       日本には四季があり、それぞれの季節に様々なイベントや活動があります。春には花見、夏には花火大会や盆踊り、秋には紅葉狩り、冬には雪祭りなど、季節ごとに楽しみ方が違います。【48】、私は春の花見が特に好きです。桜が咲く時期になると、友達と公園で集まってお弁当を食べたり、写真を撮ったりします。桜の下で過ごす時間は、毎年の大切な思い出になっています。
#     </p>
#
#     <p style="margin-bottom: 1.5em;">
#       花見は日本の伝統的なイベントですが、最近はごみの問題や騒音などのマナーが話題になっています。桜の美しさを守るためにも、ルールを守って楽しむことが大切だと思います。【49】、私は去年、友達と花見をしたとき、近くに住んでいる人の迷惑にならないように静かに過ごすよう心がけました。みんなで協力してごみを持ち帰ることも忘れませんでした。
#     </p>
#
#     <p style="margin-bottom: 1.5em;">
#       また、夏になると花火大会に行くのも楽しみの一つです。多くの人が集まるので、混雑や交通の問題もありますが、きれいな花火を見ると、夏の暑さも忘れてしまいます。日本の季節のイベントは、自然と人との関わりを感じることができる素晴らしい文化だと思います。これからも、伝統を大切にしながら、マナーを守って参加していきたいです。【50】、友達に誘われても、どうしても忙しい時は参加する【51】。しかし、できるだけ多くのイベントに参加して、日本の季節を楽しみたいと思っています。
#     </p>
#   </div>
# </div>
#
# <div class="follow-up">
#     <a><strong>48</strong></a>
#     <div class="options">
#         <li>それにしても</li>
#         <li>それなのに</li>
#         <li>そのため</li>
#         <li>例えば</li>
#     </div>
#
#     <a><strong>49</strong></a>
#     <div class="options">
#         <li>その結果</li>
#         <li>その上</li>
#         <li>例えば</li>
#         <li>また</li>
#     </div>
#
#     <a><strong>50</strong></a>
#     <div class="options">
#         <li>とはいえ</li>
#         <li>それでも</li>
#         <li>けれども</li>
#         <li>だから</li>
#     </div>
#
#     <a><strong>51</strong></a>
#     <div class="options">
#         <li>わけにはいかないのです</li>
#         <li>わけにはいかないでしょう</li>
#         <li>わけにはいかないかもしれません</li>
#         <li>わけにはいかないと思います</li>
#     </div>
# </div>
#
# 正解：4,1,2,3
# HUMAN: GOOD ENOUGH
# 2025-12-19 15:06:36,570 - INFO - jlpt - Formatter: {'html_article': '<p style="font-family: \'Hiragino Mincho ProN\', \'Yu Mincho\', serif; line-height: 1.8; margin-bottom: 1.5em;">    以下は、留学生がスピーチのために書いた文章である  </p>  <div style="border: 1px solid #000; padding: 20px; margin-bottom: 20px; font-family: \'Hiragino Mincho ProN\', \'Yu Mincho\', serif; line-height: 1.8;">    <div style="text-align: center; font-size: 1.5em; font-weight: bold; margin-bottom: 10px;">      季節のイベントと日本の文化    </div>    <div style="text-align: right; margin-bottom: 20px;">      リー ミン    </div>    <p style="margin-bottom: 1.5em;">      日本には四季があり、それぞれの季節に様々なイベントや活動があります。春には花見、夏には花火大会や盆踊り、秋には紅葉狩り、冬には雪祭りなど、季節ごとに楽しみ方が違います。【48】、私は春の花見が特に好きです。桜が咲く時期になると、友達と公園で集まってお弁当を食べたり、写真を撮ったりします。桜の下で過ごす時間は、毎年の大切な思い出になっています。    </p>    <p style="margin-bottom: 1.5em;">      花見は日本の伝統的なイベントですが、最近はごみの問題や騒音などのマナーが話題になっています。桜の美しさを守るためにも、ルールを守って楽しむことが大切だと思います。【49】、私は去年、友達と花見をしたとき、近くに住んでいる人の迷惑にならないように静かに過ごすよう心がけました。みんなで協力してごみを持ち帰ることも忘れませんでした。    </p>    <p style="margin-bottom: 1.5em;">      また、夏になると花火大会に行くのも楽しみの一つです。多くの人が集まるので、混雑や交通の問題もありますが、きれいな花火を見ると、夏の暑さも忘れてしまいます。日本の季節のイベントは、自然と人との関わりを感じることができる素晴らしい文化だと思います。これからも、伝統を大切にしながら、マナーを守って参加していきたいです。【50】、友達に誘われても、どうしても忙しい時は参加する【51】。しかし、できるだけ多くのイベントに参加して、日本の季節を楽しみたいと思っています。    </p>  </div>', 'questions': [{'html_question': '<strong>48</strong>', 'choices': ['それにしても', 'それなのに', 'そのため', '例えば'], 'correct_answer': 4}, {'html_question': '<strong>49</strong>', 'choices': ['その結果', 'その上', '例えば', 'また'], 'correct_answer': 1}, {'html_question': '<strong>50</strong>', 'choices': ['とはいえ', 'それでも', 'けれども', 'だから'], 'correct_answer': 2}, {'html_question': '<strong>51</strong>', 'choices': ['わけにはいかないのです', 'わけにはいかないでしょう', 'わけにはいかないかもしれません', 'わけにはいかないと思います'], 'correct_answer': 3}]}
# <strong>1番.</strong></br></br><p style="font-family: 'Hiragino Mincho ProN', 'Yu Mincho', serif; line-height: 1.8; margin-bottom: 1.5em;">    以下は、留学生がスピーチのために書いた文章である  </p>  <div style="border: 1px solid #000; padding: 20px; margin-bottom: 20px; font-family: 'Hiragino Mincho ProN', 'Yu Mincho', serif; line-height: 1.8;">    <div style="text-align: center; font-size: 1.5em; font-weight: bold; margin-bottom: 10px;">      季節のイベントと日本の文化    </div>    <div style="text-align: right; margin-bottom: 20px;">      リー ミン    </div>    <p style="margin-bottom: 1.5em;">      日本には四季があり、それぞれの季節に様々なイベントや活動があります。春には花見、夏には花火大会や盆踊り、秋には紅葉狩り、冬には雪祭りなど、季節ごとに楽しみ方が違います。【48】、私は春の花見が特に好きです。桜が咲く時期になると、友達と公園で集まってお弁当を食べたり、写真を撮ったりします。桜の下で過ごす時間は、毎年の大切な思い出になっています。    </p>    <p style="margin-bottom: 1.5em;">      花見は日本の伝統的なイベントですが、最近はごみの問題や騒音などのマナーが話題になっています。桜の美しさを守るためにも、ルールを守って楽しむことが大切だと思います。【49】、私は去年、友達と花見をしたとき、近くに住んでいる人の迷惑にならないように静かに過ごすよう心がけました。みんなで協力してごみを持ち帰ることも忘れませんでした。    </p>    <p style="margin-bottom: 1.5em;">      また、夏になると花火大会に行くのも楽しみの一つです。多くの人が集まるので、混雑や交通の問題もありますが、きれいな花火を見ると、夏の暑さも忘れてしまいます。日本の季節のイベントは、自然と人との関わりを感じることができる素晴らしい文化だと思います。これからも、伝統を大切にしながら、マナーを守って参加していきたいです。【50】、友達に誘われても、どうしても忙しい時は参加する【51】。しかし、できるだけ多くのイベントに参加して、日本の季節を楽しみたいと思っています。    </p>  </div>
# <p><strong>1.<strong>48</strong></strong></p>
# <ul>
# <li>それにしても</li>
# <li>それなのに</li>
# <li>そのため</li>
# <li><b>例えば</b> <span style='color:green;'>(correct)</span></li>
# </ul>
# <p><strong>2.<strong>49</strong></strong></p>
# <ul>
# <li><b>その結果</b> <span style='color:green;'>(correct)</span></li>
# <li>その上</li>
# <li>例えば</li>
# <li>また</li>
# </ul>
# <p><strong>3.<strong>50</strong></strong></p>
# <ul>
# <li>とはいえ</li>
# <li><b>それでも</b> <span style='color:green;'>(correct)</span></li>
# <li>けれども</li>
# <li>だから</li>
# </ul>
# <p><strong>4.<strong>51</strong></strong></p>
# <ul>
# <li>わけにはいかないのです</li>
# <li>わけにはいかないでしょう</li>
# <li><b>わけにはいかないかもしれません</b> <span style='color:green;'>(correct)</span></li>
# <li>わけにはいかないと思います</li>
# </ul>

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_read(random.choice(topics))
display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
# display(HTML(_render_result(result=content)))

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))
