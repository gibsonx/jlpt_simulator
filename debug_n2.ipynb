# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-09 21:46:24,919 - INFO - jlpt - ---Generator----
# 2025-11-09 21:46:30,726 - INFO - jlpt - ---REVISOR---
# 2025-11-09 21:46:31,274 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-09 21:46:31,275 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-09 21:46:31,277 - INFO - jlpt - --- Formatter ---
# 2025-11-09 21:46:31,277 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问1个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# - 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# - 女1: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# - 男1: 市の方針でゴミ箱は置かないことになってるからね。
# - 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# - 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# - 女1: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# - 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# - 女1: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# - 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: レストランで食べ物を注文する
# AI: <p class='background'>友達3人がレストランで昼ご飯を注文しようとしています。</p>
#
# <div class='conversation'>
# - 女1: 今日は何を食べようかな。メニューがたくさんあって迷っちゃうね。
# - 男1: 本当だね。僕はパスタにしようかなと思ってるけど、どれも美味しそうで決められないよ。
# - 男2: 僕はカレーにしようかな。ここのカレーは辛さが選べるみたいだよ。
# - 女1: へえ、そうなんだ。私はサラダセットにしようかな。でも、スープも付けたいな。
# - 男1: サラダセットにスープを追加できるみたいだよ。メニューの下に書いてあるよ。
# - 女1: ありがとう。じゃあ、そうするね。ドリンクはどうする？
# - 男2: 僕はアイスコーヒーにする。暑いから冷たい飲み物がいいな。
# - 男1: 僕も同じにしようかな。でも、デザートも頼もうかな。ケーキセットがあるみたいだし。
# - 女1: いいね。みんなでデザートをシェアしようか？
# - 男2: それはいいアイデアだね。じゃあ、ケーキセットを一つ頼んでみんなで分けよう。
# - 男1: そうしよう。じゃあ、注文しようか。
# </div>
# <a class='follow_up'>3人はどのようにデザートを食べることにしましたか。</a>
# <ul class='options'>
#     <li>それぞれ自分のデザートを注文する</li>
#     <li>デザートは注文しない</li>
#     <li>一つのデザートをみんなで分ける</li>
#     <li>デザートを持ち帰る</li>
# </ul>
# 正解:3
# HUMAN: GOOD ENOUGH
# 2025-11-09 21:46:33,870 - INFO - jlpt - Formatter: {'background': '友達3人がレストランで昼ご飯を注文しようとしています。', 'conversation': [{'gender': 'female1', 'context': '今日は何を食べようかな。メニューがたくさんあって迷っちゃうね。'}, {'gender': 'male1', 'context': '本当だね。僕はパスタにしようかなと思ってるけど、どれも美味しそうで決められないよ。'}, {'gender': 'male2', 'context': '僕はカレーにしようかな。ここのカレーは辛さが選べるみたいだよ。'}, {'gender': 'female1', 'context': 'へえ、そうなんだ。私はサラダセットにしようかな。でも、スープも付けたいな。'}, {'gender': 'male1', 'context': 'サラダセットにスープを追加できるみたいだよ。メニューの下に書いてあるよ。'}, {'gender': 'female1', 'context': 'ありがとう。じゃあ、そうするね。ドリンクはどうする？'}, {'gender': 'male2', 'context': '僕はアイスコーヒーにする。暑いから冷たい飲み物がいいな。'}, {'gender': 'male1', 'context': '僕も同じにしようかな。でも、デザートも頼もうかな。ケーキセットがあるみたいだし。'}, {'gender': 'female1', 'context': 'いいね。みんなでデザートをシェアしようか？'}, {'gender': 'male2', 'context': 'それはいいアイデアだね。じゃあ、ケーキセットを一つ頼んでみんなで分けよう。'}, {'gender': 'male1', 'context': 'そうしよう。じゃあ、注文しようか。'}], 'follow_up': '3人はどのようにデザートを食べることにしましたか。', 'choices': ['それぞれ自分のデザートを注文する', 'デザートは注文しない', '一つのデザートをみんなで分ける', 'デザートを持ち帰る'], 'correct_answer': 3}
# 2025-11-09 21:47:31,525 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-09 21:47:31,532 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1.wav
# 2025-11-09 21:47:31,544 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-09 21:47:31,546 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_background.wav
# 2025-11-09 21:47:31,557 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-09 21:47:31,559 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_0_speaker.wav
# 2025-11-09 21:47:31,572 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_1_speaker.wav
# 2025-11-09 21:47:31,588 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_2_speaker.wav
# 2025-11-09 21:47:31,602 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_3_speaker.wav
# 2025-11-09 21:47:31,618 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_4_speaker.wav
# 2025-11-09 21:47:31,630 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_5_speaker.wav
# 2025-11-09 21:47:31,644 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_6_speaker.wav
# 2025-11-09 21:47:31,658 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_7_speaker.wav
# 2025-11-09 21:47:31,674 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_8_speaker.wav
# 2025-11-09 21:47:31,689 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_9_speaker.wav
# 2025-11-09 21:47:31,709 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_10_speaker.wav
# 2025-11-09 21:47:31,724 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-09 21:47:31,729 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_follow_up.wav
# 2025-11-09 21:47:31,745 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_1_seq.wav
# 2025-11-09 21:47:31,764 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_1_option.wav
# 2025-11-09 21:47:31,786 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_2_seq.wav
# 2025-11-09 21:47:31,803 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_2_option.wav
# 2025-11-09 21:47:31,819 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_3_seq.wav
# 2025-11-09 21:47:31,836 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_3_option.wav
# 2025-11-09 21:47:31,857 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_4_seq.wav
# 2025-11-09 21:47:31,871 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_4_option.wav
# 2025-11-09 21:47:32,483 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_conversation_output.mp3
# 2025-11-09 21:47:35,669 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_listen_answer_1_conversation_output.mp3 as blob 7bb01d3a-bd72-11f0-b36e-005056c00008/comprehensive_expression_listen_answer_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>友達3人がレストランで昼ご飯を注文しようとしています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 今日は何を食べようかな。メニューがたくさんあって迷っちゃうね。</p>
# <p><strong>Male1:</strong> 本当だね。僕はパスタにしようかなと思ってるけど、どれも美味しそうで決められないよ。</p>
# <p><strong>Male2:</strong> 僕はカレーにしようかな。ここのカレーは辛さが選べるみたいだよ。</p>
# <p><strong>Female1:</strong> へえ、そうなんだ。私はサラダセットにしようかな。でも、スープも付けたいな。</p>
# <p><strong>Male1:</strong> サラダセットにスープを追加できるみたいだよ。メニューの下に書いてあるよ。</p>
# <p><strong>Female1:</strong> ありがとう。じゃあ、そうするね。ドリンクはどうする？</p>
# <p><strong>Male2:</strong> 僕はアイスコーヒーにする。暑いから冷たい飲み物がいいな。</p>
# <p><strong>Male1:</strong> 僕も同じにしようかな。でも、デザートも頼もうかな。ケーキセットがあるみたいだし。</p>
# <p><strong>Female1:</strong> いいね。みんなでデザートをシェアしようか？</p>
# <p><strong>Male2:</strong> それはいいアイデアだね。じゃあ、ケーキセットを一つ頼んでみんなで分けよう。</p>
# <p><strong>Male1:</strong> そうしよう。じゃあ、注文しようか。</p>
# </div>
# <p><strong>follow-up question: </strong>3人はどのようにデザートを食べることにしましたか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/7bb01d3a-bd72-11f0-b36e-005056c00008/comprehensive_expression_listen_answer_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. それぞれ自分のデザートを注文する</li>
# <li>2. デザートは注文しない</li>
# <li>3. <b>一つのデザートをみんなで分ける</b> <span style='color:green;'>(correct)</span></li>
# <li>4. デザートを持ち帰る</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-09 21:47:35,678 - INFO - jlpt - ---Generator----
# 2025-11-09 21:47:45,991 - INFO - jlpt - ---REVISOR---
# 2025-11-09 21:47:46,530 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-09 21:47:46,532 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-09 21:47:46,534 - INFO - jlpt - --- Formatter ---
# 2025-11-09 21:47:46,534 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问2个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。</p>
#
# <div class='conversation'>
# - 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方なども教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方も楽しめいただけます。西会場では、新鮮な魚介類を販売しています。
# - 女2: 新鮮な魚、おいしそう。なくなり前に早く行かなきゃ？
# - 男1: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# - 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# - 男1: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、買い物は最後にしようよ。
# - 女2: いいよ。釣りはいいの？
# - 男1: うーん、初心者向けって言ってたから今日は初めてていいかな。
# </div>
# <a class='follow_up'>質問1: 2人は最初にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
# <a class='follow_up'>質問2: 2人は2番目にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
#
#
#
# HUMAN: Generate a JLPT question regarding Topic: 異文化交流について話す
# AI: <p class='background'>大学のカフェテリアで、異文化交流イベントについて三人が話しています。</p>
#
# <div class='conversation'>
# - 女1: 昨日の異文化交流イベント、みんな参加した？
# - 男1: うん、行ったよ。初めて外国の人とじっくり話したけど、すごく楽しかった。特に、食べ物の話で盛り上がったんだ。
# - 女2: 私も行ったよ。韓国の学生と一緒に伝統的な遊びを体験したの。日本と似ているところもあって、びっくりした。
# - 男1: そうなんだ。僕はイタリアの学生と話したんだけど、食事のマナーが全然違うって言ってた。例えば、パスタを食べるときに音を立てないようにするらしいよ。
# - 女1: へえ、面白いね。私はアメリカの学生と話したけど、家族の集まり方が日本と違うって言ってた。日本はお正月に親戚が集まるけど、アメリカはクリスマスが一番大事みたい。
# - 女2: 文化の違いって、実際に話してみないと分からないことが多いよね。昨日のイベントで、もっと海外に興味が湧いたよ。
# - 男1: 僕も。今度は自分から話しかけてみたいな。最初は緊張したけど、みんな優しかったし、言葉が通じなくてもジェスチャーで伝えられることも多かった。
# - 女1: そうだね。異文化交流って、言葉だけじゃなくて、気持ちも大事だと思う。来月もイベントがあるみたいだから、また参加しようよ。
# - 女2: 賛成！次はもっといろんな国の人と話してみたいな。
# </div>
#
# <a class='follow_up'>質問1: 男1は異文化交流イベントでどんなことに驚きましたか？</a>
# <ul class='options'>
#     <li>遊び方が似ていること</li>
#     <li>食事のマナーが違うこと</li>
#     <li>家族の集まり方が違うこと</li>
#     <li>言葉が通じないこと</li>
# </ul>
# 正解:2
#
# <a class='follow_up'>質問2: 女2はイベントに参加してどう感じましたか？</a>
# <ul class='options'>
#     <li>海外に興味がなくなった</li>
#     <li>言葉が通じなくて困った</li>
#     <li>海外にもっと興味を持った</li>
#     <li>イベントに参加しなかった</li>
# </ul>
# 正解:3
# HUMAN: GOOD ENOUGH
# 2025-11-09 21:47:50,301 - INFO - jlpt - Formatter: {'background': '大学のカフェテリアで、異文化交流イベントについて三人が話しています。', 'conversation': [{'gender': 'female1', 'context': '昨日の異文化交流イベント、みんな参加した？'}, {'gender': 'male1', 'context': 'うん、行ったよ。初めて外国の人とじっくり話したけど、すごく楽しかった。特に、食べ物の話で盛り上がったんだ。'}, {'gender': 'female2', 'context': '私も行ったよ。韓国の学生と一緒に伝統的な遊びを体験したの。日本と似ているところもあって、びっくりした。'}, {'gender': 'male1', 'context': 'そうなんだ。僕はイタリアの学生と話したんだけど、食事のマナーが全然違うって言ってた。例えば、パスタを食べるときに音を立てないようにするらしいよ。'}, {'gender': 'female1', 'context': 'へえ、面白いね。私はアメリカの学生と話したけど、家族の集まり方が日本と違うって言ってた。日本はお正月に親戚が集まるけど、アメリカはクリスマスが一番大事みたい。'}, {'gender': 'female2', 'context': '文化の違いって、実際に話してみないと分からないことが多いよね。昨日のイベントで、もっと海外に興味が湧いたよ。'}, {'gender': 'male1', 'context': '僕も。今度は自分から話しかけてみたいな。最初は緊張したけど、みんな優しかったし、言葉が通じなくてもジェスチャーで伝えられることも多かった。'}, {'gender': 'female1', 'context': 'そうだね。異文化交流って、言葉だけじゃなくて、気持ちも大事だと思う。来月もイベントがあるみたいだから、また参加しようよ。'}, {'gender': 'female2', 'context': '賛成！次はもっといろんな国の人と話してみたいな。'}], 'listen_questions': [{'follow_up': '質問1: 男1は異文化交流イベントでどんなことに驚きましたか？', 'correct_answer': 2, 'choices': ['遊び方が似ていること', '食事のマナーが違うこと', '家族の集まり方が違うこと', '言葉が通じないこと']}, {'follow_up': '質問2: 女2はイベントに参加してどう感じましたか？', 'correct_answer': 3, 'choices': ['海外に興味がなくなった', '言葉が通じなくて困った', '海外にもっと興味を持った', 'イベントに参加しなかった']}]}
# 2025-11-09 21:48:25,363 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-09 21:48:25,365 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3.wav
# 2025-11-09 21:48:25,379 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-09 21:48:25,381 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_background.wav
# 2025-11-09 21:48:25,395 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-09 21:48:25,397 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-11-09 21:48:25,410 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-11-09 21:48:25,426 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-11-09 21:48:25,441 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-11-09 21:48:25,459 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-11-09 21:48:25,476 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-11-09 21:48:25,494 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-11-09 21:48:25,518 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-11-09 21:48:25,540 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_8_speaker.wav
# 2025-11-09 21:48:25,557 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-09 21:48:25,565 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_1_follow_up.wav
# 2025-11-09 21:48:25,582 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-09 21:48:25,593 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-09 21:48:25,602 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_2_follow_up.wav
# 2025-11-09 21:48:25,620 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-09 21:48:26,383 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-11-09 21:48:28,826 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\7bb01d3a-bd72-11f0-b36e-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob 7bb01d3a-bd72-11f0-b36e-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学のカフェテリアで、異文化交流イベントについて三人が話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 昨日の異文化交流イベント、みんな参加した？</p>
# <p><strong>Male1:</strong> うん、行ったよ。初めて外国の人とじっくり話したけど、すごく楽しかった。特に、食べ物の話で盛り上がったんだ。</p>
# <p><strong>Female2:</strong> 私も行ったよ。韓国の学生と一緒に伝統的な遊びを体験したの。日本と似ているところもあって、びっくりした。</p>
# <p><strong>Male1:</strong> そうなんだ。僕はイタリアの学生と話したんだけど、食事のマナーが全然違うって言ってた。例えば、パスタを食べるときに音を立てないようにするらしいよ。</p>
# <p><strong>Female1:</strong> へえ、面白いね。私はアメリカの学生と話したけど、家族の集まり方が日本と違うって言ってた。日本はお正月に親戚が集まるけど、アメリカはクリスマスが一番大事みたい。</p>
# <p><strong>Female2:</strong> 文化の違いって、実際に話してみないと分からないことが多いよね。昨日のイベントで、もっと海外に興味が湧いたよ。</p>
# <p><strong>Male1:</strong> 僕も。今度は自分から話しかけてみたいな。最初は緊張したけど、みんな優しかったし、言葉が通じなくてもジェスチャーで伝えられることも多かった。</p>
# <p><strong>Female1:</strong> そうだね。異文化交流って、言葉だけじゃなくて、気持ちも大事だと思う。来月もイベントがあるみたいだから、また参加しようよ。</p>
# <p><strong>Female2:</strong> 賛成！次はもっといろんな国の人と話してみたいな。</p>
# </div>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/7bb01d3a-bd72-11f0-b36e-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <p><strong>1.質問1: 男1は異文化交流イベントでどんなことに驚きましたか？</strong></p>
# <ul>
# <li>遊び方が似ていること</li>
# <li><b>食事のマナーが違うこと</b> <span style='color:green;'>(correct)</span></li>
# <li>家族の集まり方が違うこと</li>
# <li>言葉が通じないこと</li>
# </ul>
# <p><strong>2.質問2: 女2はイベントに参加してどう感じましたか？</strong></p>
# <ul>
# <li>海外に興味がなくなった</li>
# <li>言葉が通じなくて困った</li>
# <li><b>海外にもっと興味を持った</b> <span style='color:green;'>(correct)</span></li>
# <li>イベントに参加しなかった</li>
# </ul>
