# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-30 15:19:15,836 - INFO - jlpt - ---Generator----
# 2025-10-30 15:19:26,833 - INFO - jlpt - ---REVISOR---
# 2025-10-30 15:19:27,163 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-30 15:19:27,164 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-30 15:19:27,167 - INFO - jlpt - --- Formatter ---
# 2025-10-30 15:19:27,167 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问一个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# 女: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# 男1: 市の方針でゴミ箱は置かないことになってるからね。
# 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。
# 他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# 女: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# 女: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。
# 花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 友人との日常会話
# AI: <p class='background'>大学の友人3人が昼休みにカフェで話しています。</p>
#
# <div class='conversation'>
# 女1: 今日の授業、難しかったね。先生の説明、ちょっと早すぎた気がするけど、二人はどうだった？
# 男: 僕もそう思ったよ。特に最後の部分、全然ノートが追いつかなかった。家で復習しないとダメだな。
# 女2: 私は録音しておいたから、後で聞き直すつもり。最近、授業中に録音する人が増えてるよね。
# 女1: いいアイデアだね。私も次から録音しようかな。でも、先生に聞いてからの方がいいかな？
# 男: うん、先生によっては録音を嫌がる人もいるみたいだし、確認した方が安心だよ。
# 女2: そうだね。あと、分からなかったところは、みんなで集まって話し合うのもいいと思うよ。グループで勉強すると、意外と理解が深まることが多いし。
# 女1: じゃあ、今週の金曜日、みんなで集まって復習しない？カフェで勉強するのも楽しいし。
# 男: 賛成！金曜日なら予定が空いてるよ。みんなでやれば、きっと効率も良くなるね。
# 女2: 私も大丈夫。じゃあ、金曜日の午後に決まりだね。録音も持ってくるよ。
# 女1: ありがとう！みんなで頑張ろうね。
# </div>
# <a class='follow_up'>この会話で、友人たちは何をすることに決めましたか？</a>
# <ul class='options'>
#     <li>授業の録音を先生に渡すこと</li>
#     <li>金曜日に集まって復習すること</li>
#     <li>授業のノートを交換すること</li>
#     <li>先生に質問しに行くこと</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-10-30 15:19:31,016 - INFO - jlpt - Formatter: {'background': '大学の友人3人が昼休みにカフェで話しています。', 'follow_up': 'この会話で、友人たちは何をすることに決めましたか？', 'conversation': [{'gender': 'female1', 'context': '今日の授業、難しかったね。先生の説明、ちょっと早すぎた気がするけど、二人はどうだった？'}, {'gender': 'male1', 'context': '僕もそう思ったよ。特に最後の部分、全然ノートが追いつかなかった。家で復習しないとダメだな。'}, {'gender': 'female2', 'context': '私は録音しておいたから、後で聞き直すつもり。最近、授業中に録音する人が増えてるよね。'}, {'gender': 'female1', 'context': 'いいアイデアだね。私も次から録音しようかな。でも、先生に聞いてからの方がいいかな？'}, {'gender': 'male1', 'context': 'うん、先生によっては録音を嫌がる人もいるみたいだし、確認した方が安心だよ。'}, {'gender': 'female2', 'context': 'そうだね。あと、分からなかったところは、みんなで集まって話し合うのもいいと思うよ。グループで勉強すると、意外と理解が深まることが多いし。'}, {'gender': 'female1', 'context': 'じゃあ、今週の金曜日、みんなで集まって復習しない？カフェで勉強するのも楽しいし。'}, {'gender': 'male1', 'context': '賛成！金曜日なら予定が空いてるよ。みんなでやれば、きっと効率も良くなるね。'}, {'gender': 'female2', 'context': '私も大丈夫。じゃあ、金曜日の午後に決まりだね。録音も持ってくるよ。'}, {'gender': 'female1', 'context': 'ありがとう！みんなで頑張ろうね。'}], 'choices': ['授業の録音を先生に渡すこと', '金曜日に集まって復習すること', '授業のノートを交換すること', '先生に質問しに行くこと'], 'correct_answer': 2}
# 2025-10-30 15:19:37,692 - INFO - jlpt - /root/jlpt_simulator/voice/ding.wav
# 2025-10-30 15:19:37,695 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3.wav
# 2025-10-30 15:19:37,697 - INFO - jlpt - /root/jlpt_simulator/voice/empty_1s.wav
# 2025-10-30 15:19:37,700 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_background.wav
# 2025-10-30 15:19:37,705 - INFO - jlpt - /root/jlpt_simulator/voice/empty_1s.wav
# 2025-10-30 15:19:37,706 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_follow_up.wav
# 2025-10-30 15:19:37,712 - INFO - jlpt - /root/jlpt_simulator/voice/empty_1s.wav
# 2025-10-30 15:19:37,714 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-10-30 15:19:37,721 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-10-30 15:19:37,730 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-10-30 15:19:37,741 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-10-30 15:19:37,750 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-10-30 15:19:37,759 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-10-30 15:19:37,773 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-10-30 15:19:37,785 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-10-30 15:19:37,796 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_8_speaker.wav
# 2025-10-30 15:19:37,808 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_9_speaker.wav
# 2025-10-30 15:19:37,821 - INFO - jlpt - /root/jlpt_simulator/voice/ding.wav
# 2025-10-30 15:19:37,836 - INFO - jlpt - /root/jlpt_simulator/tmp/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_follow_up.wav
# 2025-10-30 15:19:39,323 - INFO - jlpt - Conversation audio saved as /root/jlpt_simulator/output/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-10-30 15:19:39,535 - INFO - jlpt - ✅ Uploaded /root/jlpt_simulator/output/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_conversation_output.mp3 as blob cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の友人3人が昼休みにカフェで話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 今日の授業、難しかったね。先生の説明、ちょっと早すぎた気がするけど、二人はどうだった？</p>
# <p><strong>Male1:</strong> 僕もそう思ったよ。特に最後の部分、全然ノートが追いつかなかった。家で復習しないとダメだな。</p>
# <p><strong>Female2:</strong> 私は録音しておいたから、後で聞き直すつもり。最近、授業中に録音する人が増えてるよね。</p>
# <p><strong>Female1:</strong> いいアイデアだね。私も次から録音しようかな。でも、先生に聞いてからの方がいいかな？</p>
# <p><strong>Male1:</strong> うん、先生によっては録音を嫌がる人もいるみたいだし、確認した方が安心だよ。</p>
# <p><strong>Female2:</strong> そうだね。あと、分からなかったところは、みんなで集まって話し合うのもいいと思うよ。グループで勉強すると、意外と理解が深まることが多いし。</p>
# <p><strong>Female1:</strong> じゃあ、今週の金曜日、みんなで集まって復習しない？カフェで勉強するのも楽しいし。</p>
# <p><strong>Male1:</strong> 賛成！金曜日なら予定が空いてるよ。みんなでやれば、きっと効率も良くなるね。</p>
# <p><strong>Female2:</strong> 私も大丈夫。じゃあ、金曜日の午後に決まりだね。録音も持ってくるよ。</p>
# <p><strong>Female1:</strong> ありがとう！みんなで頑張ろうね。</p>
# </div>
# <p><strong>follow-up question: </strong>この会話で、友人たちは何をすることに決めましたか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cbf555bf-b5a3-11f0-8e54-7c1e526b3a9f/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 授業の録音を先生に渡すこと</li>
# <li>2. <b>金曜日に集まって復習すること</b> <span style='color:green;'>(correct)</span></li>
# <li>3. 授業のノートを交換すること</li>
# <li>4. 先生に質問しに行くこと</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
