# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-14 22:22:12,672 - INFO - jlpt - ---Generator----
# 2025-11-14 22:22:18,747 - INFO - jlpt - ---REVISOR---
# 2025-11-14 22:22:19,360 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-14 22:22:19,361 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-14 22:22:19,364 - INFO - jlpt - --- Formatter ---
# 2025-11-14 22:22:19,366 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问1个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# - 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# - 女1: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# - 男1: 市の方針でゴミ箱は置かないことになってるからね。
# - 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# - 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# - 女1: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# - 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# - 女1: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# - 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 天気の状況について話す
# AI: <p class='background'>大学の友人3人が週末の旅行について話しています。</p>
#
# <div class='conversation'>
# - 女1: 今週末、みんなで山に行く予定だけど、天気がちょっと心配だね。昨日の予報では雨が降るかもしれないって言ってたよ。
# - 男1: そうなんだ。僕もさっき天気アプリを見たけど、午前中は曇りで午後から雨になるみたいだよ。山道は滑りやすくなるから、気をつけないとね。
# - 男2: 雨が強くなったら、無理しないで途中で引き返した方がいいと思うよ。安全第一だし。
# - 女1: そうだね。もし雨が降ったら、近くの温泉に行くのもいいかも。みんなでゆっくりできるし。
# - 男1: それもいいね。温泉なら天気に関係なく楽しめるし、雨の日は空いてるかもしれないね。
# - 男2: じゃあ、当日の朝にもう一度天気を確認して、山に行くか温泉にするか決めようか。
# - 女1: うん、それが一番いいと思う。みんなで無理せず楽しもうね。
# - 男1: 了解。じゃあ、朝に連絡し合おう。
# </div>
#
# <a class='follow_up'>この会話の中で、雨が降った場合、みんなはどうすることにしましたか？</a>
# <ul class='options'>
#     <li>山に登るのをやめて温泉に行く</li>
#     <li>雨でも山に登る</li>
#     <li>家に帰る</li>
#     <li>公園で遊ぶ</li>
# </ul>
# 正解:1
# HUMAN: GOOD ENOUGH
# 2025-11-14 22:22:22,898 - INFO - jlpt - Formatter: {'background': '大学の友人3人が週末の旅行について話しています。', 'conversation': [{'gender': 'female1', 'context': '今週末、みんなで山に行く予定だけど、天気がちょっと心配だね。昨日の予報では雨が降るかもしれないって言ってたよ。'}, {'gender': 'male1', 'context': 'そうなんだ。僕もさっき天気アプリを見たけど、午前中は曇りで午後から雨になるみたいだよ。山道は滑りやすくなるから、気をつけないとね。'}, {'gender': 'male2', 'context': '雨が強くなったら、無理しないで途中で引き返した方がいいと思うよ。安全第一だし。'}, {'gender': 'female1', 'context': 'そうだね。もし雨が降ったら、近くの温泉に行くのもいいかも。みんなでゆっくりできるし。'}, {'gender': 'male1', 'context': 'それもいいね。温泉なら天気に関係なく楽しめるし、雨の日は空いてるかもしれないね。'}, {'gender': 'male2', 'context': 'じゃあ、当日の朝にもう一度天気を確認して、山に行くか温泉にするか決めようか。'}, {'gender': 'female1', 'context': 'うん、それが一番いいと思う。みんなで無理せず楽しもうね。'}, {'gender': 'male1', 'context': '了解。じゃあ、朝に連絡し合おう。'}], 'follow_up': 'この会話の中で、雨が降った場合、みんなはどうすることにしましたか？', 'choices': ['山に登るのをやめて温泉に行く', '雨でも山に登る', '家に帰る', '公園で遊ぶ'], 'correct_answer': 1}
# 2025-11-14 22:23:20,329 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-14 22:23:20,336 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1.wav
# 2025-11-14 22:23:20,343 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-14 22:23:20,359 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_background.wav
# 2025-11-14 22:23:20,377 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-14 22:23:20,379 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_0_speaker.wav
# 2025-11-14 22:23:20,394 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_1_speaker.wav
# 2025-11-14 22:23:20,409 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_2_speaker.wav
# 2025-11-14 22:23:20,425 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_3_speaker.wav
# 2025-11-14 22:23:20,431 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_4_speaker.wav
# 2025-11-14 22:23:20,445 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_5_speaker.wav
# 2025-11-14 22:23:20,473 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_6_speaker.wav
# 2025-11-14 22:23:20,481 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_7_speaker.wav
# 2025-11-14 22:23:20,498 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-14 22:23:20,498 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_follow_up.wav
# 2025-11-14 22:23:20,519 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_1_seq.wav
# 2025-11-14 22:23:20,531 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_1_option.wav
# 2025-11-14 22:23:20,553 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_2_seq.wav
# 2025-11-14 22:23:20,571 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_2_option.wav
# 2025-11-14 22:23:20,586 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_3_seq.wav
# 2025-11-14 22:23:20,602 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_3_option.wav
# 2025-11-14 22:23:20,619 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_4_seq.wav
# 2025-11-14 22:23:20,631 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_4_option.wav
# 2025-11-14 22:23:21,247 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_conversation_output.mp3
# 2025-11-14 22:23:24,426 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_listen_answer_1_conversation_output.mp3 as blob 4fe7e2f3-c165-11f0-a9a0-005056c00008/comprehensive_expression_listen_answer_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の友人3人が週末の旅行について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 今週末、みんなで山に行く予定だけど、天気がちょっと心配だね。昨日の予報では雨が降るかもしれないって言ってたよ。</p>
# <p><strong>Male1:</strong> そうなんだ。僕もさっき天気アプリを見たけど、午前中は曇りで午後から雨になるみたいだよ。山道は滑りやすくなるから、気をつけないとね。</p>
# <p><strong>Male2:</strong> 雨が強くなったら、無理しないで途中で引き返した方がいいと思うよ。安全第一だし。</p>
# <p><strong>Female1:</strong> そうだね。もし雨が降ったら、近くの温泉に行くのもいいかも。みんなでゆっくりできるし。</p>
# <p><strong>Male1:</strong> それもいいね。温泉なら天気に関係なく楽しめるし、雨の日は空いてるかもしれないね。</p>
# <p><strong>Male2:</strong> じゃあ、当日の朝にもう一度天気を確認して、山に行くか温泉にするか決めようか。</p>
# <p><strong>Female1:</strong> うん、それが一番いいと思う。みんなで無理せず楽しもうね。</p>
# <p><strong>Male1:</strong> 了解。じゃあ、朝に連絡し合おう。</p>
# </div>
# <p><strong>follow-up question: </strong>この会話の中で、雨が降った場合、みんなはどうすることにしましたか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/4fe7e2f3-c165-11f0-a9a0-005056c00008/comprehensive_expression_listen_answer_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>山に登るのをやめて温泉に行く</b> <span style='color:green;'>(correct)</span></li>
# <li>2. 雨でも山に登る</li>
# <li>3. 家に帰る</li>
# <li>4. 公園で遊ぶ</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-14 22:23:24,441 - INFO - jlpt - ---Generator----
# 2025-11-14 22:23:31,729 - INFO - jlpt - ---REVISOR---
# 2025-11-14 22:23:32,341 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-14 22:23:32,344 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-14 22:23:32,346 - INFO - jlpt - --- Formatter ---
# 2025-11-14 22:23:32,348 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问2个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。</p>
#
# <div class='conversation'>
# - 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方なども教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方も楽しめいただけます。西会場では、新鮮な魚介類を販売しています。
# - 女2: 新鮮な魚、おいしそう。なくなり前に早く行かなきゃ？
# - 男1: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# - 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# - 男1: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、買い物は最後にしようよ。
# - 女2: いいよ。釣りはいいの？
# - 男1: うーん、初心者向けって言ってたから今日は初めてていいかな。
# </div>
# <a class='follow_up'>質問1: 2人は最初にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
# <a class='follow_up'>質問2: 2人は2番目にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
#
#
#
# HUMAN: Generate a JLPT question regarding Topic: 友人へのプレゼント選びについて話す
# AI: <p class='background'>大学の休み時間に、友人への誕生日プレゼントについて三人が話しています。</p>
#
# <div class='conversation'>
# - 女1: 来週、佐藤さんの誕生日だけど、何かプレゼントを考えてる？
# - 男1: うーん、まだ決めてないけど、佐藤さんは本が好きだから、話題の小説とかどうかなと思ってる。
# - 女2: いいね。でも、最近は忙しくて読む時間がないって言ってたよ。実用的なものの方が喜ぶかもしれないね。
# - 男1: そうか。じゃあ、コーヒーが好きだから、ちょっと高めのコーヒー豆とかはどう？
# - 女1: それもいいね。毎朝飲んでるって言ってたし。でも、コーヒー豆は他の人も考えてるかもしれないよ。
# - 女2: じゃあ、マグカップとかは？かわいいデザインのものなら、使ってもらえると思う。
# - 男1: それなら、セットでコーヒー豆とマグカップをプレゼントするのはどう？
# - 女1: いいアイデア！それなら特別感もあるし、佐藤さんもきっと喜ぶと思う。
# - 女2: じゃあ、みんなでお金を出し合って買おうよ。予算はどうする？
# - 男1: 一人千円くらいなら、いいものが買えるんじゃないかな。
# - 女1: 賛成！じゃあ、今週末にみんなで買いに行こう。
# </div>
#
# <a class='follow_up'>佐藤さんへのプレゼントについて、三人は最終的にどんなものを選びましたか？</a>
# <ul class='options'>
#     <li>話題の小説</li>
#     <li>コーヒー豆だけ</li>
#     <li>マグカップだけ</li>
#     <li>コーヒー豆とマグカップのセット</li>
# </ul>
# 正解:4
#
# <a class='follow_up'>三人がプレゼントを買うために決めた予算は、一人いくらですか？</a>
# <ul class='options'>
#     <li>五百円</li>
#     <li>千円</li>
#     <li>二千円</li>
#     <li>三千円</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-11-14 22:23:36,071 - INFO - jlpt - Formatter: {'background': '大学の休み時間に、友人への誕生日プレゼントについて三人が話しています。', 'conversation': [{'gender': 'female1', 'context': '来週、佐藤さんの誕生日だけど、何かプレゼントを考えてる？'}, {'gender': 'male1', 'context': 'うーん、まだ決めてないけど、佐藤さんは本が好きだから、話題の小説とかどうかなと思ってる。'}, {'gender': 'female2', 'context': 'いいね。でも、最近は忙しくて読む時間がないって言ってたよ。実用的なものの方が喜ぶかもしれないね。'}, {'gender': 'male1', 'context': 'そうか。じゃあ、コーヒーが好きだから、ちょっと高めのコーヒー豆とかはどう？'}, {'gender': 'female1', 'context': 'それもいいね。毎朝飲んでるって言ってたし。でも、コーヒー豆は他の人も考えてるかもしれないよ。'}, {'gender': 'female2', 'context': 'じゃあ、マグカップとかは？かわいいデザインのものなら、使ってもらえると思う。'}, {'gender': 'male1', 'context': 'それなら、セットでコーヒー豆とマグカップをプレゼントするのはどう？'}, {'gender': 'female1', 'context': 'いいアイデア！それなら特別感もあるし、佐藤さんもきっと喜ぶと思う。'}, {'gender': 'female2', 'context': 'じゃあ、みんなでお金を出し合って買おうよ。予算はどうする？'}, {'gender': 'male1', 'context': '一人千円くらいなら、いいものが買えるんじゃないかな。'}, {'gender': 'female1', 'context': '賛成！じゃあ、今週末にみんなで買いに行こう。'}], 'listen_questions': [{'follow_up': '佐藤さんへのプレゼントについて、三人は最終的にどんなものを選びましたか？', 'correct_answer': 4, 'choices': ['話題の小説', 'コーヒー豆だけ', 'マグカップだけ', 'コーヒー豆とマグカップのセット']}, {'follow_up': '三人がプレゼントを買うために決めた予算は、一人いくらですか？', 'correct_answer': 2, 'choices': ['五百円', '千円', '二千円', '三千円']}]}
# 2025-11-14 22:24:18,032 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-14 22:24:18,032 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3.wav
# 2025-11-14 22:24:18,032 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-14 22:24:18,032 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_background.wav
# 2025-11-14 22:24:18,032 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-14 22:24:18,048 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-11-14 22:24:18,054 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-11-14 22:24:18,059 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-11-14 22:24:18,063 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-11-14 22:24:18,071 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-11-14 22:24:18,080 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-11-14 22:24:18,088 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-11-14 22:24:18,093 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-11-14 22:24:18,101 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_8_speaker.wav
# 2025-11-14 22:24:18,110 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_9_speaker.wav
# 2025-11-14 22:24:18,110 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_10_speaker.wav
# 2025-11-14 22:24:18,126 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-14 22:24:18,126 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_1_follow_up.wav
# 2025-11-14 22:24:18,149 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-14 22:24:18,155 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-14 22:24:18,164 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_2_follow_up.wav
# 2025-11-14 22:24:18,172 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-14 22:24:18,873 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-11-14 22:24:21,429 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\4fe7e2f3-c165-11f0-a9a0-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob 4fe7e2f3-c165-11f0-a9a0-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の休み時間に、友人への誕生日プレゼントについて三人が話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 来週、佐藤さんの誕生日だけど、何かプレゼントを考えてる？</p>
# <p><strong>Male1:</strong> うーん、まだ決めてないけど、佐藤さんは本が好きだから、話題の小説とかどうかなと思ってる。</p>
# <p><strong>Female2:</strong> いいね。でも、最近は忙しくて読む時間がないって言ってたよ。実用的なものの方が喜ぶかもしれないね。</p>
# <p><strong>Male1:</strong> そうか。じゃあ、コーヒーが好きだから、ちょっと高めのコーヒー豆とかはどう？</p>
# <p><strong>Female1:</strong> それもいいね。毎朝飲んでるって言ってたし。でも、コーヒー豆は他の人も考えてるかもしれないよ。</p>
# <p><strong>Female2:</strong> じゃあ、マグカップとかは？かわいいデザインのものなら、使ってもらえると思う。</p>
# <p><strong>Male1:</strong> それなら、セットでコーヒー豆とマグカップをプレゼントするのはどう？</p>
# <p><strong>Female1:</strong> いいアイデア！それなら特別感もあるし、佐藤さんもきっと喜ぶと思う。</p>
# <p><strong>Female2:</strong> じゃあ、みんなでお金を出し合って買おうよ。予算はどうする？</p>
# <p><strong>Male1:</strong> 一人千円くらいなら、いいものが買えるんじゃないかな。</p>
# <p><strong>Female1:</strong> 賛成！じゃあ、今週末にみんなで買いに行こう。</p>
# </div>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/4fe7e2f3-c165-11f0-a9a0-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <p><strong>1.佐藤さんへのプレゼントについて、三人は最終的にどんなものを選びましたか？</strong></p>
# <ul>
# <li>話題の小説</li>
# <li>コーヒー豆だけ</li>
# <li>マグカップだけ</li>
# <li><b>コーヒー豆とマグカップのセット</b> <span style='color:green;'>(correct)</span></li>
# </ul>
# <p><strong>2.三人がプレゼントを買うために決めた予算は、一人いくらですか？</strong></p>
# <ul>
# <li>五百円</li>
# <li><b>千円</b> <span style='color:green;'>(correct)</span></li>
# <li>二千円</li>
# <li>三千円</li>
# </ul>
