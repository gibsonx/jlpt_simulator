# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-12 00:23:34,175 - INFO - jlpt - ---Generator----
# 2025-11-12 00:23:41,680 - INFO - jlpt - ---REVISOR---
# 2025-11-12 00:23:42,276 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-12 00:23:42,279 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-12 00:23:42,281 - INFO - jlpt - --- Formatter ---
# 2025-11-12 00:23:42,282 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问1个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# - 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# - 女1: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# - 男1: 市の方針でゴミ箱は置かないことになってるからね。
# - 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# - 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# - 女1: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# - 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# - 女1: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# - 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 好きな季節について話す
# AI: <p class='background'>大学の友人3人が昼休みに好きな季節について話しています。</p>
#
# <div class='conversation'>
# - 女1: みんなは一年の中でどの季節が一番好き？私は春が好きなんだ。桜が咲くし、気温もちょうどいいし、新しいことを始める気持ちになるから。
# - 男1: 僕は秋が一番好きかな。暑すぎず寒すぎず、散歩するのにちょうどいいし、紅葉もきれいだし。あと、秋の食べ物が美味しいと思うんだ。
# - 女2: 私は夏が好き！海に行ったり、花火大会に行ったり、友達と外で遊ぶことが多いから楽しい。暑いのは苦手だけど、夏休みがあるのも嬉しいよね。
# - 女1: 夏は確かにイベントが多いよね。でも私は暑さが苦手だから、春の方が過ごしやすいな。
# - 男1: 春もいいけど、花粉症があるからちょっと大変なんだよね。秋は空気がきれいで、読書するのにもぴったりだと思う。
# - 女2: そういえば、冬が好きな人はあまりいないのかな？私は寒いのが苦手だから、冬はあまり外に出たくないな。
# - 女1: 冬はこたつでみかんを食べるのは好きだけど、やっぱり春が一番かな。
# - 男1: みんなそれぞれ好きな季節が違うんだね。季節によって楽しみ方も変わるから面白いよね。
# </div>
# <a class='follow_up'>この会話で、女1は春が好きな理由として何を挙げていますか？</a>
# <ul class='options'>
#     <li>新しいことを始める気持ちになるから</li>
#     <li>秋の食べ物が美味しいから</li>
#     <li>夏休みがあるから</li>
#     <li>冬にこたつでみかんを食べるのが好きだから</li>
# </ul>
# 正解:1
# HUMAN: GOOD ENOUGH
# 2025-11-12 00:23:45,650 - INFO - jlpt - Formatter: {'background': '大学の友人3人が昼休みに好きな季節について話しています。', 'conversation': [{'gender': 'female1', 'context': 'みんなは一年の中でどの季節が一番好き？私は春が好きなんだ。桜が咲くし、気温もちょうどいいし、新しいことを始める気持ちになるから。'}, {'gender': 'male1', 'context': '僕は秋が一番好きかな。暑すぎず寒すぎず、散歩するのにちょうどいいし、紅葉もきれいだし。あと、秋の食べ物が美味しいと思うんだ。'}, {'gender': 'female2', 'context': '私は夏が好き！海に行ったり、花火大会に行ったり、友達と外で遊ぶことが多いから楽しい。暑いのは苦手だけど、夏休みがあるのも嬉しいよね。'}, {'gender': 'female1', 'context': '夏は確かにイベントが多いよね。でも私は暑さが苦手だから、春の方が過ごしやすいな。'}, {'gender': 'male1', 'context': '春もいいけど、花粉症があるからちょっと大変なんだよね。秋は空気がきれいで、読書するのにもぴったりだと思う。'}, {'gender': 'female2', 'context': 'そういえば、冬が好きな人はあまりいないのかな？私は寒いのが苦手だから、冬はあまり外に出たくないな。'}, {'gender': 'female1', 'context': '冬はこたつでみかんを食べるのは好きだけど、やっぱり春が一番かな。'}, {'gender': 'male1', 'context': 'みんなそれぞれ好きな季節が違うんだね。季節によって楽しみ方も変わるから面白いよね。'}], 'follow_up': 'この会話で、女1は春が好きな理由として何を挙げていますか？', 'choices': ['新しいことを始める気持ちになるから', '秋の食べ物が美味しいから', '夏休みがあるから', '冬にこたつでみかんを食べるのが好きだから'], 'correct_answer': 1}
# 2025-11-12 00:24:35,253 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-12 00:24:35,255 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1.wav
# 2025-11-12 00:24:35,266 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-12 00:24:35,268 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_background.wav
# 2025-11-12 00:24:35,279 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-12 00:24:35,282 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_0_speaker.wav
# 2025-11-12 00:24:35,295 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_1_speaker.wav
# 2025-11-12 00:24:35,309 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_2_speaker.wav
# 2025-11-12 00:24:35,329 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_3_speaker.wav
# 2025-11-12 00:24:35,343 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_4_speaker.wav
# 2025-11-12 00:24:35,360 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_5_speaker.wav
# 2025-11-12 00:24:35,376 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_6_speaker.wav
# 2025-11-12 00:24:35,399 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_7_speaker.wav
# 2025-11-12 00:24:35,423 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-12 00:24:35,436 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_follow_up.wav
# 2025-11-12 00:24:35,463 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_1_seq.wav
# 2025-11-12 00:24:35,482 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_1_option.wav
# 2025-11-12 00:24:35,506 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_2_seq.wav
# 2025-11-12 00:24:35,527 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_2_option.wav
# 2025-11-12 00:24:35,553 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_3_seq.wav
# 2025-11-12 00:24:35,575 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_3_option.wav
# 2025-11-12 00:24:35,603 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_4_seq.wav
# 2025-11-12 00:24:35,632 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_4_option.wav
# 2025-11-12 00:24:36,368 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_conversation_output.mp3
# 2025-11-12 00:24:40,303 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_listen_answer_1_conversation_output.mp3 as blob c4c6c429-bf1a-11f0-9665-005056c00008/comprehensive_expression_listen_answer_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の友人3人が昼休みに好きな季節について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> みんなは一年の中でどの季節が一番好き？私は春が好きなんだ。桜が咲くし、気温もちょうどいいし、新しいことを始める気持ちになるから。</p>
# <p><strong>Male1:</strong> 僕は秋が一番好きかな。暑すぎず寒すぎず、散歩するのにちょうどいいし、紅葉もきれいだし。あと、秋の食べ物が美味しいと思うんだ。</p>
# <p><strong>Female2:</strong> 私は夏が好き！海に行ったり、花火大会に行ったり、友達と外で遊ぶことが多いから楽しい。暑いのは苦手だけど、夏休みがあるのも嬉しいよね。</p>
# <p><strong>Female1:</strong> 夏は確かにイベントが多いよね。でも私は暑さが苦手だから、春の方が過ごしやすいな。</p>
# <p><strong>Male1:</strong> 春もいいけど、花粉症があるからちょっと大変なんだよね。秋は空気がきれいで、読書するのにもぴったりだと思う。</p>
# <p><strong>Female2:</strong> そういえば、冬が好きな人はあまりいないのかな？私は寒いのが苦手だから、冬はあまり外に出たくないな。</p>
# <p><strong>Female1:</strong> 冬はこたつでみかんを食べるのは好きだけど、やっぱり春が一番かな。</p>
# <p><strong>Male1:</strong> みんなそれぞれ好きな季節が違うんだね。季節によって楽しみ方も変わるから面白いよね。</p>
# </div>
# <p><strong>follow-up question: </strong>この会話で、女1は春が好きな理由として何を挙げていますか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/c4c6c429-bf1a-11f0-9665-005056c00008/comprehensive_expression_listen_answer_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>新しいことを始める気持ちになるから</b> <span style='color:green;'>(correct)</span></li>
# <li>2. 秋の食べ物が美味しいから</li>
# <li>3. 夏休みがあるから</li>
# <li>4. 冬にこたつでみかんを食べるのが好きだから</li>
# </ul>

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-12 00:24:40,314 - INFO - jlpt - ---Generator----
# 2025-11-12 00:24:47,465 - INFO - jlpt - ---REVISOR---
# 2025-11-12 00:24:48,071 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-12 00:24:48,074 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-12 00:24:48,075 - INFO - jlpt - --- Formatter ---
# 2025-11-12 00:24:48,076 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问2个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。</p>
#
# <div class='conversation'>
# - 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方なども教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方も楽しめいただけます。西会場では、新鮮な魚介類を販売しています。
# - 女2: 新鮮な魚、おいしそう。なくなり前に早く行かなきゃ？
# - 男1: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# - 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# - 男1: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、買い物は最後にしようよ。
# - 女2: いいよ。釣りはいいの？
# - 男1: うーん、初心者向けって言ってたから今日は初めてていいかな。
# </div>
# <a class='follow_up'>質問1: 2人は最初にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
# <a class='follow_up'>質問2: 2人は2番目にどの会場に行くですか？</a>
# <ul class='options'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
#
#
#
# HUMAN: Generate a JLPT question regarding Topic: ファッションとスタイルについて話す
# AI: <p class='background'>大学の休み時間に、友達三人がファッションとスタイルについて話しています。</p>
#
# <div class='conversation'>
# - 女1: 最近、みんな服の選び方が変わってきたと思わない？私は、前は流行だけを気にしていたけど、今は自分に合うものを選ぶようになったんだ。
# - 男1: そうだね。僕も昔は雑誌を見て、人気のブランドばかり買ってたけど、今は着心地とか、長く使えるかどうかを考えて選ぶようになったよ。
# - 女2: 私は、色の組み合わせを意識するようになったかな。明るい色を着ると気分も明るくなるし、友達にも「似合ってるね」って言われると嬉しい。
# - 女1: それ、わかる！自分の好きな色や形を知ると、買い物も楽しくなるよね。流行だけじゃなくて、自分らしさを大事にしたいな。
# - 男1: でも、時々新しいスタイルに挑戦したくなることもあるよ。失敗することもあるけど、それも楽しい経験だと思う。
# - 女2: うん、私も。友達と一緒にショッピングに行くと、普段選ばない服をすすめられて、新しい発見があるよね。
# - 女1: そうだね。結局、自分が気に入ったものを着るのが一番だと思う。人の意見も参考にしつつ、自分のスタイルを見つけたいな。
# </div>
#
# <a class='follow_up'>質問1: 女1は最近、服を選ぶときに何を重視するようになりましたか？</a>
# <ul class='options'>
#     <li>流行だけ</li>
#     <li>ブランドの人気</li>
#     <li>自分に合うもの</li>
#     <li>友達の意見</li>
# </ul>
# 正解:3
#
# <a class='follow_up'>質問2: 男1は服を選ぶときに何を考えるようになったと言っていますか？</a>
# <ul class='options'>
#     <li>値段だけ</li>
#     <li>着心地や長く使えるか</li>
#     <li>色の組み合わせ</li>
#     <li>流行だけ</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-11-12 00:24:52,049 - INFO - jlpt - Formatter: {'background': '大学の休み時間に、友達三人がファッションとスタイルについて話しています。', 'conversation': [{'gender': 'female1', 'context': '最近、みんな服の選び方が変わってきたと思わない？私は、前は流行だけを気にしていたけど、今は自分に合うものを選ぶようになったんだ。'}, {'gender': 'male1', 'context': 'そうだね。僕も昔は雑誌を見て、人気のブランドばかり買ってたけど、今は着心地とか、長く使えるかどうかを考えて選ぶようになったよ。'}, {'gender': 'female2', 'context': '私は、色の組み合わせを意識するようになったかな。明るい色を着ると気分も明るくなるし、友達にも「似合ってるね」って言われると嬉しい。'}, {'gender': 'female1', 'context': 'それ、わかる！自分の好きな色や形を知ると、買い物も楽しくなるよね。流行だけじゃなくて、自分らしさを大事にしたいな。'}, {'gender': 'male1', 'context': 'でも、時々新しいスタイルに挑戦したくなることもあるよ。失敗することもあるけど、それも楽しい経験だと思う。'}, {'gender': 'female2', 'context': 'うん、私も。友達と一緒にショッピングに行くと、普段選ばない服をすすめられて、新しい発見があるよね。'}, {'gender': 'female1', 'context': 'そうだね。結局、自分が気に入ったものを着るのが一番だと思う。人の意見も参考にしつつ、自分のスタイルを見つけたいな。'}], 'listen_questions': [{'follow_up': '質問1: 女1は最近、服を選ぶときに何を重視するようになりましたか？', 'correct_answer': 3, 'choices': ['流行だけ', 'ブランドの人気', '自分に合うもの', '友達の意見']}, {'follow_up': '質問2: 男1は服を選ぶときに何を考えるようになったと言っていますか？', 'correct_answer': 2, 'choices': ['値段だけ', '着心地や長く使えるか', '色の組み合わせ', '流行だけ']}]}
# 2025-11-12 00:25:21,273 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-12 00:25:21,278 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3.wav
# 2025-11-12 00:25:21,288 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-12 00:25:21,290 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_background.wav
# 2025-11-12 00:25:21,299 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-12 00:25:21,302 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-11-12 00:25:21,315 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-11-12 00:25:21,331 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-11-12 00:25:21,346 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-11-12 00:25:21,360 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-11-12 00:25:21,380 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-11-12 00:25:21,394 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-11-12 00:25:21,422 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-12 00:25:21,430 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_1_follow_up.wav
# 2025-11-12 00:25:21,444 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-12 00:25:21,451 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-12 00:25:21,458 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_2_follow_up.wav
# 2025-11-12 00:25:21,473 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-12 00:25:22,173 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-11-12 00:25:24,348 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\c4c6c429-bf1a-11f0-9665-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob c4c6c429-bf1a-11f0-9665-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の休み時間に、友達三人がファッションとスタイルについて話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 最近、みんな服の選び方が変わってきたと思わない？私は、前は流行だけを気にしていたけど、今は自分に合うものを選ぶようになったんだ。</p>
# <p><strong>Male1:</strong> そうだね。僕も昔は雑誌を見て、人気のブランドばかり買ってたけど、今は着心地とか、長く使えるかどうかを考えて選ぶようになったよ。</p>
# <p><strong>Female2:</strong> 私は、色の組み合わせを意識するようになったかな。明るい色を着ると気分も明るくなるし、友達にも「似合ってるね」って言われると嬉しい。</p>
# <p><strong>Female1:</strong> それ、わかる！自分の好きな色や形を知ると、買い物も楽しくなるよね。流行だけじゃなくて、自分らしさを大事にしたいな。</p>
# <p><strong>Male1:</strong> でも、時々新しいスタイルに挑戦したくなることもあるよ。失敗することもあるけど、それも楽しい経験だと思う。</p>
# <p><strong>Female2:</strong> うん、私も。友達と一緒にショッピングに行くと、普段選ばない服をすすめられて、新しい発見があるよね。</p>
# <p><strong>Female1:</strong> そうだね。結局、自分が気に入ったものを着るのが一番だと思う。人の意見も参考にしつつ、自分のスタイルを見つけたいな。</p>
# </div>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/c4c6c429-bf1a-11f0-9665-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <p><strong>1.質問1: 女1は最近、服を選ぶときに何を重視するようになりましたか？</strong></p>
# <ul>
# <li>流行だけ</li>
# <li>ブランドの人気</li>
# <li><b>自分に合うもの</b> <span style='color:green;'>(correct)</span></li>
# <li>友達の意見</li>
# </ul>
# <p><strong>2.質問2: 男1は服を選ぶときに何を考えるようになったと言っていますか？</strong></p>
# <ul>
# <li>値段だけ</li>
# <li><b>着心地や長く使えるか</b> <span style='color:green;'>(correct)</span></li>
# <li>色の組み合わせ</li>
# <li>流行だけ</li>
# </ul>
