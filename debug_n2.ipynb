# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.active_expression((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-02 22:54:54,571 - INFO - jlpt - ---Generator----
# 2025-11-02 22:55:07,000 - INFO - jlpt - ---REVISOR---
# 2025-11-02 22:55:07,540 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-02 22:55:07,543 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-02 22:55:07,547 - INFO - jlpt - --- Formatter ---
# 2025-11-02 22:55:07,549 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问2个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>
# 池で行われているイベントでアナウンスを聞いた後、女の人と男の人が話しています。
# </p>
#
# <div class='conversation'>
# 女1: 本日は桜花祭りにお越しくださり、ありがとうございます。各会場についてご案内いたします。中央会場では、今日捕れた魚や貝をその場で焼いてお召し上がりいただけます。こちらは、なくなり次第終了いたします。南会場では、初心者向けの釣り教室を開催しています。道具の貸し出しもあります。餌の付け方などもお教えいたします。東会場では、海の生き物が観察できます。地元の海の生き物を間近で見ることができ、お子様も大人の方もお楽しみいただけます。西会場では、新鮮な魚介類を販売しています。
# 女2: 新鮮な魚、おいしそう。なくなる前に早く行かなきゃ？
# 男1: え？早速買い物？先に買っちゃうともっとたくさん食べられない？
# 女2: あ、そうか。そんなに自分でたくさん食べられないって言うなら、買い物は最後にしようよ。
# 男1: あ、そうしような。まずはここに行こう。そんなに近くで生き物を観察できるって言うなら、楽しそうだし。
# 女2: いいよ。釣りはいいの？
# 男1: うーん、初心者向けって言ってたから今日は初めてでいいかな。
# </div>
# <a class='follow_up_01'>質問1: 2人は最初にどの会場に行くですか？</a>
# <ul class='options_01'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
# <a class='follow_up_02'>質問2: 2人は2番目にどの会場に行くですか？</a>
# <ul class='options_02'>
#     <li>中央会場</li>
#     <li>南会場</li>
#     <li>東会場</li>
#     <li>西会場</li>
# </ul>
#
#
#
# HUMAN: Generate a JLPT question regarding Topic: 新しいスキルを学ぶ計画について話す
# AI: <p class='background'>
# 大学のカフェテリアで、2人の女性と1人の男性が新しいスキルを学ぶ計画について話しています。
# </p>
#
# <div class='conversation'>
# 女1: 最近、何か新しいことを始めたいと思っているんだけど、みんなはどう？何か挑戦したいことある？
# 男1: 僕は写真を勉強してみたいな。スマホで撮るだけじゃなくて、本格的なカメラを使ってみたいんだ。ネットで初心者向けの講座を探してるところ。
# 女2: いいね！私は料理に挑戦したい。今まで簡単なものしか作ったことがないけど、和食やイタリア料理も作れるようになりたいな。近くのカルチャーセンターで料理教室があるみたいだから、参加しようか迷ってる。
# 女1: どちらも楽しそうだね。私は英語をもう少し話せるようになりたいな。仕事でも使う機会が増えてきたし、オンラインの会話レッスンを受けてみようかなと思ってる。
# 男1: みんな、ちゃんと目標があるんだね。始めるのは勇気がいるけど、やってみたらきっと楽しいと思うよ。お互いに進捗を報告し合ったら、続けやすいかもね。
# 女2: それ、いいアイディア！毎週集まって、どれくらいできたか話し合うのはどう？
# 女1: 賛成！みんなで励まし合えば、途中でやめずに続けられそうだね。
# 男1: じゃあ、来週から始めよう。まずはそれぞれ、どの講座や教室に申し込むか決めてみよう。
# </div>
#
# <a class='follow_up_01'>質問1: 男性はどんなスキルを学びたいと言っていますか？</a>
# <ul class='options_01'>
#     <li>料理</li>
#     <li>英語</li>
#     <li>写真</li>
#     <li>パソコン</li>
# </ul>
# 正解:3
#
# <a class='follow_up_02'>質問2: 3人は新しいスキルを続けるために何をしようとしていますか？</a>
# <ul class='options_02'>
#     <li>一緒に教室に通う</li>
#     <li>毎週進捗を話し合う</li>
#     <li>先生に相談する</li>
#     <li>本を交換する</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-11-02 22:55:10,757 - INFO - jlpt - Formatter: {'background': '大学のカフェテリアで、2人の女性と1人の男性が新しいスキルを学ぶ計画について話しています。', 'conversation': [{'gender': 'female1', 'context': '最近、何か新しいことを始めたいと思っているんだけど、みんなはどう？何か挑戦したいことある？'}, {'gender': 'male1', 'context': '僕は写真を勉強してみたいな。スマホで撮るだけじゃなくて、本格的なカメラを使ってみたいんだ。ネットで初心者向けの講座を探してるところ。'}, {'gender': 'female2', 'context': 'いいね！私は料理に挑戦したい。今まで簡単なものしか作ったことがないけど、和食やイタリア料理も作れるようになりたいな。近くのカルチャーセンターで料理教室があるみたいだから、参加しようか迷ってる。'}, {'gender': 'female1', 'context': 'どちらも楽しそうだね。私は英語をもう少し話せるようになりたいな。仕事でも使う機会が増えてきたし、オンラインの会話レッスンを受けてみようかなと思ってる。'}, {'gender': 'male1', 'context': 'みんな、ちゃんと目標があるんだね。始めるのは勇気がいるけど、やってみたらきっと楽しいと思うよ。お互いに進捗を報告し合ったら、続けやすいかもね。'}, {'gender': 'female2', 'context': 'それ、いいアイディア！毎週集まって、どれくらいできたか話し合うのはどう？'}, {'gender': 'female1', 'context': '賛成！みんなで励まし合えば、途中でやめずに続けられそうだね。'}, {'gender': 'male1', 'context': 'じゃあ、来週から始めよう。まずはそれぞれ、どの講座や教室に申し込むか決めてみよう。'}], 'listen_questions': [{'follow_up': '質問1: 男性はどんなスキルを学びたいと言っていますか？', 'correct_answer': 3, 'choices': ['料理', '英語', '写真', 'パソコン']}, {'follow_up': '質問2: 3人は新しいスキルを続けるために何をしようとしていますか？', 'correct_answer': 2, 'choices': ['一緒に教室に通う', '毎週進捗を話し合う', '先生に相談する', '本を交換する']}]}
# 2025-11-02 22:55:44,403 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-02 22:55:44,405 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3.wav
# 2025-11-02 22:55:44,407 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-02 22:55:44,408 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_background.wav
# 2025-11-02 22:55:44,413 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-02 22:55:44,415 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_0_speaker.wav
# 2025-11-02 22:55:44,422 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_1_speaker.wav
# 2025-11-02 22:55:44,430 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_2_speaker.wav
# 2025-11-02 22:55:44,439 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_3_speaker.wav
# 2025-11-02 22:55:44,451 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_4_speaker.wav
# 2025-11-02 22:55:44,461 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_5_speaker.wav
# 2025-11-02 22:55:44,470 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_6_speaker.wav
# 2025-11-02 22:55:44,491 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_7_speaker.wav
# 2025-11-02 22:55:44,512 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-02 22:55:44,521 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_1_follow_up.wav
# 2025-11-02 22:55:44,540 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-02 22:55:44,549 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-02 22:55:44,557 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_2_follow_up.wav
# 2025-11-02 22:55:44,579 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-02 22:55:45,315 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3
# 2025-11-02 22:55:49,021 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\e4518ac8-b7fb-11f0-86b1-005056c00008\comprehensive_expression_show_answer_3_conversation_output.mp3 as blob e4518ac8-b7fb-11f0-86b1-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学のカフェテリアで、2人の女性と1人の男性が新しいスキルを学ぶ計画について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female1:</strong> 最近、何か新しいことを始めたいと思っているんだけど、みんなはどう？何か挑戦したいことある？</p>
# <p><strong>Male1:</strong> 僕は写真を勉強してみたいな。スマホで撮るだけじゃなくて、本格的なカメラを使ってみたいんだ。ネットで初心者向けの講座を探してるところ。</p>
# <p><strong>Female2:</strong> いいね！私は料理に挑戦したい。今まで簡単なものしか作ったことがないけど、和食やイタリア料理も作れるようになりたいな。近くのカルチャーセンターで料理教室があるみたいだから、参加しようか迷ってる。</p>
# <p><strong>Female1:</strong> どちらも楽しそうだね。私は英語をもう少し話せるようになりたいな。仕事でも使う機会が増えてきたし、オンラインの会話レッスンを受けてみようかなと思ってる。</p>
# <p><strong>Male1:</strong> みんな、ちゃんと目標があるんだね。始めるのは勇気がいるけど、やってみたらきっと楽しいと思うよ。お互いに進捗を報告し合ったら、続けやすいかもね。</p>
# <p><strong>Female2:</strong> それ、いいアイディア！毎週集まって、どれくらいできたか話し合うのはどう？</p>
# <p><strong>Female1:</strong> 賛成！みんなで励まし合えば、途中でやめずに続けられそうだね。</p>
# <p><strong>Male1:</strong> じゃあ、来週から始めよう。まずはそれぞれ、どの講座や教室に申し込むか決めてみよう。</p>
# </div>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/e4518ac8-b7fb-11f0-86b1-005056c00008/comprehensive_expression_show_answer_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <p><strong>1.質問1: 男性はどんなスキルを学びたいと言っていますか？</strong></p>
# <ul>
# <li>料理</li>
# <li>英語</li>
# <li><b>写真</b> <span style='color:green;'>(correct)</span></li>
# <li>パソコン</li>
# </ul>
# <p><strong>2.質問2: 3人は新しいスキルを続けるために何をしようとしていますか？</strong></p>
# <ul>
# <li>一緒に教室に通う</li>
# <li><b>毎週進捗を話し合う</b> <span style='color:green;'>(correct)</span></li>
# <li>先生に相談する</li>
# <li>本を交換する</li>
# </ul>

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))
