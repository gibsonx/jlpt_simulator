# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.kanji_reading(random.choice(vocab.split(",")))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-09-29 21:50:17,589 - INFO - jlpt - ---Generator----
# 2025-09-29 21:50:21,300 - INFO - jlpt - ---REVISOR---
# 2025-09-29 21:50:22,012 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-29 21:50:22,014 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-29 21:50:22,015 - INFO - jlpt - --- Formatter ---
# 2025-09-29 21:50:22,015 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing a test paper for JLPT N2 level.
#
# Task: Your job is to write a pronunciation question corresponding to Japanes kanji for the JLPT N2 level exam paper.
#
# Step 1: Generate a short sentence within 30 words as the question stem. And select a Japanese kanji word to mark as a
# -A must contain at least one Japanese kanji, not every character is a hiragana
#
# Step 2: For word a, underline it.
# The selected words need to be marked with<u></u>, such as<u>主要</u>, and no other tags should appear in the sentence.
# Additional requirements:
# -Words in sentences should not be used in options
# -You must display the correct answer in the output with options 1, 2, 3, 4. For example: Correct solution: 1
#
# Step 3: Generate 4 options for this question. Require all of the following conditions:
# -These 4 options must be different from each other.
# -Only one option is the correct answer.
# -The generated options need to comply with Japanese pronunciation rules and should not generate non-existent pronunciations
# -Assuming that word a consists of 2-3 characters, set them in order as x[0],y[0],z[0] (if a variable is a Japanese kanji, do not display it as hiragana pronunciation). There are four options, including option 1: x[1],y[1],z[1]; Option 2: x[2],y[2],z[2]; Option 3: x[3],y[3],z[3]; Option 4: x[4],y[4],z[4]
# -If x[0] is Japanese hiragana, then: x[1]=x[2]=x[3]=x[4]=x[0]
# -If y[0] is Japanese hiragana, then: y[1]=y[2]=y[3]=y[4]=y[0]
# -If z[0] is Japanese hiragana, then: z[1]=z[2]=z[3]=z[4]=z[0]
# -Print a,x[0],y[0],z[0],x[1],y[1],z[1],x[2],y[2],z[2],x[3],y[3],z[3],x[4],y[4],z[4] in the debugging log; And print the judgment of whether x[0],y[0],z[0] are Japanese hiragana or not
#
# Step 4: output a question.
# Format: Follow the format of the 2 examples in the formal exam paper, not the content. The output must be in HTML format and the line change tag must be removed.
# Content: Ensure vocabulary is limited to N2 level.
# Reference: Get inspiration from the "Topic". Consider the feedback given in the previous conversation (if any)
# Additional requirement: Do not display problem descriptions and serial numbers in the generated content.
#
# Formal exam paper:
# --- example 1 ---
# <a>この町の<u>主要</u>な産業は何ですか。</a>
# <ul>
#     <li>じゅおう</li>
#     <li>しゅおう</li>
#     <li>じゅうよう</li>
#     <li>しゅよう</li>
# </ul>
#
# --- example 2 ---
# <a>今日とても<u>嬉しい</u>ですね。</a>
# <ul>
#     <li>うれしい</li>
#     <li>はれしい</li>
#     <li>まぶしい</li>
#     <li>きびしい</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: <class 'graphs.common.Schema.SimpleChoiceQuestionOutput'>
# AI: Debug log:
# a=<u>経験</u>, x[0]=経, y[0]=験, z[0]=None
# x[1]=けい, y[1]=けん, z[1]=
# x[2]=きょう, y[2]=けん, z[2]=
# x[3]=けい, y[3]=がん, z[3]=
# x[4]=きょう, y[4]=がん, z[4]=
# x[0] is not hiragana
# y[0] is not hiragana
# z[0] is None
#
# Correct solution: 1
#
# <a>彼は海外で多くの<u>経験</u>を積みました。</a><ul><li>けいけん</li><li>きょうけん</li><li>けいがん</li><li>きょうがん</li></ul>
# HUMAN: GOOD ENOUGH
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 graph = GraphBuilder(exam_uid=exam_uid)
#       2 factory = JLPTTaskFactory(graph, level=level)
# ----> 3 content = factory.kanji_reading(random.choice(vocab.split(",")))
#       4 display(Markdown(_render_result(result=content)))
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\JLPTTaskFactory.py:44, in JLPTTaskFactory.kanji_reading(self, word)
#      43 def kanji_reading(self, word):
# ---> 44     return self._run_task(
#      45         self.prompts_module.kanji_reading_teacher_prompt,
#      46         self.prompts_module.kanji_reading_example,
#      47         self.prompts_module.kanji_reading_reflection_prompt,
#      48         SimpleChoiceQuestionOutput,
#      49         word
#      50     )
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\JLPTTaskFactory.py:33, in JLPTTaskFactory._run_task(self, prompt, example, output_cls, word, grammar)
#      30 else:
#      31     graph = self.graph.build_agent(prompt, example, output_cls)
# ---> 33 instance = graph.invoke(
#      34     {"messages": [HumanMessage(content=f"Generate a JLPT question regarding Topic: {word}")]},
#      35     config={"configurable": {"thread_id": "1"}}
#      36 )
#      37 return instance["formatted_output"]
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\__init__.py:2375, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2373 else:
#    2374     chunks = []
# -> 2375 for chunk in self.stream(
#    2376     input,
#    2377     config,
#    2378     stream_mode=stream_mode,
#    2379     output_keys=output_keys,
#    2380     interrupt_before=interrupt_before,
#    2381     interrupt_after=interrupt_after,
#    2382     debug=debug,
#    2383     **kwargs,
#    2384 ):
#    2385     if stream_mode == "values":
#    2386         latest = chunk
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\__init__.py:2031, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2025     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2026     # computation proceeds in steps, while there are channel updates.
#    2027     # Channel updates from step N are only visible in step N+1
#    2028     # channels are guaranteed to be immutable for the duration of the step,
#    2029     # with channel updates applied only at the transition between steps.
#    2030     while loop.tick(input_keys=self.input_channels):
# -> 2031         for _ in runner.tick(
#    2032             loop.tasks.values(),
#    2033             timeout=self.step_timeout,
#    2034             retry_policy=self.retry_policy,
#    2035             get_waiter=get_waiter,
#    2036         ):
#    2037             # emit output
#    2038             yield from output()
#    2039 # emit output
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\runner.py:230, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228 t = tasks[0]
#     229 try:
# --> 230     run_with_retry(
#     231         t,
#     232         retry_policy,
#     233         configurable={
#     234             CONFIG_KEY_SEND: partial(writer, t),
#     235             CONFIG_KEY_CALL: partial(call, t),
#     236         },
#     237     )
#     238     self.commit(t, None)
#     239 except Exception as exc:
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\utils\runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\utils\runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\GraphBuilder.py:190, in GraphBuilder.formatter_node_builder.<locals>.formatter_node(state)
#     172 question = state["question"]
#     174 formatter_prompt = ChatPromptTemplate.from_messages(
#     175     [
#     176         (
#    (...)    188     ]
#     189 )
# --> 190 format_pipeline = formatter_prompt | llm.with_structured_output(OutType)
#     192 msg = format_pipeline.invoke(input={"question": question})
#     194 logger.info("Formatter: {}".format(msg))
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_openai\chat_models\azure.py:1064, in AzureChatOpenAI.with_structured_output(self, schema, method, include_raw, strict, **kwargs)
#     748 def with_structured_output(
#     749     self,
#     750     schema: Optional[_DictOrPydanticClass] = None,
#    (...)    755     **kwargs: Any,
#     756 ) -> Runnable[LanguageModelInput, _DictOrPydantic]:
#     757     """Model wrapper that returns outputs formatted to match the given schema.
#     758
#     759     Args:
#    (...)   1062             # }
#    1063     """  # noqa: E501
# -> 1064     return super().with_structured_output(
#    1065         schema, method=method, include_raw=include_raw, strict=strict, **kwargs
#    1066     )
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_openai\chat_models\base.py:1469, in BaseChatOpenAI.with_structured_output(self, schema, method, include_raw, strict, **kwargs)
#    1464 if schema is None:
#    1465     raise ValueError(
#    1466         "schema must be specified when method is not 'json_mode'. "
#    1467         "Received None."
#    1468     )
# -> 1469 response_format = _convert_to_openai_response_format(schema, strict=strict)
#    1470 llm = self.bind(
#    1471     response_format=response_format,
#    1472     ls_structured_output_format={
#    (...)   1475     },
#    1476 )
#    1477 if is_pydantic_schema:
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_openai\chat_models\base.py:2542, in _convert_to_openai_response_format(schema, strict)
#    2540     else:
#    2541         strict = False
# -> 2542 function = convert_to_openai_function(schema, strict=strict)
#    2543 function["schema"] = function.pop("parameters")
#    2544 response_format = {"type": "json_schema", "json_schema": function}
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_core\utils\function_calling.py:471, in convert_to_openai_function(function, strict)
#     464 else:
#     465     msg = (
#     466         f"Unsupported function\n\n{function}\n\nFunctions must be passed in"
#     467         " as Dict, pydantic.BaseModel, or Callable. If they're a dict they must"
#     468         " either be in OpenAI function format or valid JSON schema with top-level"
#     469         " 'title' and 'description' keys."
#     470     )
# --> 471     raise ValueError(msg)
#     473 if strict is not None:
#     474     if "strict" in oai_function and oai_function["strict"] != strict:
#
# ValueError: Unsupported function
#
# タイア
#
# Functions must be passed in as Dict, pydantic.BaseModel, or Callable. If they're a dict they must either be in OpenAI function format or valid JSON schema with top-level 'title' and 'description' keys.
# During task with name 'formatter' and id 'ef5e96ae-21f0-b286-a343-7a79f8ff2c90'

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.topic_understanding(random.choice(topics),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 graph = GraphBuilder(exam_uid=exam_uid)
#       2 factory = JLPTTaskFactory(graph, level=level)
# ----> 3 content = factory.topic_understanding(random.choice(topics),seq=1)
#       4 display(HTML(_render_result(result=content)))
#
# AttributeError: 'JLPTTaskFactory' object has no attribute 'topic_understanding'

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.keypoint_understanding(random.choice(topics),seq=2)
display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.summary_understanding(random.choice(topics),seq=2)
display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.active_expression((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.immediate_ack((random.choice(topics)),seq=4)
display(HTML(_render_result(result=content)))
