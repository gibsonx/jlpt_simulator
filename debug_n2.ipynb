# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-10 21:05:12,877 - INFO - jlpt - ---Generator----
# 2025-11-10 21:05:22,824 - INFO - jlpt - ---REVISOR---
# 2025-11-10 21:05:23,401 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-10 21:05:23,403 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-10 21:05:23,406 - INFO - jlpt - --- Formatter ---
# 2025-11-10 21:05:23,408 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N2水平撰写试卷。
#
# 任务：你的工作是写3个人之间听起来很自然的对话。要求是2男1女，或者2女一男。
#
# 第一步，你应该介绍对话的背景。
#
# 第二步，生成的对话要求总长度约为500-600字。针对某个话题进行讨论，需要有核心思想。
#
# 第三步，问1个后续问题，问题可以关于是主角的想法、这段话的主题或说话者想表达什么。
# 主题应该适合语言学习者，并反映日常情况。
#
# 第四步，根据听力内容提供多项选择题。这些选项应该测试对对话含义的理解。
#
#
# 说明：
# 格式：遵循正式试卷中的例子的格式，但不要遵循内容。
# 内容：确保词汇限制在N2级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
# 正式试卷：
# <p class='background'>地域のボランティアグループのリーダーとメンバー2人が話しています。</p>
#
# <div class='conversation'>
# - 男1: 僕たちが市と協力して定期的にゴミ拾いをしている事公園、ゴミを置いていっちゃう人が多いよね。何か対策を考えて市役所に提案しようと思うんだ。
# - 女1: お菓子の袋とかペットボトルとか、置いていっちゃう人がいるんですね。
# - 男1: 市の方針でゴミ箱は置かないことになってるからね。
# - 男2: 特にゴミが多いところから対策を考えた方がいいんじゃないですか?ゴミが目立つところに花壇を作るとか。他の公園で花壇を作ったら、その周りはゴミが減ったそうですよ。
# - 男1: ゴミが多いのはベンチの周りだよね?そこに花壇を作るのは難しいと思うんだ。
# - 女1: 私は公園全体を考えた方がいいと思うんですが... [ゴミを持ち帰りましょう] って書いた看板を増やすのはどうですか?
# - 男1: うーん、既にいくつか立ててあるから今以上に増やす必要ないんじゃないかな?</p>
# - 女1: あと私たちボランティアが見回って、ゴミを持って帰ってもらうように直接声をかけるのも効果があると思うんですけど。
# - 男1: ボランティアの負担が大きくなるのはちょっとね。うーん、まず、ゴミが多いところからなんとかしよう。花壇を作る代わりにっていうアイデアが良さそうだね。市役所の担当者に早速提案してみよう。
# </div>
# <a class='follow_up'>公園のゴミを減らすため、何を市役所に提案することにしましたか？</a>
# <ul class='options'>
#     <li>ベンチの近くに花壇を作ること</li>
#     <li>ゴミを捨てないように看板を増やすこと</li>
#     <li>公園を見回ること</li>
#     <li>公園を見回ること</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: キャリア目標について話す
# AI: <p class='background'>大学の友人3人がカフェで将来のキャリアについて話しています。</p>
#
# <div class='conversation'>
# - 女1: 最近、就職活動が本格的に始まって、将来のことを真剣に考えるようになったよ。みんなはどんな仕事に就きたいと思ってる？
# - 男1: 僕はIT企業で働きたいと思ってる。新しい技術に触れられるし、成長できる環境だと思うから。将来的にはプロジェクトリーダーになりたいんだ。
# - 女2: すごいね。私は人と関わる仕事がしたいから、教育関係に興味がある。子どもたちの成長をサポートできる先生になりたいなって思ってる。
# - 女1: 先生かあ、やりがいがありそうだね。私はまだ迷ってるけど、海外で働くことにも興味があるんだ。英語を使う仕事とか、国際的な企業もいいなって。
# - 男1: 海外で働くのは大変そうだけど、いろんな経験ができそうだね。英語は得意なの？
# - 女1: うーん、まだまだだけど、これからもっと勉強したいと思ってる。自分の可能性を広げたいし。
# - 女2: みんなそれぞれ目標があっていいね。私は教育実習が始まるから、まずは現場で経験を積みたい。将来は自分の学校を作るのが夢なんだ。
# - 男1: それは素晴らしい夢だね。僕もリーダーになれるように、今からスキルを身につけていきたいと思うよ。
# - 女1: みんなの話を聞いて、私も自分の目標をもっとはっきりさせたいな。いろいろ挑戦してみるよ。
# </div>
#
# <a class='follow_up'>女2は将来どんなことをしたいと考えていますか？</a>
# <ul class='options'>
#     <li>IT企業で働くこと</li>
#     <li>教育関係の仕事をすること</li>
#     <li>海外で働くこと</li>
#     <li>英語を使う仕事をすること</li>
# </ul>
# 正解:2
# HUMAN: GOOD ENOUGH
# 2025-11-10 21:05:27,360 - INFO - jlpt - Formatter: {'background': '大学の友人3人がカフェで将来のキャリアについて話しています。', 'conversation': [{'gender': 'female1', 'context': '最近、就職活動が本格的に始まって、将来のことを真剣に考えるようになったよ。みんなはどんな仕事に就きたいと思ってる？'}, {'gender': 'male1', 'context': '僕はIT企業で働きたいと思ってる。新しい技術に触れられるし、成長できる環境だと思うから。将来的にはプロジェクトリーダーになりたいんだ。'}, {'gender': 'female2', 'context': 'すごいね。私は人と関わる仕事がしたいから、教育関係に興味がある。子どもたちの成長をサポートできる先生になりたいなって思ってる。'}, {'gender': 'female1', 'context': '先生かあ、やりがいがありそうだね。私はまだ迷ってるけど、海外で働くことにも興味があるんだ。英語を使う仕事とか、国際的な企業もいいなって。'}, {'gender': 'male1', 'context': '海外で働くのは大変そうだけど、いろんな経験ができそうだね。英語は得意なの？'}, {'gender': 'female1', 'context': 'うーん、まだまだだけど、これからもっと勉強したいと思ってる。自分の可能性を広げたいし。'}, {'gender': 'female2', 'context': 'みんなそれぞれ目標があっていいね。私は教育実習が始まるから、まずは現場で経験を積みたい。将来は自分の学校を作るのが夢なんだ。'}, {'gender': 'male1', 'context': 'それは素晴らしい夢だね。僕もリーダーになれるように、今からスキルを身につけていきたいと思うよ。'}, {'gender': 'female1', 'context': 'みんなの話を聞いて、私も自分の目標をもっとはっきりさせたいな。いろいろ挑戦してみるよ。'}], 'follow_up': '女2は将来どんなことをしたいと考えていますか？', 'choices': ['IT企業で働くこと', '教育関係の仕事をすること', '海外で働くこと', '英語を使う仕事をすること'], 'correct_answer': 2}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 graph = GraphBuilder(exam_uid=exam_uid)
#       2 factory = JLPTTaskFactory(graph, level=level)
# ----> 3 content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
#       4 display(HTML(_render_result(result=content)))
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\JLPTTaskFactory.py:306, in JLPTTaskFactory.comprehensive_expression_listen_answer(self, word, seq)
#     293 """
#     294 specific for N2
#     295 :param word:
#     296 :param seq:
#     297 :return:
#     298 """
#     299 obj = self._run_task(
#     300     self.prompts_module.comprehensive_expression_listen_answer_teacher_prompt,
#     301     self.prompts_module.comprehensive_expression_listen_answer_example,
#    (...)    304     word
#     305 )
# --> 306 obj["audio"] = _generate_multi_dialogue(content=obj, type="comprehensive_expression_listen_answer", seq=seq, uid=self.graph.exam_uid)
#     307 return obj
#
# File ~\PycharmProjects\pythonProject\jlpt\libs\Utils.py:305, in _generate_multi_dialogue(content, type, seq, uid)
#     303 if type in ["comprehensive_expression_listen_answer"]:
#     304     follow_up_file = os.path.join(voice_tmp, f"{type}_{seq}_follow_up.wav")
# --> 305     AzureAIVoice(content["follow_up"], voices["nanami"], follow_up_file, speed="-5%")
#     307     output_files.append(os.path.join(voice_source, "ding.wav"))
#     308     output_files.append(follow_up_file)
#
# File ~\PycharmProjects\pythonProject\jlpt\libs\Utils.py:155, in AzureAIVoice(text, voice_name, filename, speed)
#     146 # Wrap the text in SSML with prosody rate
#     147 ssml = f"""
#     148 <speak xmlns="http://www.w3.org/2001/10/synthesis" version="1.0" xml:lang="ja-JP">
#     149     <voice name='{voice_name}'>
#    (...)    152 </speak>
#     153 """
# --> 155 synthesizer.speak_ssml_async(ssml).get()
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\azure\cognitiveservices\speech\speech.py:612, in ResultFuture.get(self)
#     608 """
#     609 Waits until the result is available, and returns it.
#     610 """
#     611 if not self.__resolved:
# --> 612     result_handle = self.__get_function(self._handle)
#     613     if self.__wrapped_type is not None:
#     614         self.__result = self.__wrapped_type(result_handle)
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\azure\cognitiveservices\speech\speech.py:2533, in SpeechSynthesizer.speak_ssml_async.<locals>.resolve_future(handle)
#    2531 def resolve_future(handle: _spx_handle):
#    2532     result_handle = _spx_handle(0)
# -> 2533     _call_hr_fn(fn=_sdk_lib.synthesizer_speak_async_wait_for, *[handle, max_uint32, ctypes.byref(result_handle)])
#    2534     _sdk_lib.synthesizer_async_handle_release(handle)
#    2535     return result_handle
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\azure\cognitiveservices\speech\interop.py:61, in _call_hr_fn(fn, *args)
#      59 def _call_hr_fn(*args, fn):
#      60     fn.restype = _spx_hr
# ---> 61     hr = fn(*args) if len(args) > 0 else fn()
#      62     _raise_if_failed(hr)
#
# KeyboardInterrupt:

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
