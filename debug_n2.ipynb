# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n2'
vocab, topics, grammar = _load_vocab_and_resources(level)
# Out:
# '...をはじめとして'

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))
# Out:
# 2025-12-19 14:48:05,698 - INFO - jlpt - ---Generator----
# 2025-12-19 14:48:08,383 - INFO - jlpt - ---REVISOR---
# 2025-12-19 14:48:10,101 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-12-19 14:48:10,102 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-12-19 14:48:10,103 - INFO - jlpt - --- Formatter ---
# 2025-12-19 14:48:10,104 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N2 level.
#
# Task: Your job is to write a question for a JLPT N2 level exam paper.
# You should write a short sentence and ask candidate to identify the correct kanji writing of a given word in hiragana.
# The number of kanji characters in the options must be the same. The kanji characters must be usded in Japanese daily life.
# The word in hiragana being tested needs to be underlined with <u></u>, no other tags can appear in the sentence.
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content.  The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N2 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Words in sentences should not be used in options
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n .
# - By referring the correct answer(c) in the "Historical Generation" during the question generation, you should ensure that the selection of correct answers (4,3,2,1) remains randomly distributed （25% for each）, avoid selecting the same answer(c) continuously
#
# Formal exam paper:
# --- example 1 ---
# <a>この会社を<u>しぼう</u>した理由を教えてください。</a>
# <ul>
#     <li>指望</li>
#     <li>貴望</li>
#     <li>希望</li>
#     <li>志望</li>
# </ul>
#
# --- example 2 ---
# <a>このセーターにはとても<u>やわらかい</u>毛系が使われている。</a>
# <ul>
#     <li>伸らかい</li>
#     <li>軽らかい</li>
#     <li>暖らかい</li>
#     <li>柔らかい</li>
# </ul>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: みかけ
# AI: <a>駅で<u>みかけ</u>た人が友人に似ていました。</a>
# <ul>
#     <li>見掛</li>
#     <li>味掛</li>
#     <li>未掛</li>
#     <li>美掛</li>
# </ul>
# 正解: 1 .
# HUMAN: GOOD ENOUGH
# 2025-12-19 14:48:12,393 - INFO - jlpt - Formatter: {'html_question': '駅で<u>みかけ</u>た人が友人に似ていました。', 'correct_answer': 1, 'choices': ['見掛', '味掛', '未掛', '美掛']}
# <strong>1番.</strong></br></br><p>駅で<u>みかけ</u>た人が友人に似ていました。</p><ul>
# <li>1. <b>見掛</b> <span style='color:green;'>(correct)</span></li>
# <li>2. 味掛</li>
# <li>3. 未掛</li>
# <li>4. 美掛</li>
# </ul>

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 に入れるのに最もよいものを、1·2・3・4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.words_collocation(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.sentence_structure(word=random.choice(topics),grammar=random.choice(grammar))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-12-19 14:48:12,452 - INFO - jlpt - ---Generator----
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 graph = GraphBuilder(exam_uid=exam_uid)
#       2 factory = JLPTTaskFactory(graph, level=level)
# ----> 3 content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
#       4 display(Markdown(_render_result(result=content)))
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\JLPTTaskFactory.py:142, in JLPTTaskFactory.sentence_structure(self, word, gan_history, grammar)
#     141 def sentence_structure(self, word, gan_history: Optional[str] = "", grammar: Optional[str] = None):
# --> 142     return self._run_task(
#     143         self.prompts_module.structure_selection_teacher_prompt,
#     144         self.prompts_module.structure_selection_example,
#     145         self.prompts_module.structure_selection_reflection_prompt,
#     146         MultipleQuestionOutput,
#     147         word,
#     148         gan_history,
#     149         grammar
#     150     )
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\JLPTTaskFactory.py:46, in JLPTTaskFactory._run_task(self, prompt, example, reflection_prompt, output_cls, word, gan_history, grammar)
#      37 else:
#      38     graph = self.graph.build_agent(
#      39         prompt_text=prompt,
#      40         example=example,
#    (...)     43         gan_history=gan_history
#      44     )
# ---> 46 instance = graph.invoke(
#      47     {"messages": [HumanMessage(content=f"Generate a JLPT question regarding Topic: {word}")]},
#      48     config={"configurable": {"thread_id": "1"}}
#      49 )
#      50 return instance["formatted_output"]
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\main.py:3050, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3047 chunks: list[dict[str, Any] | Any] = []
#    3048 interrupts: list[Interrupt] = []
# -> 3050 for chunk in self.stream(
#    3051     input,
#    3052     config,
#    3053     context=context,
#    3054     stream_mode=["updates", "values"]
#    3055     if stream_mode == "values"
#    3056     else stream_mode,
#    3057     print_mode=print_mode,
#    3058     output_keys=output_keys,
#    3059     interrupt_before=interrupt_before,
#    3060     interrupt_after=interrupt_after,
#    3061     durability=durability,
#    3062     **kwargs,
#    3063 ):
#    3064     if stream_mode == "values":
#    3065         if len(chunk) == 2:
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\main.py:2633, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2631 for task in loop.match_cached_writes():
#    2632     loop.output_writes(task.id, task.writes, cached=True)
# -> 2633 for _ in runner.tick(
#    2634     [t for t in loop.tasks.values() if not t.writes],
#    2635     timeout=self.step_timeout,
#    2636     get_waiter=get_waiter,
#    2637     schedule_task=loop.accept_push,
#    2638 ):
#    2639     # emit output
#    2640     yield from _output(
#    2641         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2642     )
#    2643 loop.after_tick()
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~\PycharmProjects\pythonProject\jlpt\graphs\common\GraphBuilder.py:92, in GraphBuilder.generation_node_builder.<locals>.question_generator(state)
#      89     params["grammar"] = grammar
#      91 # Format the prompt to get the actual text
# ---> 92 resolved_prompt = prompt.format_messages(**params)
#      94 state["messages"].insert(0, resolved_prompt[0])
#      96 generate = prompt | llm
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_core\prompts\chat.py:1214, in ChatPromptTemplate.format_messages(self, **kwargs)
#    1210     result.extend([message_template])
#    1211 elif isinstance(
#    1212     message_template, (BaseMessagePromptTemplate, BaseChatPromptTemplate)
#    1213 ):
# -> 1214     message = message_template.format_messages(**kwargs)
#    1215     result.extend(message)
#    1216 else:
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_core\prompts\chat.py:559, in _StringImageMessagePromptTemplate.format_messages(self, **kwargs)
#     550 def format_messages(self, **kwargs: Any) -> list[BaseMessage]:
#     551     """Format messages from kwargs.
#     552
#     553     Args:
#    (...)    557         List of BaseMessages.
#     558     """
# --> 559     return [self.format(**kwargs)]
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_core\prompts\chat.py:592, in _StringImageMessagePromptTemplate.format(self, **kwargs)
#     583 """Format the prompt template.
#     584
#     585 Args:
#    (...)    589     Formatted message.
#     590 """
#     591 if isinstance(self.prompt, StringPromptTemplate):
# --> 592     text = self.prompt.format(**kwargs)
#     593     return self._msg_class(
#     594         content=text, additional_kwargs=self.additional_kwargs
#     595     )
#     596 content: list = []
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_core\prompts\prompt.py:201, in PromptTemplate.format(self, **kwargs)
#     192 """Format the prompt with the inputs.
#     193
#     194 Args:
#    (...)    198     A formatted string.
#     199 """
#     200 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 201 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File ~\PycharmProjects\pythonProject\jlpt\venv\Lib\site-packages\langchain_core\utils\formatting.py:33, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      28     msg = (
#      29         "No arguments should be provided, "
#      30         "everything should be passed as keyword arguments."
#      31     )
#      32     raise ValueError(msg)
# ---> 33 return super().vformat(format_string, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\string.py:194, in Formatter.vformat(self, format_string, args, kwargs)
#     192 def vformat(self, format_string, args, kwargs):
#     193     used_args = set()
# --> 194     result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
#     195     self.check_unused_args(used_args, args, kwargs)
#     196     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\string.py:234, in Formatter._vformat(self, format_string, args, kwargs, used_args, recursion_depth, auto_arg_index)
#     230     auto_arg_index = False
#     232 # given the field_name, find the object it references
#     233 #  and the argument it came from
# --> 234 obj, arg_used = self.get_field(field_name, args, kwargs)
#     235 used_args.add(arg_used)
#     237 # do any conversion on the resulting object
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\string.py:299, in Formatter.get_field(self, field_name, args, kwargs)
#     296 def get_field(self, field_name, args, kwargs):
#     297     first, rest = _string.formatter_field_name_split(field_name)
# --> 299     obj = self.get_value(first, args, kwargs)
#     301     # loop through the rest of the field_name, doing
#     302     #  getattr or getitem as needed
#     303     for is_attr, i in rest:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\string.py:256, in Formatter.get_value(self, key, args, kwargs)
#     254     return args[key]
#     255 else:
# --> 256     return kwargs[key]
#
# KeyError: 'grammar'
# During task with name 'generator' and id '06368ab2-d739-dfe8-3ae9-a9cb7105a16f'

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_read(random.choice(topics))
display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# # ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### この問題では長めの話を聞きます。この問題には練習はありません。メモをとってもかまいません。問題用紙に何も印刷されていません。まず話を聞いてください。それから、質問とせんたく大力しを聞いて、1から4の中から、最もよいものを-つ選んでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_expression_listen_answer((random.choice(topics)),seq=1)
# display(HTML(_render_result(result=content)))

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_expression_show_answer((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))
