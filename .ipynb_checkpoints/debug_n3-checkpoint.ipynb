# %%
from graphs.common.node_builder import *
import random
from graphs.n3.ExamTaskHandler import ExamTaskHandler
from IPython.display import display, Markdown, HTML
from IPython.display import display, Markdown
from libs.Utils import _render_result,_generate_dialogue,render_to_html,collect_vocabulary

load_dotenv()
# Out:
# True

# %%
n3_vocab = collect_vocabulary("Vocab/n3.csv")
with open("Vocab/topics.txt", "r", encoding="utf-8") as file:
    topics_list = [line.strip() for line in file]
with open("Vocab/sentence_grammar.txt", "r", encoding="utf-8") as file:
    grammar_list = [line.strip() for line in file]
# random_word = random.choice(n3_vocab.split(","))
# random_topic = random.choice(topics_list)

# %% [markdown]
# ## Section 1. Vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# handler = ExamTaskHandler()
# content = handler.kanji_reading(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# handler = ExamTaskHandler()
# content = handler.write_kanji(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# handler = ExamTaskHandler()
# content = handler.word_meaning(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# handler = ExamTaskHandler()
# content = handler.synonym_substitution(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# handler = ExamTaskHandler()
# content = handler.word_usage(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# handler = ExamTaskHandler()
# content = handler.sentence_grammar(random.choice(topics_list),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# handler = ExamTaskHandler()
# content= handler.sentence_sort(random.choice(topics_list),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# handler = ExamTaskHandler()
# content = handler.sentence_structure(random.choice(topics_list),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# handler = ExamTaskHandler()
# content= handler.short_passage_mail_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# handler = ExamTaskHandler()
# content= handler.short_passage_notification_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# handler = ExamTaskHandler()
# content= handler.short_passage_narrative_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# handler = ExamTaskHandler()
# content= handler.midsize_passage_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# handler = ExamTaskHandler()
# content= handler.long_passage_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# handler = ExamTaskHandler()
# content= handler.info_retrieval(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# handler = ExamTaskHandler()
# content= handler.topic_understanding(random.choice(topics_list))
# content_html = _render_result(result=content)
# display(HTML(content_html))
# 
# with open("conversation.html", "w", encoding="utf-8") as f:
#     f.write(content_html)

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# handler = ExamTaskHandler()
# content= handler.keypoint_understanding(random.choice(topics_list),seq=2)
# content_html = _render_result(result=content)
# display(HTML(content_html))
# 
# with open("conversation.html", "w", encoding="utf-8") as f:
#     f.write(content_html)

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
handler = ExamTaskHandler()
content= handler.summary_understanding(word="店で価格を尋ねる",seq=1)
content_html = _render_result(result=content)
display(HTML(content_html))

with open("conversation.html", "w", encoding="utf-8") as f:
    f.write(content_html)
# Out:
# 2025-08-30 16:59:02,160 - INFO - jlpt - ---Generator----
# 2025-08-30 16:59:06,475 - INFO - jlpt - ---REVISOR---
# 2025-08-30 16:59:07,327 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-08-30 16:59:07,328 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-08-30 16:59:07,329 - INFO - jlpt - --- Formatter ---
# 2025-08-30 16:59:07,331 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N3 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman.
# First, you should introduce the background of the dialogue.
# Next, you write a dialogue which consists of 6–7 exchanges (back-and-forth turns). The total length should be approximately 200–300 words.
# After the conversation, ask a follow-up question focusing on what the conversation is about.
# The topic should be appropriate for language learners and reflect everyday situations.
# ...

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
handler = ExamTaskHandler()
content= handler.active_expression((random.choice(topics_list)),seq=1)
content_html = _render_result(result=content)
display(HTML(content_html))

with open("conversation.html", "w", encoding="utf-8") as f:
    f.write(content_html)
# Out:
# 2025-08-30 16:59:56,513 - INFO - jlpt - ---Generator----
# 2025-08-30 16:59:59,631 - INFO - jlpt - ---REVISOR---
# 2025-08-30 17:00:00,290 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-08-30 17:00:00,291 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-08-30 17:00:00,291 - INFO - jlpt - --- Formatter ---
# 2025-08-30 17:00:00,292 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N3 level.
#
# Task: your job is to generate a picture prompt that visually describes a situation.
# Generate Japanese language test questions similar to JLPT situational questions.
# For each question, describe a real-life situation in Japanese and then ask what the person should say in that situation.
# Provide three possible answers in Japanese,
# only one of which is appropriate or most natural for the situation.
# ...

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
handler = ExamTaskHandler()
content= handler.immediate_ack((random.choice(topics_list)),seq=1)
content_html = _render_result(result=content)
display(HTML(content_html))

with open("conversation.html", "w", encoding="utf-8") as f:
    f.write(content_html)
# Out:
# 2025-08-30 17:00:21,602 - INFO - jlpt - ---Generator----
# 2025-08-30 17:00:23,626 - INFO - jlpt - ---REVISOR---
# 2025-08-30 17:00:24,416 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-08-30 17:00:24,417 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-08-30 17:00:24,418 - INFO - jlpt - --- Formatter ---
# 2025-08-30 17:00:24,418 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N3 level.
#
# Task: your job is to write a realistic question that a person (either man or woman randomly) will ask.
# After that, provide three options (1–3) for what the other person might reply as options
# One of the options should be the most appropriate or natural response
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N3 level.
# ...
