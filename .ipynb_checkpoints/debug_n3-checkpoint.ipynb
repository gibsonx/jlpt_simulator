# %%
from graphs.common.node_builder import *
from graphs.common.utils import *
from graphs.common.state import *
from libs.LLMs import azure_llm, azure_ref_llm
import random
from graphs.n3.prompts import *
from langgraph.graph import StateGraph
import logging
from graphs.n3.ExamTaskHandler import ExamTaskHandler
from IPython.display import display, Markdown, HTML
from graphs.common.utils import _render_result,collect_vocabulary
from IPython.display import display, Markdown

load_dotenv()

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
# Out:
# /root/jlpt_venv/lib/python3.12/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
n3_vocab = collect_vocabulary("Vocab/n3.csv")
with open("Vocab/topics.txt", "r", encoding="utf-8") as file:
    topics_list = [line.strip() for line in file]
# random_word = random.choice(n3_vocab.split(","))
# random_topic = random.choice(topics_list)

# %% [markdown]
# ## Section 1. Vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
#handler = ExamTaskHandler()
#content = handler.kanji_reading(random.choice(n3_vocab.split(",")))
#display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# handler = ExamTaskHandler()
# content = handler.write_kanji(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# handler = ExamTaskHandler()
# content = handler.word_meaning(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# handler = ExamTaskHandler()
# content = handler.synonym_substitution(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# handler = ExamTaskHandler()
# content = handler.word_usage(random.choice(n3_vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
handler = ExamTaskHandler()
content = handler.sentence_grammar(random.choice(topics_list))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-08-05 06:34:40,492 - INFO - ---WEB SEARCH---
# 2025-08-05 06:34:40,997 - INFO - ---Generator----
# 2025-08-05 06:34:42,783 - INFO - HTTP Request: POST https://ai-rolandaws880125ai409947751408.openai.azure.com/openai/deployments/gpt-4.1/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-08-05 06:34:42,794 - INFO - Generated message: <a>山田さんは、毎朝7時に家を出て、駅まで歩きます。電車に乗っている（　　　）、ニュースを読んだり音楽を聞いたりします。</a>
# <ul class='options'>
#   <li>間に</li>
#   <li>とき</li>
#   <li>から</li>
#   <li>ので</li>
# </ul>
# 正解：1
# 2025-08-05 06:34:42,796 - INFO - ---REVISOR---
# 2025-08-05 06:34:45,487 - INFO - HTTP Request: POST https://ai-rolandaws880125ai409947751408.openai.azure.com/openai/deployments/gpt-4.1/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-08-05 06:34:45,489 - INFO - Refelect message: Content Accuracy:
# - The question is appropriate for JLPT N3, as it tests a common grammar point (「間に」vs「とき」vs others) and situational vocabulary related to daily routines.
# - The context (commuting, reading news, listening to music) is realistic and culturally relevant for Japanese learners.
#
# Question and Answer Quality:
# - The sentence is clear and free from ambiguity. The blank is positioned to test understanding of temporal expressions.
# - The distractors ("とき", "から", "ので") are plausible but clearly distinguishable at the N3 level.
# - The correct answer, 「間に」, is appropriate because it refers to actions taking place during the duration of another action (while riding the train).
#
# Detailed Refinement:
# - The vocabulary and grammar are suitable for N3.
# - The scenario is culturally appropriate and reflects a typical Japanese daily routine.
# - No issues with clarity, ambiguity, or cultural relevance.
#
# Feedback:
# GOOD ENOUGH
# 2025-08-05 06:34:45,492 - INFO - --- AI Reviser feels Good Enough ---
# 2025-08-05 06:34:45,493 - INFO - --- Formatter ---
# 2025-08-05 06:34:46,146 - INFO - HTTP Request: POST https://ai-rolandaws880125ai409947751408.openai.azure.com/openai/deployments/gpt-4.1/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-08-05 06:34:46,259 - INFO - Formatted message: {'html_question': '山田さんは、毎朝7時に家を出て、駅まで歩きます。電車に乗っている（\u3000\u3000\u3000）、ニュースを読んだり音楽を聞いたりします。', 'correct_answer': 1, 'choices': ['間に', 'とき', 'から', 'ので']}
# <html><body style="text-align: left;">
# <div>
# <p><strong>1. </strong>山田さんは、毎朝7時に家を出て、駅まで歩きます。電車に乗っている（　　　）、ニュースを読んだり音楽を聞いたりします。</p><ul>
# <li>1. <b>間に</b> <span style='color:green;'>(correct)</span></li>
# <li>2. とき</li>
# <li>3. から</li>
# <li>4. ので</li>
# </ul>
# </div>
# </body></html>

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
#handler = ExamTaskHandler()
#content= handler.sentence_sort(random.choice(topics_list))
#display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
 #handler = ExamTaskHandler()
 #content= handler.sentence_structure(random.choice(topics_list))
 #display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# handler = ExamTaskHandler()
# content= handler.short_passage_mail_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# handler = ExamTaskHandler()
# content= handler.short_passage_notification_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# handler = ExamTaskHandler()
# content= handler.short_passage_narrative_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# handler = ExamTaskHandler()
# content= handler.midsize_passage_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# handler = ExamTaskHandler()
# content= handler.long_passage_read(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
#handler = ExamTaskHandler()
#content= handler.info_retrieval(random.choice(topics_list))
#display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
handler = ExamTaskHandler()
content= handler.topic_understanding(random.choice(topics_list))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-08-05 06:34:46,403 - INFO - ---WEB SEARCH---
# 2025-08-05 06:34:46,983 - INFO - ---Generator----
# 2025-08-05 06:34:53,845 - INFO - HTTP Request: POST https://ai-rolandaws880125ai409947751408.openai.azure.com/openai/deployments/gpt-4.1/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-08-05 06:34:53,847 - INFO - Generated message: <p class='background'>家で夫婦がガーデニングについて話しています。妻は新しい花を植えたいと思っています。</p>
#
# <div class='conversation'>
# 女：ねえ、庭の花、だいぶ少なくなってきたね。そろそろ新しいのを植えない？
# 男：そうだね。最近、色がさみしくなってきたから、何か明るい花がいいな。
# 女：私はチューリップが好きだけど、どう思う？
# 男：チューリップもいいけど、ひまわりも育てやすいって聞いたよ。
# 女：ひまわりもいいね。でも、場所がせまいから、両方はむりかな。
# 男：じゃあ、どっちにする？どちらか一つに決めようか。
# 女：うーん…やっぱりチューリップにしようかな。春が楽しみだし。
# 男：わかった。じゃあ、週末にホームセンターに行って、球根を買おうか。
# 女：うん、ありがとう。一緒に植えようね。
# </div>
#
# <a class='follow-up'>この後、夫婦はまず何をしますか。</a>
# <ul class='options'>
#     <li>花をうえるばしょを広げる</li>
#     <li>ホームセンターで球根を買う</li>
#     <li>ひまわりの種をまく</li>
#     <li>庭のそうじをする</li>
# </ul>
# 正解: 2
# 2025-08-05 06:34:53,850 - INFO - ---REVISOR---
# 2025-08-05 06:34:57,704 - INFO - HTTP Request: POST https://ai-rolandaws880125ai409947751408.openai.azure.com/openai/deployments/gpt-4.1/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-08-05 06:34:57,706 - INFO - Refelect message: **Content Accuracy:**
# The conversation and question are appropriate for JLPT N3. The vocabulary and grammar are suitable for this level, and the topic (gardening, daily conversation) is relevant and practical. The question tests reading comprehension and the ability to follow a sequence of actions, which is a key skill at this level.
#
# **Question and Answer Quality:**
# The question is clear and unambiguous. The options are all plausible actions related to gardening, but only one (「ホームセンターで球根を買う」) directly follows the conversation. The distractors are reasonable and not confusing. The correct answer is clearly supported by the conversation.
#
# **Cultural and Academic Appropriateness:**
# The content is culturally appropriate, reflecting a typical Japanese home situation and the common practice of gardening. The use of "ホームセンター" and "球根" is authentic and relevant to Japanese life. There is no inappropriate or culturally insensitive content.
#
# **Detailed Recommendations:**
# - The question and options are well-crafted and at the right difficulty for N3.
# - The use of context (夫婦の会話) is effective for testing comprehension.
# - No ambiguity is present in the question or answer choices.
# - No changes necessary for instructions, format, or context.
#
# **Feedback:**
# GOOD ENOUGH
# 2025-08-05 06:34:57,708 - INFO - --- AI Reviser feels Good Enough ---
# 2025-08-05 06:34:57,709 - INFO - --- Formatter ---
# 2025-08-05 06:35:00,872 - INFO - HTTP Request: POST https://ai-rolandaws880125ai409947751408.openai.azure.com/openai/deployments/gpt-4.1/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-08-05 06:35:00,875 - INFO - Formatted message: {'background': '家で夫婦がガーデニングについて話しています。妻は新しい花を植えたいと思っています。', 'conversation': [{'gender': 'female', 'context': 'ねえ、庭の花、だいぶ少なくなってきたね。そろそろ新しいのを植えない？'}, {'gender': 'male', 'context': 'そうだね。最近、色がさみしくなってきたから、何か明るい花がいいな。'}, {'gender': 'female', 'context': '私はチューリップが好きだけど、どう思う？'}, {'gender': 'male', 'context': 'チューリップもいいけど、ひまわりも育てやすいって聞いたよ。'}, {'gender': 'female', 'context': 'ひまわりもいいね。でも、場所がせまいから、両方はむりかな。'}, {'gender': 'male', 'context': 'じゃあ、どっちにする？どちらか一つに決めようか。'}, {'gender': 'female', 'context': 'うーん…やっぱりチューリップにしようかな。春が楽しみだし。'}, {'gender': 'male', 'context': 'わかった。じゃあ、週末にホームセンターに行って、球根を買おうか。'}, {'gender': 'female', 'context': 'うん、ありがとう。一緒に植えようね。'}], 'html_question': 'この後、夫婦はまず何をしますか。', 'choices': ['花をうえるばしょを広げる', 'ホームセンターで球根を買う', 'ひまわりの種をまく', '庭のそうじをする'], 'correct_answer': 2}
# <html><body style="text-align: left;">
# <div>
# <p><strong>1. </strong>この後、夫婦はまず何をしますか。</p><ul>
# <li>1. 花をうえるばしょを広げる</li>
# <li>2. <b>ホームセンターで球根を買う</b> <span style='color:green;'>(correct)</span></li>
# <li>3. ひまわりの種をまく</li>
# <li>4. 庭のそうじをする</li>
# </ul>
# </div>
# <p><strong>Background: </strong>家で夫婦がガーデニングについて話しています。妻は新しい花を植えたいと思っています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> ねえ、庭の花、だいぶ少なくなってきたね。そろそろ新しいのを植えない？</p>
# <p><strong>Male:</strong> そうだね。最近、色がさみしくなってきたから、何か明るい花がいいな。</p>
# <p><strong>Female:</strong> 私はチューリップが好きだけど、どう思う？</p>
# <p><strong>Male:</strong> チューリップもいいけど、ひまわりも育てやすいって聞いたよ。</p>
# <p><strong>Female:</strong> ひまわりもいいね。でも、場所がせまいから、両方はむりかな。</p>
# <p><strong>Male:</strong> じゃあ、どっちにする？どちらか一つに決めようか。</p>
# <p><strong>Female:</strong> うーん…やっぱりチューリップにしようかな。春が楽しみだし。</p>
# <p><strong>Male:</strong> わかった。じゃあ、週末にホームセンターに行って、球根を買おうか。</p>
# <p><strong>Female:</strong> うん、ありがとう。一緒に植えようね。</p>
# </div>
# </body></html>

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# handler = ExamTaskHandler()
# content= handler.keypoint_understanding(random.choice(topics_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# handler = ExamTaskHandler()
# content= handler.summary_understanding((random.choice(topics_list)))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
# handler = ExamTaskHandler()
# content= handler.active_expression((random.choice(topics_list)))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# handler = ExamTaskHandler()
# content= handler.immediate_ack((random.choice(topics_list)))
# display(Markdown(_render_result(result=content)))
