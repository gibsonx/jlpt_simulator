# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n1'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.kanji_reading(random.choice(vocab.split(",")))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-10-04 12:21:45,980 - INFO - jlpt - ---Generator----
# 2025-10-04 12:21:48,944 - INFO - jlpt - ---REVISOR---
# 2025-10-04 12:21:49,466 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-04 12:21:49,470 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-04 12:21:49,474 - INFO - jlpt - --- Formatter ---
# 2025-10-04 12:21:49,475 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing a test paper for JLPT N1 level.
#
# Task: Your job is to write a pronunciation question corresponding to Japanes kanji for the JLPT N1 level exam paper.
#
# Step 1: Generate a short sentence within 30 words as the question stem. And select a Japanese kanji word to mark as a
# -A must contain at least one Japanese kanji, not every character is a hiragana
#
# Step 2: For word a, underline it.
# The selected words need to be marked with<u></u>, such as<u>主要</u>, and no other tags should appear in the sentence.
# Additional requirements:
# -Words in sentences should not be used in options
# -You must display the correct answer in the output with options 1, 2, 3, 4. For example: Correct solution: 1
#
# Step 3: Generate 4 options for this question. Require all of the following conditions:
# -These 4 options must be different from each other.
# -Only one option is the correct answer.
# -The generated options need to comply with Japanese pronunciation rules and should not generate non-existent pronunciations
# -Assuming that word a consists of 2-3 characters, set them in order as x[0],y[0],z[0] (if a variable is a Japanese kanji, do not display it as hiragana pronunciation). There are four options, including option 1: x[1],y[1],z[1]; Option 2: x[2],y[2],z[2]; Option 3: x[3],y[3],z[3]; Option 4: x[4],y[4],z[4]
# -If x[0] is Japanese hiragana, then: x[1]=x[2]=x[3]=x[4]=x[0]
# -If y[0] is Japanese hiragana, then: y[1]=y[2]=y[3]=y[4]=y[0]
# -If z[0] is Japanese hiragana, then: z[1]=z[2]=z[3]=z[4]=z[0]
# -Print a,x[0],y[0],z[0],x[1],y[1],z[1],x[2],y[2],z[2],x[3],y[3],z[3],x[4],y[4],z[4] in the debugging log; And print the judgment of whether x[0],y[0],z[0] are Japanese hiragana or not
#
# Step 4: output a question.
# Format: Follow the format of the 2 examples in the formal exam paper, not the content. The output must be in HTML format and the line change tag must be removed.
# Content: Ensure vocabulary is limited to N1 level.
# Reference: Get inspiration from the "Topic". Consider the feedback given in the previous conversation (if any)
# Additional requirement: Do not display problem descriptions and serial numbers in the generated content.
#
# Formal exam paper:
# --- example 1 ---
# <a>この町の<u>主要</u>な産業は何ですか。</a>
# <ul>
#     <li>じゅおう</li>
#     <li>しゅおう</li>
#     <li>じゅうよう</li>
#     <li>しゅよう</li>
# </ul>
#
# --- example 2 ---
# <a>今日とても<u>嬉しい</u>ですね。</a>
# <ul>
#     <li>うれしい</li>
#     <li>はれしい</li>
#     <li>まぶしい</li>
#     <li>きびしい</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: ざんだか
# AI: Debugging log:
# a=<u>残高</u>, x[0]=残, y[0]=高, z[0]=, x[1]=ざん, y[1]=だか, z[1]=, x[2]=ざん, y[2]=こう, z[2]=, x[3]=さん, y[3]=だか, z[3]=, x[4]=ざん, y[4]=たか, z[4]=
# Is x[0] hiragana? False
# Is y[0] hiragana? False
# Is z[0] hiragana? True (empty string)
# Correct solution: 1
#
# HTML output:
# <a>口座の<u>残高</u>を確認してください。</a><ul><li>ざんだか</li><li>ざんこう</li><li>さんだか</li><li>ざんたか</li></ul>
# HUMAN: GOOD ENOUGH
# 2025-10-04 12:21:50,264 - INFO - jlpt - Formatter: {'html_question': '口座の<u>残高</u>を確認してください。', 'correct_answer': 1, 'choices': ['ざんだか', 'ざんこう', 'さんだか', 'ざんたか']}
# <strong>1番.</strong></br></br><p>口座の<u>残高</u>を確認してください。</p><ul>
# <li>1. <b>ざんだか</b> <span style='color:green;'>(correct)</span></li>
# <li>2. ざんこう</li>
# <li>3. さんだか</li>
# <li>4. ざんたか</li>
# </ul>

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.topic_understanding_txt(random.choice(topics),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-04 12:21:50,371 - INFO - jlpt - ---Generator----
# 2025-10-04 12:21:52,941 - INFO - jlpt - ---REVISOR---
# 2025-10-04 12:21:53,466 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-04 12:21:53,481 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-04 12:21:53,489 - INFO - jlpt - --- Formatter ---
# 2025-10-04 12:21:53,491 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman.
#
# Step 1, write a concise background about the dialogue introduction, which exclude the follow-up question and character name.
#
# Step 2, Give characters names during the conversation. They should call each name during the conversation depending on their relationship, level of formality.
# Do not refer to them as Mr. or Miss in the conversation context. Be polite and culturally appropriate in how they address each other.
# 女：conversation context
# 男：conversation context
# Besides, the name at the end of a sentence can be omitted.
# For example: "ありがとう、佐藤さん。" the name at the end of a sentence can be omitted, like "ありがとう。"
#
# Step 3, write dialogue, the dialogue should consist of 1-3 exchanges (back-and-forth turns). The total length should be approximately 100–200 words.
#
# Step 4, after the conversation, ask a follow-up question related to the conversation and focusing on the man or woman's next action, such as
# What,When,Where,Who,How,Which,Whose,How long,How often,How much,How many.
#
# Step 5, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>会社で課長と男の人が話しています。</p>
#
# <div class='conversation'>
# 女：田中さん。初めての出張、お疲れ様でした、この出張のレポート詳みました。
# 男：はい。
# 女：出張の目的と訪問した会社で誰に会ったのかはこれています。ただ、話し合いについては最終的にどうなったのかがわかりくいています。そこを直してください。
# 男：はい、わかりました。
# 女：次の訪問日は3ヶ月後になつたんですね。
# 男：はい。
# <p class='follow-up'>男の人は出張レポートのことを直きなければなりませんか？</p>
# </div>
#
# <ul class='options'>
#     <li>しゅっちょうの　もくてき</li>
#     <li>会った人のじょうほう</li>
#     <li>話し合いのけっか</li>
#     <li>つぎのほうもん日/li>
# </ul>
#
# --- example 2 ---
# <p class='background'>会社で男の人と女の人が話しています。</p>
#
# <div class='conversation'>
# 女：あ、田中さん。明日の会議、10時からでしたっけ？
# 男：いいえ、10時じゃなくて、午後1時からですよ。場所はいつもの会議室です。
# 女：あ、そうでしたね。資料はどうすればいいですか？
# 男：事前にメールで送ってください。当日、紙で持ってこなくても大丈夫です。
# <p class='follow-up'>女の人は、何時から会議があると言われましたか。</p>
# </div>
#
# <ul class='options'>
#     <li>午前10時</li>
#     <li>午後1時</li>
#     <li>午後3時</li>
#     <li>午後5時</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 支払い方法について話す
# AI: <p class='background'>レストランで女性と男性が支払いについて話しています。</p>
#
# <div class='conversation'>
# 女：山本さん、今日のランチ、ごちそうさまでした。お会計、どうしますか？割り勘にしますか、それともまとめて払いますか？
# 男：今回は私がまとめて払いますよ。後で、細かく計算してお知らせしますね。
# 女：そうですか。じゃあ、現金とカード、どちらで支払いますか？
# 男：カードで支払います。ポイントも貯まりますし、便利ですから。
# <p class='follow-up'>男性は、どのように支払う予定ですか。</p>
# </div>
#
# <ul class='options'>
#     <li>現金でまとめて払う</li>
#     <li>カードでまとめて払う</li>
#     <li>現金で割り勘にする</li>
#     <li>カードで割り勘にする</li>
# </ul>
#
# 正解: 2
# HUMAN: GOOD ENOUGH
# 2025-10-04 12:21:55,024 - INFO - jlpt - Formatter: {'background': 'レストランで女性と男性が支払いについて話しています。', 'follow_up': '男性は、どのように支払う予定ですか。', 'conversation': [{'gender': 'female', 'context': '山本さん、今日のランチ、ごちそうさまでした。お会計、どうしますか？割り勘にしますか、それともまとめて払いますか？'}, {'gender': 'male', 'context': '今回は私がまとめて払いますよ。後で、細かく計算してお知らせしますね。'}, {'gender': 'female', 'context': 'そうですか。じゃあ、現金とカード、どちらで支払いますか？'}, {'gender': 'male', 'context': 'カードで支払います。ポイントも貯まりますし、便利ですから。'}], 'choices': ['現金でまとめて払う', 'カードでまとめて払う', '現金で割り勘にする', 'カードで割り勘にする'], 'correct_answer': 2}
# 2025-10-04 12:22:14,614 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:22:14,621 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1.wav
# 2025-10-04 12:22:14,634 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:22:14,636 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_background.wav
# 2025-10-04 12:22:14,650 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:22:14,652 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_follow_up.wav
# 2025-10-04 12:22:14,664 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:22:14,667 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_0_speaker.wav
# 2025-10-04 12:22:14,682 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_1_speaker.wav
# 2025-10-04 12:22:14,696 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_2_speaker.wav
# 2025-10-04 12:22:14,710 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_3_speaker.wav
# 2025-10-04 12:22:14,723 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:22:14,729 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_follow_up.wav
# 2025-10-04 12:22:15,073 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_conversation_output.mp3
# 2025-10-04 12:22:17,536 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\topic_understanding_1_conversation_output.mp3 as blob a378a19a-a0d9-11f0-a4e4-d4d8537023ca/topic_understanding_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>レストランで女性と男性が支払いについて話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> 山本さん、今日のランチ、ごちそうさまでした。お会計、どうしますか？割り勘にしますか、それともまとめて払いますか？</p>
# <p><strong>Male:</strong> 今回は私がまとめて払いますよ。後で、細かく計算してお知らせしますね。</p>
# <p><strong>Female:</strong> そうですか。じゃあ、現金とカード、どちらで支払いますか？</p>
# <p><strong>Male:</strong> カードで支払います。ポイントも貯まりますし、便利ですから。</p>
# </div>
# <p><strong>follow-up question: </strong>男性は、どのように支払う予定ですか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/a378a19a-a0d9-11f0-a4e4-d4d8537023ca/topic_understanding_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 現金でまとめて払う</li>
# <li>2. <b>カードでまとめて払う</b> <span style='color:green;'>(correct)</span></li>
# <li>3. 現金で割り勘にする</li>
# <li>4. カードで割り勘にする</li>
# </ul>

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.keypoint_understanding(random.choice(topics),seq=2)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-04 12:22:17,548 - INFO - jlpt - ---Generator----
# 2025-10-04 12:22:21,002 - INFO - jlpt - ---REVISOR---
# 2025-10-04 12:22:21,518 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-04 12:22:21,520 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-04 12:22:21,522 - INFO - jlpt - --- Formatter ---
# 2025-10-04 12:22:21,523 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman. Alternatively, write a personal monologue, ensuring it is logically clear and flows smoothly. The probability of dialogue and monologue appearing is 50% each
#
# If it's a conversation:
#
# Step 1, write a concise background about the dialogue introduction, which exclude the follow-up question and character name.
#
# Step 2, Give characters names during the conversation. They should call each name during the conversation depending on their relationship, level of formality.
# Do not refer to them as Mr. or Miss in the conversation context. Be polite and culturally appropriate in how they address each other.
# 女：conversation context
# 男：conversation context
# Besides, the name at the end of a sentence can be omitted.
# For example: "ありがとう、佐藤さん。" the name at the end of a sentence can be omitted, like "ありがとう。"
#
# Step 3, write dialogue, the dialogue should consist of 3-4 exchanges (back-and-forth turns). The total length should be approximately 150–180 words.
# The topic should be appropriate for language learners and reflect everyday situations.
#
# Step 4, after the conversation, ask a follow-up question focusing on understanding of the motivation or reasoning behind it, encouraging students to think deeply.
# The question should prompt students to choose the best option that matches the overall conversation or key point of the dialogue, examples:
# What is the man's reason for joining this company?
# Why is this tourist spot famous?
# Why is the woman taking the exam?
#
# Step 5, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
# If it's a monologue:
#
# Step 1, write a personal monologue of approximately 150-200 words. The following requirements must be met:
# -Ensure clear thinking, logical coherence, and no grammatical errors in the copy
# -A monologue can be an introduction to an object, an advertisement, or an inner thought process. But they all require specific items or events to occur, and they are relatively close to daily life
#
# Step 2, ask a follow-up question after the monologue ends, focusing on understanding the motivation or reasoning behind it and encouraging students to think deeply.
# This question should prompt students to choose the best option that matches the entire conversation or the key points of the conversation, such as:
# What is the reason for this person joining this company?
# Why is this tourist attraction famous?
# Why did that woman take the exam?
#
# Step 3, provide multiple-choice questions based on the listening content. These options should test understanding of the meaning of the conversation.
#
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>朝、家の玄関で妻と夫が話しています。</p>
#
# <div class='conversation'>
# 女:あれ？どうしたの？忘れ物？書類？
# 男:いや、バス停で待ってたんだけど、なぜかバスがなかなか来なくて。今日は車で会社に行くよ。車の鍵、取ってくれる？
# 女:えー、私、今日車使いたいんだけど・・・会社まで送ってったあげるよ。
# 男:本当？悪いね。走って戻ってきたら、喉渇いちゃった。ちょっと水飲んでくるから待ってて。
# 女:あ、机の上に切手が貼ってあるハガキがあったけど、出さなくていいの？
# 男:あぁ、忘れてた。取ってくるよ。
# <p class='follow-up'>夫はどうしても家に戻ってきましたか？</p>
# </div>
#
# <a class='question'></a>
# <ul class='options'>
#     <li>しょるいをわすれたから</li>
#     <li>車で会社に行くことにしたから</li>
#     <li>のどがかわいたから</li>
#     <li>はがきをわすれたから</li>
# </ul>
#
# --- example 2 ---
# <p class='background'>男の人が新しいスーパーについて話しています</p>
#
# <div class='conversation'>
# 男：昨日、新しいスーパーに行ってみました。駅から歩いて5分くらいで、とても便利です。中は広くて、野菜や果物が安いし、パンも種類が多かったです。ただ、夕方だったのでレジが混んでいて、10分ぐらい待たされました。次は午前中に行こうと思います。
# <p class='follow-up'>男の人は、このスーパーについてどう思っていますか。</p>
# </div>
#
# <ul class='options'>
#     <li>場所が遠くて不便だと思っている</li>
#     <li>品物が高いと思っている</li>
#     <li>品物はよいが、レジが混んでいると思っている</li>
#     <li>午後に行くのが一番いいと思っている</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 道を尋ねる
# AI: <p class='background'>駅前で女性が男性に道を尋ねています。</p>
#
# <div class='conversation'>
# 女：すみません、図書館へ行きたいんですが、どちらの方向ですか？
# 男：図書館ですね。この通りをまっすぐ進んで、三つ目の信号を左に曲がるとすぐ見えますよ。
# 女：三つ目の信号ですね。歩いてどれくらいかかりますか？
# 男：そうですね、急がなければ10分くらいでしょうか。途中に公園があるので、そこを目印にすると分かりやすいですよ。
# 女：ありがとうございます。公園を通れば迷わず行けそうです。助かりました。
# <p class='follow-up'>女性はなぜ男性に話しかけましたか。</p>
# </div>
#
# <ul class='options'>
#     <li>公園の場所を知りたかったから</li>
#     <li>道に迷っていたから</li>
#     <li>図書館への行き方を知りたかったから</li>
#     <li>信号の数を確認したかったから</li>
# </ul>
# 正解: 3
# HUMAN: GOOD ENOUGH
# 2025-10-04 12:22:23,232 - INFO - jlpt - Formatter: {'background': '駅前で女性が男性に道を尋ねています。', 'follow_up': '女性はなぜ男性に話しかけましたか。', 'conversation': [{'gender': 'female', 'context': 'すみません、図書館へ行きたいんですが、どちらの方向ですか？'}, {'gender': 'male', 'context': '図書館ですね。この通りをまっすぐ進んで、三つ目の信号を左に曲がるとすぐ見えますよ。'}, {'gender': 'female', 'context': '三つ目の信号ですね。歩いてどれくらいかかりますか？'}, {'gender': 'male', 'context': 'そうですね、急がなければ10分くらいでしょうか。途中に公園があるので、そこを目印にすると分かりやすいですよ。'}, {'gender': 'female', 'context': 'ありがとうございます。公園を通れば迷わず行けそうです。助かりました。'}], 'choices': ['公園の場所を知りたかったから', '道に迷っていたから', '図書館への行き方を知りたかったから', '信号の数を確認したかったから'], 'correct_answer': 3}
# 2025-10-04 12:22:45,054 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:22:45,055 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2.wav
# 2025-10-04 12:22:45,068 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:22:45,070 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_0_speaker.wav
# 2025-10-04 12:22:45,081 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:22:45,083 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_1_seq.wav
# 2025-10-04 12:22:45,095 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_1_option.wav
# 2025-10-04 12:22:45,106 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_2_seq.wav
# 2025-10-04 12:22:45,116 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_2_option.wav
# 2025-10-04 12:22:45,126 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_3_seq.wav
# 2025-10-04 12:22:45,135 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_3_option.wav
# 2025-10-04 12:22:45,146 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_4_seq.wav
# 2025-10-04 12:22:45,156 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_4_option.wav
# 2025-10-04 12:22:45,361 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_conversation_output.mp3
# 2025-10-04 12:22:45,735 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\keypoint_understanding_2_conversation_output.mp3 as blob a378a19a-a0d9-11f0-a4e4-d4d8537023ca/keypoint_understanding_2_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>駅前で女性が男性に道を尋ねています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> すみません、図書館へ行きたいんですが、どちらの方向ですか？</p>
# <p><strong>Male:</strong> 図書館ですね。この通りをまっすぐ進んで、三つ目の信号を左に曲がるとすぐ見えますよ。</p>
# <p><strong>Female:</strong> 三つ目の信号ですね。歩いてどれくらいかかりますか？</p>
# <p><strong>Male:</strong> そうですね、急がなければ10分くらいでしょうか。途中に公園があるので、そこを目印にすると分かりやすいですよ。</p>
# <p><strong>Female:</strong> ありがとうございます。公園を通れば迷わず行けそうです。助かりました。</p>
# </div>
# <p><strong>follow-up question: </strong>女性はなぜ男性に話しかけましたか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/a378a19a-a0d9-11f0-a4e4-d4d8537023ca/keypoint_understanding_2_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 公園の場所を知りたかったから</li>
# <li>2. 道に迷っていたから</li>
# <li>3. <b>図書館への行き方を知りたかったから</b> <span style='color:green;'>(correct)</span></li>
# <li>4. 信号の数を確認したかったから</li>
# </ul>

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.summary_understanding(random.choice(topics),seq=2)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-04 12:22:45,751 - INFO - jlpt - ---Generator----
# 2025-10-04 12:22:50,336 - INFO - jlpt - ---REVISOR---
# 2025-10-04 12:22:50,841 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-04 12:22:50,844 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-04 12:22:50,846 - INFO - jlpt - --- Formatter ---
# 2025-10-04 12:22:50,847 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman. Alternatively, write a personal monologue, ensuring it is logically clear and flows smoothly. The probability of dialogue and monologue appearing is 50% each
#
# Step 1, you should introduce the background of the dialogue.
#
# Step 2, the total length should be approximately 200–300 words. If you write a dialogue, then the dialogue should consists of 6–7 exchanges (back-and-forth turns).
#
# Step 3, ask a follow-up question focusing on what the protagonist thinks, the theme of this paragraph, or what the speaker wants to express.
# The topic should be appropriate for language learners and reflect everyday situations.
#
# Step 4, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>日本語学校で女の留学生と男の留学生が話しています。</p>
#
# <div class='conversation'>
# - 女: 来月で佐藤先生、学校を辞めちゃうんだよね。
# - 男: 寂しくなるね。
# - 女: うん。ねえ、クラスのみんなで先生に何か記念になるものをあげたいね。
# - 男: あ、いいね。何か身に付けるものとか?
# - 女: 先生おしゃれだし、そういうの選ぶの難しくない? それより私たちで何か作ろうよ。
# - 男: あ、メッセージカードは? クラスのみんなにも書いてもらおうよ。
# - 女: じゃ、スポーツ大会の時に撮ったクラスの集合写真を真ん中に貼って、周りにメッセージを書いてもらう?
# - 男: いいね。皆にももらえるといいね。明日、休み時間にクラスのみんなに話してみよう。
# </div>
#
# <a class='follow-up'>2人は何について話していますか? </a>
# <ul class='options'>
#     <li>先生が学校を辞める理由</li>
#     <li>先生に贈る物</li>
#     <li>クラスからのメッセージ</li>
#     <li>先生との思い出</li>
# </ul>
#
# --- example 2 ---
# <p class='background'>男の人が最近の生活について話しています</p>
#
# <div class='conversation'>
# - 男：最近、仕事が忙しくて、毎日残業しています。帰るのが遅いので、夕食はいつもコンビニで買った弁当です。でも、栄養がよくないと思うし、体も疲れやすくなってきました。だから、これからは少し早く帰って、自分で料理を作るようにしたいと思っています。健康のために、生活を変えなければならないと感じています。
# </div>
#
# <a class='follow-up'>男の人は、何を言いたいのですか？</a>
# <ul class='options'>
#     <li>忙しいので、残業をもっと増やしたい</li>
#     <li>料理を作るのがめんどうだと思っている</li>
#     <li>健康のために、生活を変えたいと思っている</li>
#     <li>コンビニの弁当はおいしくないと思っている</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 本について話す
# AI: <p class='background'>図書館で男の人と女の人が本について話しています。</p>
#
# <div class='conversation'>
# - 男: 最近、何か面白い本を読んだ？
# - 女: うん、先週、友達に勧められた小説を読んだんだけど、すごく感動したよ。
# - 男: へえ、どんな話だったの？
# - 女: 家族の絆を描いた作品で、登場人物の心の動きが丁寧に表現されていたの。読んでいるうちに、自分の家族のことも考えさせられたよ。
# - 男: そういう本って、読後にいろいろ考えさせられるよね。
# - 女: そうなの。普段はミステリーばかり読んでいるけど、たまには違うジャンルもいいなと思った。
# - 男: 僕も最近、歴史に関する本を読んでみたんだ。普段は手に取らないけど、新しい発見があって面白かったよ。
# </div>
#
# <a class='follow-up'>女の人はどんなことを感じましたか？</a>
# <ul class='options'>
#     <li>家族について考えるきっかけになった</li>
#     <li>ミステリーの面白さを再認識した</li>
#     <li>歴史の本に興味を持った</li>
#     <li>友達のおすすめを断った</li>
# </ul>
# 正解: 1
# HUMAN: GOOD ENOUGH
# 2025-10-04 12:22:53,165 - INFO - jlpt - Formatter: {'background': '図書館で男の人と女の人が本について話しています。', 'follow_up': '女の人はどんなことを感じましたか？', 'conversation': [{'gender': 'male', 'context': '最近、何か面白い本を読んだ？'}, {'gender': 'female', 'context': 'うん、先週、友達に勧められた小説を読んだんだけど、すごく感動したよ。'}, {'gender': 'male', 'context': 'へえ、どんな話だったの？'}, {'gender': 'female', 'context': '家族の絆を描いた作品で、登場人物の心の動きが丁寧に表現されていたの。読んでいるうちに、自分の家族のことも考えさせられたよ。'}, {'gender': 'male', 'context': 'そういう本って、読後にいろいろ考えさせられるよね。'}, {'gender': 'female', 'context': 'そうなの。普段はミステリーばかり読んでいるけど、たまには違うジャンルもいいなと思った。'}, {'gender': 'male', 'context': '僕も最近、歴史に関する本を読んでみたんだ。普段は手に取らないけど、新しい発見があって面白かったよ。'}], 'choices': ['家族について考えるきっかけになった', 'ミステリーの面白さを再認識した', '歴史の本に興味を持った', '友達のおすすめを断った'], 'correct_answer': 1}
# 2025-10-04 12:23:38,149 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:23:38,153 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2.wav
# 2025-10-04 12:23:38,166 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:23:38,169 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_background.wav
# 2025-10-04 12:23:38,179 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:23:38,182 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_0_speaker.wav
# 2025-10-04 12:23:38,193 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_1_speaker.wav
# 2025-10-04 12:23:38,208 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_2_speaker.wav
# 2025-10-04 12:23:38,219 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_3_speaker.wav
# 2025-10-04 12:23:38,238 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_4_speaker.wav
# 2025-10-04 12:23:38,252 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_5_speaker.wav
# 2025-10-04 12:23:38,266 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_6_speaker.wav
# 2025-10-04 12:23:38,283 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:23:38,288 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_follow_up.wav
# 2025-10-04 12:23:38,301 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_1_seq.wav
# 2025-10-04 12:23:38,316 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_1_option.wav
# 2025-10-04 12:23:38,335 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_2_seq.wav
# 2025-10-04 12:23:38,356 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_2_option.wav
# 2025-10-04 12:23:38,373 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_3_seq.wav
# 2025-10-04 12:23:38,387 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_3_option.wav
# 2025-10-04 12:23:38,413 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_4_seq.wav
# 2025-10-04 12:23:38,426 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_4_option.wav
# 2025-10-04 12:23:38,973 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_conversation_output.mp3
# 2025-10-04 12:23:40,553 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\summary_understanding_2_conversation_output.mp3 as blob a378a19a-a0d9-11f0-a4e4-d4d8537023ca/summary_understanding_2_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>図書館で男の人と女の人が本について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Male:</strong> 最近、何か面白い本を読んだ？</p>
# <p><strong>Female:</strong> うん、先週、友達に勧められた小説を読んだんだけど、すごく感動したよ。</p>
# <p><strong>Male:</strong> へえ、どんな話だったの？</p>
# <p><strong>Female:</strong> 家族の絆を描いた作品で、登場人物の心の動きが丁寧に表現されていたの。読んでいるうちに、自分の家族のことも考えさせられたよ。</p>
# <p><strong>Male:</strong> そういう本って、読後にいろいろ考えさせられるよね。</p>
# <p><strong>Female:</strong> そうなの。普段はミステリーばかり読んでいるけど、たまには違うジャンルもいいなと思った。</p>
# <p><strong>Male:</strong> 僕も最近、歴史に関する本を読んでみたんだ。普段は手に取らないけど、新しい発見があって面白かったよ。</p>
# </div>
# <p><strong>follow-up question: </strong>女の人はどんなことを感じましたか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/a378a19a-a0d9-11f0-a4e4-d4d8537023ca/summary_understanding_2_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>家族について考えるきっかけになった</b> <span style='color:green;'>(correct)</span></li>
# <li>2. ミステリーの面白さを再認識した</li>
# <li>3. 歴史の本に興味を持った</li>
# <li>4. 友達のおすすめを断った</li>
# </ul>

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.active_expression((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-04 12:23:40,564 - INFO - jlpt - ---Generator----
# 2025-10-04 12:23:44,238 - INFO - jlpt - ---REVISOR---
# 2025-10-04 12:23:44,743 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-04 12:23:44,746 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-04 12:23:44,747 - INFO - jlpt - --- Formatter ---
# 2025-10-04 12:23:44,748 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Create an AI-friendly picture prompt that visually depicts a scene where a question is being asked.
# Indicate clearly who speaks first: if a woman asks the question, a man should be shown answering, and if a man asks, a woman should answer.
# The scene should be illustrated without any background text. And there is a black arrow pointing to the party who is about to answer the question. The arrow must closely follow the party who is about to answer the question.
#
# Generate Japanese language test questions similar to JLPT situational questions.
# For each question, describe a real-life situation in Japanese and then ask what the person should say in that situation.
# Provide three possible answers in Japanese.
# only one of which is appropriate or most natural for the situation.
# The correct answer must be highly relevant to the question and logical. The answer needs to maintain coherence with the previous question and not be too abrupt. For example, according to different scenarios, it is best to add a "あのう〜／へ〜／すみません／わ〜" connector as a buffer.
# The language used in the correct answer needs to match the identity of both interlocutors.
# For example, students must use respectful language towards their teachers, and subordinates must also use respectful language towards their superiors.
# Keep the situations practical and relevant to everyday life in Japan. Do not mention or refer to blurred faces.
#
# The picture description must be in a dedicated section named: background.
# The gender of the character indicated by the arrow in the picture needs to be consistent with the gender of the character generating the conversation.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3. for example: 正解: 1
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>
# The scene shows a young person standing at the entrance of a house, holding a bag and facing three adults who are standing together inside the house.
# The setting is indoors and feels polite and formal, as if the young person is greeting or saying goodbye to the adults.
# Include a vase with flowers on a shelf or table near the entrance.
# There is a black arrow pointing towards the young person.
# </p>
#
# <div class='conversation'>
# - 男: 休みの間、友達の家に泊めてもらいました。帰る時、友達の両親に挨拶します。何と言いますか？
# </div>
#
# <a class='follow_up'>休みの間、友達の家に泊めてもらいました。帰る時、友達の両親に挨拶します。何と言いますか？</a>
# <ul class='options'>
#     <li>お世話になりました</li>
#     <li>お邪魔します</li>
#     <li>気をつけて帰ってください</li>
# </ul>
#
# --- example 2 ---
# <p class='background'>
# The scene takes place in a café or restaurant.
# A woman is sitting at a table with drinks in front of her, speaking to a server who stands beside her table holding a tray with a glass.
# There are additional tables and chairs in the background, with drinks and utensils visible.
# There is a black arrow pointing towards the woman.
# </p>
#
# <div class='conversation'>
# - 女: カフェで窓側の席が空きました。席を変われるかどうか聞きたいです。店員に何と言いますか？
# </div>
#
# <a class='follow_up'>カフェで窓側の席が空きました。席を変われるかどうか聞きたいです。店員に何と言いますか？</a>
# <ul class='options'>
#     <li>あの席に変わってもらえますか</li>
#     <li>窓側の席に座らないといけませんか</li>
#     <li>あっちの席に移れますか</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 通勤について説明する
# AI: <p class='background'>
# The scene depicts an office break room. A woman in business attire is standing near a table with a cup, speaking to a man who is seated and reading a newspaper. There is a window showing a cityscape outside, and a clock on the wall indicates morning hours. The black arrow is pointing towards the man, indicating he is about to answer.
# </p>
#
# <div class='conversation'>
# - 女: 新しく入社した同僚に、毎日の移動方法について尋ねられました。どのように答えますか？
# </div>
#
# <a class='follow_up'>新しく入社した同僚に、毎日の移動方法について尋ねられました。どのように答えますか？</a>
# <ul class='options'>
#     <li>あのう、普段は電車を利用しています</li>
#     <li>へ〜、会社は遠いですね</li>
#     <li>すみません、まだ分かりません</li>
# </ul>
# 正解: 1
# HUMAN: GOOD ENOUGH
# 2025-10-04 12:23:46,246 - INFO - jlpt - Formatter: {'background': 'The scene depicts an office break room. A woman in business attire is standing near a table with a cup, speaking to a man who is seated and reading a newspaper. There is a window showing a cityscape outside, and a clock on the wall indicates morning hours. The black arrow is pointing towards the man, indicating he is about to answer.', 'follow_up': '新しく入社した同僚に、毎日の移動方法について尋ねられました。どのように答えますか？', 'conversation': [{'gender': 'female', 'context': '新しく入社した同僚に、毎日の移動方法について尋ねられました。どのように答えますか？'}], 'choices': ['あのう、普段は電車を利用しています', 'へ〜、会社は遠いですね', 'すみません、まだ分かりません'], 'correct_answer': 1}
# 2025-10-04 12:24:04,618 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:24:04,621 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3.wav
# 2025-10-04 12:24:04,631 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:24:04,633 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_0_speaker.wav
# 2025-10-04 12:24:04,646 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:24:04,649 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_1_seq.wav
# 2025-10-04 12:24:04,659 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_1_option.wav
# 2025-10-04 12:24:04,670 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_2_seq.wav
# 2025-10-04 12:24:04,681 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_2_option.wav
# 2025-10-04 12:24:04,693 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_3_seq.wav
# 2025-10-04 12:24:04,704 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_3_option.wav
# 2025-10-04 12:24:04,934 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_conversation_output.mp3
# 2025-10-04 12:24:05,289 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\active_expression_3_conversation_output.mp3 as blob a378a19a-a0d9-11f0-a4e4-d4d8537023ca/active_expression_3_conversation_output.mp3
# 2025-10-04 12:24:06,004 - INFO - jlpt - pause 60 sec to wait for task 629341d1ac5132c7d196ccff7bb71d9b completion
# 2025-10-04 12:25:22,179 - INFO - jlpt - Attempt 1: Image not ready yet.
# <strong>1番.</strong></br></br><p><strong>Background: </strong>The scene depicts an office break room. A woman in business attire is standing near a table with a cup, speaking to a man who is seated and reading a newspaper. There is a window showing a cityscape outside, and a clock on the wall indicates morning hours. The black arrow is pointing towards the man, indicating he is about to answer.</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> 新しく入社した同僚に、毎日の移動方法について尋ねられました。どのように答えますか？</p>
# </div>
# <p><strong>follow-up question: </strong>新しく入社した同僚に、毎日の移動方法について尋ねられました。どのように答えますか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/a378a19a-a0d9-11f0-a4e4-d4d8537023ca/active_expression_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <div style="margin:1em 0;">
#   <img src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-image-prod/4o_images_629341d1ac5132c7d196ccff7bb71d9b_image_1.png" alt="Result image" style="max-width:30%; border:1px solid #ccc; border-radius:8px;">
# </div>
# <ul>
# <li>1. <b>あのう、普段は電車を利用しています</b> <span style='color:green;'>(correct)</span></li>
# <li>2. へ〜、会社は遠いですね</li>
# <li>3. すみません、まだ分かりません</li>
# </ul>

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.immediate_ack((random.choice(topics)),seq=4)
display(HTML(_render_result(result=content)))
# Out:
# 2025-10-04 12:25:38,296 - INFO - jlpt - ---Generator----
# 2025-10-04 12:25:40,441 - INFO - jlpt - ---REVISOR---
# 2025-10-04 12:25:40,928 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-10-04 12:25:40,930 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-10-04 12:25:40,931 - INFO - jlpt - --- Formatter ---
# 2025-10-04 12:25:40,932 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N3水平撰写试卷。
#
# 任务：出一道符合N3水平的听力题。具体步骤如下：
#
# 步骤1：设置一个场景，两人个人a和b生成一段只有一个回合的对话。要求对话：
# - a的发言字数在20-40个单词左右
# - 贴近日本实际的日常生活。且a和b的对话可以是一男一女，也可以是两个相同性别的人。b对于a的回复，必须自然且符合语境，且不存在歧义，和其他模棱两可的回复
# - 对话通顺、语法正确，语义连贯
# - 对话的用户符合两个对话人的身份。比如学生对老师使用敬语，下属对上司也需要使用敬语，而两个年龄相同的朋友之间，使用普通的平语
#
# 步骤2：a作为首先说话的人，他说的话作为题干。b作为第二个说话的人，他说的话作为答案。
#
# 步骤3：除了b说的话之外，生成额外2个选项，共计3个选项。且要求：
# - 除了b说的话之外，另外两个是错误答案。错误原因：可能因为不符合上下文的回复逻辑，或者是不符合两个对话人身份的回复
# - 错误答案可以与正确答案有一定相似度，对答题人产生一定迷惑性
#
# 说明：
# 格式：遵循正式试卷中2个例子的格式，但不要遵循内容。
# 内容：确保词汇量限制在N3级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3。例如：正解:1.
#
#
# Formal exam paper:
# --- example 1 ---
# <a class='follow_up'> 女：足、痛そうだね。年後のテニスの練習、休んだら？</a>
# <ul class='options'>
# 　<li>そうです、今日は帰るね</li>
# 　<li>今日は練習、ないんだね</li>
# 　<li>テニス、今日は休むの？</li>
# </ul>
#
# --- example 2 ---
# <a class='follow_up'>男：町の花火大会、今年はやらないことになったそうだよ。</a>
# <ul class='options'>
# 　<li>やらないもしれなかったね</li>
# 　<li>え？なんて？楽しみにしていたのに…</li>
# 　<li>じゃ、見に行かなきゃね</li>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 課題と解決策について話す
# AI: <a class='follow_up'>女：レポートの締め切りが明日なのに、まだ半分しか終わっていないんだ。どうしたらいいかな。</a>
# <ul class='options'>
# 　<li>じゃ、一緒に図書館でやろうか？</li>
# 　<li>もう全部終わったんだね</li>
# 　<li>締め切りは来週だと思うよ</li>
# </ul>
# 正解:1.
# HUMAN: GOOD ENOUGH
# 2025-10-04 12:25:42,314 - INFO - jlpt - Formatter: {'follow_up': '女：レポートの締め切りが明日なのに、まだ半分しか終わっていないんだ。どうしたらいいかな。', 'conversation': [{'gender': 'female', 'context': 'レポートの締め切りが明日なのに、まだ半分しか終わっていないんだ。どうしたらいいかな。'}], 'choices': ['じゃ、一緒に図書館でやろうか？', 'もう全部終わったんだね', '締め切りは来週だと思うよ'], 'correct_answer': 1}
# 2025-10-04 12:25:59,746 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-10-04 12:25:59,748 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4.wav
# 2025-10-04 12:25:59,759 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:25:59,763 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_0_speaker.wav
# 2025-10-04 12:25:59,777 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-10-04 12:25:59,779 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_1_seq.wav
# 2025-10-04 12:25:59,788 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_1_option.wav
# 2025-10-04 12:25:59,801 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_2_seq.wav
# 2025-10-04 12:25:59,811 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_2_option.wav
# 2025-10-04 12:25:59,821 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_3_seq.wav
# 2025-10-04 12:25:59,831 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_3_option.wav
# 2025-10-04 12:26:00,057 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_conversation_output.mp3
# 2025-10-04 12:26:00,404 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\a378a19a-a0d9-11f0-a4e4-d4d8537023ca\immediate_ack_4_conversation_output.mp3 as blob a378a19a-a0d9-11f0-a4e4-d4d8537023ca/immediate_ack_4_conversation_output.mp3
# <strong>1番.</strong></br></br><div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> レポートの締め切りが明日なのに、まだ半分しか終わっていないんだ。どうしたらいいかな。</p>
# </div>
# <p><strong>follow-up question: </strong>女：レポートの締め切りが明日なのに、まだ半分しか終わっていないんだ。どうしたらいいかな。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/a378a19a-a0d9-11f0-a4e4-d4d8537023ca/immediate_ack_4_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>じゃ、一緒に図書館でやろうか？</b> <span style='color:green;'>(correct)</span></li>
# <li>2. もう全部終わったんだね</li>
# <li>3. 締め切りは来週だと思うよ</li>
# </ul>
