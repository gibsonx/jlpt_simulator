# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n1'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(word=random.choice(vocab.split(",")),gan_history="text")
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(word=random.choice(topics),grammar=random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.midsize_passage_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2026-01-25 14:02:36,993 - INFO - jlpt - ---Generator----
# 2026-01-25 14:02:45,951 - INFO - jlpt - ---REVISOR---
# 2026-01-25 14:02:48,413 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2026-01-25 14:02:48,415 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2026-01-25 14:02:48,416 - INFO - jlpt - --- Formatter ---
# 2026-01-25 14:02:48,417 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a reading question for a JLPT N1 level exam.
# First you need to write a mid-size article around 450 words for student to read.
# The keypoints being tested in each question needs to be underlined with <u></u>
# Then, you give 2 questions by the related content in the article. the meaning of keypoint cannot be found in the article.
# Then, you give a question by the related content in the article.
# Instead, it should require the test-taker to infer, summarize, or understand the context or intent of the passage.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Words in sentences should not be used in options
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n .
# - By referring the correct answer(c) in the "Historical Generation" during the question generation, you should ensure that the selection of correct answers (4,3,2,1) remains randomly distributed （25% for each）, avoid selecting the same answer(c) continuously
#
# Formal exam paper:
# --- example1----
# <div class="article" style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; background-color: #f9f9f9; color: #333;">
#     <p style="margin-bottom: 1.5em; text-align: justify;">以下は、羽毛を持つ恐竜について述べられた文章である。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">恐竜には、鳥のように卵を温める習性があったことがわかっています。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify; font-size: 0.9em; color: #555; margin-left: 1em;">（中略）</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">気になるのは、いつから卵を温めるようになったのかということですが、羽毛を持った時点で、卵を温める習性も持っていた可能性があります。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">羽毛を持つことで、体温が維持できるようになるので、その体温を使って卵の温度を一定に保つことができます。特に夜間は気温が下がるので、夜に親が卵の上に座って眠っていれば、卵の保温にはとても効果的です。卵が一定の温かさで保たれていれば、さまざまな環境で卵が孵る確率が高くなります。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">は虫類は卵を温めません。は虫類の卵は、放置されても、1日のうちある程度の時間、気温が30度を超えるなどの条件が整っていれば、自然と孵ります。その代わり、は虫類は1年のうち気温の高い限られた時期にしか産卵しません。生息地域も限られます。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">羽毛のある恐竜が、鳥に近い体温を持っていたとすれば、夏以外の季節でも、寒冷地でも、安定して35～40度ほどの温度で卵を温めることが可能です。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">厳密に言うと、羽毛があると体の熱を逃がさないので、卵を温めるには不向きです。人間で言うと、衣服の上からでは温めにくいのと同じです。温めるなら、服の中に入れて直接体温が伝わるようにするはずです。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">卵を抱く時期の鳥も、卵と接する部分の羽毛がなくなり、皮膚がむき出しになります。恐竜が卵を温めていたとすれば、おそらく同じように、お腹のあたりの羽毛が抜けていたと思われます。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify; font-size: 0.9em; color: #555; margin-left: 1em;">（注）生息地域：生活している地域</p>
# </div>
#
# <div class="follow-up">
#     <a>筆者によると、羽毛を持つことにはどのような利点があるか。</a>
#     <ul class="options">
#         <li>低温の環境でも、卵を一定の温かさで保つことができる。</li>
#         <li>低温の環境でも、卵の成長を促し早く孵すことができる。</li>
#         <li>環境にかかわらず体温が維持でき、卵が多く産める。</li>
#         <li>環境に合わせて卵の温度を調整でき、早く孵すことができる。</li>
#     </ul>
#
#     <a>お腹のあたりの羽毛が抜けていたと思われますとあるが、筆者はなぜそう考えるのか。</a>
#     <ul class="options">
#         <li>体の熱を逃がすことで、卵を温めすぎるのを防げるから</li>
#         <li>皮膚から卵に直接体温が伝わることで、効率的に卵を温められるから</li>
#         <li>卵に皮膚を直接当てることで、卵の温度を知ることができるから</li>
#         <li>卵と接する部分の皮膚がむき出しになることで、卵が抱きやすくなるから</li>
#     </ul>
# </div>
#
# ---example2---
# <div class="article" style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; color: #333; background-color: #f9f9f9;">
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         以下は、羽毛を持つ恐竜について述べられた文章である。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         恐竜には、鳥のように卵を温める習性があったことがわかっています。
#     </p>
#
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">
#         （中略）
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         気になるのは、いつから卵を温めるようになったのかということですが、羽毛を持った時点で、卵を温める習性も持っていた可能性があります。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         羽毛を持つことで、体温が維持できるようになるので、その体温を使って卵の温度を一定に保つことができます。特に夜間は気温が下がるので、夜に親が卵の上に座って眠っていれば、卵の保温にはとても効果的です。卵が一定の温かさで保たれていれば、さまざまな環境で卵が孵る確率が高くなります。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         は虫類は卵を温めません。は虫類の卵は、放置されても、1日のうちある程度の時間、気温が30度を超えるなどの条件が整っていれば、自然と孵ります。その代わり、は虫類は1年のうち気温の高い限られた時期にしか産卵しません。生息地域も限られます。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         羽毛のある恐竜が、鳥に近い体温を持っていたとすれば、夏以外の季節でも、寒冷地でも、安定して35～40度ほどの温度で卵を温めることが可能です。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         厳密に言うと、羽毛があると体の熱を逃がさないので、卵を温めるには不向きです。人間で言うと、衣服の上からでは温めにくいのと同じです。温めるなら、服の中に入れて直接体温が伝わるようにするはずです。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         卵を抱く時期の鳥も、卵と接する部分の羽毛がなくなり、皮膚がむき出しになります。恐竜が卵を温めていたとすれば、おそらく同じように、
#         <span style="text-decoration: underline; text-underline-offset: 2px;">お腹のあたりの羽毛が抜けていたと思われます。</span>
#     </p>
#
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">
#         （注）生息地域：生活している地域
#     </p>
# </div>
#
# <div class="follow-up">
# <a>筆者によると、羽毛を持つことにはどのような利点があるか。</a>
# <ul class="options">
#     <li>低温の環境でも、卵を一定の温かさで保つことができる。</li>
#     <li>低温の環境でも、卵の成長を促し早く孵すことができる。</li>
#     <li>環境にかかわらず体温が維持でき、卵が多く産める。</li>
#     <li>環境に合わせて卵の温度を調整でき、早く孵すことができる。</li>
# </ul>
#
# <a><span class="underline">お腹のあたりの羽毛が抜けていたと思われます</span>とあるが、筆者はなぜそう考えるのか。</a>
# <ul class="options">
#     <li>体の熱を逃がすことで、卵を温めすぎるのを防げるから</li>
#     <li>皮膚から卵に直接体温が伝わることで、効率的に卵を温められるから</li>
#     <li>卵に皮膚を直接当てることで、卵の温度を知ることができるから</li>
#     <li>卵と接する部分の皮膚がむき出しになることで、卵が抱きやすくなるから</li>
# </ul>
# </div>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: 家事の分担について話す
# AI: <div class="article" style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; background-color: #f9f9f9; color: #333;">
#     <p style="margin-bottom: 1.5em; text-align: justify;">現代社会において、家庭内の役割分担は大きく変化してきている。かつては、家事は主に女性が担うものとされていたが、近年では男女ともに仕事を持つ家庭が増え、<u>家事の分担について話し合う機会が多くなっている</u>。この変化は、家族の在り方や価値観の多様化とも密接に関係している。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">家事の分担を巡る議論では、単純に作業量を均等にするだけではなく、各自の得意分野や生活リズムを考慮することが重要だとされる。例えば、料理が得意な人が食事を担当し、掃除が苦手な人は他の役割を担うなど、柔軟な分担が求められる。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">また、<u>家事の分担がうまくいかない場合、家庭内のストレスや不満が蓄積しやすい</u>。そのため、定期的に話し合いを持ち、状況に応じて分担を見直すことが推奨されている。特に子育てや介護など、家事以外の負担が増える時期には、家族全員の協力が不可欠となる。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">一方で、家事の分担に関する意識は、世代や地域によっても異なる。都市部では共働き世帯が多く、分担の必要性が強く認識されているが、地方では従来の役割分担が根強く残っている場合もある。こうした背景を踏まえ、社会全体で家事の分担について考えることが、より良い家庭環境を築くために重要だと言える。</p>
#     <p style="margin-bottom: 1.5em; text-align: justify;">家事の分担は単なる作業の割り振りではなく、家族のコミュニケーションや相互理解を深める機会でもある。公平な分担を目指すことで、家族の絆が強まり、日々の生活がより充実したものとなるだろう。</p>
# </div>
#
# <div class="follow-up">
#     <a><span class="underline">家事の分担について話し合う機会が多くなっている</span>とあるが、その背景として最も適切なものはどれか。</a>
#     <ul class="options">
#         <li>家庭内での役割が固定されているため</li>
#         <li>家族の人数が減少しているため</li>
#         <li>共働き世帯が増加しているため</li>
#         <li>家事の内容が複雑化しているため</li>
#     </ul>
#     正解: 3
#     <a><span class="underline">家事の分担がうまくいかない場合、家庭内のストレスや不満が蓄積しやすい</span>とあるが、これを防ぐために推奨されていることは何か。</a>
#     <ul class="options">
#         <li>家事を外部に委託すること</li>
#         <li>家族で定期的に話し合うこと</li>
#         <li>役割を一人に集中させること</li>
#         <li>作業を自動化すること</li>
#     </ul>
#     正解: 2
#     <a>この文章全体を通して、筆者が家事の分担について最も強調したいことは何か。</a>
#     <ul class="options">
#         <li>家事の分担は家族の関係性を深める重要な要素である</li>
#         <li>家事の分担は世代によって大きく異なるものである</li>
#         <li>家事の分担は外部の支援を活用するべきである</li>
#         <li>家事の分担は都市部でのみ必要とされるものである</li>
#     </ul>
#     正解: 1
# </div>
# HUMAN: GOOD ENOUGH
# 2026-01-25 14:02:53,833 - INFO - jlpt - Formatter: {'html_article': '<div class="article" style="font-family: \'Segoe UI\', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; background-color: #f9f9f9; color: #333;"><p style="margin-bottom: 1.5em; text-align: justify;">現代社会において、家庭内の役割分担は大きく変化してきている。かつては、家事は主に女性が担うものとされていたが、近年では男女ともに仕事を持つ家庭が増え、<u>家事の分担について話し合う機会が多くなっている</u>。この変化は、家族の在り方や価値観の多様化とも密接に関係している。</p><p style="margin-bottom: 1.5em; text-align: justify;">家事の分担を巡る議論では、単純に作業量を均等にするだけではなく、各自の得意分野や生活リズムを考慮することが重要だとされる。例えば、料理が得意な人が食事を担当し、掃除が苦手な人は他の役割を担うなど、柔軟な分担が求められる。</p><p style="margin-bottom: 1.5em; text-align: justify;">また、<u>家事の分担がうまくいかない場合、家庭内のストレスや不満が蓄積しやすい</u>。そのため、定期的に話し合いを持ち、状況に応じて分担を見直すことが推奨されている。特に子育てや介護など、家事以外の負担が増える時期には、家族全員の協力が不可欠となる。</p><p style="margin-bottom: 1.5em; text-align: justify;">一方で、家事の分担に関する意識は、世代や地域によっても異なる。都市部では共働き世帯が多く、分担の必要性が強く認識されているが、地方では従来の役割分担が根強く残っている場合もある。こうした背景を踏まえ、社会全体で家事の分担について考えることが、より良い家庭環境を築くために重要だと言える。</p><p style="margin-bottom: 1.5em; text-align: justify;">家事の分担は単なる作業の割り振りではなく、家族のコミュニケーションや相互理解を深める機会でもある。公平な分担を目指すことで、家族の絆が強まり、日々の生活がより充実したものとなるだろう。</p></div>', 'questions': [{'html_question': '<span class="underline">家事の分担について話し合う機会が多くなっている</span>とあるが、その背景として最も適切なものはどれか。', 'correct_answer': 3, 'choices': ['家庭内での役割が固定されているため', '家族の人数が減少しているため', '共働き世帯が増加しているため', '家事の内容が複雑化しているため']}, {'html_question': '<span class="underline">家事の分担がうまくいかない場合、家庭内のストレスや不満が蓄積しやすい</span>とあるが、これを防ぐために推奨されていることは何か。', 'correct_answer': 2, 'choices': ['家事を外部に委託すること', '家族で定期的に話し合うこと', '役割を一人に集中させること', '作業を自動化すること']}, {'html_question': 'この文章全体を通して、筆者が家事の分担について最も強調したいことは何か。', 'correct_answer': 1, 'choices': ['家事の分担は家族の関係性を深める重要な要素である', '家事の分担は世代によって大きく異なるものである', '家事の分担は外部の支援を活用するべきである', '家事の分担は都市部でのみ必要とされるものである']}]}
# <strong>1番.</strong></br></br><div class="article" style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; background-color: #f9f9f9; color: #333;"><p style="margin-bottom: 1.5em; text-align: justify;">現代社会において、家庭内の役割分担は大きく変化してきている。かつては、家事は主に女性が担うものとされていたが、近年では男女ともに仕事を持つ家庭が増え、<u>家事の分担について話し合う機会が多くなっている</u>。この変化は、家族の在り方や価値観の多様化とも密接に関係している。</p><p style="margin-bottom: 1.5em; text-align: justify;">家事の分担を巡る議論では、単純に作業量を均等にするだけではなく、各自の得意分野や生活リズムを考慮することが重要だとされる。例えば、料理が得意な人が食事を担当し、掃除が苦手な人は他の役割を担うなど、柔軟な分担が求められる。</p><p style="margin-bottom: 1.5em; text-align: justify;">また、<u>家事の分担がうまくいかない場合、家庭内のストレスや不満が蓄積しやすい</u>。そのため、定期的に話し合いを持ち、状況に応じて分担を見直すことが推奨されている。特に子育てや介護など、家事以外の負担が増える時期には、家族全員の協力が不可欠となる。</p><p style="margin-bottom: 1.5em; text-align: justify;">一方で、家事の分担に関する意識は、世代や地域によっても異なる。都市部では共働き世帯が多く、分担の必要性が強く認識されているが、地方では従来の役割分担が根強く残っている場合もある。こうした背景を踏まえ、社会全体で家事の分担について考えることが、より良い家庭環境を築くために重要だと言える。</p><p style="margin-bottom: 1.5em; text-align: justify;">家事の分担は単なる作業の割り振りではなく、家族のコミュニケーションや相互理解を深める機会でもある。公平な分担を目指すことで、家族の絆が強まり、日々の生活がより充実したものとなるだろう。</p></div>
# <p><strong>1.<span class="underline">家事の分担について話し合う機会が多くなっている</span>とあるが、その背景として最も適切なものはどれか。</strong></p>
# <ul>
# <li>家庭内での役割が固定されているため</li>
# <li>家族の人数が減少しているため</li>
# <li><b>共働き世帯が増加しているため</b> <span style='color:green;'>(correct)</span></li>
# <li>家事の内容が複雑化しているため</li>
# </ul>
# <p><strong>2.<span class="underline">家事の分担がうまくいかない場合、家庭内のストレスや不満が蓄積しやすい</span>とあるが、これを防ぐために推奨されていることは何か。</strong></p>
# <ul>
# <li>家事を外部に委託すること</li>
# <li><b>家族で定期的に話し合うこと</b> <span style='color:green;'>(correct)</span></li>
# <li>役割を一人に集中させること</li>
# <li>作業を自動化すること</li>
# </ul>
# <p><strong>3.この文章全体を通して、筆者が家事の分担について最も強調したいことは何か。</strong></p>
# <ul>
# <li><b>家事の分担は家族の関係性を深める重要な要素である</b> <span style='color:green;'>(correct)</span></li>
# <li>家事の分担は世代によって大きく異なるものである</li>
# <li>家事の分担は外部の支援を活用するべきである</li>
# <li>家事の分担は都市部でのみ必要とされるものである</li>
# </ul>

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(understanding_read)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.understanding_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2026-01-25 14:02:53,843 - INFO - jlpt - ---Generator----
# 2026-01-25 14:03:05,621 - INFO - jlpt - ---REVISOR---
# 2026-01-25 14:03:07,945 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2026-01-25 14:03:07,948 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2026-01-25 14:03:07,949 - INFO - jlpt - --- Formatter ---
# 2026-01-25 14:03:07,951 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N1水平撰写试卷。
#
# 任务：你的工作是为JLPT N1水平考试写一道阅读题。
# 首先，你需要写一篇大约800字的长篇文章供学生阅读。
# 然后，根据文章中的相关内容给出3个问题。
# 目的是确保学生能够理解文章的内容。
#
# 说明：
# 格式：遵循正式试卷中示例的格式，而不是内容。输出必须为html格式，并删除行更改标记。
# 内容：确保词汇量限制在N1级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈和批评（如果存在）,避免重复生成"历史题目"的问题(q)或给出的答案(a)。
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。问题中的单词也不能出现在选项中
# -在输出中显示正确答案，选项为4,3,2,1 随机例如：正解：n, 考虑历史题目的正确答案（c）, 正确答案分布要随机平均（25%），避免重复选同一答案
#
#
# 正式试卷：
# <div class="article" style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; color: #333; background-color: #f9f9f9;">
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         以下は、ある数学者が描いた文章である。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         数学というものは、解き方がわかってしまったあとで、力がつくことはない。解き方を身につける前の、まだ解き方のわからない間だけが、力をつけるチャンスである。解けるようになるのは同じでも、それまでのあり方で、力が身につくかどうかが、きまってくる。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         それに、おもしろいのも、本当は、まだ解けないで、いろいろと考えている間である。解けなきゃつまらないようだが、それは早く解こうとあせるからで、楽しみは解けるまでのほうにある。解けるようになったあとは、むしろむなしい。だいたい、「答えのわかっている謎」なんて、意味がない。解き方がわからないからこそ、問題の名にあたいするのだ。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         もちろん、まったく手がつかないのでは、おもしろくもないが、案外に、多少はわからないでも、うまく
#         <span style="text-decoration: underline; text-underline-offset: 2px;">頭のなかに飼っておくと</span>、
#         そのうちに馴れてくれて、わかってきたりする。その、だんだん少しずつ、わかりかけというのも、オツなものだ。そのためには、それを飼っておく、頭の牧場がゆたかでなければならない。本当のところは、数学の力というのは、いろいろとわかったことをためこむより、わからないのを飼っておける、その牧場のゆたかさのほうにあるのかもしれない。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         とくに、公式などをおぼえるのには、ぼくは反対である。それは簡単すぎて、少しもおもしろくないし、おぼえたものは忘れるものだ。とくに、急いでおぼえたものは、早く忘れる。同じおぼえるにしても、なるべくなら時間をかけたほうが、長持ちする。
#     </p>
#
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">
#         （中略）
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         このごろは、テストでおどされることが多いので、わかること、解けることを急ぐ傾向にある。たしかに、テストなどでは、時間がかぎられているので、急ぐのも多少は仕方がない。しかしながら、時間を制限されたときに急いでできるためには、時間の制限されていないときに、時間を気にしないでやっておいたほうがよい。テストで急ぐためには、テスト以外で急がないほうがよいのである。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         どんなやり方でも、わかって、問題が解けるようになる、という結果は同じかもしれない。しかし、ゆったりとやると、そのわかり方にコクが出てくるものだ。そして、その結果に達するまでの道筋を楽しむことで、力がつく。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         勉強を楽しむなんて、と思うかもしれないが、それは目的ばかり見てあせるからで、楽しむ気になれば、なんだって楽しめるものだ。
#     </p>
#
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">(注1)手がつかない：ここでは、できない</p>
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">(注2)オツな：ここでは、おもしろい</p>
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">(注3)おどされる：ここでは、早く問題を解かされる</p>
#     <p style="font-size: 0.9em; color: #555; margin-left: 1em; margin-top: 1.5em;">(注4)コク：深み。</p>
#
# </div>
#
#
# <a>数学の問題を解くことについて、筆者の考えに合うのはどれか。</a>
# <ul class="options">
#     <li>早く解けなくても、解き方を身につけることが大切だ。</li>
#     <li>解けても解けなくても、問題に取り組むことが大切だ。</li>
#     <li>解けなかった問題が解けるようになったらおもしろくなる。</li>
#     <li>解き方のわからない問題を解こうとすることに意味がある。</li>
# </ul>
#
# <a><span class="underline">頭のなかに飼っておく</span>とはどういうことか。</a>
# <ul class="options">
#     <li>わかる問題を手がかりにして、わからない問題を考えること</li>
#     <li>わかる問題とわからない問題を、頭のなかで区別しておくこと。</li>
#     <li>わからない問題をわかるまで解き続けていること</li>
#     <li>わからない状態のまま、問題を頭のなかに残しておくこと</li>
# </ul>
#
# <a>筆者によると、どのように勉強すればよいか。</a>
# <ul class="options">
#     <li>結果を急がずに、考えることを楽しむ。</li>
#     <li>結果に達することができれば、どんなやり方でもよい。</li>
#     <li>目的を忘れないで、あせらずに勉強を楽しめばよい。</li>
#     <li>自分に合ったやり方を探して、時間を気にせず取り組む。</li>
# </ul>
#
# </body>
# </html>
#
# 历史题目:
#
# HUMAN: Generate a JLPT question regarding Topic: 学校や職場での一日の流れについて話す
# AI: <div class="article" style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; line-height: 1.8; max-width: 800px; margin: 40px auto; padding: 20px; color: #333; background-color: #f9f9f9;">
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         私は現在、都内の中規模な企業で働いている。毎朝、通勤電車に揺られながら、今日一日がどのように過ぎていくのかを考えるのが習慣になっている。会社に到着すると、まずはメールの確認から始まる。急ぎの連絡が入っていないかをチェックし、必要に応じて返信をする。その後、部署ごとに行われる朝礼に参加し、上司からの連絡事項や当日の業務内容について共有される。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         午前中は、主に資料作成や会議の準備に時間を割くことが多い。特に週の初めは、前週の業務報告書をまとめたり、今週の目標を設定したりする作業が中心となる。昼休みになると、同僚と近くの飲食店で昼食をとることが多い。昼食後は、気分転換も兼ねて少し散歩をすることもある。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         午後は、会議や打ち合わせが続くことが多い。プロジェクトの進捗状況を報告したり、取引先との打ち合わせに参加したりする。時には、急な依頼が舞い込むこともあり、予定していた作業を後回しにせざるを得ないこともある。そのような場合でも、優先順位を考えながら柔軟に対応することが求められる。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         夕方になると、日中に発生した課題や未処理の業務を整理し、翌日に備えてタスクをまとめる。退社前には、再度メールを確認し、必要な連絡を済ませる。仕事を終えて会社を出ると、ほっとした気持ちになることが多い。帰宅後は、趣味の読書や音楽を楽しみながら、翌日のエネルギーを蓄えるようにしている。
#     </p>
#
#     <p style="margin-bottom: 1.5em; text-align: justify;">
#         このように、私の一日は決して特別なものではないが、日々の積み重ねが自分自身の成長につながっていると感じている。忙しい中にも小さな達成感や充実感を見つけることが、仕事を続ける上での大きな支えとなっている。
#     </p>
#
# </div>
#
# <a>筆者の午前中の過ごし方として最も適切なのはどれか。</a>
# <ul class="options">
#     <li>会議や打ち合わせに参加することが多い。</li>
#     <li>資料作成や業務報告書の作成に集中することが多い。</li>
#     <li>取引先との連絡を優先して行うことが多い。</li>
#     <li>昼食後に気分転換のために散歩をすることが多い。</li>
# </ul>
# 正解：2
#
# <a>午後に起こりうることとして本文から考えられるのはどれか。</a>
# <ul class="options">
#     <li>予定していた作業をすべて終わらせることができる。</li>
#     <li>急な依頼が来ても、必ず断ることができる。</li>
#     <li>状況に応じて優先順位を変えて対応することがある。</li>
#     <li>昼休みの後に再び朝礼が行われることが多い。</li>
# </ul>
# 正解：3
#
# <a>筆者が仕事を続ける上で大切にしていることは何か。</a>
# <ul class="options">
#     <li>毎日決まった時間に退社すること。</li>
#     <li>小さな達成感や充実感を見つけること。</li>
#     <li>趣味の時間を最優先にすること。</li>
#     <li>すべての業務を一人でこなすこと。</li>
# </ul>
# 正解：2
#
# </body>
# </html>
# HUMAN: GOOD ENOUGH
# 2026-01-25 14:03:13,524 - INFO - jlpt - Formatter: {'html_article': '<p style="margin-bottom: 1.5em; text-align: justify;">私は現在、都内の中規模な企業で働いている。毎朝、通勤電車に揺られながら、今日一日がどのように過ぎていくのかを考えるのが習慣になっている。会社に到着すると、まずはメールの確認から始まる。急ぎの連絡が入っていないかをチェックし、必要に応じて返信をする。その後、部署ごとに行われる朝礼に参加し、上司からの連絡事項や当日の業務内容について共有される。</p><p style="margin-bottom: 1.5em; text-align: justify;">午前中は、主に資料作成や会議の準備に時間を割くことが多い。特に週の初めは、前週の業務報告書をまとめたり、今週の目標を設定したりする作業が中心となる。昼休みになると、同僚と近くの飲食店で昼食をとることが多い。昼食後は、気分転換も兼ねて少し散歩をすることもある。</p><p style="margin-bottom: 1.5em; text-align: justify;">午後は、会議や打ち合わせが続くことが多い。プロジェクトの進捗状況を報告したり、取引先との打ち合わせに参加したりする。時には、急な依頼が舞い込むこともあり、予定していた作業を後回しにせざるを得ないこともある。そのような場合でも、優先順位を考えながら柔軟に対応することが求められる。</p><p style="margin-bottom: 1.5em; text-align: justify;">夕方になると、日中に発生した課題や未処理の業務を整理し、翌日に備えてタスクをまとめる。退社前には、再度メールを確認し、必要な連絡を済ませる。仕事を終えて会社を出ると、ほっとした気持ちになることが多い。帰宅後は、趣味の読書や音楽を楽しみながら、翌日のエネルギーを蓄えるようにしている。</p><p style="margin-bottom: 1.5em; text-align: justify;">このように、私の一日は決して特別なものではないが、日々の積み重ねが自分自身の成長につながっていると感じている。忙しい中にも小さな達成感や充実感を見つけることが、仕事を続ける上での大きな支えとなっている。</p>', 'questions': [{'html_question': '筆者の午前中の過ごし方として最も適切なのはどれか。', 'correct_answer': 2, 'choices': ['会議や打ち合わせに参加することが多い。', '資料作成や業務報告書の作成に集中することが多い。', '取引先との連絡を優先して行うことが多い。', '昼食後に気分転換のために散歩をすることが多い。']}, {'html_question': '午後に起こりうることとして本文から考えられるのはどれか。', 'correct_answer': 3, 'choices': ['予定していた作業をすべて終わらせることができる。', '急な依頼が来ても、必ず断ることができる。', '状況に応じて優先順位を変えて対応することがある。', '昼休みの後に再び朝礼が行われることが多い。']}, {'html_question': '筆者が仕事を続ける上で大切にしていることは何か。', 'correct_answer': 2, 'choices': ['毎日決まった時間に退社すること。', '小さな達成感や充実感を見つけること。', '趣味の時間を最優先にすること。', 'すべての業務を一人でこなすこと。']}]}
# <strong>1番.</strong></br></br><p style="margin-bottom: 1.5em; text-align: justify;">私は現在、都内の中規模な企業で働いている。毎朝、通勤電車に揺られながら、今日一日がどのように過ぎていくのかを考えるのが習慣になっている。会社に到着すると、まずはメールの確認から始まる。急ぎの連絡が入っていないかをチェックし、必要に応じて返信をする。その後、部署ごとに行われる朝礼に参加し、上司からの連絡事項や当日の業務内容について共有される。</p><p style="margin-bottom: 1.5em; text-align: justify;">午前中は、主に資料作成や会議の準備に時間を割くことが多い。特に週の初めは、前週の業務報告書をまとめたり、今週の目標を設定したりする作業が中心となる。昼休みになると、同僚と近くの飲食店で昼食をとることが多い。昼食後は、気分転換も兼ねて少し散歩をすることもある。</p><p style="margin-bottom: 1.5em; text-align: justify;">午後は、会議や打ち合わせが続くことが多い。プロジェクトの進捗状況を報告したり、取引先との打ち合わせに参加したりする。時には、急な依頼が舞い込むこともあり、予定していた作業を後回しにせざるを得ないこともある。そのような場合でも、優先順位を考えながら柔軟に対応することが求められる。</p><p style="margin-bottom: 1.5em; text-align: justify;">夕方になると、日中に発生した課題や未処理の業務を整理し、翌日に備えてタスクをまとめる。退社前には、再度メールを確認し、必要な連絡を済ませる。仕事を終えて会社を出ると、ほっとした気持ちになることが多い。帰宅後は、趣味の読書や音楽を楽しみながら、翌日のエネルギーを蓄えるようにしている。</p><p style="margin-bottom: 1.5em; text-align: justify;">このように、私の一日は決して特別なものではないが、日々の積み重ねが自分自身の成長につながっていると感じている。忙しい中にも小さな達成感や充実感を見つけることが、仕事を続ける上での大きな支えとなっている。</p>
# <p><strong>1.筆者の午前中の過ごし方として最も適切なのはどれか。</strong></p>
# <ul>
# <li>会議や打ち合わせに参加することが多い。</li>
# <li><b>資料作成や業務報告書の作成に集中することが多い。</b> <span style='color:green;'>(correct)</span></li>
# <li>取引先との連絡を優先して行うことが多い。</li>
# <li>昼食後に気分転換のために散歩をすることが多い。</li>
# </ul>
# <p><strong>2.午後に起こりうることとして本文から考えられるのはどれか。</strong></p>
# <ul>
# <li>予定していた作業をすべて終わらせることができる。</li>
# <li>急な依頼が来ても、必ず断ることができる。</li>
# <li><b>状況に応じて優先順位を変えて対応することがある。</b> <span style='color:green;'>(correct)</span></li>
# <li>昼休みの後に再び朝礼が行われることが多い。</li>
# </ul>
# <p><strong>3.筆者が仕事を続ける上で大切にしていることは何か。</strong></p>
# <ul>
# <li>毎日決まった時間に退社すること。</li>
# <li><b>小さな達成感や充実感を見つけること。</b> <span style='color:green;'>(correct)</span></li>
# <li>趣味の時間を最優先にすること。</li>
# <li>すべての業務を一人でこなすこと。</li>
# </ul>

# %% [markdown]
# ### 問題4 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2026-01-25 14:03:13,537 - INFO - jlpt - ---Generator----
# 2026-01-25 14:03:25,545 - INFO - jlpt - ---REVISOR---
# 2026-01-25 14:03:27,876 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2026-01-25 14:03:27,878 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2026-01-25 14:03:27,880 - INFO - jlpt - --- Formatter ---
# 2026-01-25 14:03:27,881 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Task: Your job is to write a reading question for a JLPT N1 level exam.
# First you need to write a long article around 450 words for student to read.
# Then, you give 2 questions by the related content in the article.
# The purpose is to ensure the students are able to understand the meaning of the article.
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Words in sentences should not be used in options
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n .
# - By referring the correct answer(c) in the "Historical Generation" during the question generation, you should ensure that the selection of correct answers (4,3,2,1) remains randomly distributed （25% for each）, avoid selecting the same answer(c) continuously
#
#
# Formal exam paper:
# <div class='article'>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">まじめで責任感が強く、負けず嫌いな人は「あきらめない」傾向があります。「あきらめない」ことは、基本的にはもちろんいいことなのですが、しかし一方、あきらめたほうがよいことも、実はけっこうあるものです。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">一所懸命に取り組んでも、うまくいかない、成果が出ない、充足感や満足感が得られない。そうした場合は「あきらめる」というのも、十分よい選択肢になります。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">こうした場合の「あきらめる」とは、「やめてしまう」ということです。</p>
#         <p class="note" style="font-size: 0.9em; color: #555; margin-top: 1.5em; margin-bottom: 1.2em; text-align: justify;">（中略）</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">やめる際には、「うまくいかなかった。やめてよかった」と思うのがコツでしょうね。うまくいかなかったことを悔やみつつやめるのは、避けたいものです。それでは、うまくいかなかったことが尾をひいてしまいます。「うまくいかなくてよかった」と思うくらいがちょうどいいでしょう。それができるようになると、一時的に落ち込んでも、立ち直りが早くなります。</p>
#     </div>
#
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">最近は仕事で悩んでいる人に対して「無理をしないであきらめたほうがよい。」というアドバイスを目にすることがある。もちろん体調を崩してしまうような場合には途中でやめるべきだ。しかしあきらめるということは、やれることはすべてやり尽くしたあとで考えるべきではないだろうか。困難な目標ほど簡単には達成できないものだ。だから、最初から、できなければあきらめてもいいんだという気持ちでいては、つらくなったときに頑張り続けることができない。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">仮にどうしてもうまくいかずにあきらめることになったとしても、精いっぱい努力した結果ならば納得できる。落ち込んだりくよくよしたりするのではなく気持ちを切り替えて、しっかり原因を考えて次に生かすことが重要だ。</p>
#         <p class="note" style="font-size: 0.9em; color: #555; margin-top: 1.5em; margin-bottom: 1.2em; text-align: justify;">(注) 尾を引く：ずっと残る</p>
#     </div>
# </div>
#
# <a>あきらめることについて、AとBはどのように述べているか。</a>
# <ul class="options"">
#     <li>AもBも、成果が出せる可能性が低いばあいには、あきらめたほうがよいと述べている。</li>
#     <li>AもBも、つらくても、できるだけあきらめずに頑張ったほうがよいと述べている。</li>
#     <li>Aは状況によっては、あきらめたほうがよいこともあると述べ、Bはあきらめてもいいと思ったほうが、頑張り続けられる場合もあると述べている。</li>
#     <li>Aは努力しても結果に結びつかない場合は、あきらめたほうがよいと述べ、Bは十分にやってみるまでは、あきらめることを考えるべきではないと述べている。</li>
# </ul>
#
# <a>AとBの認識で共通していることは何か。</a>
# <ul class="options">
#     <li>あきらめることになった原因を考えるべきだ。</li>
#     <li>あきらめるのが早ければ、早く立ち直れる。</li>
#     <li>あきらめたことでも、再挑戦することはできる。</li>
#     <li>あきらめたことを後悔してはいけない。</li>
# </ul>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: ショッピング体験を説明する
# AI: <div class='article'>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">都市部の大型商業施設では、消費者の満足度を高めるために様々な工夫が凝らされている。例えば、商品の陳列方法や照明の使い方、さらには店員の接客態度まで、細部にわたって配慮が行き届いている。こうした環境の中で買い物をすることで、利用者は単なる物品の購入以上の価値を感じることができる。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">一方、地方の商店街では、地域の特色を生かしたサービスが重視されている。地元の生産者と直接交流できるイベントや、季節ごとの特別な催しなど、訪れる人々に親しみやすさと温かみを提供している。こうした体験は、都市部の効率的な買い物とは異なる満足感をもたらす。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">近年は、インターネットを利用した購買活動も急速に普及している。自宅にいながら世界中の商品を比較し、注文できる利便性は多くの人々に支持されている。しかし、画面越しのやり取りでは、実際に手に取って選ぶ楽しみや、店員との会話による発見が得られないという声もある。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">このように、買い物の方法や場所によって得られる体験は大きく異なる。消費者は自身の目的や気分に応じて、最適な選択をすることが求められている。今後は、従来の店舗と新しい技術が融合したサービスがさらに発展し、より多様な体験が提供されることが期待されている。</p>
#     </div>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">私は最近、友人と一緒に新しくできた複合施設へ行った。そこでは、最新の技術を活用したサービスが多く導入されていた。例えば、スマートフォンを使って商品の情報を瞬時に確認できたり、混雑状況をリアルタイムで把握できるシステムがあった。これにより、効率的に目的の品を探すことができ、待ち時間も短縮された。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">また、店内には休憩スペースやカフェが併設されており、買い物の合間にゆっくりと過ごすことができた。スタッフの対応も丁寧で、困ったことがあればすぐに相談できる雰囲気だった。従来の買い物とは違い、施設全体が一つの体験型空間として設計されている印象を受けた。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">このような場所では、単に商品を手に入れるだけでなく、過ごす時間そのものが価値となる。今後もこうした新しい形態の施設が増えていくことで、買い物の楽しみ方もさらに広がっていくのではないかと感じた。</p>
#     </div>
# </div>
# <a>都市部と地方の買い物体験について、AとBはどのように述べているか。</a>
# <ul class="options">
#     <li>Aは都市部の施設が効率性を重視し、Bは地方の商店街が地域性を強調していると述べている。</li>
#     <li>Aは都市部と地方の違いを説明し、Bは新しい施設の技術的な側面に注目している。</li>
#     <li>Aは商業施設の工夫や地方の特色を述べ、Bは最新技術による利便性と体験型空間について述べている。</li>
#     <li>Aは買い物の方法ごとの体験の違いを説明し、Bは従来の買い物との比較をしている。</li>
# </ul>
# <a>両者の記述から推測できる今後の買い物体験の展望は何か。</a>
# <ul class="options">
#     <li>消費者が自分の目的に合わせて場所を選ぶ傾向が強まる。</li>
#     <li>店舗の数が減少し、インターネットでの購入が主流になる。</li>
#     <li>地域ごとの特色が失われ、全国的に同じサービスが広がる。</li>
#     <li>技術と従来の店舗が融合し、多様な体験が提供される。</li>
# </ul>
# 正解: 3, 4
# HUMAN: GOOD ENOUGH
# 2026-01-25 14:03:42,071 - INFO - jlpt - Formatter: {'html_article': '<div class=\'article\'>    <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>        <p style="margin-bottom: 1.2em; text-align: justify;">都市部の大型商業施設では、消費者の満足度を高めるために様々な工夫が凝らされている。例えば、商品の陳列方法や照明の使い方、さらには店員の接客態度まで、細部にわたって配慮が行き届いている。こうした環境の中で買い物をすることで、利用者は単なる物品の購入以上の価値を感じることができる。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">一方、地方の商店街では、地域の特色を生かしたサービスが重視されている。地元の生産者と直接交流できるイベントや、季節ごとの特別な催しなど、訪れる人々に親しみやすさと温かみを提供している。こうした体験は、都市部の効率的な買い物とは異なる満足感をもたらす。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">近年は、インターネットを利用した購買活動も急速に普及している。自宅にいながら世界中の商品を比較し、注文できる利便性は多くの人々に支持されている。しかし、画面越しのやり取りでは、実際に手に取って選ぶ楽しみや、店員との会話による発見が得られないという声もある。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">このように、買い物の方法や場所によって得られる体験は大きく異なる。消費者は自身の目的や気分に応じて、最適な選択をすることが求められている。今後は、従来の店舗と新しい技術が融合したサービスがさらに発展し、より多様な体験が提供されることが期待されている。</p>    </div>    <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>        <p style="margin-bottom: 1.2em; text-align: justify;">私は最近、友人と一緒に新しくできた複合施設へ行った。そこでは、最新の技術を活用したサービスが多く導入されていた。例えば、スマートフォンを使って商品の情報を瞬時に確認できたり、混雑状況をリアルタイムで把握できるシステムがあった。これにより、効率的に目的の品を探すことができ、待ち時間も短縮された。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">また、店内には休憩スペースやカフェが併設されており、買い物の合間にゆっくりと過ごすことができた。スタッフの対応も丁寧で、困ったことがあればすぐに相談できる雰囲気だった。従来の買い物とは違い、施設全体が一つの体験型空間として設計されている印象を受けた。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">このような場所では、単に商品を手に入れるだけでなく、過ごす時間そのものが価値となる。今後もこうした新しい形態の施設が増えていくことで、買い物の楽しみ方もさらに広がっていくのではないかと感じた。</p>    </div></div>', 'questions': [{'html_question': '都市部と地方の買い物体験について、AとBはどのように述べているか。', 'choices': ['Aは都市部の施設が効率性を重視し、Bは地方の商店街が地域性を強調していると述べている。', 'Aは都市部と地方の違いを説明し、Bは新しい施設の技術的な側面に注目している。', 'Aは商業施設の工夫や地方の特色を述べ、Bは最新技術による利便性と体験型空間について述べている。', 'Aは買い物の方法ごとの体験の違いを説明し、Bは従来の買い物との比較をしている。'], 'correct_answer': 2}, {'html_question': '両者の記述から推測できる今後の買い物体験の展望は何か。', 'choices': ['消費者が自分の目的に合わせて場所を選ぶ傾向が強まる。', '店舗の数が減少し、インターネットでの購入が主流になる。', '地域ごとの特色が失われ、全国的に同じサービスが広がる。', '技術と従来の店舗が融合し、多様な体験が提供される。'], 'correct_answer': 3}]}
# <strong>1番.</strong></br></br><div class='article'>    <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>        <p style="margin-bottom: 1.2em; text-align: justify;">都市部の大型商業施設では、消費者の満足度を高めるために様々な工夫が凝らされている。例えば、商品の陳列方法や照明の使い方、さらには店員の接客態度まで、細部にわたって配慮が行き届いている。こうした環境の中で買い物をすることで、利用者は単なる物品の購入以上の価値を感じることができる。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">一方、地方の商店街では、地域の特色を生かしたサービスが重視されている。地元の生産者と直接交流できるイベントや、季節ごとの特別な催しなど、訪れる人々に親しみやすさと温かみを提供している。こうした体験は、都市部の効率的な買い物とは異なる満足感をもたらす。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">近年は、インターネットを利用した購買活動も急速に普及している。自宅にいながら世界中の商品を比較し、注文できる利便性は多くの人々に支持されている。しかし、画面越しのやり取りでは、実際に手に取って選ぶ楽しみや、店員との会話による発見が得られないという声もある。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">このように、買い物の方法や場所によって得られる体験は大きく異なる。消費者は自身の目的や気分に応じて、最適な選択をすることが求められている。今後は、従来の店舗と新しい技術が融合したサービスがさらに発展し、より多様な体験が提供されることが期待されている。</p>    </div>    <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>        <p style="margin-bottom: 1.2em; text-align: justify;">私は最近、友人と一緒に新しくできた複合施設へ行った。そこでは、最新の技術を活用したサービスが多く導入されていた。例えば、スマートフォンを使って商品の情報を瞬時に確認できたり、混雑状況をリアルタイムで把握できるシステムがあった。これにより、効率的に目的の品を探すことができ、待ち時間も短縮された。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">また、店内には休憩スペースやカフェが併設されており、買い物の合間にゆっくりと過ごすことができた。スタッフの対応も丁寧で、困ったことがあればすぐに相談できる雰囲気だった。従来の買い物とは違い、施設全体が一つの体験型空間として設計されている印象を受けた。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">このような場所では、単に商品を手に入れるだけでなく、過ごす時間そのものが価値となる。今後もこうした新しい形態の施設が増えていくことで、買い物の楽しみ方もさらに広がっていくのではないかと感じた。</p>    </div></div>
# <p><strong>1.都市部と地方の買い物体験について、AとBはどのように述べているか。</strong></p>
# <ul>
# <li>Aは都市部の施設が効率性を重視し、Bは地方の商店街が地域性を強調していると述べている。</li>
# <li><b>Aは都市部と地方の違いを説明し、Bは新しい施設の技術的な側面に注目している。</b> <span style='color:green;'>(correct)</span></li>
# <li>Aは商業施設の工夫や地方の特色を述べ、Bは最新技術による利便性と体験型空間について述べている。</li>
# <li>Aは買い物の方法ごとの体験の違いを説明し、Bは従来の買い物との比較をしている。</li>
# </ul>
# <p><strong>2.両者の記述から推測できる今後の買い物体験の展望は何か。</strong></p>
# <ul>
# <li>消費者が自分の目的に合わせて場所を選ぶ傾向が強まる。</li>
# <li>店舗の数が減少し、インターネットでの購入が主流になる。</li>
# <li><b>地域ごとの特色が失われ、全国的に同じサービスが広がる。</b> <span style='color:green;'>(correct)</span></li>
# <li>技術と従来の店舗が融合し、多様な体験が提供される。</li>
# </ul>

# %% [markdown]
# ### 問題5 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.topic_understanding_txt(random.choice(topics),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2026-01-25 14:03:42,100 - INFO - jlpt - ---Generator----
# 2026-01-25 14:03:46,509 - INFO - jlpt - ---REVISOR---
# 2026-01-25 14:03:48,573 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2026-01-25 14:03:48,576 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2026-01-25 14:03:48,583 - INFO - jlpt - --- Formatter ---
# 2026-01-25 14:03:48,586 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman.
#
# Step 1, write a concise background about the dialogue introduction, which exclude the follow-up question and character name.
#
# Step 2, Give characters names during the conversation. They should call each name during the conversation depending on their relationship, level of formality.
# Do not refer to them as Mr. or Miss in the conversation context. Be polite and culturally appropriate in how they address each other.
# 女：conversation context
# 男：conversation context
# Besides, the name at the end of a sentence can be omitted.
# For example: "ありがとう、佐藤さん。" the name at the end of a sentence can be omitted, like "ありがとう。"
#
# Step 3, write dialogue, the dialogue should consist of 6-9 exchanges (back-and-forth turns). The total length should be approximately 300-400 words.
#
# Step 4, after the conversation, ask a follow-up question related to the conversation and focusing on the man or woman's next action, such as
# What,When,Where,Who,How,Which,Whose,How long,How often,How much,How many.
#
# Step 5, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Words in sentences should not be used in options
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n . By referring the correct answer(c) in the "Historical Generation" during the question generation, you should ensure that the selection of correct answers (4,3,2,1) remains randomly distributed （25% for each）, avoid selecting the same answer(c) continuously
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>大学で女の学生と男の学生が話しています。男の学生はこの後まず、何をしますか。</p>
#
# <div class='conversation'>
# 女：中村くん、シンポジウムのポスター、掲示板に貼ってくれたんだね。ありがとう。
# 男：ええ、他に僕がやっておくことってありますか？
# 女：マイクとか会場の準備は前日にすればいいし、当日のスタッフ用のスケジュール表、これないから欲しいな、今週中にお願いしていい？
# 男：あ、はい。<br>
# 女：それから１番大事な当日配る資料、コピーまだなんじゃない？100部だよね？
# 男：あ、それなんですけど、発表者の方からの資料が全部そろってないんですよ。
# 女：そう、みなさんお忙しい方ばかりだから…私の方で発表者に資料を送ってもらうようにすぐに連絡をするから、集まったら次第コピーしよう。週明けには出してもらうようにするね。<br>
# 男：はい、わかりました。
# </div>
#
# <p class="follow-up">男の学生は、この後まず何をしますか。</p>
# <div class="options">
#  <li>シンポジウムのポスターを貼る</li>
#  <li>スタッフの当日の予定表を作る</li>
#  <li>当日配る資料をコピーする</li>
#  <li>発表者に連絡する</li>
# </p>
# </div>
#
#
# --- example 2 ---
# <p class='background'>スーパーで男の店長と女の店員が話しています。女の店員はこの後まず、何をしますか。</p>
#
# <div class='conversation'>
# 女：おはようございます、森田さん。今日は一部の商品に値引きシールを付ける作業をやってくれることになってるね。
# 男: あ、はい。準備してます。
# 男： えっと、忙しい時に悪いんだけど、倉庫に行って南コーヒーの豆、何袋あるか数えてきてくれる？数が少なかったら今日中に注文しないといけないんだ。
# 女：あ、わかりました。急ぎですか？<br>
# 男：あー、そのシールを貼る作業が終わってからでいいから。袋の数を数えたらメモを私の机の上に置いといて。
# 女：わかりました。<br>
# 男：お客さんがレジにたくさん並んでるから、私もすぐレジを手伝わなきゃいけなくて。値引シールを付けた商品をレジの横の棚に並べるのは明日の開店前にみんなですればいいから。じゃ、よろしくね。
# </div>
#
# <p class="follow-up">女の店員はこの後まず、何をしますか。</p>
# <div class="options">
#      <li>商品に値引きシールを貼る</li>
#      <li>倉庫で南コーヒーの数を数える</li>
#      <li>レジの手伝いをする</li>
#      <li>商品をレジの横の棚に並べる</li>
#   </p>
# </div>
#
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: 新しいスキルを学ぶ計画について話す
# AI: <p class='background'>会社の休憩室で女の社員と男の社員が話しています。男の社員はこの後まず、何をしますか。</p>
#
# <div class='conversation'>
# 女：山口さん、来月から新しいプロジェクトが始まるって聞きましたけど、何か準備しているんですか？
# 男：ええ、実はプロジェクトで必要になるプログラミングのスキルを身につけようと思って、オンライン講座を探しているところです。
# 女：それはいいですね。もうどの講座にするか決めたんですか？
# 男：まだ迷っていて、いくつか候補があるんですが、内容や講師の評判を比較してから決めようと思っています。
# 女：忙しい中で勉強するのは大変でしょうけど、計画的に進めればきっと身につきますよ。いつから始める予定ですか？
# 男：できれば今週中に講座を選んで、来週から受講を始めたいと思っています。
# 女：じゃあ、まずは講座の比較ですね。もしよかったら、私も以前受けた講座の情報をお伝えしますよ。
# 男：ありがとうございます。参考にさせていただきます。まずは候補を絞ってみますね。
# </div>
#
# <p class="follow-up">男の社員はこの後まず、何をしますか。</p>
# <div class="options">
#  <li>プロジェクトの準備を始める</li>
#  <li>オンライン講座を受講する</li>
#  <li>講座の内容や評判を調べる</li>
#  <li>女の社員に講座の情報を聞く</li>
# </div>
# 正解: 3
# HUMAN: GOOD ENOUGH
# 2026-01-25 14:03:51,845 - INFO - jlpt - Formatter: {'background': '会社の休憩室で女の社員と男の社員が話しています。男の社員はこの後まず、何をしますか。', 'follow_up': '男の社員はこの後まず、何をしますか。', 'conversation': [{'gender': 'female', 'context': '山口さん、来月から新しいプロジェクトが始まるって聞きましたけど、何か準備しているんですか？'}, {'gender': 'male', 'context': 'ええ、実はプロジェクトで必要になるプログラミングのスキルを身につけようと思って、オンライン講座を探しているところです。'}, {'gender': 'female', 'context': 'それはいいですね。もうどの講座にするか決めたんですか？'}, {'gender': 'male', 'context': 'まだ迷っていて、いくつか候補があるんですが、内容や講師の評判を比較してから決めようと思っています。'}, {'gender': 'female', 'context': '忙しい中で勉強するのは大変でしょうけど、計画的に進めればきっと身につきますよ。いつから始める予定ですか？'}, {'gender': 'male', 'context': 'できれば今週中に講座を選んで、来週から受講を始めたいと思っています。'}, {'gender': 'female', 'context': 'じゃあ、まずは講座の比較ですね。もしよかったら、私も以前受けた講座の情報をお伝えしますよ。'}, {'gender': 'male', 'context': 'ありがとうございます。参考にさせていただきます。まずは候補を絞ってみますね。'}], 'choices': ['プロジェクトの準備を始める', 'オンライン講座を受講する', '講座の内容や評判を調べる', '女の社員に講座の情報を聞く'], 'correct_answer': 2}
# 2026-01-25 14:04:21,759 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2026-01-25 14:04:21,762 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1.wav
# 2026-01-25 14:04:21,765 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2026-01-25 14:04:21,766 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_background.wav
# 2026-01-25 14:04:21,770 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2026-01-25 14:04:21,773 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_follow_up.wav
# 2026-01-25 14:04:21,776 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2026-01-25 14:04:21,778 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_0_speaker.wav
# 2026-01-25 14:04:21,782 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_1_speaker.wav
# 2026-01-25 14:04:21,789 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_2_speaker.wav
# 2026-01-25 14:04:21,795 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_3_speaker.wav
# 2026-01-25 14:04:21,801 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_4_speaker.wav
# 2026-01-25 14:04:21,811 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_5_speaker.wav
# 2026-01-25 14:04:21,817 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_6_speaker.wav
# 2026-01-25 14:04:21,826 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_7_speaker.wav
# 2026-01-25 14:04:21,833 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2026-01-25 14:04:21,840 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_follow_up.wav
# 2026-01-25 14:04:22,405 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_conversation_output.mp3
# 2026-01-25 14:04:25,639 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\72cc8576-f9b3-11f0-b18d-d4d8537023ca\topic_understanding_txt_1_conversation_output.mp3 as blob 72cc8576-f9b3-11f0-b18d-d4d8537023ca/topic_understanding_txt_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>会社の休憩室で女の社員と男の社員が話しています。男の社員はこの後まず、何をしますか。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> 山口さん、来月から新しいプロジェクトが始まるって聞きましたけど、何か準備しているんですか？</p>
# <p><strong>Male:</strong> ええ、実はプロジェクトで必要になるプログラミングのスキルを身につけようと思って、オンライン講座を探しているところです。</p>
# <p><strong>Female:</strong> それはいいですね。もうどの講座にするか決めたんですか？</p>
# <p><strong>Male:</strong> まだ迷っていて、いくつか候補があるんですが、内容や講師の評判を比較してから決めようと思っています。</p>
# <p><strong>Female:</strong> 忙しい中で勉強するのは大変でしょうけど、計画的に進めればきっと身につきますよ。いつから始める予定ですか？</p>
# <p><strong>Male:</strong> できれば今週中に講座を選んで、来週から受講を始めたいと思っています。</p>
# <p><strong>Female:</strong> じゃあ、まずは講座の比較ですね。もしよかったら、私も以前受けた講座の情報をお伝えしますよ。</p>
# <p><strong>Male:</strong> ありがとうございます。参考にさせていただきます。まずは候補を絞ってみますね。</p>
# </div>
# <p><strong>follow-up question: </strong>男の社員はこの後まず、何をしますか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/72cc8576-f9b3-11f0-b18d-d4d8537023ca/topic_understanding_txt_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. プロジェクトの準備を始める</li>
# <li>2. <b>オンライン講座を受講する</b> <span style='color:green;'>(correct)</span></li>
# <li>3. 講座の内容や評判を調べる</li>
# <li>4. 女の社員に講座の情報を聞く</li>
# </ul>

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.active_expression((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))
