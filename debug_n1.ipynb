# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n1'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.kanji_reading(random.choice(vocab.split(",")))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-09-19 21:36:10,410 - INFO - jlpt - ---Generator----
# 2025-09-19 21:36:13,845 - INFO - jlpt - ---REVISOR---
# 2025-09-19 21:36:14,928 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-19 21:36:14,930 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-19 21:36:14,931 - INFO - jlpt - --- Formatter ---
# 2025-09-19 21:36:14,933 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing a test paper for JLPT N1 level.
#
# Task: Your job is to write a pronunciation question corresponding to Japanes kanji for the JLPT N1 level exam paper.
#
# Step 1: Generate a short sentence within 30 words as the question stem. And select a Japanese kanji word to mark as a
# -A must contain at least one Japanese kanji, not every character is a hiragana
#
# Step 2: For word a, underline it.
# The selected words need to be marked with<u></u>, such as<u>主要</u>, and no other tags should appear in the sentence.
# Additional requirements:
# -Words in sentences should not be used in options
# -You must display the correct answer in the output with options 1, 2, 3, 4. For example: Correct solution: 1
#
# Step 3: Generate 4 options for this question. Require all of the following conditions:
# -These 4 options must be different from each other.
# -Only one option is the correct answer.
# -The generated options need to comply with Japanese pronunciation rules and should not generate non-existent pronunciations
# -Assuming that word a consists of 2-3 characters, set them in order as x[0],y[0],z[0] (if a variable is a Japanese kanji, do not display it as hiragana pronunciation). There are four options, including option 1: x[1],y[1],z[1]; Option 2: x[2],y[2],z[2]; Option 3: x[3],y[3],z[3]; Option 4: x[4],y[4],z[4]
# -If x[0] is Japanese hiragana, then: x[1]=x[2]=x[3]=x[4]=x[0]
# -If y[0] is Japanese hiragana, then: y[1]=y[2]=y[3]=y[4]=y[0]
# -If z[0] is Japanese hiragana, then: z[1]=z[2]=z[3]=z[4]=z[0]
# -Print a,x[0],y[0],z[0],x[1],y[1],z[1],x[2],y[2],z[2],x[3],y[3],z[3],x[4],y[4],z[4] in the debugging log; And print the judgment of whether x[0],y[0],z[0] are Japanese hiragana or not
#
# Step 4: output a question.
# Format: Follow the format of the 2 examples in the formal exam paper, not the content. The output must be in HTML format and the line change tag must be removed.
# Content: Ensure vocabulary is limited to N1 level.
# Reference: Get inspiration from the "Topic". Consider the feedback given in the previous conversation (if any)
# Additional requirement: Do not display problem descriptions and serial numbers in the generated content.
#
# Formal exam paper:
# --- example 1 ---
# <a>この町の<u>主要</u>な産業は何ですか。</a>
# <ul>
#     <li>じゅおう</li>
#     <li>しゅおう</li>
#     <li>じゅうよう</li>
#     <li>しゅよう</li>
# </ul>
#
# --- example 2 ---
# <a>今日とても<u>嬉しい</u>ですね。</a>
# <ul>
#     <li>うれしい</li>
#     <li>はれしい</li>
#     <li>まぶしい</li>
#     <li>きびしい</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: だいべん
# AI: Debugging log:
# a=代弁, x[0]=代, y[0]=弁, z[0]=, x[1]=だい, y[1]=べん, z[1]=, x[2]=たい, y[2]=べん, z[2]=, x[3]=だい, y[3]=ぶん, z[3]=, x[4]=たい, y[4]=ぶん, z[4]=
# x[0] is not hiragana
# y[0] is not hiragana
# z[0] is empty (no third character)
#
# Correct solution: 1
#
# HTML output:
# <a>彼は私の意見を<u>代弁</u>してくれました。</a><ul><li>だいべん</li><li>たいべん</li><li>だいぶん</li><li>たいぶん</li></ul>
# HUMAN: GOOD ENOUGH
# 2025-09-19 21:36:16,739 - INFO - jlpt - Formatter: {'html_question': '彼は私の意見を<u>代弁</u>してくれました。', 'correct_answer': 1, 'choices': ['だいべん', 'たいべん', 'だいぶん', 'たいぶん']}
# <strong>1番.</strong></br></br><p>彼は私の意見を<u>代弁</u>してくれました。</p><ul>
# <li>1. <b>だいべん</b> <span style='color:green;'>(correct)</span></li>
# <li>2. たいべん</li>
# <li>3. だいぶん</li>
# <li>4. たいぶん</li>
# </ul>

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar_list))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.topic_understanding(random.choice(topics),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-09-14 11:13:38,566 - INFO - jlpt - ---Generator----
# 2025-09-14 11:13:41,690 - INFO - jlpt - ---REVISOR---
# 2025-09-14 11:13:42,618 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-14 11:13:42,621 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-14 11:13:42,624 - INFO - jlpt - --- Formatter ---
# 2025-09-14 11:13:42,625 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman.
#
# Step 1, write a concise background about the dialogue introduction, which exclude the follow-up question and character name.
#
# Step 2, Give characters names during the conversation. They should call each name during the conversation depending on their relationship, level of formality.
# Do not refer to them as Mr. or Miss in the conversation context. Be polite and culturally appropriate in how they address each other.
# 女：conversation context
# 男：conversation context
# Besides, the name at the end of a sentence can be omitted.
# For example: "ありがとう、佐藤さん。" the name at the end of a sentence can be omitted, like "ありがとう。"
#
# Step 3, write dialogue, the dialogue should consist of 1-3 exchanges (back-and-forth turns). The total length should be approximately 100–200 words.
#
# Step 4, after the conversation, ask a follow-up question related to the conversation and focusing on the man or woman's next action, such as
# What,When,Where,Who,How,Which,Whose,How long,How often,How much,How many.
#
# Step 5, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>会社で課長と男の人が話しています。</p>
#
# <div class='conversation'>
# 女：田中さん。初めての出張、お疲れ様でした、この出張のレポート詳みました。
# 男：はい。
# 女：出張の目的と訪問した会社で誰に会ったのかはこれています。ただ、話し合いについては最終的にどうなったのかがわかりくいています。そこを直してください。
# 男：はい、わかりました。
# 女：次の訪問日は3ヶ月後になつたんですね。
# 男：はい。
# <p class='follow-up'>男の人は出張レポートのことを直きなければなりませんか？</p>
# </div>
#
# <ul class='options'>
#     <li>しゅっちょうの　もくてき</li>
#     <li>会った人のじょうほう</li>
#     <li>話し合いのけっか</li>
#     <li>つぎのほうもん日/li>
# </ul>
#
# --- example 2 ---
# <p class='background'>会社で男の人と女の人が話しています。</p>
#
# <div class='conversation'>
# 女：あ、田中さん。明日の会議、10時からでしたっけ？
# 男：いいえ、10時じゃなくて、午後1時からですよ。場所はいつもの会議室です。
# 女：あ、そうでしたね。資料はどうすればいいですか？
# 男：事前にメールで送ってください。当日、紙で持ってこなくても大丈夫です。
# <p class='follow-up'>女の人は、何時から会議があると言われましたか。</p>
# </div>
#
# <ul class='options'>
#     <li>午前10時</li>
#     <li>午後1時</li>
#     <li>午後3時</li>
#     <li>午後5時</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: ボランティア活動について話す
# AI: <p class='background'>大学の学生センターで、二人の学生がボランティア活動について話しています。</p>
#
# <div class='conversation'>
# 女：山本くん、今度の週末、地域の清掃活動に参加しない？学生会で人手が足りなくて困っているの。
# 男：そうなんだ。実は、今週はレポートの締め切りが重なってて、ちょっと厳しいかもしれない。でも、来月なら余裕があるから、その時に何かあればぜひ声をかけてほしい。
# 女：わかった。じゃあ、来月のイベントが決まったらまた連絡するね。
# <p class='follow-up'>男の人は、どのような時にボランティア活動に参加したいと言っていますか。</p>
# </div>
#
# <ul class='options'>
#     <li>今週の週末</li>
#     <li>来月</li>
#     <li>来週</li>
#     <li>今日</li>
# </ul>
#
# 正解: 2
# HUMAN: GOOD ENOUGH
# 2025-09-14 11:13:44,680 - INFO - jlpt - Formatter: {'background': '大学の学生センターで、二人の学生がボランティア活動について話しています。', 'follow_up': '男の人は、どのような時にボランティア活動に参加したいと言っていますか。', 'conversation': [{'gender': 'female', 'context': '山本くん、今度の週末、地域の清掃活動に参加しない？学生会で人手が足りなくて困っているの。'}, {'gender': 'male', 'context': 'そうなんだ。実は、今週はレポートの締め切りが重なってて、ちょっと厳しいかもしれない。でも、来月なら余裕があるから、その時に何かあればぜひ声をかけてほしい。'}, {'gender': 'female', 'context': 'わかった。じゃあ、来月のイベントが決まったらまた連絡するね。'}], 'choices': ['今週の週末', '来月', '来週', '今日'], 'correct_answer': 2}
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_background.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_follow_up.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_0_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_1_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_2_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_follow_up.wav
# Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_conversation_output.mp3
# ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\topic_understanding_1_conversation_output.mp3 as blob cb7fdef8-9118-11f0-8278-005056c00008/topic_understanding_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>大学の学生センターで、二人の学生がボランティア活動について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> 山本くん、今度の週末、地域の清掃活動に参加しない？学生会で人手が足りなくて困っているの。</p>
# <p><strong>Male:</strong> そうなんだ。実は、今週はレポートの締め切りが重なってて、ちょっと厳しいかもしれない。でも、来月なら余裕があるから、その時に何かあればぜひ声をかけてほしい。</p>
# <p><strong>Female:</strong> わかった。じゃあ、来月のイベントが決まったらまた連絡するね。</p>
# </div>
# <p><strong>follow-up question: </strong>男の人は、どのような時にボランティア活動に参加したいと言っていますか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cb7fdef8-9118-11f0-8278-005056c00008/topic_understanding_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 今週の週末</li>
# <li>2. <b>来月</b> <span style='color:green;'>(correct)</span></li>
# <li>3. 来週</li>
# <li>4. 今日</li>
# </ul>

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.keypoint_understanding(random.choice(topics),seq=2)
display(HTML(_render_result(result=content)))
# Out:
# 2025-09-14 11:14:04,875 - INFO - jlpt - ---Generator----
# 2025-09-14 11:14:09,585 - INFO - jlpt - ---REVISOR---
# 2025-09-14 11:14:10,639 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-14 11:14:10,641 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-14 11:14:10,643 - INFO - jlpt - --- Formatter ---
# 2025-09-14 11:14:10,644 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman. Alternatively, write a personal monologue, ensuring it is logically clear and flows smoothly. The probability of dialogue and monologue appearing is 50% each
#
# If it's a conversation:
#
# Step 1, write a concise background about the dialogue introduction, which exclude the follow-up question and character name.
#
# Step 2, Give characters names during the conversation. They should call each name during the conversation depending on their relationship, level of formality.
# Do not refer to them as Mr. or Miss in the conversation context. Be polite and culturally appropriate in how they address each other.
# 女：conversation context
# 男：conversation context
# Besides, the name at the end of a sentence can be omitted.
# For example: "ありがとう、佐藤さん。" the name at the end of a sentence can be omitted, like "ありがとう。"
#
# Step 3, write dialogue, the dialogue should consist of 3-4 exchanges (back-and-forth turns). The total length should be approximately 150–180 words.
# The topic should be appropriate for language learners and reflect everyday situations.
#
# Step 4, after the conversation, ask a follow-up question focusing on understanding of the motivation or reasoning behind it, encouraging students to think deeply.
# The question should prompt students to choose the best option that matches the overall conversation or key point of the dialogue, examples:
# What is the man's reason for joining this company?
# Why is this tourist spot famous?
# Why is the woman taking the exam?
#
# Step 5, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
# If it's a monologue:
#
# Step 1, write a personal monologue of approximately 150-200 words. The following requirements must be met:
# -Ensure clear thinking, logical coherence, and no grammatical errors in the copy
# -A monologue can be an introduction to an object, an advertisement, or an inner thought process. But they all require specific items or events to occur, and they are relatively close to daily life
#
# Step 2, ask a follow-up question after the monologue ends, focusing on understanding the motivation or reasoning behind it and encouraging students to think deeply.
# This question should prompt students to choose the best option that matches the entire conversation or the key points of the conversation, such as:
# What is the reason for this person joining this company?
# Why is this tourist attraction famous?
# Why did that woman take the exam?
#
# Step 3, provide multiple-choice questions based on the listening content. These options should test understanding of the meaning of the conversation.
#
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>朝、家の玄関で妻と夫が話しています。</p>
#
# <div class='conversation'>
# 女:あれ？どうしたの？忘れ物？書類？
# 男:いや、バス停で待ってたんだけど、なぜかバスがなかなか来なくて。今日は車で会社に行くよ。車の鍵、取ってくれる？
# 女:えー、私、今日車使いたいんだけど・・・会社まで送ってったあげるよ。
# 男:本当？悪いね。走って戻ってきたら、喉渇いちゃった。ちょっと水飲んでくるから待ってて。
# 女:あ、机の上に切手が貼ってあるハガキがあったけど、出さなくていいの？
# 男:あぁ、忘れてた。取ってくるよ。
# <p class='follow-up'>夫はどうしても家に戻ってきましたか？</p>
# </div>
#
# <a class='question'></a>
# <ul class='options'>
#     <li>しょるいをわすれたから</li>
#     <li>車で会社に行くことにしたから</li>
#     <li>のどがかわいたから</li>
#     <li>はがきをわすれたから</li>
# </ul>
#
# --- example 2 ---
# <p class='background'>男の人が新しいスーパーについて話しています</p>
#
# <div class='conversation'>
# 男：昨日、新しいスーパーに行ってみました。駅から歩いて5分くらいで、とても便利です。中は広くて、野菜や果物が安いし、パンも種類が多かったです。ただ、夕方だったのでレジが混んでいて、10分ぐらい待たされました。次は午前中に行こうと思います。
# <p class='follow-up'>男の人は、このスーパーについてどう思っていますか。</p>
# </div>
#
# <ul class='options'>
#     <li>場所が遠くて不便だと思っている</li>
#     <li>品物が高いと思っている</li>
#     <li>品物はよいが、レジが混んでいると思っている</li>
#     <li>午後に行くのが一番いいと思っている</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 学校や職場での一日の流れについて話す
# AI: <p class='background'>昼休みに、職場の休憩室で同僚同士が今日の予定について話しています。</p>
#
# <div class='conversation'>
# 女：午前中は会議が長引いて、資料の整理が全然できなかったの。午後は何か予定ある？
# 男：午後は、まず取引先に電話して、その後は新しい企画書をまとめるつもり。急ぎの仕事がなければ、手伝えるよ。
# 女：ありがとう。実は、部長から追加のデータ分析も頼まれてしまって。終わるか不安だな。
# 男：じゃあ、企画書が終わったら、そっちも手伝うよ。お互い早めに片付けよう。
# 女：助かる。昼休みが終わったら、すぐ取りかかるね。
# <p class='follow-up'>男は午後、どのように仕事を進める予定ですか。</p>
# </div>
#
# <ul class='options'>
#     <li>会議の準備を優先する</li>
#     <li>同僚の資料整理だけを手伝う</li>
#     <li>自分の仕事を終えた後、同僚を手伝う</li>
#     <li>昼休みの間にすべて終わらせる</li>
# </ul>
# 正解: 3
# HUMAN: GOOD ENOUGH
# 2025-09-14 11:14:13,243 - INFO - jlpt - Formatter: {'background': '昼休みに、職場の休憩室で同僚同士が今日の予定について話しています。', 'follow_up': '男は午後、どのように仕事を進める予定ですか。', 'conversation': [{'gender': 'female', 'context': '午前中は会議が長引いて、資料の整理が全然できなかったの。午後は何か予定ある？'}, {'gender': 'male', 'context': '午後は、まず取引先に電話して、その後は新しい企画書をまとめるつもり。急ぎの仕事がなければ、手伝えるよ。'}, {'gender': 'female', 'context': 'ありがとう。実は、部長から追加のデータ分析も頼まれてしまって。終わるか不安だな。'}, {'gender': 'male', 'context': 'じゃあ、企画書が終わったら、そっちも手伝うよ。お互い早めに片付けよう。'}, {'gender': 'female', 'context': '助かる。昼休みが終わったら、すぐ取りかかるね。'}], 'choices': ['会議の準備を優先する', '同僚の資料整理だけを手伝う', '自分の仕事を終えた後、同僚を手伝う', '昼休みの間にすべて終わらせる'], 'correct_answer': 3}
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_background.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_follow_up.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_0_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_1_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_2_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_3_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_4_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_follow_up.wav
# Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_conversation_output.mp3
# ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\keypoint_understanding_2_conversation_output.mp3 as blob cb7fdef8-9118-11f0-8278-005056c00008/keypoint_understanding_2_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>昼休みに、職場の休憩室で同僚同士が今日の予定について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> 午前中は会議が長引いて、資料の整理が全然できなかったの。午後は何か予定ある？</p>
# <p><strong>Male:</strong> 午後は、まず取引先に電話して、その後は新しい企画書をまとめるつもり。急ぎの仕事がなければ、手伝えるよ。</p>
# <p><strong>Female:</strong> ありがとう。実は、部長から追加のデータ分析も頼まれてしまって。終わるか不安だな。</p>
# <p><strong>Male:</strong> じゃあ、企画書が終わったら、そっちも手伝うよ。お互い早めに片付けよう。</p>
# <p><strong>Female:</strong> 助かる。昼休みが終わったら、すぐ取りかかるね。</p>
# </div>
# <p><strong>follow-up question: </strong>男は午後、どのように仕事を進める予定ですか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cb7fdef8-9118-11f0-8278-005056c00008/keypoint_understanding_2_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 会議の準備を優先する</li>
# <li>2. 同僚の資料整理だけを手伝う</li>
# <li>3. <b>自分の仕事を終えた後、同僚を手伝う</b> <span style='color:green;'>(correct)</span></li>
# <li>4. 昼休みの間にすべて終わらせる</li>
# </ul>

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.summary_understanding(random.choice(topics),seq=2)
display(HTML(_render_result(result=content)))
# Out:
# 2025-09-14 11:14:36,900 - INFO - jlpt - ---Generator----
# 2025-09-14 11:14:42,751 - INFO - jlpt - ---REVISOR---
# 2025-09-14 11:14:43,824 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-14 11:14:43,826 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-14 11:14:43,827 - INFO - jlpt - --- Formatter ---
# 2025-09-14 11:14:43,827 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman. Alternatively, write a personal monologue, ensuring it is logically clear and flows smoothly. The probability of dialogue and monologue appearing is 50% each
#
# Step 1, you should introduce the background of the dialogue.
#
# Step 2, the total length should be approximately 200–300 words. If you write a dialogue, then the dialogue should consists of 6–7 exchanges (back-and-forth turns).
#
# Step 3, ask a follow-up question focusing on what the protagonist thinks, the theme of this paragraph, or what the speaker wants to express.
# The topic should be appropriate for language learners and reflect everyday situations.
#
# Step 4, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3,4. for example: 正解: 1
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>日本語学校で女の留学生と男の留学生が話しています。</p>
#
# <div class='conversation'>
# - 女: 来月で佐藤先生、学校を辞めちゃうんだよね。
# - 男: 寂しくなるね。
# - 女: うん。ねえ、クラスのみんなで先生に何か記念になるものをあげたいね。
# - 男: あ、いいね。何か身に付けるものとか?
# - 女: 先生おしゃれだし、そういうの選ぶの難しくない? それより私たちで何か作ろうよ。
# - 男: あ、メッセージカードは? クラスのみんなにも書いてもらおうよ。
# - 女: じゃ、スポーツ大会の時に撮ったクラスの集合写真を真ん中に貼って、周りにメッセージを書いてもらう?
# - 男: いいね。皆にももらえるといいね。明日、休み時間にクラスのみんなに話してみよう。
# </div>
#
# <a class='follow-up'>2人は何について話していますか? </a>
# <ul class='options'>
#     <li>先生が学校を辞める理由</li>
#     <li>先生に贈る物</li>
#     <li>クラスからのメッセージ</li>
#     <li>先生との思い出</li>
# </ul>
#
# --- example 2 ---
# <p class='background'>男の人が最近の生活について話しています</p>
#
# <div class='conversation'>
# - 男：最近、仕事が忙しくて、毎日残業しています。帰るのが遅いので、夕食はいつもコンビニで買った弁当です。でも、栄養がよくないと思うし、体も疲れやすくなってきました。だから、これからは少し早く帰って、自分で料理を作るようにしたいと思っています。健康のために、生活を変えなければならないと感じています。
# </div>
#
# <a class='follow-up'>男の人は、何を言いたいのですか？</a>
# <ul class='options'>
#     <li>忙しいので、残業をもっと増やしたい</li>
#     <li>料理を作るのがめんどうだと思っている</li>
#     <li>健康のために、生活を変えたいと思っている</li>
#     <li>コンビニの弁当はおいしくないと思っている</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 趣味の道具やギアについて話す
# AI: <p class='background'>カフェで友人同士の男女が趣味について話しています。</p>
#
# <div class='conversation'>
# - 男: 最近、新しいカメラを買ったんだ。ずっと欲しかったモデルで、やっと手に入れたよ。
# - 女: へえ、写真撮るのが趣味だったよね。やっぱり今までのと全然違う？
# - 男: うん、性能が格段に上がって、細かい部分まできれいに写るんだ。重さも軽くなって、持ち運びやすいし。
# - 女: それなら、撮影に出かけるのも楽しくなりそうだね。どんな写真を撮るのが好きなの？
# - 男: 風景が多いかな。特に山とか海とか、自然の中で撮るのが好きなんだ。
# - 女: いいね。私も最近、登山用の靴を新調したんだ。前のはもう古くて滑りやすかったから。
# - 男: それは大事だよ。道具が良いと、趣味ももっと充実するよね。今度一緒に山に行って、写真撮ろうか。
# </div>
#
# <a class='follow-up'>男の人は、どんな気持ちで話していますか？</a>
# <ul class='options'>
#     <li>新しい道具を手に入れて、趣味がもっと楽しくなった</li>
#     <li>道具が増えすぎて困っている</li>
#     <li>写真を撮るのをやめたいと思っている</li>
#     <li>友人の趣味に興味がない</li>
# </ul>
# 正解: 1
# HUMAN: GOOD ENOUGH
# 2025-09-14 11:14:46,992 - INFO - jlpt - Formatter: {'background': 'カフェで友人同士の男女が趣味について話しています。', 'follow_up': '男の人は、どんな気持ちで話していますか？', 'conversation': [{'gender': 'male', 'context': '最近、新しいカメラを買ったんだ。ずっと欲しかったモデルで、やっと手に入れたよ。'}, {'gender': 'female', 'context': 'へえ、写真撮るのが趣味だったよね。やっぱり今までのと全然違う？'}, {'gender': 'male', 'context': 'うん、性能が格段に上がって、細かい部分まできれいに写るんだ。重さも軽くなって、持ち運びやすいし。'}, {'gender': 'female', 'context': 'それなら、撮影に出かけるのも楽しくなりそうだね。どんな写真を撮るのが好きなの？'}, {'gender': 'male', 'context': '風景が多いかな。特に山とか海とか、自然の中で撮るのが好きなんだ。'}, {'gender': 'female', 'context': 'いいね。私も最近、登山用の靴を新調したんだ。前のはもう古くて滑りやすかったから。'}, {'gender': 'male', 'context': 'それは大事だよ。道具が良いと、趣味ももっと充実するよね。今度一緒に山に行って、写真撮ろうか。'}], 'choices': ['新しい道具を手に入れて、趣味がもっと楽しくなった', '道具が増えすぎて困っている', '写真を撮るのをやめたいと思っている', '友人の趣味に興味がない'], 'correct_answer': 1}
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_background.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_0_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_1_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_2_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_3_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_4_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_5_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_6_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_follow_up.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_1_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_1_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_2_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_2_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_3_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_3_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_4_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_4_option.wav
# Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_conversation_output.mp3
# ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\summary_understanding_2_conversation_output.mp3 as blob cb7fdef8-9118-11f0-8278-005056c00008/summary_understanding_2_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>カフェで友人同士の男女が趣味について話しています。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Male:</strong> 最近、新しいカメラを買ったんだ。ずっと欲しかったモデルで、やっと手に入れたよ。</p>
# <p><strong>Female:</strong> へえ、写真撮るのが趣味だったよね。やっぱり今までのと全然違う？</p>
# <p><strong>Male:</strong> うん、性能が格段に上がって、細かい部分まできれいに写るんだ。重さも軽くなって、持ち運びやすいし。</p>
# <p><strong>Female:</strong> それなら、撮影に出かけるのも楽しくなりそうだね。どんな写真を撮るのが好きなの？</p>
# <p><strong>Male:</strong> 風景が多いかな。特に山とか海とか、自然の中で撮るのが好きなんだ。</p>
# <p><strong>Female:</strong> いいね。私も最近、登山用の靴を新調したんだ。前のはもう古くて滑りやすかったから。</p>
# <p><strong>Male:</strong> それは大事だよ。道具が良いと、趣味ももっと充実するよね。今度一緒に山に行って、写真撮ろうか。</p>
# </div>
# <p><strong>follow-up question: </strong>男の人は、どんな気持ちで話していますか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cb7fdef8-9118-11f0-8278-005056c00008/summary_understanding_2_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>新しい道具を手に入れて、趣味がもっと楽しくなった</b> <span style='color:green;'>(correct)</span></li>
# <li>2. 道具が増えすぎて困っている</li>
# <li>3. 写真を撮るのをやめたいと思っている</li>
# <li>4. 友人の趣味に興味がない</li>
# </ul>

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.active_expression((random.choice(topics)),seq=3)
display(HTML(_render_result(result=content)))
# Out:
# 2025-09-14 11:15:33,589 - INFO - jlpt - ---Generator----
# 2025-09-14 11:15:38,334 - INFO - jlpt - ---REVISOR---
# 2025-09-14 11:15:39,012 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-14 11:15:39,016 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-14 11:15:39,018 - INFO - jlpt - --- Formatter ---
# 2025-09-14 11:15:39,019 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Create an AI-friendly picture prompt that visually depicts a scene where a question is being asked.
# Indicate clearly who speaks first: if a woman asks the question, a man should be shown answering, and if a man asks, a woman should answer.
# The scene should be illustrated without any background text. And there is a black arrow pointing to the party who is about to answer the question. The arrow must closely follow the party who is about to answer the question.
#
# Generate Japanese language test questions similar to JLPT situational questions.
# For each question, describe a real-life situation in Japanese and then ask what the person should say in that situation.
# Provide three possible answers in Japanese.
# only one of which is appropriate or most natural for the situation.
# The correct answer must be highly relevant to the question and logical. The answer needs to maintain coherence with the previous question and not be too abrupt. For example, according to different scenarios, it is best to add a "あのう〜／へ〜／すみません／わ〜" connector as a buffer.
# The language used in the correct answer needs to match the identity of both interlocutors.
# For example, students must use respectful language towards their teachers, and subordinates must also use respectful language towards their superiors.
# Keep the situations practical and relevant to everyday life in Japan. Do not mention or refer to blurred faces.
#
# The picture description must be in a dedicated section named: background.
# The gender of the character indicated by the arrow in the picture needs to be consistent with the gender of the character generating the conversation.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Get inspiration from the "Topic" given by the user. Consider the feedback given in the previous conversation if it exists
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, the options are 1,2,3. for example: 正解: 1
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>
# The scene shows a young person standing at the entrance of a house, holding a bag and facing three adults who are standing together inside the house.
# The setting is indoors and feels polite and formal, as if the young person is greeting or saying goodbye to the adults.
# Include a vase with flowers on a shelf or table near the entrance.
# There is a black arrow pointing towards the young person.
# </p>
#
# <div class='conversation'>
# - 男: 休みの間、友達の家に泊めてもらいました。帰る時、友達の両親に挨拶します。何と言いますか？
# </div>
#
# <a class='follow_up'>休みの間、友達の家に泊めてもらいました。帰る時、友達の両親に挨拶します。何と言いますか？</a>
# <ul class='options'>
#     <li>お世話になりました</li>
#     <li>お邪魔します</li>
#     <li>気をつけて帰ってください</li>
# </ul>
#
# --- example 2 ---
# <p class='background'>
# The scene takes place in a café or restaurant.
# A woman is sitting at a table with drinks in front of her, speaking to a server who stands beside her table holding a tray with a glass.
# There are additional tables and chairs in the background, with drinks and utensils visible.
# There is a black arrow pointing towards the woman.
# </p>
#
# <div class='conversation'>
# - 女: カフェで窓側の席が空きました。席を変われるかどうか聞きたいです。店員に何と言いますか？
# </div>
#
# <a class='follow_up'>カフェで窓側の席が空きました。席を変われるかどうか聞きたいです。店員に何と言いますか？</a>
# <ul class='options'>
#     <li>あの席に変わってもらえますか</li>
#     <li>窓側の席に座らないといけませんか</li>
#     <li>あっちの席に移れますか</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 仕事のプロジェクトについて話す
# AI: <p class='background'>
# The scene shows an office meeting room with a rectangular table.
# A man in a business suit is sitting at the table, holding a document and looking at a woman who stands at the head of the table, pointing to a chart on a whiteboard.
# Other colleagues are seated around the table, some with laptops open.
# There is a black arrow pointing towards the man who is sitting and about to answer.
# </p>
#
# <div class='conversation'>
# - 女: プロジェクトの進捗について会議で上司に質問されました。どのように答えますか？
# </div>
#
# <a class='follow_up'>プロジェクトの進捗について会議で上司に質問されました。どのように答えますか？</a>
# <ul class='options'>
#     <li>あのう、現在の状況をご説明いたします</li>
#     <li>まあ、あとで見ておきます</li>
#     <li>へえ、知りませんでした</li>
# </ul>
# 正解: 1
# HUMAN: GOOD ENOUGH
# 2025-09-14 11:15:40,827 - INFO - jlpt - Formatter: {'background': 'The scene shows an office meeting room with a rectangular table. A man in a business suit is sitting at the table, holding a document and looking at a woman who stands at the head of the table, pointing to a chart on a whiteboard. Other colleagues are seated around the table, some with laptops open. There is a black arrow pointing towards the man who is sitting and about to answer.', 'follow_up': 'プロジェクトの進捗について会議で上司に質問されました。どのように答えますか？', 'conversation': [{'gender': 'female', 'context': 'プロジェクトの進捗について会議で上司に質問されました。どのように答えますか？'}], 'choices': ['あのう、現在の状況をご説明いたします', 'まあ、あとで見ておきます', 'へえ、知りませんでした'], 'correct_answer': 1}
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_0_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_1_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_1_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_2_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_2_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_3_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_3_option.wav
# Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_conversation_output.mp3
# ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\active_expression_3_conversation_output.mp3 as blob cb7fdef8-9118-11f0-8278-005056c00008/active_expression_3_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>The scene shows an office meeting room with a rectangular table. A man in a business suit is sitting at the table, holding a document and looking at a woman who stands at the head of the table, pointing to a chart on a whiteboard. Other colleagues are seated around the table, some with laptops open. There is a black arrow pointing towards the man who is sitting and about to answer.</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> プロジェクトの進捗について会議で上司に質問されました。どのように答えますか？</p>
# </div>
# <p><strong>follow-up question: </strong>プロジェクトの進捗について会議で上司に質問されました。どのように答えますか？</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cb7fdef8-9118-11f0-8278-005056c00008/active_expression_3_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <div style="margin:1em 0;">
#   <img src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-image-prod/4o_images_c54747582cad8d82c632caa832d4db9a_image_1.png" alt="Result image" style="max-width:30%; border:1px solid #ccc; border-radius:8px;">
# </div>
# <ul>
# <li>1. <b>あのう、現在の状況をご説明いたします</b> <span style='color:green;'>(correct)</span></li>
# <li>2. まあ、あとで見ておきます</li>
# <li>3. へえ、知りませんでした</li>
# </ul>

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.immediate_ack((random.choice(topics)),seq=4)
display(HTML(_render_result(result=content)))
# Out:
# 2025-09-14 11:16:00,771 - INFO - jlpt - ---Generator----
# 2025-09-14 11:16:03,270 - INFO - jlpt - ---REVISOR---
# 2025-09-14 11:16:04,105 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-09-14 11:16:04,107 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-09-14 11:16:04,109 - INFO - jlpt - --- Formatter ---
# 2025-09-14 11:16:04,111 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N3水平撰写试卷。
#
# 任务：出一道符合N3水平的听力题。具体步骤如下：
#
# 步骤1：设置一个场景，两人个人a和b生成一段只有一个回合的对话。要求对话：
# - a的发言字数在20-40个单词左右
# - 贴近日本实际的日常生活。且a和b的对话可以是一男一女，也可以是两个相同性别的人。b对于a的回复，必须自然且符合语境，且不存在歧义，和其他模棱两可的回复
# - 对话通顺、语法正确，语义连贯
# - 对话的用户符合两个对话人的身份。比如学生对老师使用敬语，下属对上司也需要使用敬语，而两个年龄相同的朋友之间，使用普通的平语
#
# 步骤2：a作为首先说话的人，他说的话作为题干。b作为第二个说话的人，他说的话作为答案。
#
# 步骤3：除了b说的话之外，生成额外2个选项，共计3个选项。且要求：
# - 除了b说的话之外，另外两个是错误答案。错误原因：可能因为不符合上下文的回复逻辑，或者是不符合两个对话人身份的回复
# - 错误答案可以与正确答案有一定相似度，对答题人产生一定迷惑性
#
# 说明：
# 格式：遵循正式试卷中2个例子的格式，但不要遵循内容。
# 内容：确保词汇量限制在N3级。
# 参考：从用户给出的“Topic”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -句子中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3。例如：正解:1.
#
#
# Formal exam paper:
# --- example 1 ---
# <a class='follow_up'> 女：足、痛そうだね。年後のテニスの練習、休んだら？</a>
# <ul class='options'>
# 　<li>そうです、今日は帰るね</li>
# 　<li>今日は練習、ないんだね</li>
# 　<li>テニス、今日は休むの？</li>
# </ul>
#
# --- example 2 ---
# <a class='follow_up'>男：町の花火大会、今年はやらないことになったそうだよ。</a>
# <ul class='options'>
# 　<li>やらないもしれなかったね</li>
# 　<li>え？なんて？楽しみにしていたのに…</li>
# 　<li>じゃ、見に行かなきゃね</li>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 支払い方法について話す
# AI: <a class='follow_up'>女：すみません、この店でクレジットカードは使えますか？現金しか持っていないので、もし使えなかったら困るんですが。</a>
# <ul class='options'>
# 　<li>はい、ご利用いただけますのでご安心ください。</li>
# 　<li>カードは持っていませんが、現金で払います。</li>
# 　<li>現金は使えませんので、カードでお願いします。</li>
# </ul>
# 正解:1
# HUMAN: GOOD ENOUGH
# 2025-09-14 11:16:05,822 - INFO - jlpt - Formatter: {'follow_up': '女：すみません、この店でクレジットカードは使えますか？現金しか持っていないので、もし使えなかったら困るんですが。', 'conversation': [{'gender': 'female', 'context': 'すみません、この店でクレジットカードは使えますか？現金しか持っていないので、もし使えなかったら困るんですが。'}], 'choices': ['はい、ご利用いただけますのでご安心ください。', 'カードは持っていませんが、現金で払います。', '現金は使えませんので、カードでお願いします。'], 'correct_answer': 1}
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_0_speaker.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_1_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_1_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_2_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_2_option.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_3_seq.wav
# C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_3_option.wav
# Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_conversation_output.mp3
# ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\cb7fdef8-9118-11f0-8278-005056c00008\immediate_ack_4_conversation_output.mp3 as blob cb7fdef8-9118-11f0-8278-005056c00008/immediate_ack_4_conversation_output.mp3
# <strong>1番.</strong></br></br><div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> すみません、この店でクレジットカードは使えますか？現金しか持っていないので、もし使えなかったら困るんですが。</p>
# </div>
# <p><strong>follow-up question: </strong>女：すみません、この店でクレジットカードは使えますか？現金しか持っていないので、もし使えなかったら困るんですが。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/cb7fdef8-9118-11f0-8278-005056c00008/immediate_ack_4_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. <b>はい、ご利用いただけますのでご安心ください。</b> <span style='color:green;'>(correct)</span></li>
# <li>2. カードは持っていませんが、現金で払います。</li>
# <li>3. 現金は使えませんので、カードでお願いします。</li>
# </ul>
