# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n1'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.kanji_reading(word=random.choice(vocab.split(",")),gan_history="text")
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.midsize_passage_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-20 00:04:15,637 - INFO - jlpt - ---Generator----
# 2025-11-20 00:04:29,744 - INFO - jlpt - ---REVISOR---
# 2025-11-20 00:04:30,452 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-20 00:04:30,453 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-20 00:04:30,455 - INFO - jlpt - --- Formatter ---
# 2025-11-20 00:04:30,455 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a reading question for a JLPT N1 level exam.
# First you need to write a mid-size article around 450 words for student to read.
# The keypoints being tested in each question needs to be underlined with <u></u>
# Then, you give 2 questions by the related content in the article. the meaning of keypoint cannot be found in the article.
# Then, you give a question by the related content in the article.
# Instead, it should require the test-taker to infer, summarize, or understand the context or intent of the passage.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n . The options are 1,2,3,4. ensuring a balanced distribution of correct answers across options.
#
# Formal exam paper:
# --- example1----
# <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>羽毛を持つ恐竜について</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .page-number {
#             text-align: right;
#             font-weight: bold;
#             margin-top: 2em;
#             color: #666;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#     </style>
# </head>
# <body>
# <div class='article'>
#     <p>以下は、羽毛を持つ恐竜について述べられた文章である。</p>
#     <p>恐竜には、鳥のように卵を温める習性があったことがわかっています。</p>
#     <p class="note">（中略）</p>
#     <p>気になるのは、いつから卵を温めるようになったのかということですが、羽毛を持った時点で、卵を温める習性も持っていた可能性があります。</p>
#     <p>羽毛を持つことで、体温が維持できるようになるので、その体温を使って卵の温度を一定に保つことができます。特に夜間は気温が下がるので、夜に親が卵の上に座って眠っていれば、卵の保温にはとても効果的です。卵が一定の温かさで保たれていれば、さまざまな環境で卵が孵る確率が高くなります。</p>
#     <p>は虫類は卵を温めません。は虫類の卵は、放置されても、1日のうちある程度の時間、気温が30度を超えるなどの条件が整っていれば、自然と孵ります。その代わり、は虫類は1年のうち気温の高い限られた時期にしか産卵しません。生息地域も限られます。</p>
#     <p>羽毛のある恐竜が、鳥に近い体温を持っていたとすれば、夏以外の季節でも、寒冷地でも、安定して35～40度ほどの温度で卵を温めることが可能です。</p>
#     <p>厳密に言うと、羽毛があると体の熱を逃がさないので、卵を温めるには不向きです。人間で言うと、衣服の上からでは温めにくいのと同じです。温めるなら、服の中に入れて直接体温が伝わるようにするはずです。</p>
#     <p>卵を抱く時期の鳥も、卵と接する部分の羽毛がなくなり、皮膚がむき出しになります。恐竜が卵を温めていたとすれば、おそらく同じように、お腹のあたりの羽毛が抜けていたと思われます。</p>
#     <p class="note">（注）生息地域：生活している地域</p>
# </div>
#
# <div class="follow-up">
#     <a>筆者によると、羽毛を持つことにはどのような利点があるか。</a>
#     <ul class="options">
#         <li>低温の環境でも、卵を一定の温かさで保つことができる。</li>
#         <li>低温の環境でも、卵の成長を促し早く孵すことができる。</li>
#         <li>環境にかかわらず体温が維持でき、卵が多く産める。</li>
#         <li>環境に合わせて卵の温度を調整でき、早く孵すことができる。</li>
#     </ul>
#
#     <a>お腹のあたりの羽毛が抜けていたと思われますとあるが、筆者はなぜそう考えるのか。</a>
#     <ul class="options">
#         <li>体の熱を逃がすことで、卵を温めすぎるのを防げるから</li>
#         <li>皮膚から卵に直接体温が伝わることで、効率的に卵を温められるから</li>
#         <li>卵に皮膚を直接当てることで、卵の温度を知ることができるから</li>
#         <li>卵と接する部分の皮膚がむき出しになることで、卵が抱きやすくなるから</li>
#     </ul>
# </div>
#
# </body>
# </html>
#
# ---example2---
# <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>羽毛を持つ恐竜について</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .page-number {
#             text-align: right;
#             font-weight: bold;
#             margin-top: 2em;
#             color: #666;
#         }
#         .underline {
#             text-decoration: underline;
#             text-underline-offset: 2px;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#     </style>
# </head>
# <body>
# <div class='article'>
#     <p>以下は、羽毛を持つ恐竜について述べられた文章である。</p>
#     <p>恐竜には、鳥のように卵を温める習性があったことがわかっています。</p>
#     <p class="note">（中略）</p>
#     <p>気になるのは、いつから卵を温めるようになったのかということですが、羽毛を持った時点で、卵を温める習性も持っていた可能性があります。</p>
#     <p>羽毛を持つことで、体温が維持できるようになるので、その体温を使って卵の温度を一定に保つことができます。特に夜間は気温が下がるので、夜に親が卵の上に座って眠っていれば、卵の保温にはとても効果的です。卵が一定の温かさで保たれていれば、さまざまな環境で卵が孵る確率が高くなります。</p>
#     <p>は虫類は卵を温めません。は虫類の卵は、放置されても、1日のうちある程度の時間、気温が30度を超えるなどの条件が整っていれば、自然と孵ります。その代わり、は虫類は1年のうち気温の高い限られた時期にしか産卵しません。生息地域も限られます。</p>
#     <p>羽毛のある恐竜が、鳥に近い体温を持っていたとすれば、夏以外の季節でも、寒冷地でも、安定して35～40度ほどの温度で卵を温めることが可能です。</p>
#     <p>厳密に言うと、羽毛があると体の熱を逃がさないので、卵を温めるには不向きです。人間で言うと、衣服の上からでは温めにくいのと同じです。温めるなら、服の中に入れて直接体温が伝わるようにするはずです。</p>
#     <p>卵を抱く時期の鳥も、卵と接する部分の羽毛がなくなり、皮膚がむき出しになります。恐竜が卵を温めていたとすれば、おそらく同じように、<span class="underline">お腹のあたりの羽毛が抜けていたと思われます。</span> </p>
#     <p class="note">（注）生息地域：生活している地域</p>
# </div>
#
# <div class="follow-up">
# <a>筆者によると、羽毛を持つことにはどのような利点があるか。</a>
# <ul class="options">
#     <li>低温の環境でも、卵を一定の温かさで保つことができる。</li>
#     <li>低温の環境でも、卵の成長を促し早く孵すことができる。</li>
#     <li>環境にかかわらず体温が維持でき、卵が多く産める。</li>
#     <li>環境に合わせて卵の温度を調整でき、早く孵すことができる。</li>
# </ul>
#
# <a><span class="underline">お腹のあたりの羽毛が抜けていたと思われます</span>とあるが、筆者はなぜそう考えるのか。</a>
# <ul class="options">
#     <li>体の熱を逃がすことで、卵を温めすぎるのを防げるから</li>
#     <li>皮膚から卵に直接体温が伝わることで、効率的に卵を温められるから</li>
#     <li>卵に皮膚を直接当てることで、卵の温度を知ることができるから</li>
#     <li>卵と接する部分の皮膚がむき出しになることで、卵が抱きやすくなるから</li>
# </ul>
# </div>
# </body>
# </html>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: 将来の抱負について話す
# AI: <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>将来の抱負について話す</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .underline {
#             text-decoration: underline;
#             text-underline-offset: 2px;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#     </style>
# </head>
# <body>
# <div class='article'>
#     <p>以下は、将来の抱負について述べられた文章である。</p>
#     <p>私は大学卒業後、社会に出て自分の力を試したいと考えている。学生時代は、知識を身につけることに重点を置いてきたが、これからは実践を通じて成長したい。特に、<span class="underline">自分の専門分野で社会に貢献できる人材になること</span>を目標としている。</p>
#     <p>そのためには、単に知識を増やすだけではなく、柔軟な発想や協調性も必要だと痛感している。最近は、異なる価値観を持つ人々と意見を交わす機会が増え、視野が広がった。これからも積極的に新しいことに挑戦し、失敗を恐れず経験を重ねていきたい。</p>
#     <p>また、将来的には海外で働くことも視野に入れている。異文化の中で自分を試すことで、より多くのことを学べると信じている。語学力の向上はもちろん、現地の人々との交流を通じて、<span class="underline">多様な価値観を理解し受け入れる力</span>を養いたい。</p>
#     <p>しかし、理想を追い求めるだけでは現実に直面したときに挫折することもあるだろう。だからこそ、日々の努力を怠らず、目の前の課題に一つずつ向き合う姿勢を大切にしたい。将来の抱負を実現するためには、地道な積み重ねが不可欠だと考えている。</p>
#     <p>今後も自分自身を高めることを忘れず、社会に必要とされる存在になれるよう努めていきたい。</p>
# </div>
#
# <div class="follow-up">
# <a><span class="underline">自分の専門分野で社会に貢献できる人材になること</span>とは、筆者にとってどのような意味を持つか。</a>
# <ul class="options">
#     <li>自分の得意分野を活かして、社会の課題解決に携わること</li>
#     <li>自分の知識を活かして、周囲の人々に助言すること</li>
#     <li>自分の能力を高めて、個人的な目標を達成すること</li>
#     <li>自分の経験を活かして、後輩の指導にあたること</li>
# </ul>
# 正解: 1
#
# <a><span class="underline">多様な価値観を理解し受け入れる力</span>を養いたいとあるが、筆者はなぜその力が必要だと考えているか。</a>
# <ul class="options">
#     <li>異なる考え方を尊重することで、円滑な人間関係を築けるから</li>
#     <li>新しい知識を得ることで、専門分野の発展につながるから</li>
#     <li>自分の意見を強く主張できるようになるから</li>
#     <li>海外で働く際に、現地の文化に適応しやすくなるから</li>
# </ul>
# 正解: 4
#
# <a>筆者の将来の抱負について、本文全体から推測できることは何か。</a>
# <ul class="options">
#     <li>自分の成長だけでなく、社会への貢献も重視している</li>
#     <li>専門分野の知識を深めることだけを目指している</li>
#     <li>海外での生活を最優先に考えている</li>
#     <li>失敗を避けるために慎重な行動を心がけている</li>
# </ul>
# 正解: 1
# </div>
# </body>
# </html>
# HUMAN: GOOD ENOUGH
# 2025-11-20 00:04:36,125 - INFO - jlpt - Formatter: {'html_article': '<p>以下は、将来の抱負について述べられた文章である。</p><p>私は大学卒業後、社会に出て自分の力を試したいと考えている。学生時代は、知識を身につけることに重点を置いてきたが、これからは実践を通じて成長したい。特に、<span class="underline">自分の専門分野で社会に貢献できる人材になること</span>を目標としている。</p><p>そのためには、単に知識を増やすだけではなく、柔軟な発想や協調性も必要だと痛感している。最近は、異なる価値観を持つ人々と意見を交わす機会が増え、視野が広がった。これからも積極的に新しいことに挑戦し、失敗を恐れず経験を重ねていきたい。</p><p>また、将来的には海外で働くことも視野に入れている。異文化の中で自分を試すことで、より多くのことを学べると信じている。語学力の向上はもちろん、現地の人々との交流を通じて、<span class="underline">多様な価値観を理解し受け入れる力</span>を養いたい。</p><p>しかし、理想を追い求めるだけでは現実に直面したときに挫折することもあるだろう。だからこそ、日々の努力を怠らず、目の前の課題に一つずつ向き合う姿勢を大切にしたい。将来の抱負を実現するためには、地道な積み重ねが不可欠だと考えている。</p><p>今後も自分自身を高めることを忘れず、社会に必要とされる存在になれるよう努めていきたい。</p>', 'questions': [{'html_question': '<span class="underline">自分の専門分野で社会に貢献できる人材になること</span>とは、筆者にとってどのような意味を持つか。', 'correct_answer': 1, 'choices': ['自分の得意分野を活かして、社会の課題解決に携わること', '自分の知識を活かして、周囲の人々に助言すること', '自分の能力を高めて、個人的な目標を達成すること', '自分の経験を活かして、後輩の指導にあたること']}, {'html_question': '<span class="underline">多様な価値観を理解し受け入れる力</span>を養いたいとあるが、筆者はなぜその力が必要だと考えているか。', 'correct_answer': 4, 'choices': ['異なる考え方を尊重することで、円滑な人間関係を築けるから', '新しい知識を得ることで、専門分野の発展につながるから', '自分の意見を強く主張できるようになるから', '海外で働く際に、現地の文化に適応しやすくなるから']}, {'html_question': '筆者の将来の抱負について、本文全体から推測できることは何か。', 'correct_answer': 1, 'choices': ['自分の成長だけでなく、社会への貢献も重視している', '専門分野の知識を深めることだけを目指している', '海外での生活を最優先に考えている', '失敗を避けるために慎重な行動を心がけている']}]}
# <strong>1番.</strong></br></br><p>以下は、将来の抱負について述べられた文章である。</p><p>私は大学卒業後、社会に出て自分の力を試したいと考えている。学生時代は、知識を身につけることに重点を置いてきたが、これからは実践を通じて成長したい。特に、<span class="underline">自分の専門分野で社会に貢献できる人材になること</span>を目標としている。</p><p>そのためには、単に知識を増やすだけではなく、柔軟な発想や協調性も必要だと痛感している。最近は、異なる価値観を持つ人々と意見を交わす機会が増え、視野が広がった。これからも積極的に新しいことに挑戦し、失敗を恐れず経験を重ねていきたい。</p><p>また、将来的には海外で働くことも視野に入れている。異文化の中で自分を試すことで、より多くのことを学べると信じている。語学力の向上はもちろん、現地の人々との交流を通じて、<span class="underline">多様な価値観を理解し受け入れる力</span>を養いたい。</p><p>しかし、理想を追い求めるだけでは現実に直面したときに挫折することもあるだろう。だからこそ、日々の努力を怠らず、目の前の課題に一つずつ向き合う姿勢を大切にしたい。将来の抱負を実現するためには、地道な積み重ねが不可欠だと考えている。</p><p>今後も自分自身を高めることを忘れず、社会に必要とされる存在になれるよう努めていきたい。</p>
# <p><strong>1.<span class="underline">自分の専門分野で社会に貢献できる人材になること</span>とは、筆者にとってどのような意味を持つか。</strong></p>
# <ul>
# <li><b>自分の得意分野を活かして、社会の課題解決に携わること</b> <span style='color:green;'>(correct)</span></li>
# <li>自分の知識を活かして、周囲の人々に助言すること</li>
# <li>自分の能力を高めて、個人的な目標を達成すること</li>
# <li>自分の経験を活かして、後輩の指導にあたること</li>
# </ul>
# <p><strong>2.<span class="underline">多様な価値観を理解し受け入れる力</span>を養いたいとあるが、筆者はなぜその力が必要だと考えているか。</strong></p>
# <ul>
# <li>異なる考え方を尊重することで、円滑な人間関係を築けるから</li>
# <li>新しい知識を得ることで、専門分野の発展につながるから</li>
# <li>自分の意見を強く主張できるようになるから</li>
# <li><b>海外で働く際に、現地の文化に適応しやすくなるから</b> <span style='color:green;'>(correct)</span></li>
# </ul>
# <p><strong>3.筆者の将来の抱負について、本文全体から推測できることは何か。</strong></p>
# <ul>
# <li><b>自分の成長だけでなく、社会への貢献も重視している</b> <span style='color:green;'>(correct)</span></li>
# <li>専門分野の知識を深めることだけを目指している</li>
# <li>海外での生活を最優先に考えている</li>
# <li>失敗を避けるために慎重な行動を心がけている</li>
# </ul>

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(understanding_read)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.understanding_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-20 00:04:36,135 - INFO - jlpt - ---Generator----
# 2025-11-20 00:04:47,225 - INFO - jlpt - ---REVISOR---
# 2025-11-20 00:04:48,035 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-20 00:04:48,037 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-20 00:04:48,038 - INFO - jlpt - --- Formatter ---
# 2025-11-20 00:04:48,039 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N1水平撰写试卷。
#
# 任务：你的工作是为JLPT N1水平考试写一道阅读题。
# 首先，你需要写一篇大约800字的长篇文章供学生阅读。
# 然后，根据文章中的相关内容给出3个问题。
# 目的是确保学生能够理解文章的内容。
#
# 说明：
# 格式：遵循正式试卷中示例的格式，而不是内容。输出必须为html格式，并删除行更改标记。
# 内容：确保词汇量限制在N1级。
# 参考：从用户给出的“主题”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -文章中的单词既不能用于问题，也不能用于选项。
# -在输出中显示正确答案，选项为1,2,3,4.例如：正解：n, 正确答案分布要平均，不要集中在某个选项
#
#
# 正式试卷：
# <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>数学の問題を解くことについて</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .page-number {
#             text-align: right;
#             font-weight: bold;
#             margin-top: 2em;
#             color: #666;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#         .underline {
#             text-decoration: underline;
#             text-underline-offset: 2px;
#         }
#         sup {
#             font-size: 0.8em;
#         }
#     </style>
# </head>
# <body>
# <div class='article'>
#     <p>以下は、ある数学者が描いた文章である。</p>
#     <p>数学というものは、解き方がわかってしまったあとで、力がつくことはない。解き方を身につける前の、まだ解き方のわからない間だけが、力をつけるチャンスである。解けるようになるのは同じでも、それまでのあり方で、力が身につくかどうかが、きまってくる。</p>
#     <p>それに、おもしろいのも、本当は、まだ解けないで、いろいろと考えている間である。解けなきゃつまらないようだが、それは早く解こうとあせるからで、楽しみは解けるまでのほうにある。解けるようになったあとは、むしろむなしい。だいたい、「答えのわかっている謎」なんて、意味がない。解き方がわからないからこそ、問題の名にあたいするのだ。</p>
#     <p>もちろん、まったく手がつかないのでは、おもしろくもないが、案外に、多少はわからないでも、うまく<span class="underline">頭のなかに飼っておくと</span>、そのうちに馴れてくれて、わかってきたりする。その、だんだん少しずつ、わかりかけというのも、オツなものだ。そのためには、それを飼っておく、頭の牧場がゆたかでなければならない。本当のところは、数学の力というのは、いろいろとわかったことをためこむより、わからないのを飼っておける、その牧場のゆたかさのほうにあるのかもしれない。</p>
#     <p>とくに、公式などをおぼえるのには、ぼくは反対である。それは簡単すぎて、少しもおもしろくないし、おぼえたものは忘れるものだ。とくに、急いでおぼえたものは、早く忘れる。同じおぼえるにしても、なるべくなら時間をかけたほうが、長持ちする。</p>
#     <p class="note">（中略）</p>
#     <p>このごろは、テストでおどされることが多いので、わかること、解けることを急ぐ傾向にある。たしかに、テストなどでは、時間がかぎられているので、急ぐのも多少は仕方がない。しかしながら、時間を制限されたときに急いでできるためには、時間の制限されていないときに、時間を気にしないでやっておいたほうがよい。テストで急ぐためには、テスト以外で急がないほうがよいのである。</p>
#     <p>どんなやり方でも、わかって、問題が解けるようになる、という結果は同じかもしれない。しかし、ゆったりとやると、そのわかり方にコクが出てくるものだ。そして、その結果に達するまでの道筋を楽しむことで、力がつく。</p>
#     <p>勉強を楽しむなんて、と思うかもしれないが、それは目的ばかり見てあせるからで、楽しむ気になれば、なんだって楽しめるものだ。</p>
#     <p class="note">(注1)手がつかない：ここでは、できない</p>
#     <p class="note">(注2)オツな：ここでは、おもしろい</p>
#     <p class="note">(注3)おどされる：ここでは、早く問題を解かされる</p>
#     <p class="note">(注4)コク：深み。</p>
# </div>
#
# <a>数学の問題を解くことについて、筆者の考えに合うのはどれか。</a>
# <ul class="options">
#     <li>早く解けなくても、解き方を身につけることが大切だ。</li>
#     <li>解けても解けなくても、問題に取り組むことが大切だ。</li>
#     <li>解けなかった問題が解けるようになったらおもしろくなる。</li>
#     <li>解き方のわからない問題を解こうとすることに意味がある。</li>
# </ul>
#
# <a><span class="underline">頭のなかに飼っておく</span>とはどういうことか。</a>
# <ul class="options">
#     <li>わかる問題を手がかりにして、わからない問題を考えること</li>
#     <li>わかる問題とわからない問題を、頭のなかで区別しておくこと。</li>
#     <li>わからない問題をわかるまで解き続けていること</li>
#     <li>わからない状態のまま、問題を頭のなかに残しておくこと</li>
# </ul>
#
# <a>筆者によると、どのように勉強すればよいか。</a>
# <ul class="options">
#     <li>結果を急がずに、考えることを楽しむ。</li>
#     <li>結果に達することができれば、どんなやり方でもよい。</li>
#     <li>目的を忘れないで、あせらずに勉強を楽しめばよい。</li>
#     <li>自分に合ったやり方を探して、時間を気にせず取り組む。</li>
# </ul>
#
# </body>
# </html>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 地域社会への貢献について話す
# AI: <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>地域社会への貢献について</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .page-number {
#             text-align: right;
#             font-weight: bold;
#             margin-top: 2em;
#             color: #666;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#         .underline {
#             text-decoration: underline;
#             text-underline-offset: 2px;
#         }
#         sup {
#             font-size: 0.8em;
#         }
#     </style>
# </head>
# <body>
# <div class='article'>
#     <p>以下は、ある市民が地域社会への貢献について述べた文章である。</p>
#     <p>近年、地域社会のつながりが希薄になっていると指摘されることが多い。都市化や生活様式の変化により、隣人との交流が減り、孤立感を抱える人も増えている。しかし、地域社会への貢献は、個人の満足感や安心感を高めるだけでなく、社会全体の安定にも寄与する重要な行為である。</p>
#     <p>地域社会への貢献と一口に言っても、その形はさまざまである。例えば、清掃活動や防災訓練への参加、子どもや高齢者の見守り、地域イベントの運営などが挙げられる。これらの活動は、特別な能力や知識がなくても、誰でも参加できるものが多い。自分にできる範囲で行動することが、地域の活性化につながる。</p>
#     <p>また、地域社会への貢献は、個人の成長にもつながる。人と協力して何かを成し遂げる経験は、自己肯定感を高めるだけでなく、他者への理解を深める機会にもなる。特に、異なる世代や背景を持つ人々と交流することで、視野が広がり、多様な価値観を受け入れる力が養われる。</p>
#     <p>一方で、地域社会への貢献には課題もある。忙しい日常の中で時間を捻出することが難しいと感じる人も多い。また、活動に参加するきっかけが見つからない場合もある。そのため、地域の行政や団体が情報を積極的に発信し、参加しやすい環境を整えることが求められる。</p>
#     <p>最近では、インターネットを活用した地域活動も増えている。オンラインでの情報共有や、SNSを通じた呼びかけなど、新しい形の貢献が広がっている。これにより、従来の方法では参加が難しかった人も、気軽に地域社会と関わることができるようになった。</p>
#     <p>地域社会への貢献は、誰か特定の人だけが担うものではなく、住民一人ひとりが意識して取り組むべきものである。小さな行動が積み重なり、やがて大きな変化を生み出す。自分の住む地域をより良くするために、できることから始めてみることが大切だ。</p>
#     <p class="note">(注1)希薄：ここでは、弱い、少ない</p>
#     <p class="note">(注2)見守り：ここでは、注意して見ていること</p>
#     <p class="note">(注3)自己肯定感：自分を肯定的に評価する気持ち</p>
# </div>
#
# <a>筆者が考える地域社会への貢献の意義として最も適切なのはどれか。</a>
# <ul class="options">
#     <li>地域の伝統を守ることができる。</li>
#     <li>個人と社会の両方に良い影響を与える。</li>
#     <li>行政の負担を減らすことができる。</li>
#     <li>新しい友人を作ることができる。</li>
# </ul>
# 正解：2
#
# <a>地域社会への貢献の方法として、筆者が述べているものはどれか。</a>
# <ul class="options">
#     <li>地域の歴史を学ぶこと</li>
#     <li>地域の活動に自分のできる範囲で参加すること</li>
#     <li>地域の施設を利用すること</li>
#     <li>地域の問題を話し合うこと</li>
# </ul>
# 正解：2
#
# <a>地域社会への貢献の課題として、筆者が挙げているものはどれか。</a>
# <ul class="options">
#     <li>活動の内容が複雑であること</li>
#     <li>参加者が限られていること</li>
#     <li>参加するきっかけや時間の確保が難しいこと</li>
#     <li>活動の成果が見えにくいこと</li>
# </ul>
# 正解：3
#
# </body>
# </html>
# HUMAN: GOOD ENOUGH
# 2025-11-20 00:04:54,337 - INFO - jlpt - Formatter: {'html_article': '<p>以下は、ある市民が地域社会への貢献について述べた文章である。</p><p>近年、地域社会のつながりが希薄になっていると指摘されることが多い。都市化や生活様式の変化により、隣人との交流が減り、孤立感を抱える人も増えている。しかし、地域社会への貢献は、個人の満足感や安心感を高めるだけでなく、社会全体の安定にも寄与する重要な行為である。</p><p>地域社会への貢献と一口に言っても、その形はさまざまである。例えば、清掃活動や防災訓練への参加、子どもや高齢者の見守り、地域イベントの運営などが挙げられる。これらの活動は、特別な能力や知識がなくても、誰でも参加できるものが多い。自分にできる範囲で行動することが、地域の活性化につながる。</p><p>また、地域社会への貢献は、個人の成長にもつながる。人と協力して何かを成し遂げる経験は、自己肯定感を高めるだけでなく、他者への理解を深める機会にもなる。特に、異なる世代や背景を持つ人々と交流することで、視野が広がり、多様な価値観を受け入れる力が養われる。</p><p>一方で、地域社会への貢献には課題もある。忙しい日常の中で時間を捻出することが難しいと感じる人も多い。また、活動に参加するきっかけが見つからない場合もある。そのため、地域の行政や団体が情報を積極的に発信し、参加しやすい環境を整えることが求められる。</p><p>最近では、インターネットを活用した地域活動も増えている。オンラインでの情報共有や、SNSを通じた呼びかけなど、新しい形の貢献が広がっている。これにより、従来の方法では参加が難しかった人も、気軽に地域社会と関わることができるようになった。</p><p>地域社会への貢献は、誰か特定の人だけが担うものではなく、住民一人ひとりが意識して取り組むべきものである。小さな行動が積み重なり、やがて大きな変化を生み出す。自分の住む地域をより良くするために、できることから始めてみることが大切だ。</p><p class="note">(注1)希薄：ここでは、弱い、少ない</p><p class="note">(注2)見守り：ここでは、注意して見ていること</p><p class="note">(注3)自己肯定感：自分を肯定的に評価する気持ち</p>', 'questions': [{'html_question': '筆者が考える地域社会への貢献の意義として最も適切なのはどれか。', 'correct_answer': 2, 'choices': ['地域の伝統を守ることができる。', '個人と社会の両方に良い影響を与える。', '行政の負担を減らすことができる。', '新しい友人を作ることができる。']}, {'html_question': '地域社会への貢献の方法として、筆者が述べているものはどれか。', 'correct_answer': 2, 'choices': ['地域の歴史を学ぶこと', '地域の活動に自分のできる範囲で参加すること', '地域の施設を利用すること', '地域の問題を話し合うこと']}, {'html_question': '地域社会への貢献の課題として、筆者が挙げているものはどれか。', 'correct_answer': 3, 'choices': ['活動の内容が複雑であること', '参加者が限られていること', '参加するきっかけや時間の確保が難しいこと', '活動の成果が見えにくいこと']}]}
# <strong>1番.</strong></br></br><p>以下は、ある市民が地域社会への貢献について述べた文章である。</p><p>近年、地域社会のつながりが希薄になっていると指摘されることが多い。都市化や生活様式の変化により、隣人との交流が減り、孤立感を抱える人も増えている。しかし、地域社会への貢献は、個人の満足感や安心感を高めるだけでなく、社会全体の安定にも寄与する重要な行為である。</p><p>地域社会への貢献と一口に言っても、その形はさまざまである。例えば、清掃活動や防災訓練への参加、子どもや高齢者の見守り、地域イベントの運営などが挙げられる。これらの活動は、特別な能力や知識がなくても、誰でも参加できるものが多い。自分にできる範囲で行動することが、地域の活性化につながる。</p><p>また、地域社会への貢献は、個人の成長にもつながる。人と協力して何かを成し遂げる経験は、自己肯定感を高めるだけでなく、他者への理解を深める機会にもなる。特に、異なる世代や背景を持つ人々と交流することで、視野が広がり、多様な価値観を受け入れる力が養われる。</p><p>一方で、地域社会への貢献には課題もある。忙しい日常の中で時間を捻出することが難しいと感じる人も多い。また、活動に参加するきっかけが見つからない場合もある。そのため、地域の行政や団体が情報を積極的に発信し、参加しやすい環境を整えることが求められる。</p><p>最近では、インターネットを活用した地域活動も増えている。オンラインでの情報共有や、SNSを通じた呼びかけなど、新しい形の貢献が広がっている。これにより、従来の方法では参加が難しかった人も、気軽に地域社会と関わることができるようになった。</p><p>地域社会への貢献は、誰か特定の人だけが担うものではなく、住民一人ひとりが意識して取り組むべきものである。小さな行動が積み重なり、やがて大きな変化を生み出す。自分の住む地域をより良くするために、できることから始めてみることが大切だ。</p><p class="note">(注1)希薄：ここでは、弱い、少ない</p><p class="note">(注2)見守り：ここでは、注意して見ていること</p><p class="note">(注3)自己肯定感：自分を肯定的に評価する気持ち</p>
# <p><strong>1.筆者が考える地域社会への貢献の意義として最も適切なのはどれか。</strong></p>
# <ul>
# <li>地域の伝統を守ることができる。</li>
# <li><b>個人と社会の両方に良い影響を与える。</b> <span style='color:green;'>(correct)</span></li>
# <li>行政の負担を減らすことができる。</li>
# <li>新しい友人を作ることができる。</li>
# </ul>
# <p><strong>2.地域社会への貢献の方法として、筆者が述べているものはどれか。</strong></p>
# <ul>
# <li>地域の歴史を学ぶこと</li>
# <li><b>地域の活動に自分のできる範囲で参加すること</b> <span style='color:green;'>(correct)</span></li>
# <li>地域の施設を利用すること</li>
# <li>地域の問題を話し合うこと</li>
# </ul>
# <p><strong>3.地域社会への貢献の課題として、筆者が挙げているものはどれか。</strong></p>
# <ul>
# <li>活動の内容が複雑であること</li>
# <li>参加者が限られていること</li>
# <li><b>参加するきっかけや時間の確保が難しいこと</b> <span style='color:green;'>(correct)</span></li>
# <li>活動の成果が見えにくいこと</li>
# </ul>

# %% [markdown]
# ### 問題4 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.comprehensive_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-20 00:04:54,349 - INFO - jlpt - ---Generator----
# 2025-11-20 00:05:05,883 - INFO - jlpt - ---REVISOR---
# 2025-11-20 00:05:06,566 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-20 00:05:06,567 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-20 00:05:06,569 - INFO - jlpt - --- Formatter ---
# 2025-11-20 00:05:06,569 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Task: Your job is to write a reading question for a JLPT N1 level exam.
# First you need to write a long article around 450 words for student to read.
# Then, you give 2 questions by the related content in the article.
# The purpose is to ensure the students are able to understand the meaning of the article.
#
#
# Instructions:
# Format: follow the format of the example in the formal exam paper but not the content. The output must be in html format and remove line change tag.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the article can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n . The options are 1,2,3,4. ensuring a balanced distribution of correct answers across options.
#
#
# Formal exam paper:
# <!DOCTYPE html>
# <html lang="ja">
# <div class='article'>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">まじめで責任感が強く、負けず嫌いな人は「あきらめない」傾向があります。「あきらめない」ことは、基本的にはもちろんいいことなのですが、しかし一方、あきらめたほうがよいことも、実はけっこうあるものです。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">一所懸命に取り組んでも、うまくいかない、成果が出ない、充足感や満足感が得られない。そうした場合は「あきらめる」というのも、十分よい選択肢になります。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">こうした場合の「あきらめる」とは、「やめてしまう」ということです。</p>
#         <p class="note" style="font-size: 0.9em; color: #555; margin-top: 1.5em; margin-bottom: 1.2em; text-align: justify;">（中略）</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">やめる際には、「うまくいかなかった。やめてよかった」と思うのがコツでしょうね。うまくいかなかったことを悔やみつつやめるのは、避けたいものです。それでは、うまくいかなかったことが尾をひいてしまいます。「うまくいかなくてよかった」と思うくらいがちょうどいいでしょう。それができるようになると、一時的に落ち込んでも、立ち直りが早くなります。</p>
#     </div>
#
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">最近は仕事で悩んでいる人に対して「無理をしないであきらめたほうがよい。」というアドバイスを目にすることがある。もちろん体調を崩してしまうような場合には途中でやめるべきだ。しかしあきらめるということは、やれることはすべてやり尽くしたあとで考えるべきではないだろうか。困難な目標ほど簡単には達成できないものだ。だから、最初から、できなければあきらめてもいいんだという気持ちでいては、つらくなったときに頑張り続けることができない。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">仮にどうしてもうまくいかずにあきらめることになったとしても、精いっぱい努力した結果ならば納得できる。落ち込んだりくよくよしたりするのではなく気持ちを切り替えて、しっかり原因を考えて次に生かすことが重要だ。</p>
#         <p class="note" style="font-size: 0.9em; color: #555; margin-top: 1.5em; margin-bottom: 1.2em; text-align: justify;">(注) 尾を引く：ずっと残る</p>
#     </div>
# </div>
#
# <a>あきらめることについて、AとBはどのように述べているか。</a>
# <ul class="options"">
#     <li>AもBも、成果が出せる可能性が低いばあいには、あきらめたほうがよいと述べている。</li>
#     <li>AもBも、つらくても、できるだけあきらめずに頑張ったほうがよいと述べている。</li>
#     <li>Aは状況によっては、あきらめたほうがよいこともあると述べ、Bはあきらめてもいいと思ったほうが、頑張り続けられる場合もあると述べている。</li>
#     <li>Aは努力しても結果に結びつかない場合は、あきらめたほうがよいと述べ、Bは十分にやってみるまでは、あきらめることを考えるべきではないと述べている。</li>
# </ul>
#
# <a>AとBの認識で共通していることは何か。</a>
# <ul class="options">
#     <li>あきらめることになった原因を考えるべきだ。</li>
#     <li>あきらめるのが早ければ、早く立ち直れる。</li>
#     <li>あきらめたことでも、再挑戦することはできる。</li>
#     <li>あきらめたことを後悔してはいけない。</li>
# </ul>
#
# </body>
# </html>
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: 最近のニュースについて意見を述べる
# AI: <!DOCTYPE html>
# <html lang="ja">
# <div class='article'>
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">現代社会では、情報が瞬時に世界中に広がるため、ニュースの影響力が非常に大きくなっている。特に最近では、インターネットを通じて個人が自由に意見を発信できるようになったことで、報道の在り方や受け止め方にも変化が生じている。例えば、ある事件が発生した際、テレビや新聞だけでなく、SNSでも様々な見解が飛び交い、事実と異なる内容が拡散されることも少なくない。そのため、受け手側には情報の真偽を見極める力が求められている。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">一方で、ニュースを通じて社会問題に関心を持つ人が増えたことは、肯定的に評価できる。以前は限られた層しか知り得なかった出来事も、今では多くの人が知識を得て議論に参加できるようになった。これにより、社会全体で問題解決に向けた動きが活発化している。しかし、情報の受け取り方によっては、誤解や偏見が生まれる危険性もあるため、冷静な判断が重要である。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">ニュースを見て自分の意見を述べる際には、複数の情報源を比較し、根拠を持って主張することが求められる。感情的になりすぎず、客観的な視点を持つことで、より建設的な議論が可能となる。今後も情報社会が進展する中で、個人の意見表明のあり方が問われ続けるだろう。</p>
#     </div>
#
#     <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">
#         <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>
#         <p style="margin-bottom: 1.2em; text-align: justify;">最近の報道を見ていると、情報の拡散速度が以前とは比べものにならないほど速くなっていることを実感する。特に、ネット上では誰もが簡単に発言できるため、事実関係が十分に確認されないまま話題が広がることがある。こうした状況では、受け手が慎重に内容を吟味しなければ、誤った認識を持つ危険性が高まる。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">一方で、様々な立場から意見が述べられることで、従来の一方的な報道に比べて多角的な視点が得られるようになったのは大きな進歩だと考える。多くの人が社会問題について考え、自分なりの見方を持つことは、民主主義の発展にも寄与している。しかし、情報の取捨選択や意見の表明には責任が伴うため、安易な発言は避けるべきだろう。</p>
#         <p style="margin-bottom: 1.2em; text-align: justify;">今後は、情報を受け取る側も発信する側も、より高い意識を持って行動することが求められる。正確な知識と冷静な判断力が、健全な議論を支える基盤となるはずだ。</p>
#     </div>
# </div>
#
# <a>最近のニュースに関して、AとBはどのような点に注意すべきだと述べているか。</a>
# <ul class="options">
#     <li>情報の内容をすぐに信じることが重要だと述べている。</li>
#     <li>複数の立場からの意見を無視して自分の考えを優先すべきだと述べている。</li>
#     <li>情報の正確さや多様な視点を意識し、冷静に判断する必要があると述べている。</li>
#     <li>報道の速度が遅いほうが社会にとって良いと述べている。</li>
# </ul>
# 正解: 3
#
# <a>AとBの主張に共通していることは何か。</a>
# <ul class="options">
#     <li>情報を受け取る際には慎重さが求められる。</li>
#     <li>感情的な意見表明が社会を活性化させる。</li>
#     <li>一方的な報道だけを参考にするべきだ。</li>
#     <li>個人の意見は社会問題に影響しない。</li>
# </ul>
# 正解: 1
#
# </body>
# </html>
# HUMAN: GOOD ENOUGH
# 2025-11-20 00:05:13,536 - INFO - jlpt - Formatter: {'html_article': '<div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>        <p style="margin-bottom: 1.2em; text-align: justify;">現代社会では、情報が瞬時に世界中に広がるため、ニュースの影響力が非常に大きくなっている。特に最近では、インターネットを通じて個人が自由に意見を発信できるようになったことで、報道の在り方や受け止め方にも変化が生じている。例えば、ある事件が発生した際、テレビや新聞だけでなく、SNSでも様々な見解が飛び交い、事実と異なる内容が拡散されることも少なくない。そのため、受け手側には情報の真偽を見極める力が求められている。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">一方で、ニュースを通じて社会問題に関心を持つ人が増えたことは、肯定的に評価できる。以前は限られた層しか知り得なかった出来事も、今では多くの人が知識を得て議論に参加できるようになった。これにより、社会全体で問題解決に向けた動きが活発化している。しかし、情報の受け取り方によっては、誤解や偏見が生まれる危険性もあるため、冷静な判断が重要である。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">ニュースを見て自分の意見を述べる際には、複数の情報源を比較し、根拠を持って主張することが求められる。感情的になりすぎず、客観的な視点を持つことで、より建設的な議論が可能となる。今後も情報社会が進展する中で、個人の意見表明のあり方が問われ続けるだろう。</p>    </div>    <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>        <p style="margin-bottom: 1.2em; text-align: justify;">最近の報道を見ていると、情報の拡散速度が以前とは比べものにならないほど速くなっていることを実感する。特に、ネット上では誰もが簡単に発言できるため、事実関係が十分に確認されないまま話題が広がることがある。こうした状況では、受け手が慎重に内容を吟味しなければ、誤った認識を持つ危険性が高まる。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">一方で、様々な立場から意見が述べられることで、従来の一方的な報道に比べて多角的な視点が得られるようになったのは大きな進歩だと考える。多くの人が社会問題について考え、自分なりの見方を持つことは、民主主義の発展にも寄与している。しかし、情報の取捨選択や意見の表明には責任が伴うため、安易な発言は避けるべきだろう。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">今後は、情報を受け取る側も発信する側も、より高い意識を持って行動することが求められる。正確な知識と冷静な判断力が、健全な議論を支える基盤となるはずだ。</p>    </div>', 'questions': [{'html_question': '最近のニュースに関して、AとBはどのような点に注意すべきだと述べているか。', 'correct_answer': 3, 'choices': ['情報の内容をすぐに信じることが重要だと述べている。', '複数の立場からの意見を無視して自分の考えを優先すべきだと述べている。', '情報の正確さや多様な視点を意識し、冷静に判断する必要があると述べている。', '報道の速度が遅いほうが社会にとって良いと述べている。']}, {'html_question': 'AとBの主張に共通していることは何か。', 'correct_answer': 1, 'choices': ['情報を受け取る際には慎重さが求められる。', '感情的な意見表明が社会を活性化させる。', '一方的な報道だけを参考にするべきだ。', '個人の意見は社会問題に影響しない。']}]}
# <strong>1番.</strong></br></br><div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">A</span>        <p style="margin-bottom: 1.2em; text-align: justify;">現代社会では、情報が瞬時に世界中に広がるため、ニュースの影響力が非常に大きくなっている。特に最近では、インターネットを通じて個人が自由に意見を発信できるようになったことで、報道の在り方や受け止め方にも変化が生じている。例えば、ある事件が発生した際、テレビや新聞だけでなく、SNSでも様々な見解が飛び交い、事実と異なる内容が拡散されることも少なくない。そのため、受け手側には情報の真偽を見極める力が求められている。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">一方で、ニュースを通じて社会問題に関心を持つ人が増えたことは、肯定的に評価できる。以前は限られた層しか知り得なかった出来事も、今では多くの人が知識を得て議論に参加できるようになった。これにより、社会全体で問題解決に向けた動きが活発化している。しかし、情報の受け取り方によっては、誤解や偏見が生まれる危険性もあるため、冷静な判断が重要である。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">ニュースを見て自分の意見を述べる際には、複数の情報源を比較し、根拠を持って主張することが求められる。感情的になりすぎず、客観的な視点を持つことで、より建設的な議論が可能となる。今後も情報社会が進展する中で、個人の意見表明のあり方が問われ続けるだろう。</p>    </div>    <div class="section" style="margin-bottom: 3em; padding: 20px; background-color: #fff; border: 1px solid #ccc; border-radius: 12px;">        <span class="label" style="font-size: 1.4em; font-weight: bold; margin-bottom: 1em; display: block;">B</span>        <p style="margin-bottom: 1.2em; text-align: justify;">最近の報道を見ていると、情報の拡散速度が以前とは比べものにならないほど速くなっていることを実感する。特に、ネット上では誰もが簡単に発言できるため、事実関係が十分に確認されないまま話題が広がることがある。こうした状況では、受け手が慎重に内容を吟味しなければ、誤った認識を持つ危険性が高まる。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">一方で、様々な立場から意見が述べられることで、従来の一方的な報道に比べて多角的な視点が得られるようになったのは大きな進歩だと考える。多くの人が社会問題について考え、自分なりの見方を持つことは、民主主義の発展にも寄与している。しかし、情報の取捨選択や意見の表明には責任が伴うため、安易な発言は避けるべきだろう。</p>        <p style="margin-bottom: 1.2em; text-align: justify;">今後は、情報を受け取る側も発信する側も、より高い意識を持って行動することが求められる。正確な知識と冷静な判断力が、健全な議論を支える基盤となるはずだ。</p>    </div>
# <p><strong>1.最近のニュースに関して、AとBはどのような点に注意すべきだと述べているか。</strong></p>
# <ul>
# <li>情報の内容をすぐに信じることが重要だと述べている。</li>
# <li>複数の立場からの意見を無視して自分の考えを優先すべきだと述べている。</li>
# <li><b>情報の正確さや多様な視点を意識し、冷静に判断する必要があると述べている。</b> <span style='color:green;'>(correct)</span></li>
# <li>報道の速度が遅いほうが社会にとって良いと述べている。</li>
# </ul>
# <p><strong>2.AとBの主張に共通していることは何か。</strong></p>
# <ul>
# <li><b>情報を受け取る際には慎重さが求められる。</b> <span style='color:green;'>(correct)</span></li>
# <li>感情的な意見表明が社会を活性化させる。</li>
# <li>一方的な報道だけを参考にするべきだ。</li>
# <li>個人の意見は社会問題に影響しない。</li>
# </ul>

# %% [markdown]
# ### 問題5 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.topic_understanding_txt(random.choice(topics),seq=1)
display(HTML(_render_result(result=content)))
# Out:
# 2025-11-20 00:05:13,570 - INFO - jlpt - ---Generator----
# 2025-11-20 00:05:18,103 - INFO - jlpt - ---REVISOR---
# 2025-11-20 00:05:18,714 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-20 00:05:18,717 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-20 00:05:18,721 - INFO - jlpt - --- Formatter ---
# 2025-11-20 00:05:18,724 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing an exam paper for the JLPT N1 level.
#
# Task: Your job is to write a natural-sounding conversation between a man and a woman.
#
# Step 1, write a concise background about the dialogue introduction, which exclude the follow-up question and character name.
#
# Step 2, Give characters names during the conversation. They should call each name during the conversation depending on their relationship, level of formality.
# Do not refer to them as Mr. or Miss in the conversation context. Be polite and culturally appropriate in how they address each other.
# 女：conversation context
# 男：conversation context
# Besides, the name at the end of a sentence can be omitted.
# For example: "ありがとう、佐藤さん。" the name at the end of a sentence can be omitted, like "ありがとう。"
#
# Step 3, write dialogue, the dialogue should consist of 6-9 exchanges (back-and-forth turns). The total length should be approximately 300-400 words.
#
# Step 4, after the conversation, ask a follow-up question related to the conversation and focusing on the man or woman's next action, such as
# What,When,Where,Who,How,Which,Whose,How long,How often,How much,How many.
#
# Step 5, provide multiple-choice options based on the listening content. These options should test comprehension of the conversation’s meaning.
#
# Instructions:
# Format: follow the format of the 2 examples in the formal exam paper but not the content.
# Content: Ensure the vocabulary is restricted to N1 level.
# Reference: Generate new content based on the user-provided "Topic", taking into account any previous feedback and critique. Also, avoid repeating previously asked questions or given answers in Historical Generation.
# Additional Requirement:
# - Don't show question instructions and sequence number in the generated content.
# - The word in the sentence can neither be used in the question nor options.
# - You must show the correct answer in the output, for example: 正解: n . The options are 1,2,3,4. ensuring a balanced distribution of correct answers across options.
#
#
#
# Formal exam paper:
# --- example 1 ---
# <p class='background'>大学で女の学生と男の学生が話しています。男の学生はこの後まず、何をしますか。</p>
#
# <div class='conversation'>
# 女：中村くん、シンポジウムのポスター、掲示板に貼ってくれたんだね。ありがとう。
# 男：ええ、他に僕がやっておくことってありますか？
# 女：マイクとか会場の準備は前日にすればいいし、当日のスタッフ用のスケジュール表、これないから欲しいな、今週中にお願いしていい？
# 男：あ、はい。<br>
# 女：それから１番大事な当日配る資料、コピーまだなんじゃない？100部だよね？
# 男：あ、それなんですけど、発表者の方からの資料が全部そろってないんですよ。
# 女：そう、みなさんお忙しい方ばかりだから…私の方で発表者に資料を送ってもらうようにすぐに連絡をするから、集まったら次第コピーしよう。週明けには出してもらうようにするね。<br>
# 男：はい、わかりました。
# </div>
#
# <p class="follow-up">男の学生は、この後まず何をしますか。</p>
# <div class="options">
#      1. シンポジウムのポスターを貼る<br>
#      2. スタッフの当日の予定表を作る<br>
#      3. 当日配る資料をコピーする<br>
#      4. 発表者に連絡する
#   </p>
# </div>
#
#
# --- example 2 ---
# <p class='background'>スーパーで男の店長と女の店員が話しています。女の店員はこの後まず、何をしますか。</p>
#
# <div class='conversation'>
# 女：おはようございます、森田さん。今日は一部の商品に値引きシールを付ける作業をやってくれることになってるね。
# 男: あ、はい。準備してます。
# 男： えっと、忙しい時に悪いんだけど、倉庫に行って南コーヒーの豆、何袋あるか数えてきてくれる？数が少なかったら今日中に注文しないといけないんだ。
# 女：あ、わかりました。急ぎですか？<br>
# 男：あー、そのシールを貼る作業が終わってからでいいから。袋の数を数えたらメモを私の机の上に置いといて。
# 女：わかりました。<br>
# 男：お客さんがレジにたくさん並んでるから、私もすぐレジを手伝わなきゃいけなくて。値引シールを付けた商品をレジの横の棚に並べるのは明日の開店前にみんなですればいいから。じゃ、よろしくね。
# </div>
#
# <p class="follow-up">女の店員はこの後まず、何をしますか。</p>
# <div class="options">
#      <li>商品に値引きシールを貼る</li>
#      <li>倉庫で南コーヒーの数を数える</li>
#      <li>レジの手伝いをする</li>
#      <li>商品をレジの横の棚に並べる</li>
#   </p>
# </div>
#
#
# Historical Generation :
#
# HUMAN: Generate a JLPT question regarding Topic: ペットについて話す
# AI: <p class='background'>オフィスで女の社員と男の社員が昼休みに話しています。男の社員はこの後まず、何をしますか。</p>
#
# <div class='conversation'>
# 女：佐々木さん、最近犬を飼い始めたって聞きましたけど、どうですか？<br>
# 男：ええ、毎日がにぎやかになりました。朝も早く起こされるし、散歩も欠かせません。<br>
# 女：それは大変ですね。でも、癒されることも多いでしょう？<br>
# 男：もちろんです。仕事で疲れて帰っても、玄関で待っていてくれるので、すぐに元気になります。<br>
# 女：うらやましいです。私は猫派なんですけど、犬もいいなと思うことがあります。<br>
# 男：猫も静かでいいですよね。ところで、昼休みが終わったら、ペットショップに注文していた餌を受け取りに行く予定なんです。<br>
# 女：そうなんですね。帰りに寄るんですか？<br>
# 男：ええ、会社から近いので、仕事が終わったらすぐに立ち寄るつもりです。<br>
# 女：ペットのためにいろいろと気を使っているんですね。<br>
# 男：はい、健康管理も大事ですから。
# </div>
#
# <p class="follow-up">男の社員はこの後まず、何をしますか。</p>
# <div class="options">
#      1. 犬と散歩する<br>
#      2. ペットショップに行く<br>
#      3. 会社で仕事をする<br>
#      4. 猫の話をする
#   </p>
# </div>
# 正解: 3
# HUMAN: GOOD ENOUGH
# 2025-11-20 00:05:21,370 - INFO - jlpt - Formatter: {'background': 'オフィスで女の社員と男の社員が昼休みに話しています。男の社員はこの後まず、何をしますか。', 'follow_up': '男の社員はこの後まず、何をしますか。', 'conversation': [{'gender': 'female', 'context': '佐々木さん、最近犬を飼い始めたって聞きましたけど、どうですか？'}, {'gender': 'male', 'context': 'ええ、毎日がにぎやかになりました。朝も早く起こされるし、散歩も欠かせません。'}, {'gender': 'female', 'context': 'それは大変ですね。でも、癒されることも多いでしょう？'}, {'gender': 'male', 'context': 'もちろんです。仕事で疲れて帰っても、玄関で待っていてくれるので、すぐに元気になります。'}, {'gender': 'female', 'context': 'うらやましいです。私は猫派なんですけど、犬もいいなと思うことがあります。'}, {'gender': 'male', 'context': '猫も静かでいいですよね。ところで、昼休みが終わったら、ペットショップに注文していた餌を受け取りに行く予定なんです。'}, {'gender': 'female', 'context': 'そうなんですね。帰りに寄るんですか？'}, {'gender': 'male', 'context': 'ええ、会社から近いので、仕事が終わったらすぐに立ち寄るつもりです。'}, {'gender': 'female', 'context': 'ペットのためにいろいろと気を使っているんですね。'}, {'gender': 'male', 'context': 'はい、健康管理も大事ですから。'}], 'choices': ['犬と散歩する', 'ペットショップに行く', '会社で仕事をする', '猫の話をする'], 'correct_answer': 3}
# 2025-11-20 00:05:58,244 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-20 00:05:58,248 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1.wav
# 2025-11-20 00:05:58,250 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-20 00:05:58,251 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_background.wav
# 2025-11-20 00:05:58,256 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-20 00:05:58,259 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_follow_up.wav
# 2025-11-20 00:05:58,275 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\empty_1s.wav
# 2025-11-20 00:05:58,278 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_0_speaker.wav
# 2025-11-20 00:05:58,294 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_1_speaker.wav
# 2025-11-20 00:05:58,310 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_2_speaker.wav
# 2025-11-20 00:05:58,325 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_3_speaker.wav
# 2025-11-20 00:05:58,342 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_4_speaker.wav
# 2025-11-20 00:05:58,360 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_5_speaker.wav
# 2025-11-20 00:05:58,379 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_6_speaker.wav
# 2025-11-20 00:05:58,395 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_7_speaker.wav
# 2025-11-20 00:05:58,415 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_8_speaker.wav
# 2025-11-20 00:05:58,431 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_9_speaker.wav
# 2025-11-20 00:05:58,446 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\voice\ding.wav
# 2025-11-20 00:05:58,454 - INFO - jlpt - C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\tmp\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_follow_up.wav
# 2025-11-20 00:05:59,071 - INFO - jlpt - Conversation audio saved as C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_conversation_output.mp3
# 2025-11-20 00:06:03,043 - INFO - jlpt - ✅ Uploaded C:\Users\Administrator\PycharmProjects\pythonProject\jlpt\output\6581cbfb-c561-11f0-979d-d4d8537023c7\topic_understanding_txt_1_conversation_output.mp3 as blob 6581cbfb-c561-11f0-979d-d4d8537023c7/topic_understanding_txt_1_conversation_output.mp3
# <strong>1番.</strong></br></br><p><strong>Background: </strong>オフィスで女の社員と男の社員が昼休みに話しています。男の社員はこの後まず、何をしますか。</p>
# <div style="margin: 1em 0; padding: 1em; border: 1px solid #ccc;">
# <p><strong>Female:</strong> 佐々木さん、最近犬を飼い始めたって聞きましたけど、どうですか？</p>
# <p><strong>Male:</strong> ええ、毎日がにぎやかになりました。朝も早く起こされるし、散歩も欠かせません。</p>
# <p><strong>Female:</strong> それは大変ですね。でも、癒されることも多いでしょう？</p>
# <p><strong>Male:</strong> もちろんです。仕事で疲れて帰っても、玄関で待っていてくれるので、すぐに元気になります。</p>
# <p><strong>Female:</strong> うらやましいです。私は猫派なんですけど、犬もいいなと思うことがあります。</p>
# <p><strong>Male:</strong> 猫も静かでいいですよね。ところで、昼休みが終わったら、ペットショップに注文していた餌を受け取りに行く予定なんです。</p>
# <p><strong>Female:</strong> そうなんですね。帰りに寄るんですか？</p>
# <p><strong>Male:</strong> ええ、会社から近いので、仕事が終わったらすぐに立ち寄るつもりです。</p>
# <p><strong>Female:</strong> ペットのためにいろいろと気を使っているんですね。</p>
# <p><strong>Male:</strong> はい、健康管理も大事ですから。</p>
# </div>
# <p><strong>follow-up question: </strong>男の社員はこの後まず、何をしますか。</p>
# <audio controls style="margin-left:1em;">
#   <source src="https://strolandaws8409947751408.blob.core.windows.net/jlpt-voice-prod/6581cbfb-c561-11f0-979d-d4d8537023c7/topic_understanding_txt_1_conversation_output.mp3" type="audio/mpeg">
# Your browser does not support the audio element.
# </audio>
# <ul>
# <li>1. 犬と散歩する</li>
# <li>2. ペットショップに行く</li>
# <li>3. <b>会社で仕事をする</b> <span style='color:green;'>(correct)</span></li>
# <li>4. 猫の話をする</li>
# </ul>

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.active_expression((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))
