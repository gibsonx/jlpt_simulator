# %%
import os
from graphs.common.JLPTTaskFactory import JLPTTaskFactory
import random
from graphs.common.GraphBuilder import GraphBuilder
from IPython.display import display, Markdown, HTML
from libs.Utils import _render_result, _load_vocab_and_resources
import uuid

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
exam_uid = str(uuid.uuid1())
level = 'n1'
vocab, topics, grammar = _load_vocab_and_resources(level)

# %% [markdown]
# ## Section 1. vocabulary

# %% [markdown]
# ### 問題1 のことばの読み方として最もよいものを、1・2・3・4から一つえらびなさい (kanji_reading)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.kanji_reading(word=random.choice(vocab.split(",")),gan_history="text")
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-15 14:06:22,247 - INFO - jlpt - ---Generator----
# 2025-11-15 14:06:25,941 - INFO - jlpt - ---REVISOR---
# 2025-11-15 14:06:26,705 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-15 14:06:26,706 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-15 14:06:26,708 - INFO - jlpt - --- Formatter ---
# 2025-11-15 14:06:26,709 - INFO - jlpt - Final Conversation:
# SYSTEM:
# Role: You are a Japanese teacher writing a test paper for JLPT N1 level.
#
# Task: Your job is to write a pronunciation question corresponding to Japanes kanji for the JLPT N1 level exam paper.
#
# Step 1: Generate a short sentence within 30 words as the question stem. And select a Japanese kanji word to mark as a
# -A must contain at least one Japanese kanji, not every character is a hiragana
#
# Step 2: For word a, underline it.
# The selected words need to be marked with<u></u>, such as<u>主要</u>, and no other tags should appear in the sentence.
# Additional requirements:
# -Words in sentences should not be used in options
# -You must display the correct answer in the output with options 1, 2, 3, 4. For example: Correct solution: 1
#
# Step 3: Generate 4 options for this question. Require all of the following conditions:
# -These 4 options must be different from each other.
# -Only one option is the correct answer.
# -The generated options need to comply with Japanese pronunciation rules and should not generate non-existent pronunciations
# -Assuming that word a consists of 2-3 characters, set them in order as x[0],y[0],z[0] (if a variable is a Japanese kanji, do not display it as hiragana pronunciation). There are four options, including option 1: x[1],y[1],z[1]; Option 2: x[2],y[2],z[2]; Option 3: x[3],y[3],z[3]; Option 4: x[4],y[4],z[4]
# -If x[0] is Japanese hiragana, then: x[1]=x[2]=x[3]=x[4]=x[0]
# -If y[0] is Japanese hiragana, then: y[1]=y[2]=y[3]=y[4]=y[0]
# -If z[0] is Japanese hiragana, then: z[1]=z[2]=z[3]=z[4]=z[0]
# -Print a,x[0],y[0],z[0],x[1],y[1],z[1],x[2],y[2],z[2],x[3],y[3],z[3],x[4],y[4],z[4] in the debugging log; And print the judgment of whether x[0],y[0],z[0] are Japanese hiragana or not
#
# Step 4: output a question.
# Format: Follow the format of the 2 examples in the formal exam paper, not the content. The output must be in HTML format and the line change tag must be removed.
# Content: Ensure vocabulary is limited to N1 level.
# Reference: Get inspiration from the "Topic". Consider the feedback given in the previous conversation (if any)
# Additional requirement: Do not display problem descriptions and serial numbers in the generated content.
#
# Formal exam paper:
# --- example 1 ---
# <a>食品の<u>腐敗</u>を防止する。</a>
# <ul>
#     <li>ふはい</li>
#     <li>ふばい</li>
#     <li>ふうはい</li>
#     <li>ふうばい</li>
# </ul>
#
# --- example 2 ---
# <a>手紙の内容は、私を<u>戒める</u>ものだった。</a>
# <ul>
#     <li>とがめる</li>
#     <li>せめる</li>
#     <li>なぐさめる</li>
#     <li>いましめる</li>
# </ul>
#
#
# HUMAN: Generate a JLPT question regarding Topic: text
# AI: Debugging log:
# a=<u>添削</u>, x[0]=添, y[0]=削, z[0]=, x[1]=てん, y[1]=さく, z[1]=, x[2]=そ, y[2]=さく, z[2]=, x[3]=てん, y[3]=しゅう, z[3]=, x[4]=そ, y[4]=しゅう, z[4]=
# x[0] is not hiragana
# y[0] is not hiragana
# z[0] is empty
#
# Correct solution: 1
#
# HTML output:
# <a>先生が私の作文を<u>添削</u>してくださった。</a><ul><li>てんさく</li><li>そさく</li><li>てんしゅう</li><li>そしゅう</li></ul>
# HUMAN: GOOD ENOUGH
# 2025-11-15 14:06:27,601 - INFO - jlpt - Formatter: {'html_question': '先生が私の作文を<u>添削</u>してくださった。', 'correct_answer': 1, 'choices': ['てんさく', 'そさく', 'てんしゅう', 'そしゅう']}
# <strong>1番.</strong></br></br><p>先生が私の作文を<u>添削</u>してくださった。</p><ul>
# <li>1. <b>てんさく</b> <span style='color:green;'>(correct)</span></li>
# <li>2. そさく</li>
# <li>3. てんしゅう</li>
# <li>4. そしゅう</li>
# </ul>

# %% [markdown]
# ### 問題2 このことばを漢字で書くとき、最もよいものを、1・2・3・4から一つえらびなさい (write_kanji)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.write_kanji(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3（　）に入れるのに最もよいものを、1・2・3・4から一つえらびなさい。 (word_meaning)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_meaning(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題4 に意味が最も近いものを、1・2・3・4から一つえらびなさい。(synonym_substitution)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.synonym_substitution(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎのことばの使い方として最もよいものを、1・2・3・4から一つえらびなさい。 (word_usage)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.word_usage(random.choice(vocab.split(",")))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 2. Grammar

# %% [markdown]
# ### 問題1 つぎの文の（　　　）に入れるのに最もよいものを、１・２・３・４から一つえらびなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_grammar(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの文の ★ に入る最もよいものを、1・2・3・4から一つえらびなさい。(sentence_sort)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_sort(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、文章全体の内容を考えて、文中の 19 から 22 の中に入る最もよいものを、1・2・3・4から一つえらびなさい (sentence_structure)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.sentence_structure(random.choice(topics),random.choice(grammar))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 3: Reading Comprehension

# %% [markdown]
# ### 問題1-1 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_mail_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_mail_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-2 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_notification_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_notification_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題1-3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい (short_passage_narrative_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.short_passage_narrative_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題2 つぎの(1)と(2)の文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。 (midsize_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.midsize_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題3 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(understanding_read)

# %%
graph = GraphBuilder(exam_uid=exam_uid)
factory = JLPTTaskFactory(graph, level=level)
content = factory.understanding_read(random.choice(topics))
display(Markdown(_render_result(result=content)))
# Out:
# 2025-11-15 14:06:27,719 - INFO - jlpt - ---Generator----
# 2025-11-15 14:06:40,655 - INFO - jlpt - ---REVISOR---
# 2025-11-15 14:06:41,383 - INFO - jlpt - Reflect Feedback: GOOD ENOUGH
# 2025-11-15 14:06:41,385 - INFO - jlpt - --- AI Reviser feels Good Enough ---
# 2025-11-15 14:06:41,387 - INFO - jlpt - --- Formatter ---
# 2025-11-15 14:06:41,387 - INFO - jlpt - Final Conversation:
# SYSTEM:
# 角色：你是一名日语老师，正在为JLPT N1水平撰写试卷。
#
# 任务：任务：你的工作是为JLPT N1水平考试写一道阅读题。
# 首先，你需要写一篇大约800字的长篇文章供学生阅读。
# 然后，根据文章中的相关内容给出3个问题。
# 目的是确保学生能够理解文章的内容。
#
#
# 说明：
# 格式：遵循正式试卷中示例的格式，而不是内容。输出必须为html格式，并删除行更改标记。
# 内容：确保词汇量限制在N1级。
# 参考：从用户给出的“主题”中获得灵感。考虑前一次对话中给出的反馈（如果存在）
# 附加要求：
# -不要在生成的内容中显示问题说明和序列号。
# -文章中的单词既不能用于问题，也不能用于选项。
# -您必须在输出中显示正确答案，选项为1,2,3,4。例如：正解:1.
#
#
#
# 正式试卷：
# <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>数学の問題を解くことについて</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .page-number {
#             text-align: right;
#             font-weight: bold;
#             margin-top: 2em;
#             color: #666;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#         .underline {
#             text-decoration: underline;
#             text-underline-offset: 2px;
#         }
#         sup {
#             font-size: 0.8em;
#         }
#     </style>
# </head>
# <body>
#
# <p>以下は、ある数学者が描いた文章である。</p>
#
# <p>数学というものは、解き方がわかってしまったあとで、力がつくことはない。解き方を身につける前の、まだ解き方のわからない間だけが、力をつけるチャンスである。解けるようになるのは同じでも、それまでのあり方で、力が身につくかどうかが、きまってくる。</p>
#
# <p>それに、おもしろいのも、本当は、まだ解けないで、いろいろと考えている間である。解けなきゃつまらないようだが、それは早く解こうとあせるからで、楽しみは解けるまでのほうにある。解けるようになったあとは、むしろむなしい。だいたい、「答えのわかっている謎」なんて、意味がない。解き方がわからないからこそ、問題の名にあたいするのだ。</p>
#
# <p>もちろん、まったく手がつかないのでは、おもしろくもないが、案外に、多少はわからないでも、うまく<span class="underline">頭のなかに飼っておくと</span>、そのうちに馴れてくれて、わかってきたりする。その、だんだん少しずつ、わかりかけというのも、オツなものだ。そのためには、それを飼っておく、頭の牧場がゆたかでなければならない。本当のところは、数学の力というのは、いろいろとわかったことをためこむより、わからないのを飼っておける、その牧場のゆたかさのほうにあるのかもしれない。</p>
#
# <p>とくに、公式などをおぼえるのには、ぼくは反対である。それは簡単すぎて、少しもおもしろくないし、おぼえたものは忘れるものだ。とくに、急いでおぼえたものは、早く忘れる。同じおぼえるにしても、なるべくなら時間をかけたほうが、長持ちする。</p>
#
# <p class="note">（中略）</p>
#
# <p>このごろは、テストでおどされることが多いので、わかること、解けることを急ぐ傾向にある。たしかに、テストなどでは、時間がかぎられているので、急ぐのも多少は仕方がない。しかしながら、時間を制限されたときに急いでできるためには、時間の制限されていないときに、時間を気にしないでやっておいたほうがよい。テストで急ぐためには、テスト以外で急がないほうがよいのである。</p>
#
# <p>どんなやり方でも、わかって、問題が解けるようになる、という結果は同じかもしれない。しかし、ゆったりとやると、そのわかり方にコクが出てくるものだ。そして、その結果に達するまでの道筋を楽しむことで、力がつく。</p>
#
# <p>勉強を楽しむなんて、と思うかもしれないが、それは目的ばかり見てあせるからで、楽しむ気になれば、なんだって楽しめるものだ。</p>
#
# <p class="note">(注1)手がつかない：ここでは、できない</p>
# <p class="note">(注2)オツな：ここでは、おもしろい</p>
# <p class="note">(注3)おどされる：ここでは、早く問題を解かされる</p>
# <p class="note">(注4)コク：深み。</p>
#
# <div class="page-number">57</div>
#
# <p>数学の問題を解くことについて、筆者の考えに合うのはどれか。</p>
#
# <ol>
#     <li>早く解けなくても、解き方を身につけることが大切だ。</li>
#     <li>解けても解けなくても、問題に取り組むことが大切だ。</li>
#     <li>解けなかった問題が解けるようになったらおもしろくなる。</li>
#     <li>解き方のわからない問題を解こうとすることに意味がある。</li>
# </ol>
#
# <hr>
#
# <div class="page-number">58</div>
#
# <p><span class="underline">頭のなかに飼っておく</span>とはどういうことか。</p>
#
# <ol>
#     <li>わかる問題を手がかりにして、わからない問題を考えること</li>
#     <li>わかる問題とわからない問題を、頭のなかで区別しておくこと。</li>
#     <li>わからない問題をわかるまで解き続けていること</li>
#     <li>わからない状態のまま、問題を頭のなかに残しておくこと</li>
# </ol>
#
# <hr>
#
# <div class="page-number">59</div>
#
# <p>筆者によると、どのように勉強すればよいか。</p>
#
# <ol>
#     <li>結果を急がずに、考えることを楽しむ。</li>
#     <li>結果に達することができれば、どんなやり方でもよい。</li>
#     <li>目的を忘れないで、あせらずに勉強を楽しめばよい。</li>
#     <li>自分に合ったやり方を探して、時間を気にせず取り組む。</li>
# </ol>
#
# </body>
# </html>
#
#
# HUMAN: Generate a JLPT question regarding Topic: 家事の分担について話す
# AI: <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>家事の分担について話す</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             line-height: 1.8;
#             max-width: 800px;
#             margin: 40px auto;
#             padding: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         p {
#             margin-bottom: 1.5em;
#             text-align: justify;
#         }
#         .note {
#             font-size: 0.9em;
#             color: #555;
#             margin-left: 1em;
#         }
#         .page-number {
#             text-align: right;
#             font-weight: bold;
#             margin-top: 2em;
#             color: #666;
#         }
#         ol {
#             margin-top: 2em;
#         }
#         li {
#             margin-bottom: 0.8em;
#         }
#         hr {
#             border: none;
#             border-top: 1px dashed #ccc;
#             margin: 3em 0;
#         }
#         .underline {
#             text-decoration: underline;
#             text-underline-offset: 2px;
#         }
#         sup {
#             font-size: 0.8em;
#         }
#     </style>
# </head>
# <body>
#
# <p>以下は、ある社会学者が家事の分担について述べた文章である。</p>
#
# <p>現代社会において、家庭内の家事の分担は大きな課題となっている。かつては、家事は主に女性が担うものとされてきたが、近年では共働き家庭が増え、家事の役割分担について再考する必要性が高まっている。家事の分担が不公平である場合、家庭内のストレスや不満が生じやすく、夫婦間の関係にも影響を及ぼすことがある。</p>
#
# <p>家事の分担を円滑に進めるためには、まず家族全員が自分の役割について話し合うことが重要である。例えば、料理や掃除、洗濯などの具体的な作業をリストアップし、それぞれがどの作業を担当するかを決めることで、責任の所在が明確になる。また、家事の負担が一方に偏らないよう、定期的に分担の見直しを行うことも有効である。</p>
#
# <p>しかし、家事の分担を決める際には、単に作業量だけでなく、各自の生活リズムや体力、得意不得意も考慮する必要がある。例えば、朝早く出勤する人には夜の家事を多めに割り当てるなど、柔軟な対応が求められる。さらに、家事を「手伝う」という意識ではなく、「共同で担う」という姿勢が大切である。家事は家庭を維持するための基本的な活動であり、誰か一人に任せるべきものではない。</p>
#
# <p>家事の分担がうまくいくと、家族の協力や信頼が深まり、家庭内の雰囲気も良くなる。逆に、分担が不十分だと、無意識のうちに不満が蓄積し、コミュニケーションの障害となることもある。そのため、家事について定期的に意見を交換し、必要に応じて調整することが、円満な家庭生活のためには不可欠である。</p>
#
# <p>近年では、家事の分担をサポートするためのサービスや技術も発展している。例えば、家事代行サービスや便利な家電製品の利用によって、家事の負担を軽減することが可能となった。しかし、こうしたサービスを利用する場合でも、家族間で役割や責任について話し合うことが重要である。家事の分担は、単なる作業の割り当てではなく、家族の協力と理解を深めるための機会でもある。</p>
#
# <p class="note">(注1)家事代行サービス：家事を専門の業者が代わりに行うサービス</p>
# <p class="note">(注2)家電製品：家庭で使う電気製品</p>
#
# <div class="page-number">61</div>
#
# <p>筆者が家事の分担について最も強調していることは何か。</p>
# <ol>
#     <li>家事の作業量を均等にすることが重要である。</li>
#     <li>家族全員が協力し合う姿勢を持つことが大切である。</li>
#     <li>家事代行サービスを積極的に利用するべきである。</li>
#     <li>家事は女性が中心となって行うべきである。</li>
# </ol>
# 正解:2
#
# <hr>
#
# <div class="page-number">62</div>
#
# <p>家事の分担を決める際に考慮すべき点として、本文で述べられているものはどれか。</p>
# <ol>
#     <li>各自の生活リズムや得意なことを考える。</li>
#     <li>家事の分担を毎日変更する。</li>
#     <li>家事の分担を一度決めたら変えない。</li>
#     <li>家事の分担を家族以外の人に任せる。</li>
# </ol>
# 正解:1
#
# <hr>
#
# <div class="page-number">63</div>
#
# <p>家事の分担がうまくいかない場合、家庭内で起こりやすいことは何か。</p>
# <ol>
#     <li>家族の信頼が深まる。</li>
#     <li>不満が蓄積し、コミュニケーションに支障が出る。</li>
#     <li>家事の負担が減る。</li>
#     <li>家庭内の雰囲気が明るくなる。</li>
# </ol>
# 正解:2
#
# </body>
# </html>
# HUMAN: GOOD ENOUGH
# 2025-11-15 14:06:46,576 - INFO - jlpt - Formatter: {'html_article': '<p>以下は、ある社会学者が家事の分担について述べた文章である。</p><p>現代社会において、家庭内の家事の分担は大きな課題となっている。かつては、家事は主に女性が担うものとされてきたが、近年では共働き家庭が増え、家事の役割分担について再考する必要性が高まっている。家事の分担が不公平である場合、家庭内のストレスや不満が生じやすく、夫婦間の関係にも影響を及ぼすことがある。</p><p>家事の分担を円滑に進めるためには、まず家族全員が自分の役割について話し合うことが重要である。例えば、料理や掃除、洗濯などの具体的な作業をリストアップし、それぞれがどの作業を担当するかを決めることで、責任の所在が明確になる。また、家事の負担が一方に偏らないよう、定期的に分担の見直しを行うことも有効である。</p><p>しかし、家事の分担を決める際には、単に作業量だけでなく、各自の生活リズムや体力、得意不得意も考慮する必要がある。例えば、朝早く出勤する人には夜の家事を多めに割り当てるなど、柔軟な対応が求められる。さらに、家事を「手伝う」という意識ではなく、「共同で担う」という姿勢が大切である。家事は家庭を維持するための基本的な活動であり、誰か一人に任せるべきものではない。</p><p>家事の分担がうまくいくと、家族の協力や信頼が深まり、家庭内の雰囲気も良くなる。逆に、分担が不十分だと、無意識のうちに不満が蓄積し、コミュニケーションの障害となることもある。そのため、家事について定期的に意見を交換し、必要に応じて調整することが、円満な家庭生活のためには不可欠である。</p><p>近年では、家事の分担をサポートするためのサービスや技術も発展している。例えば、家事代行サービスや便利な家電製品の利用によって、家事の負担を軽減することが可能となった。しかし、こうしたサービスを利用する場合でも、家族間で役割や責任について話し合うことが重要である。家事の分担は、単なる作業の割り当てではなく、家族の協力と理解を深めるための機会でもある。</p><p class="note">(注1)家事代行サービス：家事を専門の業者が代わりに行うサービス</p><p class="note">(注2)家電製品：家庭で使う電気製品</p>', 'questions': [{'html_question': '筆者が家事の分担について最も強調していることは何か。', 'correct_answer': 2, 'choices': ['家事の作業量を均等にすることが重要である。', '家族全員が協力し合う姿勢を持つことが大切である。', '家事代行サービスを積極的に利用するべきである。', '家事は女性が中心となって行うべきである。']}, {'html_question': '家事の分担を決める際に考慮すべき点として、本文で述べられているものはどれか。', 'correct_answer': 1, 'choices': ['各自の生活リズムや得意なことを考える。', '家事の分担を毎日変更する。', '家事の分担を一度決めたら変えない。', '家事の分担を家族以外の人に任せる。']}, {'html_question': '家事の分担がうまくいかない場合、家庭内で起こりやすいことは何か。', 'correct_answer': 2, 'choices': ['家族の信頼が深まる。', '不満が蓄積し、コミュニケーションに支障が出る。', '家事の負担が減る。', '家庭内の雰囲気が明るくなる。']}]}
# <strong>1番.</strong></br></br><p>以下は、ある社会学者が家事の分担について述べた文章である。</p><p>現代社会において、家庭内の家事の分担は大きな課題となっている。かつては、家事は主に女性が担うものとされてきたが、近年では共働き家庭が増え、家事の役割分担について再考する必要性が高まっている。家事の分担が不公平である場合、家庭内のストレスや不満が生じやすく、夫婦間の関係にも影響を及ぼすことがある。</p><p>家事の分担を円滑に進めるためには、まず家族全員が自分の役割について話し合うことが重要である。例えば、料理や掃除、洗濯などの具体的な作業をリストアップし、それぞれがどの作業を担当するかを決めることで、責任の所在が明確になる。また、家事の負担が一方に偏らないよう、定期的に分担の見直しを行うことも有効である。</p><p>しかし、家事の分担を決める際には、単に作業量だけでなく、各自の生活リズムや体力、得意不得意も考慮する必要がある。例えば、朝早く出勤する人には夜の家事を多めに割り当てるなど、柔軟な対応が求められる。さらに、家事を「手伝う」という意識ではなく、「共同で担う」という姿勢が大切である。家事は家庭を維持するための基本的な活動であり、誰か一人に任せるべきものではない。</p><p>家事の分担がうまくいくと、家族の協力や信頼が深まり、家庭内の雰囲気も良くなる。逆に、分担が不十分だと、無意識のうちに不満が蓄積し、コミュニケーションの障害となることもある。そのため、家事について定期的に意見を交換し、必要に応じて調整することが、円満な家庭生活のためには不可欠である。</p><p>近年では、家事の分担をサポートするためのサービスや技術も発展している。例えば、家事代行サービスや便利な家電製品の利用によって、家事の負担を軽減することが可能となった。しかし、こうしたサービスを利用する場合でも、家族間で役割や責任について話し合うことが重要である。家事の分担は、単なる作業の割り当てではなく、家族の協力と理解を深めるための機会でもある。</p><p class="note">(注1)家事代行サービス：家事を専門の業者が代わりに行うサービス</p><p class="note">(注2)家電製品：家庭で使う電気製品</p>
# <p><strong>1.筆者が家事の分担について最も強調していることは何か。</strong></p>
# <ul>
# <li>家事の作業量を均等にすることが重要である。</li>
# <li><b>家族全員が協力し合う姿勢を持つことが大切である。</b> <span style='color:green;'>(correct)</span></li>
# <li>家事代行サービスを積極的に利用するべきである。</li>
# <li>家事は女性が中心となって行うべきである。</li>
# </ul>
# <p><strong>2.家事の分担を決める際に考慮すべき点として、本文で述べられているものはどれか。</strong></p>
# <ul>
# <li><b>各自の生活リズムや得意なことを考える。</b> <span style='color:green;'>(correct)</span></li>
# <li>家事の分担を毎日変更する。</li>
# <li>家事の分担を一度決めたら変えない。</li>
# <li>家事の分担を家族以外の人に任せる。</li>
# </ul>
# <p><strong>3.家事の分担がうまくいかない場合、家庭内で起こりやすいことは何か。</strong></p>
# <ul>
# <li>家族の信頼が深まる。</li>
# <li><b>不満が蓄積し、コミュニケーションに支障が出る。</b> <span style='color:green;'>(correct)</span></li>
# <li>家事の負担が減る。</li>
# <li>家庭内の雰囲気が明るくなる。</li>
# </ul>

# %% [markdown]
# ### 問題4 次の文章は、「相談者」からの相談と、それに対するAとBからの回答である。三つの文章を読んで、後の問いに対する答えとして、最もよいものを1·2·3·4から-つ選びなさい。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.comprehensive_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題5 つぎの文章を読んで、質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい。(long_passage_read)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.long_passage_read(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ### 問題6 これを読んで、下の質問に答えなさい。答えは、1・2・3・4から最もよいものを一つえらびなさい Information retrieval (info_retrieval)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.info_retrieval(random.choice(topics))
# display(Markdown(_render_result(result=content)))

# %% [markdown]
# ## Section 4. Listening Comprehension

# %% [markdown]
# ### 問題1 では、まず質問を聞いてください。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。 (topic_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.topic_understanding_txt(random.choice(topics),seq=1)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題2 では、まず質問を聞いてください。そのあと、問題用紙を見てください。読む時間があります。それから話を聞いて、問題用紙の1から4の中から、最もよいものを一つえらんでください。
#  (keypoint_understanding)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.keypoint_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題3では、問題用紙（もんだいようし）に何（なに）も いんさつされていません。この問題（もんだい）は、ぜんたいとして どんな ないようかを聞（き）く 問題（もんだい）です。話（はなし）の前（まえ）に 質問（しつもん）は ありません。まず 話（はなし）を 聞（き）いてください。それから、質問（しつもん）と せんたくし を聞（き）いて、1から4の中（なか）から、最（もっと）も よい ものを 一（ひと）つ えらんでください。

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.summary_understanding(random.choice(topics),seq=2)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題4 では、元を見ながら質問を聞いてください。やじるし（➔）の人は何と言いますか。1 から 3 の中から、最もよいものを一つえらんでください。 (active_expression)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.active_expression((random.choice(topics)),seq=3)
# display(HTML(_render_result(result=content)))

# %% [markdown]
# ### 問題5 では、問題用紙に何もいんさつしていません。まず文を聞いてください。それから、そのへんしを聞いて、1 から 3 の中から、最もよいものを一つえらんでください。 (immediate_ack)

# %%
# graph = GraphBuilder(exam_uid=exam_uid)
# factory = JLPTTaskFactory(graph, level=level)
# content = factory.immediate_ack((random.choice(topics)),seq=4)
# display(HTML(_render_result(result=content)))
